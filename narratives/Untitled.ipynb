# %%
import pandas as pd

# %%
dataset = "cv"
query = pd.read_csv("../data/" + dataset + '.csv')

if dataset == 'cuba' or dataset == 'cuba_small' or dataset == 'cuba_160': # This is date time.
    query['date'] = pd.to_datetime(query['date'], infer_datetime_format=True) #8/22/2019 12:15
else:
    query['date'] = pd.to_datetime(query['date'], infer_datetime_format=True)

# %%
query
# Out:
#     id                                              title  \
# 0    0  China pneumonia outbreak: Mystery virus probed...
# 1    1  China pneumonia: Sars ruled out as dozens fall...
# 2    2  China mystery illness: travellers checked as o...
# 3    3  China reports first death from mysterious outb...
# 4    4  Japan confirms first case of coronavirus infec...
# 5    5  Coronavirus: more cases and second death repor...
# 6    6  CDC to screen at three US airports for signs o...
# 7    7   Vaccine for new Chinese coronavirus in the works
# 8    8  China confirms human-to-human transmission of ...
# 9    9  New China virus: Cases triple as infection spr...
# 10  10  Coronavirus: health officials announce first k...
# 11  11  The Test a Deadly Coronavirus Outbreak Poses t...
# 12  12  New China virus: Warning against cover-up as n...
# 13  13  Coronavirus: China advises against travel to W...
# 14  14  Life inside ground zero of Wuhan coronavirus o...
# ...
