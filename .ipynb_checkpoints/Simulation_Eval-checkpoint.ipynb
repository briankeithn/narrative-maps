# %% [markdown]
# # Semantic Interactions Simulation Evaluation

# %% [markdown]
# ## Imports and Reading Data

# %%
import sys
import os
cwd = os.getcwd()
print(cwd)
nwd = os.path.join(cwd, "narratives")
sys.path.insert(0, nwd)
# Out:
# C:\narrative-maps

# %%
import pandas as pd
import numpy as np
import re
import networkx as nx
import itertools  
from math import log, exp, sqrt
import matplotlib.pyplot as plt
from ast import literal_eval
import json

# LP
from packages.resolveLP import solve_LP_from_query, compute_sim
from packages.graph_utils import *
from packages.globals import *

# %%
base_total_samples = 10

# %% [markdown]
# ## Reading Data

# %%
def clean_publication(graph_df):
    publication_dict = {'www.bbc.com': 'bbc',
                    'www.aljazeera.com': 'ajz',
                    'www.nytimes.com': 'nyt',
                    'www.theguardian.com': 'tgn',
                    'edition.cnn.com': 'cnn',
                    'www.cnn.com': 'cnn',
                    'Reuters': 'reu',
                    'www.reuters.com': 'reu',
                    'Business Insider': 'bin',
                    'CNN': 'cnn',
                    'The Hill': 'hill',
                    'The New York Times': 'nyt',
                    'CNBC': 'cnbc',
                    'Breitbart': 'brb',
                    'www.breitbart.com': 'brb',
                    'Fox News': 'fox',
                    'www.foxnews.com': 'fox',
                    'CIA': 'cia',
                    'FBI': 'fbi',
                    'Army CID': 'cid',
                    'INS': 'ins',
                    'Sanctioned Intercepts': 'sai',
                    'NSA': 'nsa',
                    'abcnews.go.com': 'abc',
                    'apnews.com': 'apn',
                    'www.firstpost.com': 'fpost',
                    'theconversation.com': 'tcon',
                    'nypost.com': 'nyp',
                    'newscomworld.com': 'nwc',
                    'havanatimes.org': 'hvt',
                    'www.nbcnews.com': 'nbc',
                    'www.local10.com': 'l10',
                    'www.trtworld.com': 'trt',
                    'www.washingtonpost.com': 'wapo',
                    'www.xinhuanet.com': 'xinhua'
                    }
    graph_df['publication'] = graph_df['publication'].map(publication_dict).fillna('default')
    return graph_df

# %%
def read_query(dataset, start_date=None, end_date=None, partial=False):
    data_dir = os.path.join(cwd, "data")
    data_file = str(dataset) + '.csv'
    data_file_path = os.path.join(data_dir, data_file)
    if partial:
        columns_to_skip = 'embed'
        query = pd.read_csv(data_file_path, usecols=lambda x: x not in columns_to_skip)
    else:
        query = pd.read_csv(data_file_path)
    query = clean_publication(query)

    # Inferring datatime format (this might bring issues depending on the data!)
    query['date'] = pd.to_datetime(query['date'], infer_datetime_format=True) #8/22/2019 12:15

    if start_date is not None:
        query = query[(query['date'] >= pd.to_datetime(start_date, format='%Y-%m-%d'))]

    if end_date is not None:
        query = query[(query['date'] <= pd.to_datetime(end_date, format='%Y-%m-%d'))]

    if not partial:
        embed_list = ['embed']
        query[embed_list] = query[embed_list].replace(r'( )+', ',', regex=True)
        query[embed_list] = query[embed_list].replace('\[,', '[', regex=True)
        query[embed_list] = query[embed_list].replace(',]', ']', regex=True)
        query[embed_list] = query[embed_list].applymap(literal_eval).applymap(np.array)

        if 'cluster_vec' in query.columns: # Predefined clusters!
            query[['cluster_vec']] = query[['cluster_vec']].applymap(literal_eval).applymap(np.array)

    query.reset_index(inplace=True)
    query['id'] = [str(i) for i in list(query.index)]

    return query

# %%
dataset = "cuba_160"
query = read_query(dataset)
sim_table = compute_sim(query)

# %%
aux = query[(query.title.str.contains(r'(?:\s|\b)[Uu](?:\.)?[sS](?:\.)?[Aa]?(?:\.)?(?:\s|\b)', regex=True) |
                                 query.title.str.contains('united states', case=False)) & 
                                 ~(query.title.str.contains('miami', case=False) 
                                   | query.title.str.contains('florida', case=False))]
print(len(aux.index))
# Out:
# 30

# %% [markdown]
# ## Map Generation

# %%
def generate_map(query, dataset, previous_actions=[], k_input=8, mincover_input=20, window=30, start_nodes=[], 
                 verbose=True, random_state=42, force_cluster=False, use_temporal=False, use_entities=False):
    operation_list = []
    for item in previous_actions:
        if item.get("action") == "add-node":
            for node in item['content']:
                operation_list.append("AN:" + node)
        elif item.get("action") == "add-edge":
             operation_list.append("AE:" + item["content"])
        elif item.get("action") == "remove-node":
            for node in item['content']:
                operation_list.append("RN:" + node)
        elif item.get("action") == "remove-edge":
            for edge in item['content']:
                operation_list.append("RE:" + edge)
        elif item.get("action") == "add-cluster-list":
             operation_list.append("ACL:" + str(item['content'][0]) + "-" + str(item['content'][1]))
    
    # Solve LP and create new graph_df.
    cluster_size_est = np.sqrt(len(query.index))/2
    cluster_size_est = 5 * round(cluster_size_est / 5) # Round to nearest multiple of 5
    n_neighbors = 2
    if len(query.index) > 40:
        n_neighbors = 10
    elif len(query.index) > 120:
        n_neighbors = cluster_size_est

    graph_df_new, status, scatter_df, sim_table, clust_sim_table, ent_table, ent_doc_list, cluster_assignment = solve_LP_from_query(query, 
        dataset=dataset, operations=operation_list, 
        K=k_input, mincover=mincover_input/100, 
        min_samples=2, min_cluster_size=cluster_size_est, n_neighbors=n_neighbors, min_dist=1/100,
        start_nodes=start_nodes, verbose=verbose, random_state=random_state, force_cluster=force_cluster,
        use_temporal=use_temporal, use_entities=use_entities)
    status_msg = "LP Status: " + status[1] + ", Clusters: " + str(status[0])

    if 'Optimal' in status[1]:
        # Generate graph from LP solution.
        G = build_graph(graph_df_new)
        storylines = graph_stories(G, start_nodes=start_nodes, end_nodes=[])
        status_msg += ", Storylines: " + str(len(storylines))

        # We now apply transitive reduction.
        remove_list_transitive = []
        for story in storylines:
            max_idx = len(story) - 1
            for idx, node in enumerate(story):
                out_edges = G.out_edges(node)
                # If it's not the last element in the story (no need to clean the last one, because there are no in-story outgoing edges)
                if idx != max_idx:
                    for edge in out_edges:
                        if edge[1] in story and edge[1] != story[idx + 1]: # If it's an in-story edge and not the immediately adjacent one.
                            remove_list_transitive.append(edge)
        G.remove_edges_from(remove_list_transitive)
        # We now filter redundant interstory connections.
        remove_list_interstory = []
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            keep_set = set()
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            if len(edge_boundary_list_i) > 0:
                earliest_i = min(edge_boundary_list_i, key = lambda t: (t[0], t[1]))
                latest_i = max(edge_boundary_list_i, key = lambda t: (t[0], t[1]))
            else:
                earliest_i = None
            if len(edge_boundary_list_j) > 0:
                earliest_j = min(edge_boundary_list_j, key = lambda t: (t[1], t[0]))
                latest_j = max(edge_boundary_list_j, key = lambda t: (t[1], t[0]))
            else:
                earliest_j = None
            if not earliest_i and not earliest_j:
                # No connections
                continue
            elif earliest_i and not earliest_j:
                # One-sided.
                if earliest_i == latest_i: # There's only one connection, keep it.
                    continue
                elif earliest_i[0] == latest_i[0]:
                    # This means that the second values are different, but the first one is the same.
                    # For this special case we keep the earliest one.
                    keep_set.add(earliest_i)
                else:
                    # Keep both
                    keep_set.add(earliest_i)
                    keep_set.add(latest_i)
            elif not earliest_i and earliest_j:
                # One-sided and reversed.
                if earliest_j == latest_j: # There's only one connection, keep it.
                    continue
                elif earliest_j[1] == latest_j[1]:
                    # This means that the first values are different, but the second one is the same.
                    # For this special case we keep the earliest one.
                    keep_set.add(earliest_j)
                else:
                    # Keep both
                    keep_set.add(earliest_j)
                    keep_set.add(latest_j)
            else:
                # Two-sided.
                if earliest_i[0] < earliest_j[1]:
                    # E_i happened first. Keep it
                    keep_set.add(earliest_i)
                    if latest_i[0] > latest_j[1]:
                        # L_i happened last. Keep it.
                        keep_set.add(latest_i)
                    else:
                        keep_set.add(latest_j)
                else:
                    # E_j happened first.
                    keep_set.add(earliest_j)
                    if latest_i[0] > latest_j[1]:
                        # E_i happened last. Keep it.
                        keep_set.add(latest_i)
                    else:
                        keep_set.add(latest_j)
            redundant_edge_set = set(edge_boundary_list_i) | set(edge_boundary_list_j)
            remove_list_interstory += list(redundant_edge_set - keep_set)

        G.remove_edges_from(remove_list_interstory)

        for node in G.nodes:
            sum_node = sum([exp(-data['weight']) for u, v, data in G.out_edges(node, data=True)])
            if sum_node == 0:
                continue
            for u, v, data in G.out_edges(node, data=True):
                G[u][v]['weight'] = -log(exp(-data['weight']) / sum_node)
            sum_node = sum([exp(-G[u][v]['weight']) for u, v, data in G.out_edges(node, data=True)])
        # Update graph_df
        for i, row in graph_df_new.iterrows():
            new_adj_list = [v for u, v in G.out_edges(str(row['id']))]
            new_adj_weights = [exp(-G[u][v]['weight']) for u, v in G.out_edges(str(row['id']))]
            graph_df_new.at[i,'adj_list'] = new_adj_list
            graph_df_new.at[i,'adj_weights'] = new_adj_weights

        for node in G.nodes:  
            sum_node = sum([exp(-data['weight']) for u, v, data in G.out_edges(node, data=True)])
            if sum_node == 0:
                continue
            for u, v, data in G.out_edges(node, data=True):
                G[u][v]['weight'] = -log(exp(-data['weight']) / sum_node)
            sum_node = sum([exp(-data['weight']) for u, v, data in G.out_edges(node, data=True)])

        # Update graph_df
        for i, row in graph_df_new.iterrows():
            new_adj_list = [v for u, v in G.out_edges(str(row['id']))]
            new_adj_weights = [exp(-G[u][v]['weight']) for u, v in G.out_edges(str(row['id']))]
            graph_df_new.at[i,'adj_list'] = new_adj_list
            graph_df_new.at[i,'adj_weights'] = new_adj_weights
            
        #print(graph_df_new)
        return G, graph_df_new, storylines

# %% [markdown]
# ## Plots

# %%
def plot_complexity_metric(all_iterations, all_complexities, column):
    max_val_list = []
    for idx, complexity in enumerate(all_complexities):
        max_val_list.append(max(complexity[column]))
    max_val = max(max_val_list) 
    fig, ax = plt.subplots(ncols=2, figsize=(10,4))
    ax[0].title.set_text('All runs')
    ax[0].set_xlabel('# of Iterations')
    ax[0].set_ylabel(column)
    ax[0].set_ylim(0, max_val)
    ax[1].title.set_text('Average')
    ax[1].set_xlabel('# of Iterations')
    ax[1].set_ylabel(column)
    ax[1].set_ylim(0, max_val)
    # All elements    
    for idx, complexity in enumerate(all_complexities):
        ax[0].plot(list(range(len(complexity[column]))), complexity[column], '-r')
    # Average
    max_iter = max(all_iterations)
    extended_metric_list = []
    for idx, complexity in enumerate(all_complexities):
        metric_list_extended = list(complexity[column]) + [list(complexity[column])[-1] for _ in range(max_iter - len(complexity[column]))]
        extended_metric_list.append(metric_list_extended)
    extended_metric_array = np.array(extended_metric_list)
    average_metric = np.nanmean(extended_metric_array, axis=0)
    ax[1].plot(list(range(max_iter)), average_metric, '-r')
    
def plot_error_rate(all_iterations, all_percents):
    max_val_list = []
    for idx, percent_list in enumerate(all_percents):
        max_val_list.append(max(percent_list))
    max_val = max(max_val_list) 
    fig, ax = plt.subplots(ncols=2, figsize=(10,4))
    ax[0].title.set_text('All runs')
    ax[0].set_xlabel('# of Iterations')
    ax[0].set_ylabel('Error Rate')
    ax[0].set_ylim(0, max_val)
    ax[1].title.set_text('Average')
    ax[1].set_xlabel('# of Iterations')
    ax[1].set_ylabel('Error Rate')
    ax[1].set_ylim(0, max_val)
    # All elements
    for idx, percent_list in enumerate(all_percents):
        ax[0].plot(list(range(all_iterations[idx])), percent_list, '-r')
    # Average
    max_iter = max(all_iterations)
    extended_percent_list = []
    for percent_list in all_percents:
        percent_list_extended = percent_list + [percent_list[-1] for _ in range(max_iter - len(percent_list))]
        extended_percent_list.append(percent_list_extended)
    extended_percent_array = np.array(extended_percent_list)
    average_percent = np.nanmean(extended_percent_array, axis=0)
    ax[1].plot(list(range(max_iter)), average_percent, '-r')

# %%
def plot_all(all_iterations, all_percents, all_complexities):
    plot_error_rate(all_iterations, all_percents)
    plot_complexity_metric(all_iterations, all_complexities, column='Nodes')
    plot_complexity_metric(all_iterations, all_complexities, column='Edges')
    plot_complexity_metric(all_iterations, all_complexities, column='Stories')
    plot_complexity_metric(all_iterations, all_complexities, column='Regular Stories')
    plot_complexity_metric(all_iterations, all_complexities, column='Singleton Stories')
    plot_complexity_metric(all_iterations, all_complexities, column='Interstory Connections')

# %% [markdown]
# ## Operation Templates

# %%
add_node = {"action": "add-node", "content": ["node_id"]} # String list of node ids
add_edge = {"action": "add-edge", "content": "edge_id"} # String of edge id
rem_node = {"action": "remove-node", "content": ["node_id"]} # String list of node ids
rem_edge = {"action": "remove-edge", "content": ["edge_id"]} # String list of edge id
cluster_list = {"action": "add-node", "content": "[node_id]-cid"} # String with the format [cluster_node_ids]-cluster_id.

# %% [markdown]
# ## Remove Nodes
# ### Removing Nodes from Map (Right-leaning articles only)
# Goal: Remove right-biased news articles from the map. We fix a center starting point from Reuters: "Cuba sees biggest protests for decades as pandemic adds to woes" (Node ID: 124)

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state)
        filter_nodes = graph_df[graph_df.bias == 'Right']
        percent_filter_nodes = len(filter_nodes.index) / len(graph_df.index)
        remove_node_list = [str(node) for node in filter_nodes.id.tolist()]
        remove_node = {"action": "remove-node", "content": remove_node_list}
        previous_actions.append(remove_node)
        percent_list.append(percent_filter_nodes)
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list

    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.5294117647058824 {'action': 'remove-node', 'content': ['17', '36', '40', '51', '52', '58', '127', '132', '146']}
# Complexity: [17, 20, 5, 3, 2, 8]
# Step: 2 0.21052631578947367 {'action': 'remove-node', 'content': ['22', '35', '49', '76']}
# Complexity: [19, 21, 6, 2, 4, 8]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 24, 8, 4, 4, 13]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.3888888888888889 {'action': 'remove-node', 'content': ['22', '53', '71', '89', '108', '127', '146']}
# Complexity: [18, 21, 6, 2, 4, 9]
# Step: 2 0.07142857142857142 {'action': 'remove-node', 'content': ['72']}
# Complexity: [14, 18, 6, 1, 5, 10]
# Step: 3 0.07142857142857142 {'action': 'remove-node', 'content': ['47']}
# Complexity: [14, 19, 5, 3, 2, 10]
# Step: 4 0.07142857142857142 {'action': 'remove-node', 'content': ['45']}
# Complexity: [14, 20, 7, 2, 5, 13]
# Step: 5 0.06666666666666667 {'action': 'remove-node', 'content': ['23']}
# Complexity: [15, 19, 7, 3, 4, 11]
# Step: 6 0.07142857142857142 {'action': 'remove-node', 'content': ['17']}
# Complexity: [14, 18, 6, 1, 5, 10]
# Step: 7 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [13, 16, 5, 2, 3, 8]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.35294117647058826 {'action': 'remove-node', 'content': ['36', '49', '51', '66', '132', '146']}
# Complexity: [17, 17, 4, 3, 1, 4]
# Step: 2 0.2 {'action': 'remove-node', 'content': ['45', '53', '96', '127']}
# Complexity: [20, 23, 8, 4, 4, 11]
# Step: 3 0.15 {'action': 'remove-node', 'content': ['23', '35', '52']}
# Complexity: [20, 23, 7, 4, 3, 10]
# Step: 4 0.2222222222222222 {'action': 'remove-node', 'content': ['58', '72', '76', '136']}
# Complexity: [18, 19, 5, 3, 2, 6]
# Step: 5 0.17391304347826086 {'action': 'remove-node', 'content': ['17', '93', '103', '108']}
# Complexity: [23, 26, 6, 4, 2, 9]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [21, 24, 8, 5, 3, 11]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.42105263157894735 {'action': 'remove-node', 'content': ['17', '18', '36', '52', '54', '58', '72', '134']}
# Complexity: [19, 22, 8, 2, 6, 11]
# Step: 2 0.22727272727272727 {'action': 'remove-node', 'content': ['16', '69', '89', '136', '150']}
# Complexity: [22, 27, 8, 5, 3, 13]
# Step: 3 0.05555555555555555 {'action': 'remove-node', 'content': ['45']}
# Complexity: [18, 21, 6, 4, 2, 9]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 22, 8, 3, 5, 11]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.21052631578947367 {'action': 'remove-node', 'content': ['35', '53', '112', '127']}
# Complexity: [19, 25, 10, 3, 7, 16]
# Step: 2 0.3 {'action': 'remove-node', 'content': ['73', '76', '84', '129', '131', '150']}
# Complexity: [20, 22, 6, 5, 1, 8]
# Step: 3 0.2777777777777778 {'action': 'remove-node', 'content': ['18', '47', '69', '93', '104']}
# Complexity: [18, 21, 7, 4, 3, 10]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [17, 20, 7, 4, 3, 10]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.47058823529411764 {'action': 'remove-node', 'content': ['17', '35', '36', '53', '54', '66', '108', '127']}
# Complexity: [17, 21, 6, 3, 3, 10]
# Step: 2 0.1875 {'action': 'remove-node', 'content': ['19', '47', '146']}
# Complexity: [16, 17, 4, 3, 1, 5]
# Step: 3 0.10526315789473684 {'action': 'remove-node', 'content': ['89', '129']}
# Complexity: [19, 19, 6, 4, 2, 6]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 21, 7, 3, 4, 10]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.3684210526315789 {'action': 'remove-node', 'content': ['17', '35', '36', '45', '103', '127', '146']}
# Complexity: [19, 23, 7, 4, 3, 11]
# Step: 2 0.16666666666666666 {'action': 'remove-node', 'content': ['47', '51', '134']}
# Complexity: [18, 21, 6, 4, 2, 9]
# Step: 3 0.058823529411764705 {'action': 'remove-node', 'content': ['53']}
# Complexity: [17, 20, 6, 3, 3, 9]
# Step: 4 0.05555555555555555 {'action': 'remove-node', 'content': ['96']}
# Complexity: [18, 23, 6, 4, 2, 11]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [21, 24, 7, 5, 2, 10]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.42857142857142855 {'action': 'remove-node', 'content': ['17', '18', '19', '36', '54', '73', '127', '132', '146']}
# Complexity: [21, 26, 7, 4, 3, 12]
# Step: 2 0.15 {'action': 'remove-node', 'content': ['51', '59', '84']}
# Complexity: [20, 24, 6, 6, 0, 10]
# Step: 3 0.058823529411764705 {'action': 'remove-node', 'content': ['104']}
# Complexity: [17, 18, 5, 4, 1, 6]
# Step: 4 0.125 {'action': 'remove-node', 'content': ['49', '53', '150']}
# Complexity: [24, 28, 7, 4, 3, 11]
# Step: 5 0.045454545454545456 {'action': 'remove-node', 'content': ['96']}
# Complexity: [22, 26, 6, 4, 2, 10]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 22, 6, 4, 2, 9]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.35294117647058826 {'action': 'remove-node', 'content': ['16', '21', '84', '127', '134', '146']}
# Complexity: [17, 22, 7, 2, 5, 12]
# Step: 2 0.23529411764705882 {'action': 'remove-node', 'content': ['17', '31', '35', '45']}
# Complexity: [17, 21, 6, 3, 3, 10]
# Step: 3 0.125 {'action': 'remove-node', 'content': ['49', '58']}
# Complexity: [16, 18, 4, 3, 1, 6]
# Step: 4 0.05555555555555555 {'action': 'remove-node', 'content': ['103']}
# Complexity: [18, 21, 6, 3, 3, 9]
# Step: 5 0.05555555555555555 {'action': 'remove-node', 'content': ['54']}
# Complexity: [18, 20, 7, 3, 4, 9]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [16, 19, 7, 3, 4, 10]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.3684210526315789 {'action': 'remove-node', 'content': ['45', '53', '64', '93', '103', '108', '134']}
# Complexity: [19, 22, 6, 2, 4, 9]
# Step: 2 0.15 {'action': 'remove-node', 'content': ['22', '36', '112']}
# Complexity: [20, 24, 6, 3, 3, 10]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [15, 20, 6, 3, 3, 11]

# %%
results_delete_right = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_delete_right.json', 'w') as fp:
    json.dump(results_delete_right, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Fox and Breitbart only

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state)
        filter_nodes = graph_df[graph_df['url'].str.contains('foxnews') | graph_df['url'].str.contains('breitbart')]
        percent_filter_nodes = len(filter_nodes.index) / len(graph_df.index)
        remove_node_list = [str(node) for node in filter_nodes.id.tolist()]
        remove_node = {"action": "remove-node", "content": remove_node_list}
        previous_actions.append(remove_node)
        percent_list.append(percent_filter_nodes)
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.4117647058823529 {'action': 'remove-node', 'content': ['36', '40', '51', '52', '58', '127', '132']}
# Complexity: [17, 20, 5, 3, 2, 8]
# Step: 2 0.125 {'action': 'remove-node', 'content': ['35', '49']}
# Complexity: [16, 17, 4, 2, 2, 5]
# Step: 3 0.08695652173913043 {'action': 'remove-node', 'content': ['136', '150']}
# Complexity: [23, 29, 7, 5, 2, 13]
# Step: 4 0.08333333333333333 {'action': 'remove-node', 'content': ['112', '129']}
# Complexity: [24, 28, 9, 4, 5, 13]
# Step: 5 0.1 {'action': 'remove-node', 'content': ['54', '72']}
# Complexity: [20, 24, 7, 4, 3, 11]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 20, 6, 4, 2, 8]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.16666666666666666 {'action': 'remove-node', 'content': ['71', '108', '127']}
# Complexity: [18, 21, 6, 2, 4, 9]
# Step: 2 0.0625 {'action': 'remove-node', 'content': ['72']}
# Complexity: [16, 19, 7, 3, 4, 10]
# Step: 3 0.058823529411764705 {'action': 'remove-node', 'content': ['23']}
# Complexity: [17, 20, 7, 3, 4, 10]
# Step: 4 0.15 {'action': 'remove-node', 'content': ['45', '47', '132']}
# Complexity: [20, 23, 8, 3, 5, 11]
# Step: 5 0.0625 {'action': 'remove-node', 'content': ['59']}
# Complexity: [16, 21, 8, 2, 6, 13]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [16, 19, 7, 3, 4, 10]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.29411764705882354 {'action': 'remove-node', 'content': ['36', '49', '51', '66', '132']}
# Complexity: [17, 17, 4, 3, 1, 4]
# Step: 2 0.17647058823529413 {'action': 'remove-node', 'content': ['45', '52', '127']}
# Complexity: [17, 20, 6, 3, 3, 9]
# Step: 3 0.1 {'action': 'remove-node', 'content': ['35', '58']}
# Complexity: [20, 23, 8, 5, 3, 11]
# Step: 4 0.08695652173913043 {'action': 'remove-node', 'content': ['28', '136']}
# Complexity: [23, 29, 9, 4, 5, 15]
# Step: 5 0.05555555555555555 {'action': 'remove-node', 'content': ['103']}
# Complexity: [18, 22, 7, 3, 4, 11]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [17, 19, 6, 3, 3, 8]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.3157894736842105 {'action': 'remove-node', 'content': ['18', '36', '52', '54', '58', '72']}
# Complexity: [19, 22, 8, 2, 6, 11]
# Step: 2 0.20833333333333334 {'action': 'remove-node', 'content': ['69', '84', '129', '132', '136']}
# Complexity: [24, 27, 7, 5, 2, 10]
# Step: 3 0.045454545454545456 {'action': 'remove-node', 'content': ['45']}
# Complexity: [22, 25, 7, 5, 2, 10]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 22, 7, 4, 3, 10]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.15789473684210525 {'action': 'remove-node', 'content': ['35', '112', '127']}
# Complexity: [19, 25, 10, 3, 7, 16]
# Step: 2 0.05555555555555555 {'action': 'remove-node', 'content': ['58']}
# Complexity: [18, 22, 9, 3, 6, 13]
# Step: 3 0.17647058823529413 {'action': 'remove-node', 'content': ['64', '69', '84']}
# Complexity: [17, 20, 7, 3, 4, 10]
# Step: 4 0.11764705882352941 {'action': 'remove-node', 'content': ['56', '150']}
# Complexity: [17, 21, 9, 3, 6, 13]
# Step: 5 0.2222222222222222 {'action': 'remove-node', 'content': ['18', '47', '93', '129']}
# Complexity: [18, 24, 10, 2, 8, 16]
# Step: 6 0.11764705882352941 {'action': 'remove-node', 'content': ['54', '132']}
# Complexity: [17, 22, 9, 1, 8, 14]
# Step: 7 0.05263157894736842 {'action': 'remove-node', 'content': ['71']}
# Complexity: [19, 23, 10, 4, 6, 14]
# Step: 8 0.1111111111111111 {'action': 'remove-node', 'content': ['45', '72']}
# Complexity: [18, 22, 10, 3, 7, 14]
# Step: 9 0.058823529411764705 {'action': 'remove-node', 'content': ['59']}
# Complexity: [17, 23, 10, 1, 9, 16]
# Step: 10 0.10526315789473684 {'action': 'remove-node', 'content': ['66', '103']}
# Complexity: [19, 22, 9, 3, 6, 12]
# Step: 11 0.05263157894736842 {'action': 'remove-node', 'content': ['28']}
# Complexity: [19, 23, 10, 4, 6, 14]
# Step: 12 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [17, 20, 8, 2, 6, 11]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.35294117647058826 {'action': 'remove-node', 'content': ['35', '36', '54', '66', '108', '127']}
# Complexity: [17, 21, 6, 3, 3, 10]
# Step: 2 0.1111111111111111 {'action': 'remove-node', 'content': ['19', '47']}
# Complexity: [18, 19, 5, 3, 2, 6]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [16, 18, 5, 3, 2, 7]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.2631578947368421 {'action': 'remove-node', 'content': ['35', '36', '45', '103', '127']}
# Complexity: [19, 23, 7, 4, 3, 11]
# Step: 2 0.045454545454545456 {'action': 'remove-node', 'content': ['47']}
# Complexity: [22, 25, 6, 4, 2, 9]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 22, 6, 4, 2, 10]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.2857142857142857 {'action': 'remove-node', 'content': ['18', '19', '36', '54', '127', '132']}
# Complexity: [21, 26, 7, 4, 3, 12]
# Step: 2 0.10526315789473684 {'action': 'remove-node', 'content': ['35', '84']}
# Complexity: [19, 23, 7, 5, 2, 11]
# Step: 3 0.17391304347826086 {'action': 'remove-node', 'content': ['49', '59', '66', '104']}
# Complexity: [23, 28, 10, 6, 4, 15]
# Step: 4 0.05263157894736842 {'action': 'remove-node', 'content': ['58']}
# Complexity: [19, 23, 6, 4, 2, 10]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [21, 28, 7, 6, 1, 14]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.17647058823529413 {'action': 'remove-node', 'content': ['21', '84', '127']}
# Complexity: [17, 22, 7, 2, 5, 12]
# Step: 2 0.0625 {'action': 'remove-node', 'content': ['45']}
# Complexity: [16, 19, 5, 3, 2, 8]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [16, 18, 4, 3, 1, 6]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.2631578947368421 {'action': 'remove-node', 'content': ['45', '64', '93', '103', '108']}
# Complexity: [19, 22, 6, 2, 4, 9]
# Step: 2 0.05555555555555555 {'action': 'remove-node', 'content': ['112']}
# Complexity: [18, 20, 6, 3, 3, 8]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 22, 7, 3, 4, 11]

# %%
results_delete_right = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_delete_fox_bb.json', 'w') as fp:
    json.dump(results_delete_right, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Removing Miami + Florida references
# There's 39 after the protests start.

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
i = 0
total_samples = base_total_samples
while i < total_samples:
    drop = False
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, 
                                               verbose=False, random_state=random_state, force_cluster=False)
        filter_nodes = graph_df[graph_df.title.str.contains('miami', case=False) | 
                                   graph_df.title.str.contains('florida', case=False)]
        percent_filter_nodes = len(filter_nodes.index) / len(graph_df.index)
        remove_node_list = [str(node) for node in filter_nodes.id.tolist()]
        remove_node = {"action": "remove-node", "content": remove_node_list}
        previous_actions.append(remove_node)
        percent_list.append(percent_filter_nodes)
        if percent_filter_nodes == 0 and inner_iter_count == 0: # first iteration has no miami/florida nodes. 
            drop = True
            total_samples += 1
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    i += 1
    for action in previous_actions:
        actions += action['content']
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.23529411764705882 {'action': 'remove-node', 'content': ['36', '40', '51', '58']}
# Complexity: [17, 20, 5, 3, 2, 8]
# Step: 2 0.1111111111111111 {'action': 'remove-node', 'content': ['35', '63']}
# Complexity: [18, 20, 7, 2, 5, 9]
# Step: 3 0.05555555555555555 {'action': 'remove-node', 'content': ['46']}
# Complexity: [18, 20, 6, 4, 2, 8]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 20, 7, 3, 4, 8]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.1111111111111111 {'action': 'remove-node', 'content': ['53', '122']}
# Complexity: [18, 21, 6, 2, 4, 9]
# Step: 2 0.058823529411764705 {'action': 'remove-node', 'content': ['126']}
# Complexity: [17, 23, 7, 5, 2, 13]
# Step: 3 0.05263157894736842 {'action': 'remove-node', 'content': ['63']}
# Complexity: [19, 21, 5, 3, 2, 7]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 24, 7, 4, 3, 12]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.23529411764705882 {'action': 'remove-node', 'content': ['36', '49', '51', '122']}
# Complexity: [17, 17, 4, 3, 1, 4]
# Step: 2 0.05555555555555555 {'action': 'remove-node', 'content': ['53']}
# Complexity: [18, 20, 6, 4, 2, 8]
# Step: 3 0.05555555555555555 {'action': 'remove-node', 'content': ['35']}
# Complexity: [18, 22, 7, 3, 4, 11]
# Step: 4 0.05 {'action': 'remove-node', 'content': ['58']}
# Complexity: [20, 21, 4, 2, 2, 5]
# Step: 5 0.05 {'action': 'remove-node', 'content': ['63']}
# Complexity: [20, 21, 6, 3, 3, 7]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [16, 19, 6, 3, 3, 9]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.15789473684210525 {'action': 'remove-node', 'content': ['36', '58', '63']}
# Complexity: [19, 22, 8, 2, 6, 11]
# Step: 2 0.05263157894736842 {'action': 'remove-node', 'content': ['126']}
# Complexity: [19, 23, 7, 4, 3, 11]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 22, 9, 3, 6, 13]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.21052631578947367 {'action': 'remove-node', 'content': ['35', '46', '53', '140']}
# Complexity: [19, 25, 10, 3, 7, 16]
# Step: 2 0.05 {'action': 'remove-node', 'content': ['126']}
# Complexity: [20, 23, 10, 3, 7, 13]
# Step: 3 0.11764705882352941 {'action': 'remove-node', 'content': ['94', '122']}
# Complexity: [17, 22, 9, 2, 7, 14]
# Step: 4 0.05555555555555555 {'action': 'remove-node', 'content': ['88']}
# Complexity: [18, 24, 9, 4, 5, 15]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 21, 9, 3, 6, 12]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.17647058823529413 {'action': 'remove-node', 'content': ['35', '36', '53']}
# Complexity: [17, 21, 6, 3, 3, 10]
# Step: 2 0.11764705882352941 {'action': 'remove-node', 'content': ['63', '122']}
# Complexity: [17, 20, 5, 3, 2, 8]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [17, 21, 7, 2, 5, 11]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.10526315789473684 {'action': 'remove-node', 'content': ['35', '36']}
# Complexity: [19, 23, 7, 4, 3, 11]
# Step: 2 0.05555555555555555 {'action': 'remove-node', 'content': ['122']}
# Complexity: [18, 20, 5, 3, 2, 7]
# Step: 3 0.1 {'action': 'remove-node', 'content': ['51', '53']}
# Complexity: [20, 25, 7, 5, 2, 12]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 22, 7, 3, 4, 11]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.09523809523809523 {'action': 'remove-node', 'content': ['36', '122']}
# Complexity: [21, 26, 7, 4, 3, 12]
# Step: 2 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 20, 6, 2, 4, 8]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.058823529411764705 {'action': 'remove-node', 'content': ['122']}
# Complexity: [17, 22, 7, 2, 5, 12]
# Step: 2 0.125 {'action': 'remove-node', 'content': ['35', '49', '58']}
# Complexity: [24, 28, 7, 5, 2, 11]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [15, 19, 5, 3, 2, 9]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.05263157894736842 {'action': 'remove-node', 'content': ['53']}
# Complexity: [19, 22, 6, 2, 4, 9]
# Step: 2 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [15, 17, 4, 2, 2, 6]

# %%
results_delete_florida = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_delete_florida.json', 'w') as fp:
    json.dump(results_delete_florida, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Remove Edges
# ### Remove Inconsistent Edges
# Goal: Remove right-biased news articles from the map. We use the same starting point from before.

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_edges = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_edges > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state)
        edges = list(G.edges())
        filter_edges = []
        for node_i, node_j in edges:
            bias_i = graph_df.loc[graph_df['id'] == int(node_i)].iloc[0]['bias']
            bias_j = graph_df.loc[graph_df['id'] == int(node_j)].iloc[0]['bias']
            if (bias_i == 'Right' and bias_j == 'Left') or (bias_i == 'Left' and bias_j == 'Right'):
                filter_edges.append((node_i, node_j))
        remove_edge_list = [node_i + "-" + node_j for node_i, node_j in filter_edges]
        percent_filter_edges = len(filter_edges) / len(edges)
        
        remove_edge = {"action": "remove-edge", "content": remove_edge_list}
        previous_actions.append(remove_edge)
        percent_list.append(percent_filter_edges)
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_edges, remove_edge)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.1 {'action': 'remove-edge', 'content': ['132-147', '48-58']}
# Complexity: [17, 20, 5, 3, 2, 8]
# Step: 2 0.08 {'action': 'remove-edge', 'content': ['12-36', '144-146']}
# Complexity: [22, 25, 6, 5, 1, 9]
# Step: 3 0.15 {'action': 'remove-edge', 'content': ['132-144', '13-36', '146-147']}
# Complexity: [17, 20, 6, 2, 4, 9]
# Step: 4 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [18, 19, 5, 4, 1, 6]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.14285714285714285 {'action': 'remove-edge', 'content': ['22-33', '48-53', '71-107']}
# Complexity: [18, 21, 6, 2, 4, 9]
# Step: 2 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [17, 19, 5, 2, 3, 7]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.11764705882352941 {'action': 'remove-edge', 'content': ['20-36', '33-36']}
# Complexity: [17, 17, 4, 3, 1, 4]
# Step: 2 0.2 {'action': 'remove-edge', 'content': ['11-35', '36-39', '20-45', '39-49', '90-127']}
# Complexity: [21, 25, 8, 4, 4, 12]
# Step: 3 0.10526315789473684 {'action': 'remove-edge', 'content': ['12-45', '146-147']}
# Complexity: [18, 19, 3, 3, 0, 4]
# Step: 4 0.05 {'action': 'remove-edge', 'content': ['20-28']}
# Complexity: [18, 20, 5, 3, 2, 7]
# Step: 5 0.045454545454545456 {'action': 'remove-edge', 'content': ['20-35']}
# Complexity: [18, 22, 5, 4, 1, 9]
# Step: 6 0.05263157894736842 {'action': 'remove-edge', 'content': ['20-22']}
# Complexity: [16, 19, 5, 3, 2, 8]
# Step: 7 0.1111111111111111 {'action': 'remove-edge', 'content': ['11-22', '20-66']}
# Complexity: [16, 18, 4, 2, 2, 6]
# Step: 8 0.09090909090909091 {'action': 'remove-edge', 'content': ['20-23', '11-28']}
# Complexity: [18, 22, 6, 4, 2, 10]
# Step: 9 0.05 {'action': 'remove-edge', 'content': ['11-45']}
# Complexity: [18, 20, 4, 3, 1, 6]
# Step: 10 0.05263157894736842 {'action': 'remove-edge', 'content': ['33-35']}
# Complexity: [17, 19, 4, 2, 2, 6]
# Step: 11 0.047619047619047616 {'action': 'remove-edge', 'content': ['12-36']}
# Complexity: [18, 21, 4, 3, 1, 7]
# Step: 12 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [19, 23, 7, 3, 4, 11]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.045454545454545456 {'action': 'remove-edge', 'content': ['72-90']}
# Complexity: [19, 22, 8, 2, 6, 11]
# Step: 2 0.08695652173913043 {'action': 'remove-edge', 'content': ['11-16', '13-36']}
# Complexity: [20, 23, 7, 4, 3, 10]
# Step: 3 0.045454545454545456 {'action': 'remove-edge', 'content': ['134-135']}
# Complexity: [18, 22, 8, 3, 5, 12]
# Step: 4 0.037037037037037035 {'action': 'remove-edge', 'content': ['11-36']}
# Complexity: [20, 27, 8, 5, 3, 15]
# Step: 5 0.041666666666666664 {'action': 'remove-edge', 'content': ['13-16']}
# Complexity: [19, 24, 7, 4, 3, 12]
# Step: 6 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [18, 23, 7, 3, 4, 12]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.28 {'action': 'remove-edge', 'content': ['35-43', '65-112', '43-53', '91-127', '112-113', '127-138', '121-127']}
# Complexity: [19, 25, 10, 3, 7, 16]
# Step: 2 0.043478260869565216 {'action': 'remove-edge', 'content': ['131-138']}
# Complexity: [18, 23, 8, 4, 4, 13]
# Step: 3 0.23809523809523808 {'action': 'remove-edge', 'content': ['53-61', '65-84', '58-65', '84-124', '124-127']}
# Complexity: [17, 21, 7, 3, 4, 11]
# Step: 4 0.18181818181818182 {'action': 'remove-edge', 'content': ['65-76', '36-65', '84-86', '127-141']}
# Complexity: [18, 22, 7, 4, 3, 11]
# Step: 5 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [17, 22, 8, 3, 5, 13]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.047619047619047616 {'action': 'remove-edge', 'content': ['20-36']}
# Complexity: [17, 21, 6, 3, 3, 10]
# Step: 2 0.13043478260869565 {'action': 'remove-edge', 'content': ['11-19', '19-27', '27-47']}
# Complexity: [20, 23, 5, 3, 2, 8]
# Step: 3 0.043478260869565216 {'action': 'remove-edge', 'content': ['27-54']}
# Complexity: [20, 23, 7, 4, 3, 10]
# Step: 4 0.05555555555555555 {'action': 'remove-edge', 'content': ['146-147']}
# Complexity: [15, 18, 5, 2, 3, 8]
# Step: 5 0.16666666666666666 {'action': 'remove-edge', 'content': ['20-35', '19-20', '54-113', '89-138']}
# Complexity: [21, 24, 6, 4, 2, 9]
# Step: 6 0.043478260869565216 {'action': 'remove-edge', 'content': ['13-19']}
# Complexity: [20, 23, 7, 5, 2, 10]
# Step: 7 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [16, 19, 5, 4, 1, 8]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.21739130434782608 {'action': 'remove-edge', 'content': ['36-90', '33-35', '17-33', '103-113', '113-146']}
# Complexity: [19, 23, 7, 4, 3, 11]
# Step: 2 0.15789473684210525 {'action': 'remove-edge', 'content': ['17-27', '27-36', '96-113']}
# Complexity: [17, 19, 5, 3, 2, 7]
# Step: 3 0.17391304347826086 {'action': 'remove-edge', 'content': ['33-36', '33-51', '36-48', '53-113']}
# Complexity: [19, 23, 6, 3, 3, 10]
# Step: 4 0.05 {'action': 'remove-edge', 'content': ['47-90']}
# Complexity: [19, 20, 5, 3, 2, 6]
# Step: 5 0.037037037037037035 {'action': 'remove-edge', 'content': ['73-90']}
# Complexity: [21, 27, 7, 5, 2, 13]
# Step: 6 0.043478260869565216 {'action': 'remove-edge', 'content': ['22-33']}
# Complexity: [18, 23, 7, 3, 4, 12]
# Step: 7 0.13043478260869565 {'action': 'remove-edge', 'content': ['36-39', '127-138', '146-154']}
# Complexity: [19, 23, 6, 4, 2, 10]
# Step: 8 0.04 {'action': 'remove-edge', 'content': ['36-42']}
# Complexity: [19, 25, 6, 4, 2, 12]
# Step: 9 0.037037037037037035 {'action': 'remove-edge', 'content': ['33-47']}
# Complexity: [22, 27, 7, 5, 2, 12]
# Step: 10 0.04 {'action': 'remove-edge', 'content': ['47-61']}
# Complexity: [19, 25, 9, 5, 4, 15]
# Step: 11 0.043478260869565216 {'action': 'remove-edge', 'content': ['33-45']}
# Complexity: [19, 23, 7, 3, 4, 11]
# Step: 12 0.043478260869565216 {'action': 'remove-edge', 'content': ['89-90']}
# Complexity: [19, 23, 6, 3, 3, 10]
# Step: 13 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [20, 25, 8, 5, 3, 13]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.23076923076923078 {'action': 'remove-edge', 'content': ['61-127', '19-33', '33-54', '54-61', '65-73', '73-138']}
# Complexity: [21, 26, 7, 4, 3, 12]
# Step: 2 0.045454545454545456 {'action': 'remove-edge', 'content': ['65-127']}
# Complexity: [20, 22, 6, 3, 3, 8]
# Step: 3 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [20, 22, 5, 3, 2, 7]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.045454545454545456 {'action': 'remove-edge', 'content': ['127-135']}
# Complexity: [17, 22, 7, 2, 5, 12]
# Step: 2 0.041666666666666664 {'action': 'remove-edge', 'content': ['90-127']}
# Complexity: [18, 24, 9, 3, 6, 15]
# Step: 3 0.041666666666666664 {'action': 'remove-edge', 'content': ['84-90']}
# Complexity: [18, 24, 7, 3, 4, 13]
# Step: 4 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [18, 25, 9, 3, 6, 16]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.3181818181818182 {'action': 'remove-edge', 'content': ['64-77', '103-113', '77-93', '108-117', '93-107', '113-134', '134-135']}
# Complexity: [19, 22, 6, 2, 4, 9]
# Step: 2 0.23809523809523808 {'action': 'remove-edge', 'content': ['45-48', '11-45', '48-53', '86-93', '103-135']}
# Complexity: [19, 21, 6, 4, 2, 8]
# Step: 3 0.09090909090909091 {'action': 'remove-edge', 'content': ['12-45', '112-117']}
# Complexity: [19, 22, 7, 3, 4, 10]
# Step: 4 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [18, 20, 6, 4, 2, 8]

# %%
results_delete_edges = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_delete_edges.json', 'w') as fp:
    json.dump(results_delete_edges, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Add Edges + Remove Edges
# ### Make Storylines Consistent (Starting from "Center" Storyline)

# %%
from collections import Counter
def most_common(lst):
    # Exclude local and center.
    lst[:] = [x for x in lst if x != 'Center' and x != 'Local']
    if len(lst) == 0:
        return None
    data = Counter(lst)
    return max(lst, key=data.get)

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples

for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list_nodes = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state)
        nodes = list(G.nodes())
        remove_node_list = []
        add_edges = []
        #print("Storylines: " + str(storylines))
        for story in storylines:
            #print("Current story: " + str(story))
            story_biases = [graph_df.loc[graph_df['id'] == int(story_node)].iloc[0]['bias'] for story_node in story]
            story_bias = most_common(story_biases)
            opposite_bias = None
            if story_bias == 'Left':
                opposite_bias = 'Right'
            else:
                opposite_bias = 'Left'
            skip_count = 0
            mark = None
            if opposite_bias is not None:
                for node in story:
                    bias = graph_df.loc[graph_df['id'] == int(node)].iloc[0]['bias']
                    if mark is not None and skip_count > 0 and bias != opposite_bias:
                        add_edge = {"action": "add-edge", "content": str(mark) + "-" + str(node)} # String of edge id
                        add_edges.append(str(mark) + "-" + str(node))
                        previous_actions.append(add_edge)
                        mark = node
                        skip_count = 0
                    if bias != opposite_bias:
                        mark = node
                    else:
                        remove_node_list.append(node)
                        skip_count += 1            
        remove_node = {"action": "remove-node", "content": remove_node_list}
        for node in remove_node_list:
            previous_actions[:] = [action for action in previous_actions if not (action['action'] == 'add-edge' and str(node) in action['content'].split("-"))]
        previous_actions.append(remove_node)                
        percent_filter_nodes = len(remove_node_list) / len(nodes)              
        percent_list_nodes.append(percent_filter_nodes)
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node, "add-edge: " + str(add_edges))
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    for action in previous_actions:
        if type(action['content']) == list:
            actions += action['content']
        else:
            actions.append(action['content'])
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list_nodes)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.058823529411764705 {'action': 'remove-node', 'content': ['58']} add-edge: ['48-130']
# Complexity: [17, 20, 5, 3, 2, 8]
# Step: 2 0.10526315789473684 {'action': 'remove-node', 'content': ['147', '27']} add-edge: ['146-151']
# Complexity: [19, 23, 8, 3, 5, 12]
# Step: 3 0.125 {'action': 'remove-node', 'content': ['77', '15']} add-edge: ['36-132', '16-17']
# Complexity: [16, 18, 5, 4, 1, 7]
# Step: 4 0.05263157894736842 {'action': 'remove-node', 'content': ['146']} add-edge: []
# Complexity: [19, 23, 8, 3, 5, 12]
# Step: 5 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [19, 22, 7, 3, 4, 10]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.16666666666666666 {'action': 'remove-node', 'content': ['33', '48', '107']} add-edge: ['10-53']
# Complexity: [18, 21, 6, 2, 4, 9]
# Step: 2 0.0625 {'action': 'remove-node', 'content': ['13']} add-edge: ['53-57']
# Complexity: [16, 19, 5, 2, 3, 8]
# Step: 3 0.0625 {'action': 'remove-node', 'content': ['15']} add-edge: ['53-57']
# Complexity: [16, 19, 5, 2, 3, 8]
# Step: 4 0.1111111111111111 {'action': 'remove-node', 'content': ['11', '77']} add-edge: ['45-47']
# Complexity: [18, 21, 5, 2, 3, 8]
# Step: 5 0.0625 {'action': 'remove-node', 'content': ['20']} add-edge: ['53-57']
# Complexity: [16, 18, 6, 2, 4, 8]
# Step: 6 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [16, 19, 5, 2, 3, 8]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.11764705882352941 {'action': 'remove-node', 'content': ['20', '90']} add-edge: ['10-36', '85-114']
# Complexity: [17, 17, 4, 3, 1, 4]
# Step: 2 0.125 {'action': 'remove-node', 'content': ['11', '33']} add-edge: ['35-36']
# Complexity: [16, 19, 4, 3, 1, 7]
# Step: 3 0.09523809523809523 {'action': 'remove-node', 'content': ['15', '39']} add-edge: ['36-52']
# Complexity: [21, 26, 9, 3, 6, 14]
# Step: 4 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [15, 16, 5, 2, 3, 6]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.10526315789473684 {'action': 'remove-node', 'content': ['90', '138']} add-edge: ['72-92']
# Complexity: [19, 22, 8, 2, 6, 11]
# Step: 2 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [19, 23, 8, 3, 5, 12]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.10526315789473684 {'action': 'remove-node', 'content': ['127', '43']} add-edge: ['91-138', '35-53']
# Complexity: [19, 25, 10, 3, 7, 16]
# Step: 2 0.058823529411764705 {'action': 'remove-node', 'content': ['53']} add-edge: ['10-55']
# Complexity: [17, 20, 9, 3, 6, 12]
# Step: 3 0.07692307692307693 {'action': 'remove-node', 'content': ['35']} add-edge: ['10-37']
# Complexity: [13, 15, 7, 1, 6, 9]
# Step: 4 0.0625 {'action': 'remove-node', 'content': ['84']} add-edge: ['65-86']
# Complexity: [16, 15, 10, 1, 9, 9]
# Step: 5 0.0625 {'action': 'remove-node', 'content': ['112']} add-edge: ['106-113']
# Complexity: [16, 16, 10, 2, 8, 10]
# Step: 6 0.04 {'action': 'remove-node', 'content': ['65']} add-edge: ['58-85']
# Complexity: [25, 24, 19, 4, 15, 18]
# Step: 7 0.10526315789473684 {'action': 'remove-node', 'content': ['18', '113']} add-edge: ['104-131']
# Complexity: [19, 17, 13, 3, 10, 11]
# Step: 8 0.045454545454545456 {'action': 'remove-node', 'content': ['90']} add-edge: ['85-92']
# Complexity: [22, 16, 9, 7, 2, 3]
# Step: 9 0.047619047619047616 {'action': 'remove-node', 'content': ['91']} add-edge: []
# Complexity: [21, 14, 9, 7, 2, 2]
# Step: 10 0.047619047619047616 {'action': 'remove-node', 'content': ['124']} add-edge: []
# Complexity: [21, 15, 11, 6, 5, 5]
# Step: 11 0.05 {'action': 'remove-node', 'content': ['104']} add-edge: ['86-106']
# Complexity: [20, 14, 10, 6, 4, 4]
# Step: 12 0.10526315789473684 {'action': 'remove-node', 'content': ['23', '131']} add-edge: ['10-61']
# Complexity: [19, 14, 8, 6, 2, 3]
# Step: 13 0.09523809523809523 {'action': 'remove-node', 'content': ['146', '83']} add-edge: []
# Complexity: [21, 15, 11, 7, 4, 5]
# Step: 14 0.0625 {'action': 'remove-node', 'content': ['98']} add-edge: []
# Complexity: [16, 10, 8, 6, 2, 2]
# Step: 15 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [19, 13, 12, 6, 6, 6]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.11764705882352941 {'action': 'remove-node', 'content': ['20', '147']} add-edge: ['10-36']
# Complexity: [17, 21, 6, 3, 3, 10]
# Step: 2 0.0625 {'action': 'remove-node', 'content': ['138']} add-edge: []
# Complexity: [16, 18, 5, 4, 1, 7]
# Step: 3 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [16, 20, 7, 2, 5, 11]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.10526315789473684 {'action': 'remove-node', 'content': ['36', '33']} add-edge: ['10-90', '17-78']
# Complexity: [19, 23, 7, 4, 3, 11]
# Step: 2 0.16666666666666666 {'action': 'remove-node', 'content': ['113', '135', '90']} add-edge: ['92-115', '134-151']
# Complexity: [18, 20, 5, 3, 2, 7]
# Step: 3 0.09375 {'action': 'remove-node', 'content': ['138', '27', '47']} add-edge: ['108-158', '21-45']
# Complexity: [32, 29, 12, 9, 3, 9]
# Step: 4 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [29, 25, 13, 8, 5, 9]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.14285714285714285 {'action': 'remove-node', 'content': ['73', '146', '132']} add-edge: ['65-114']
# Complexity: [21, 26, 7, 4, 3, 12]
# Step: 2 0.17391304347826086 {'action': 'remove-node', 'content': ['61', '65', '33', '96']} add-edge: ['54-149']
# Complexity: [23, 21, 10, 7, 3, 8]
# Step: 3 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [18, 20, 5, 3, 2, 7]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [17, 22, 7, 2, 5, 12]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.2631578947368421 {'action': 'remove-node', 'content': ['113', '135', '144', '64', '93']} add-edge: ['103-134', '134-139', '57-77', '77-107']
# Complexity: [19, 22, 6, 2, 4, 9]
# Step: 2 0.21052631578947367 {'action': 'remove-node', 'content': ['141', '45', '53', '86']} add-edge: ['27-48', '48-107', '57-108']
# Complexity: [19, 22, 6, 3, 3, 9]
# Step: 3 0.14705882352941177 {'action': 'remove-node', 'content': ['44', '77', '103', '61', '89']} add-edge: ['107-117', '72-108']
# Complexity: [34, 31, 17, 10, 7, 14]
# Step: 4 0.08 {'action': 'remove-node', 'content': ['48', '108']} add-edge: ['16-62', '107-117']
# Complexity: [25, 20, 10, 7, 3, 5]
# Step: 5 0.22727272727272727 {'action': 'remove-node', 'content': ['154', '36', '54', '112', '16']} add-edge: ['27-117']
# Complexity: [22, 25, 8, 4, 4, 11]
# Step: 6 0.03571428571428571 {'action': 'remove-node', 'content': ['121']} add-edge: []
# Complexity: [28, 21, 11, 9, 2, 4]
# Step: 7 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [26, 20, 11, 7, 4, 5]

# %%
results_consistent_story = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_consistent_story.json', 'w') as fp:
    json.dump(results_consistent_story, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## "Clustering"
# 2 clusters only: High-bias Breitbart vs Center-unbiased storylines.
# Metric: internal storyline consistency (avoid connections between high-bias and low-bias articles)
#
# ### Semi-supervised umap with constraints

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
i = 0
total_samples = base_total_samples
while i < total_samples:
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consistent throughout the same iteration.
    drop = False
    while percent_filter >= 0.05:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, 
                                               verbose=False, random_state=random_state, force_cluster=True)
        nodes = list(G.edges())
        #print(storylines)
        breitbart_nodes = graph_df[graph_df.url.str.contains('breitbart')] # Cluster 1
        center_nodes = graph_df[graph_df.bias == 'Center'] # Cluster 2
        breitbart_cluster = [str(node) for node in breitbart_nodes['id'].tolist()]
        center_cluster = [str(node) for node in center_nodes['id'].tolist()]
        
        breitbart_action = {"action": "add-cluster-list", "content": [breitbart_cluster, 1]}
        center_action = {"action": "add-cluster-list", "content": [center_cluster, 2]}
        
        previous_actions.append(breitbart_action)
        previous_actions.append(center_action)
        
        non_isolated_nodes = set()
        breitbart_n = len(breitbart_cluster)
        center_n = len(center_cluster)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        for combination in itertools.combinations(breitbart_cluster,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
      
        for combination in itertools.combinations(center_cluster,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
                
        print("Total cluster 1: " + str(breitbart_n))
        print("Total cluster 1: " + str(center_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
        if breitbart_n + center_n == 0:
            percent_filter = 0.0
        else:        
            percent_filter = 1 - len(non_isolated_nodes) / (breitbart_n + center_n)
        percent_list.append(percent_filter)
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, breitbart_action, center_action)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
        
    i += 1
    actions = []
    for action in previous_actions:
        if action['action'] == 'add-cluster-list':
            actions += action['content'][0] 
        elif type(action['content']) == list:
            actions += action['content']
        else:
            actions.append(action['content'])
            
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Total cluster 1: 2
# Total cluster 1: 4
# Same story 1 Direct connection 0 Same parent 1 Same children 1
# Step: 1 0.33333333333333337 {'action': 'add-cluster-list', 'content': [['36', '58'], 1]} {'action': 'add-cluster-list', 'content': [['10', '25', '142', '143'], 2]}
# Complexity: [17, 20, 5, 3, 2, 8]
# Cluster:
# [36, 58]
# Filtered cluster [58]
# Filtered cluster []
# Cluster:
# [10, 25, 142, 143]
# Filtered cluster [25, 142, 143]
# Filtered cluster [142, 143]
# Filtered cluster [143]
# Filtered cluster []
# Total cluster 1: 8
# Total cluster 1: 23
# Same story 24 Direct connection 8 Same parent 2 Same children 5
# Step: 2 0.16129032258064513 {'action': 'add-cluster-list', 'content': [['19', '23', '36', '44', '45', '54', '58', '84'], 1]} {'action': 'add-cluster-list', 'content': [['10', '24', '25', '37', '41', '57', '62', '70', '75', '79', '80', '81', '92', '99', '106', '110', '139', '142', '143', '153', '155', '156', '159'], 2]}
# Complexity: [65, 74, 24, 11, 13, 33]
# Cluster:
# [19, 23, 36, 44, 45, 54, 58, 84]
# Filtered cluster [23, 36, 44, 45, 54, 58, 84]
# Filtered cluster [36, 44, 45, 54, 58, 84]
# Filtered cluster [44, 45, 54, 58, 84]
# Filtered cluster [45, 54, 58, 84]
# Filtered cluster [54, 58, 84]
# Filtered cluster [58, 84]
# Filtered cluster [84]
# Filtered cluster []
# Cluster:
# [10, 24, 25, 37, 41, 57, 62, 70, 75, 79, 80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [24, 25, 37, 41, 57, 62, 70, 75, 79, 80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [25, 37, 41, 57, 62, 70, 75, 79, 80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [37, 41, 57, 62, 70, 75, 79, 80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [41, 57, 62, 70, 75, 79, 80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [57, 62, 70, 75, 79, 80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [62, 70, 75, 79, 80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [70, 75, 79, 80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [75, 79, 80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [79, 80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [80, 81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [81, 92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [92, 99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [99, 106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [106, 110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [110, 139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [139, 142, 143, 153, 155, 156, 159]
# Filtered cluster [142, 143, 153, 155, 156, 159]
# Filtered cluster [143, 153, 155, 156, 159]
# Filtered cluster [153, 155, 156, 159]
# Filtered cluster [155, 156, 159]
# Filtered cluster [156, 159]
# Filtered cluster [159]
# Filtered cluster []
# Total cluster 1: 10
# Total cluster 1: 25
# Same story 43 Direct connection 10 Same parent 0 Same children 16
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['19', '23', '28', '36', '44', '45', '47', '54', '58', '84'], 1]} {'action': 'add-cluster-list', 'content': [['10', '24', '25', '37', '41', '57', '60', '62', '70', '75', '79', '80', '81', '92', '99', '106', '109', '110', '139', '142', '143', '153', '155', '156', '159'], 2]}
# Complexity: [55, 61, 21, 12, 9, 27]
# ===================================
# Sample #1
# ===================================
# Total cluster 1: 1
# Total cluster 1: 6
# Same story 3 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.4285714285714286 {'action': 'add-cluster-list', 'content': [['71'], 1]} {'action': 'add-cluster-list', 'content': [['10', '57', '62', '70', '120', '143'], 2]}
# Complexity: [18, 21, 6, 2, 4, 9]
# Cluster:
# [71]
# Filtered cluster []
# Cluster:
# [10, 57, 62, 70, 120, 143]
# Filtered cluster [57, 62, 70, 120, 143]
# Filtered cluster [62, 70, 120, 143]
# Filtered cluster [70, 120, 143]
# Filtered cluster [120, 143]
# Filtered cluster [143]
# Filtered cluster []
# Total cluster 1: 10
# Total cluster 1: 28
# Same story 11 Direct connection 14 Same parent 8 Same children 17
# Step: 2 0.26315789473684215 {'action': 'add-cluster-list', 'content': [['19', '23', '44', '45', '47', '54', '58', '71', '103', '116'], 1]} {'action': 'add-cluster-list', 'content': [['10', '24', '25', '37', '57', '62', '70', '74', '81', '92', '99', '100', '105', '106', '115', '120', '123', '139', '142', '143', '148', '152', '153', '155', '156', '157', '158', '159'], 2]}
# Complexity: [91, 127, 38, 25, 13, 74]
# Cluster:
# [19, 23, 44, 45, 47, 54, 58, 71, 103, 116]
# Filtered cluster [23, 44, 45, 47, 54, 58, 71, 103, 116]
# Filtered cluster [44, 45, 47, 54, 58, 71, 103, 116]
# Filtered cluster [45, 47, 54, 58, 71, 103, 116]
# Filtered cluster [47, 54, 58, 71, 103, 116]
# Filtered cluster [54, 58, 71, 103, 116]
# Filtered cluster [58, 71, 103, 116]
# Filtered cluster [71, 103, 116]
# Filtered cluster [103, 116]
# Filtered cluster [116]
# Filtered cluster []
# Cluster:
# [10, 24, 25, 37, 57, 62, 70, 74, 81, 92, 99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [24, 25, 37, 57, 62, 70, 74, 81, 92, 99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [25, 37, 57, 62, 70, 74, 81, 92, 99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [37, 57, 62, 70, 74, 81, 92, 99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [57, 62, 70, 74, 81, 92, 99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [62, 70, 74, 81, 92, 99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [70, 74, 81, 92, 99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [74, 81, 92, 99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [81, 92, 99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [92, 99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [99, 100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [100, 105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [105, 106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [106, 115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [115, 120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [120, 123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [123, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [153, 155, 156, 157, 158, 159]
# Filtered cluster [155, 156, 157, 158, 159]
# Filtered cluster [156, 157, 158, 159]
# Filtered cluster [157, 158, 159]
# Filtered cluster [158, 159]
# Filtered cluster [159]
# Filtered cluster []
# Total cluster 1: 14
# Total cluster 1: 31
# Same story 39 Direct connection 18 Same parent 3 Same children 18
# Step: 3 0.0888888888888889 {'action': 'add-cluster-list', 'content': [['19', '23', '28', '44', '45', '47', '54', '58', '66', '71', '72', '84', '103', '116'], 1]} {'action': 'add-cluster-list', 'content': [['10', '24', '25', '37', '57', '62', '70', '74', '80', '81', '85', '92', '99', '100', '105', '106', '115', '120', '123', '137', '139', '142', '143', '148', '152', '153', '155', '156', '157', '158', '159'], 2]}
# Complexity: [72, 85, 21, 20, 1, 34]
# Cluster:
# [19, 23, 28, 44, 45, 47, 54, 58, 66, 71, 72, 84, 103, 116]
# Filtered cluster [23, 28, 44, 45, 47, 54, 58, 66, 71, 72, 84, 103, 116]
# Filtered cluster [28, 44, 45, 47, 54, 58, 66, 71, 72, 84, 103, 116]
# Filtered cluster [44, 45, 47, 54, 58, 66, 71, 72, 84, 103, 116]
# Filtered cluster [45, 47, 54, 58, 66, 71, 72, 84, 103, 116]
# Filtered cluster [47, 54, 58, 66, 71, 72, 84, 103, 116]
# Filtered cluster [54, 58, 66, 71, 72, 84, 103, 116]
# Filtered cluster [58, 66, 71, 72, 84, 103, 116]
# Filtered cluster [66, 71, 72, 84, 103, 116]
# Filtered cluster [71, 72, 84, 103, 116]
# Filtered cluster [72, 84, 103, 116]
# Filtered cluster [84, 103, 116]
# Filtered cluster [103, 116]
# Filtered cluster [116]
# Filtered cluster []
# Cluster:
# [10, 24, 25, 37, 57, 62, 70, 74, 80, 81, 85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [24, 25, 37, 57, 62, 70, 74, 80, 81, 85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [25, 37, 57, 62, 70, 74, 80, 81, 85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [37, 57, 62, 70, 74, 80, 81, 85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [57, 62, 70, 74, 80, 81, 85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [62, 70, 74, 80, 81, 85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [70, 74, 80, 81, 85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [74, 80, 81, 85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [80, 81, 85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [81, 85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [85, 92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [92, 99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [99, 100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [100, 105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [105, 106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [106, 115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [115, 120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [120, 123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [123, 137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [137, 139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [139, 142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [142, 143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [143, 148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [148, 152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [152, 153, 155, 156, 157, 158, 159]
# Filtered cluster [153, 155, 156, 157, 158, 159]
# Filtered cluster [155, 156, 157, 158, 159]
# Filtered cluster [156, 157, 158, 159]
# Filtered cluster [157, 158, 159]
# Filtered cluster [158, 159]
# Filtered cluster [159]
# Filtered cluster []
# Total cluster 1: 14
# Total cluster 1: 31
# Same story 76 Direct connection 12 Same parent 1 Same children 19
# Step: 4 0.0 {'action': 'add-cluster-list', 'content': [['19', '23', '28', '44', '45', '47', '54', '58', '66', '71', '72', '84', '103', '116'], 1]} {'action': 'add-cluster-list', 'content': [['10', '24', '25', '37', '57', '62', '70', '74', '80', '81', '85', '92', '99', '100', '105', '106', '115', '120', '123', '137', '139', '142', '143', '148', '152', '153', '155', '156', '157', '158', '159'], 2]}
# Complexity: [63, 69, 19, 12, 7, 25]
# ===================================
# Sample #2
# ===================================
# Total cluster 1: 2
# Total cluster 1: 5
# Same story 3 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [['36', '66'], 1]} {'action': 'add-cluster-list', 'content': [['10', '75', '85', '139', '159'], 2]}
# Complexity: [17, 17, 4, 3, 1, 4]
# ===================================
# Sample #3
# ===================================
# Total cluster 1: 4
# Total cluster 1: 5
# Same story 5 Direct connection 0 Same parent 3 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [['36', '54', '58', '72'], 1]} {'action': 'add-cluster-list', 'content': [['10', '92', '152', '153', '156'], 2]}
# Complexity: [19, 22, 8, 2, 6, 11]
# ===================================
# Sample #4
# ===================================
# Total cluster 1: 0
# Total cluster 1: 5
# Same story 0 Direct connection 0 Same parent 1 Same children 2
# Step: 1 0.4 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['10', '60', '62', '92', '159'], 2]}
# Complexity: [19, 25, 10, 3, 7, 16]
# Cluster:
# []
# Cluster:
# [10, 60, 62, 92, 159]
# Filtered cluster [60, 62, 92, 159]
# Filtered cluster [62, 92, 159]
# Filtered cluster [92, 159]
# Filtered cluster [159]
# Filtered cluster []
# Total cluster 1: 12
# Total cluster 1: 16
# Same story 9 Direct connection 6 Same parent 2 Same children 14
# Step: 2 0.1785714285714286 {'action': 'add-cluster-list', 'content': [['23', '28', '44', '45', '47', '54', '58', '66', '71', '72', '84', '103'], 1]} {'action': 'add-cluster-list', 'content': [['10', '24', '25', '37', '57', '60', '62', '70', '74', '78', '81', '92', '110', '123', '139', '159'], 2]}
# Complexity: [55, 72, 21, 13, 8, 38]
# Cluster:
# [23, 28, 44, 45, 47, 54, 58, 66, 71, 72, 84, 103]
# Filtered cluster [28, 44, 45, 47, 54, 58, 66, 71, 72, 84, 103]
# Filtered cluster [44, 45, 47, 54, 58, 66, 71, 72, 84, 103]
# Filtered cluster [45, 47, 54, 58, 66, 71, 72, 84, 103]
# Filtered cluster [47, 54, 58, 66, 71, 72, 84, 103]
# Filtered cluster [54, 58, 66, 71, 72, 84, 103]
# Filtered cluster [58, 66, 71, 72, 84, 103]
# Filtered cluster [66, 71, 72, 84, 103]
# Filtered cluster [71, 72, 84, 103]
# Filtered cluster [72, 84, 103]
# Filtered cluster [84, 103]
# Filtered cluster [103]
# Filtered cluster []
# Cluster:
# [10, 24, 25, 37, 57, 60, 62, 70, 74, 78, 81, 92, 110, 123, 139, 159]
# Filtered cluster [24, 25, 37, 57, 60, 62, 70, 74, 78, 81, 92, 110, 123, 139, 159]
# Filtered cluster [25, 37, 57, 60, 62, 70, 74, 78, 81, 92, 110, 123, 139, 159]
# Filtered cluster [37, 57, 60, 62, 70, 74, 78, 81, 92, 110, 123, 139, 159]
# Filtered cluster [57, 60, 62, 70, 74, 78, 81, 92, 110, 123, 139, 159]
# Filtered cluster [60, 62, 70, 74, 78, 81, 92, 110, 123, 139, 159]
# Filtered cluster [62, 70, 74, 78, 81, 92, 110, 123, 139, 159]
# Filtered cluster [70, 74, 78, 81, 92, 110, 123, 139, 159]
# Filtered cluster [74, 78, 81, 92, 110, 123, 139, 159]
# Filtered cluster [78, 81, 92, 110, 123, 139, 159]
# Filtered cluster [81, 92, 110, 123, 139, 159]
# Filtered cluster [92, 110, 123, 139, 159]
# Filtered cluster [110, 123, 139, 159]
# Filtered cluster [123, 139, 159]
# Filtered cluster [139, 159]
# Filtered cluster [159]
# Filtered cluster []
# Total cluster 1: 13
# Total cluster 1: 19
# Same story 42 Direct connection 10 Same parent 2 Same children 10
# Step: 3 0.03125 {'action': 'add-cluster-list', 'content': [['19', '23', '28', '44', '45', '47', '54', '58', '66', '71', '72', '84', '103'], 1]} {'action': 'add-cluster-list', 'content': [['10', '24', '25', '37', '57', '60', '62', '70', '74', '78', '81', '92', '99', '110', '123', '137', '139', '148', '159'], 2]}
# Complexity: [65, 76, 23, 10, 13, 34]
# ===================================
# Sample #5
# ===================================
# Total cluster 1: 3
# Total cluster 1: 5
# Same story 4 Direct connection 2 Same parent 1 Same children 0
# Step: 1 0.125 {'action': 'add-cluster-list', 'content': [['36', '54', '66'], 1]} {'action': 'add-cluster-list', 'content': [['10', '14', '70', '143', '157'], 2]}
# Complexity: [17, 21, 6, 3, 3, 10]
# Cluster:
# [36, 54, 66]
# Filtered cluster [54, 66]
# Filtered cluster [66]
# Filtered cluster []
# Cluster:
# [10, 14, 70, 143, 157]
# Filtered cluster [14, 70, 143, 157]
# Filtered cluster [70, 143, 157]
# Filtered cluster [143, 157]
# Filtered cluster [157]
# Filtered cluster []
# Total cluster 1: 7
# Total cluster 1: 21
# Same story 13 Direct connection 8 Same parent 3 Same children 6
# Step: 2 0.1428571428571429 {'action': 'add-cluster-list', 'content': [['36', '44', '45', '54', '58', '66', '72'], 1]} {'action': 'add-cluster-list', 'content': [['10', '14', '25', '37', '57', '70', '75', '81', '85', '92', '99', '100', '106', '109', '115', '123', '139', '143', '153', '157', '159'], 2]}
# Complexity: [54, 62, 24, 12, 12, 32]
# Cluster:
# [36, 44, 45, 54, 58, 66, 72]
# Filtered cluster [44, 45, 54, 58, 66, 72]
# Filtered cluster [45, 54, 58, 66, 72]
# Filtered cluster [54, 58, 66, 72]
# Filtered cluster [58, 66, 72]
# Filtered cluster [66, 72]
# Filtered cluster [72]
# Filtered cluster []
# Cluster:
# [10, 14, 25, 37, 57, 70, 75, 81, 85, 92, 99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [14, 25, 37, 57, 70, 75, 81, 85, 92, 99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [25, 37, 57, 70, 75, 81, 85, 92, 99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [37, 57, 70, 75, 81, 85, 92, 99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [57, 70, 75, 81, 85, 92, 99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [70, 75, 81, 85, 92, 99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [75, 81, 85, 92, 99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [81, 85, 92, 99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [85, 92, 99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [92, 99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [99, 100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [100, 106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [106, 109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [109, 115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [115, 123, 139, 143, 153, 157, 159]
# Filtered cluster [123, 139, 143, 153, 157, 159]
# Filtered cluster [139, 143, 153, 157, 159]
# Filtered cluster [143, 153, 157, 159]
# Filtered cluster [153, 157, 159]
# Filtered cluster [157, 159]
# Filtered cluster [159]
# Filtered cluster []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-06d7792fa419> in <module>
#      17
#      18     while percent_filter >= 0.05:
# ---> 19         G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions,
#      20                                                verbose=False, random_state=random_state, force_cluster=True)
#      21         nodes = list(G.edges())
#
# <ipython-input-8-a9ac91f0d2f3> in generate_map(query, dataset, previous_actions, k_input, mincover_input, window, start_nodes, verbose, random_state, force_cluster, use_temporal, use_entities)
#      26         n_neighbors = cluster_size_est
#      27
# ---> 28     graph_df_new, status, scatter_df, sim_table, clust_sim_table, ent_table, ent_doc_list, cluster_assignment = solve_LP_from_query(query,
#      29         dataset=dataset, operations=operation_list,
#      30         K=k_input, mincover=mincover_input/100,
#
# C:\narrative-maps\narratives\packages\resolveLP.py in solve_LP_from_query(query, dataset, operations, K, mincover, min_samples, min_cluster_size, n_neighbors, min_dist, sigma_t, start_nodes, end_nodes, verbose, random_state, force_cluster, use_entities, use_temporal, strict_start, umap_init, cosine_sim)
#     707         print("Solving model...")
#     708         print("--- %s seconds ---" % (time() - start_time))
# --> 709     prob.solve(PULP_CBC_CMD(mip=False, warmStart=True))#(GLPK_CMD(path = 'C:\\glpk-4.65\\w64\\glpsol.exe', options = ["--tmlim", "180"]))
#     710
#     711
#
# ~\anaconda3\lib\site-packages\pulp\pulp.py in solve(self, solver, **kwargs)
#    1878         # time it
#    1879         self.startClock()
# -> 1880         status = solver.actualSolve(self, **kwargs)
#    1881         self.stopClock()
#    1882         self.restoreObjective(wasNone, dummyVar)
#
# ~\anaconda3\lib\site-packages\pulp\apis\coin_api.py in actualSolve(self, lp, **kwargs)
#     132     def actualSolve(self, lp, **kwargs):
#     133         """Solve a well formulated lp problem"""
# --> 134         return self.solve_CBC(lp, **kwargs)
#     135
#     136     def available(self):
#
# ~\anaconda3\lib\site-packages\pulp\apis\coin_api.py in solve_CBC(self, lp, use_mps)
#     192         args.extend(cmds[1:].split())
#     193         cbc = subprocess.Popen(args, stdout=pipe, stderr=pipe, stdin=devnull)
# --> 194         if cbc.wait() != 0:
#     195             raise PulpSolverError(
#     196                 "Pulp: Error while trying to execute, use msg=True for more details"
#
# ~\anaconda3\lib\subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# ~\anaconda3\lib\subprocess.py in _wait(self, timeout)
#    1359             if self.returncode is None:
#    1360                 # API note: Returns immediately if timeout_millis == 0.
# -> 1361                 result = _winapi.WaitForSingleObject(self._handle,
#    1362                                                      timeout_millis)
#    1363                 if result == _winapi.WAIT_TIMEOUT:
#
# KeyboardInterrupt:

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_clustering.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Test with Florida/Miami news vs general US news

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
i = 0
total_samples = base_total_samples
while i < total_samples:
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    drop = False
    
    while percent_filter >= 0.05:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, 
                                               verbose=False, random_state=random_state, force_cluster=True)
        nodes = list(G.edges())
        
        breitbart_nodes = graph_df[graph_df.title.str.contains('miami', case=False) | 
                                   graph_df.title.str.contains('florida', case=False)] # Cluster 1
        center_nodes = graph_df[(graph_df.title.str.contains(r'(\s|\b)[Uu](?:\.)?[sS](?:\.)?[Aa]?(?:\.)?(\s|\b)', regex=True) |
                                 graph_df.title.str.contains('united states', case=False)) & 
                                 ~(graph_df.title.str.contains('miami', case=False) 
                                   | graph_df.title.str.contains('florida', case=False))] # Cluster 2
        breitbart_cluster = [str(node) for node in breitbart_nodes['id'].tolist()]
        center_cluster = [str(node) for node in center_nodes['id'].tolist()]
        
        breitbart_action = {"action": "add-cluster-list", "content": [breitbart_cluster, 1]}
        center_action = {"action": "add-cluster-list", "content": [center_cluster, 2]}
        
        previous_actions.append(breitbart_action)
        previous_actions.append(center_action)
        
        non_isolated_nodes = set()
        breitbart_n = len(breitbart_cluster)
        center_n = len(center_cluster)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        for combination in itertools.combinations(breitbart_cluster,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1

                
        for combination in itertools.combinations(center_cluster,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
        
        print("Total cluster 1: " + str(breitbart_n))
        print("Total cluster 1: " + str(center_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
        
        if breitbart_n + center_n == 0:
            percent_filter = 0.0
        else:
            percent_filter = 1 - len(non_isolated_nodes) / (breitbart_n + center_n)
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
            
        percent_list.append(percent_filter)

        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, breitbart_action, center_action)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    i += 1
    actions = []
    for action in previous_actions:
        if action['action'] == 'add-cluster-list':
            actions += action['content'][0] 
        elif type(action['content']) == list:
            actions += action['content']
        else:
            actions.append(action['content'])
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_clustering.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Add Node
# Adding nodes and clustering.
#
# ### Miami + Florida

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
subset_query = query.loc[124:].astype({'id': 'int32'})
i = 0

while i < total_samples:
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    
    while percent_filter > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], 
                                               previous_actions=previous_actions, verbose=False, 
                                               random_state=random_state, force_cluster=True)
        
        all_relevant_nodes = subset_query[subset_query.title.str.contains('miami', case=False) 
                                                 | subset_query.title.str.contains('florida', case=False)]
        relevant_nodes = graph_df[graph_df.title.str.contains('miami', case=False) | 
                                   graph_df.title.str.contains('florida', case=False)]
        
        unselected_relevant_nodes = (all_relevant_nodes.merge(relevant_nodes, on=['id'], how='left', indicator=True)
                                     .query('_merge == "left_only"')
                                     .drop('_merge', 1))
        relevant_node_list = [str(node) for node in relevant_nodes.id.tolist()]
        # Select first 10% nodes.
        percentage = 10
        selected_nodes_df = unselected_relevant_nodes.head(int(len(unselected_relevant_nodes.index) * (percentage / 100)))
        selected_nodes_list = [str(node) for node in selected_nodes_df.id.tolist()]
        
        add_node = {"action": "add-node", "content": selected_nodes_list}
        previous_actions.append(add_node)
        
        # Mark nodes as part of the same cluster
        new_cluster = {"action": "add-cluster-list", "content": [relevant_node_list, 1]}
        previous_actions.append(new_cluster)
        
        # Are the relevant nodes connected?
        non_isolated_nodes = set()
        relevant_node_n = len(relevant_nodes)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        for combination in itertools.combinations(relevant_node_list,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
        
        print("# of Relevant Nodes: " + str(relevant_node_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
        
        if relevant_node_n == 0:
            percent_filter = 0.0
        else:
            percent_filter = 1 - len(non_isolated_nodes) / relevant_node_n
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
            
        percent_list.append(percent_filter)
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, add_node, "Relevant nodes: " + str(relevant_node_list))
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    
    i += 1
    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_clustering.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Biden

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
subset_query = query.loc[124:].astype({'id': 'int32'})
i = 0

while i < total_samples:
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    
    while percent_filter > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], 
                                               previous_actions=previous_actions, verbose=False, 
                                               random_state=random_state, force_cluster=True)
        
        all_relevant_nodes = subset_query[subset_query.title.str.contains('biden', case=False) 
                                                 | subset_query.title.str.contains('biden', case=False)]
        relevant_nodes = graph_df[graph_df.title.str.contains('biden', case=False) | 
                                   graph_df.title.str.contains('biden', case=False)]
        
        unselected_relevant_nodes = (all_relevant_nodes.merge(relevant_nodes, on=['id'], how='left', indicator=True)
                                     .query('_merge == "left_only"')
                                     .drop('_merge', 1))
        relevant_node_list = [str(node) for node in relevant_nodes.id.tolist()]
        # Select first 10% nodes.
        percentage = 5
        selected_nodes_df = unselected_relevant_nodes.head(int(len(unselected_relevant_nodes.index) * (percentage / 100)))
        selected_nodes_list = [str(node) for node in selected_nodes_df.id.tolist()]
        
        add_node = {"action": "add-node", "content": selected_nodes_list}
        previous_actions.append(add_node)
        
        # Mark nodes as part of the same cluster
        new_cluster = {"action": "add-cluster-list", "content": [relevant_node_list, 1]}
        previous_actions.append(new_cluster)
        
        # Are the relevant nodes connected?
        non_isolated_nodes = set()
        relevant_node_n = len(relevant_nodes)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        for combination in itertools.combinations(relevant_node_list,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
        
        print("# of Relevant Nodes: " + str(relevant_node_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
        
        if relevant_node_n == 0:
            percent_filter = 0.0
        else:
            percent_filter = 1 - len(non_isolated_nodes) / relevant_node_n
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
            
        percent_list.append(percent_filter)
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, add_node, "Relevant nodes: " + str(relevant_node_list))
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    
    i += 1
    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_clustering.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Clean-up - Singleton Storylines

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
subset_query = query.loc[124:].astype({'id': 'int32'})
i = 0

while i < total_samples:
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    
    while percent_filter > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], 
                                               previous_actions=previous_actions, verbose=False, 
                                               random_state=random_state, force_cluster=True)
        

        singletons = [lst for lst in storylines if len(lst) == 1]
        remove_node_list = [str(singleton[0]) for singleton in singletons]
        remove_node = {"action": "remove-node", "content": remove_node_list}
        previous_actions.append(remove_node)
        percent_filter = len(singletons) / len(storylines)

        if percent_filter == 0 and inner_iter_count == 0:
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
            
        percent_list.append(percent_filter)
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, remove_node)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    
    i += 1
    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_clustering.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Generate Final Plot

# %%
f = open('results_delete_right.json')
results_delete_right = json.load(f)
f = open('results_delete_fox_bb.json')
results_delete_fox_bb = json.load(f)
f = open('results_delete_florida.json')
results_delete_florida = json.load(f)
f = open('results_delete_edges.json')
results_delete_edges = json.load(f)
f = open('results_consistent_story.json')
results_consistent_story = json.load(f)
f = open('results_clustering_bb_center.json')
results_clustering_bb_center = json.load(f)
f = open('results_clustering_florida.json')
results_clustering_florida = json.load(f)
f = open('results_add_florida.json')
results_add_florida = json.load(f)
f = open('results_add_biden.json')
results_add_biden = json.load(f)

# %%
def average_series(json_dict):
    all_iterations = json_dict['iterations']
    all_percents = json_dict['percents']
    max_iter = max(all_iterations)
    extended_percent_list = []
    for percent_list in all_percents:
        percent_list_extended = percent_list + [0 for _ in range(max_iter - len(percent_list))]
        extended_percent_list.append(percent_list_extended)
    extended_percent_array = np.array(extended_percent_list)
    average_percent = np.mean(extended_percent_array, axis=0)
    return average_percent

# %%
def generate_x_y(json_dict):
    y = average_series(json_dict)
    x = range(max(json_dict['iterations']))
    return x, y

# %%
average_percent = average_series(results_delete_right)
max_iter = max(results_delete_right['iterations'])

# %%
heigth = 40
width = 32
plt.rcParams['figure.figsize'] = [heigth/2.54, width/2.54]
plt.rcParams.update({'font.size': 14})

# %%
fig, axs = plt.subplots(3, 3)

x, y = generate_x_y(results_delete_florida)
axs[0, 0].plot(x, y, 'tab:red')
axs[0, 0].set_title(r'$\bf{(a)}$ ' + 'T1 - Remove Irrelevant Events\nFlorida/Miami')

x, y = generate_x_y(results_delete_fox_bb)
axs[0, 1].plot(x, y, 'tab:red')
axs[0, 1].set_title(r'$\bf{(b)}$ ' + 'T1 - Remove Irrelevant Events\nFox News/Breitbart')

x, y = generate_x_y(results_delete_right)
axs[0, 2].plot(x, y, 'tab:red')
axs[0, 2].set_title(r'$\bf{(c)}$ ' + 'T1 - Remove Irrelevant Events\nRight-leaning Sources')

x, y = generate_x_y(results_delete_edges)
axs[1, 0].plot(x, y, 'tab:blue')
axs[1, 0].set_title(r'$\bf{(d)}$ ' + 'T2 - Removing Inconsistent Edges')

x, y = generate_x_y(results_consistent_story)
axs[1, 1].plot(x, y, 'tab:green')
axs[1, 1].set_title(r'$\bf{(e)}$ ' + 'T3 - Clean Up Storylines')

x, y = generate_x_y(results_clustering_florida)
axs[1, 2].plot(x, y, 'tab:orange')
axs[1, 2].set_title(r'$\bf{(f)}$ ' + 'T4 - Cluster Events\nMiami/Florida vs. Other US News')

x, y = generate_x_y(results_clustering_bb_center)
axs[2, 0].plot(x, y, 'tab:orange')
axs[2, 0].set_title(r'$\bf{(g)}$ ' + 'T4 - Cluster Events\nBreitbart vs. Unbiased News')

x, y = generate_x_y(results_add_florida)
axs[2, 1].plot(x, y, 'tab:purple')
axs[2, 1].set_title(r'$\bf{(h)}$ ' + 'T5 - Add Relevant Events\nFlorida/Miami')

x, y = generate_x_y(results_add_biden)
axs[2, 2].plot(x, y, 'tab:purple')
axs[2, 2].set_title(r'$\bf{(i)}$ ' + 'T5 - Add Relevant Events\nBiden')

for ax in axs.flat:
    ax.set(xlabel='Iterations', ylabel='Error Rate')

fig.tight_layout()
# Hide x labels and tick labels for top plots and y ticks for right plots.
from matplotlib.ticker import MaxNLocator
for ax in axs.flat:
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    #ax.label_outer()
