# %% [markdown]
# # Testing Other LPs

# %% [markdown]
# ## Imports

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import sys
import os
cwd = os.getcwd()
print(cwd)
nwd = os.path.join(cwd, "..", "narratives")
sys.path.insert(0, nwd)
# Out:
# C:\narrative-maps\tests

# %%
import matplotlib.pyplot as plt

# %%
import pydot
from IPython.display import SVG

# %%
from packages.solve_LP import *
from packages.graph_utils import *

# %% [markdown]
# ## Reading Data

# %%
def clean_publication(graph_df):
    publication_dict = {'www.bbc.com': 'bbc',
                    'www.aljazeera.com': 'ajz',
                    'www.nytimes.com': 'nyt',
                    'www.theguardian.com': 'tgn',
                    'edition.cnn.com': 'cnn',
                    'www.cnn.com': 'cnn',
                    'Reuters': 'reu',
                    'www.reuters.com': 'reu',
                    'Business Insider': 'bin',
                    'CNN': 'cnn',
                    'The Hill': 'hill',
                    'The New York Times': 'nyt',
                    'CNBC': 'cnbc',
                    'Breitbart': 'brb',
                    'www.breitbart.com': 'brb',
                    'Fox News': 'fox',
                    'www.foxnews.com': 'fox',
                    'CIA': 'cia',
                    'FBI': 'fbi',
                    'Army CID': 'cid',
                    'INS': 'ins',
                    'Sanctioned Intercepts': 'sai',
                    'NSA': 'nsa',
                    'abcnews.go.com': 'abc',
                    'apnews.com': 'apn',
                    'www.firstpost.com': 'fpost',
                    'theconversation.com': 'tcon',
                    'nypost.com': 'nyp',
                    'newscomworld.com': 'nwc',
                    'havanatimes.org': 'hvt',
                    'www.nbcnews.com': 'nbc',
                    'www.local10.com': 'l10',
                    'www.trtworld.com': 'trt',
                    'www.washingtonpost.com': 'wapo',
                    'www.xinhuanet.com': 'xinhua'
                    }
    graph_df['publication'] = graph_df['publication'].map(publication_dict).fillna('default')
    return graph_df

# %%
def read_query(dataset, start_date=None, end_date=None, partial=False):
    data_file = str(dataset) + '.csv'
    data_file_path = os.path.join(cwd, "..", "data", data_file)
    if partial:
        columns_to_skip = 'embed'
        query = pd.read_csv(data_file_path, usecols=lambda x: x not in columns_to_skip)
    else:
        query = pd.read_csv(data_file_path)
    query = clean_publication(query)

    # Inferring datatime format (this might bring issues depending on the data!)
    query['date'] = pd.to_datetime(query['date'], infer_datetime_format=True) #8/22/2019 12:15

    if start_date is not None:
        query = query[(query['date'] >= pd.to_datetime(start_date, format='%Y-%m-%d'))]

    if end_date is not None:
        query = query[(query['date'] <= pd.to_datetime(end_date, format='%Y-%m-%d'))]

    if not partial:
        embed_list = ['embed']
        query[embed_list] = query[embed_list].replace(r'( )+', ',', regex=True)
        query[embed_list] = query[embed_list].replace('\[,', '[', regex=True)
        query[embed_list] = query[embed_list].replace(',]', ']', regex=True)
        query[embed_list] = query[embed_list].applymap(literal_eval).applymap(np.array)

        if 'cluster_vec' in query.columns: # Predefined clusters!
            query[['cluster_vec']] = query[['cluster_vec']].applymap(literal_eval).applymap(np.array)

    query.reset_index(inplace=True)
    query['id'] = [str(i) for i in list(query.index)]

    return query

# %%
dataset = "cuba_160"
query = read_query(dataset)
sim_table = compute_sim(query)

# %% [markdown]
# ## Plots

# %%
def plot_complexity_metric(all_iterations, all_complexities, column):
    max_val_list = []
    for idx, complexity in enumerate(all_complexities):
        max_val_list.append(max(complexity[column]))
    max_val = max(max_val_list) 
    fig, ax = plt.subplots(ncols=2, figsize=(10,4))
    ax[0].title.set_text('All runs')
    ax[0].set_xlabel('# of Iterations')
    ax[0].set_ylabel(column)
    ax[0].set_ylim(0, max_val)
    ax[1].title.set_text('Average')
    ax[1].set_xlabel('# of Iterations')
    ax[1].set_ylabel(column)
    ax[1].set_ylim(0, max_val)
    # All elements    
    for idx, complexity in enumerate(all_complexities):
        ax[0].plot(list(range(len(complexity[column]))), complexity[column], '-r')
    # Average
    max_iter = max(all_iterations)
    extended_metric_list = []
    for idx, complexity in enumerate(all_complexities):
        metric_list_extended = list(complexity[column]) + [list(complexity[column])[-1] for _ in range(max_iter - len(complexity[column]))]
        extended_metric_list.append(metric_list_extended)
    extended_metric_array = np.array(extended_metric_list)
    average_metric = np.nanmean(extended_metric_array, axis=0)
    ax[1].plot(list(range(max_iter)), average_metric, '-r')
    
def plot_error_rate(all_iterations, all_percents):
    max_val_list = []
    for idx, percent_list in enumerate(all_percents):
        max_val_list.append(max(percent_list))
    max_val = max(max_val_list) 
    fig, ax = plt.subplots(ncols=2, figsize=(10,4))
    ax[0].title.set_text('All runs')
    ax[0].set_xlabel('# of Iterations')
    ax[0].set_ylabel('Error Rate')
    ax[0].set_ylim(0, max_val)
    ax[1].title.set_text('Average')
    ax[1].set_xlabel('# of Iterations')
    ax[1].set_ylabel('Error Rate')
    ax[1].set_ylim(0, max_val)
    # All elements
    for idx, percent_list in enumerate(all_percents):
        ax[0].plot(list(range(all_iterations[idx])), percent_list, '-r')
    # Average
    max_iter = max(all_iterations)
    extended_percent_list = []
    for percent_list in all_percents:
        percent_list_extended = percent_list + [percent_list[-1] for _ in range(max_iter - len(percent_list))]
        extended_percent_list.append(percent_list_extended)
    extended_percent_array = np.array(extended_percent_list)
    average_percent = np.nanmean(extended_percent_array, axis=0)
    ax[1].plot(list(range(max_iter)), average_percent, '-r')

# %%
def plot_all(all_iterations, all_percents, all_complexities):
    plot_error_rate(all_iterations, all_percents)
    plot_complexity_metric(all_iterations, all_complexities, column='Nodes')
    plot_complexity_metric(all_iterations, all_complexities, column='Edges')
    plot_complexity_metric(all_iterations, all_complexities, column='Stories')
    plot_complexity_metric(all_iterations, all_complexities, column='Regular Stories')
    plot_complexity_metric(all_iterations, all_complexities, column='Singleton Stories')
    plot_complexity_metric(all_iterations, all_complexities, column='Interstory Connections')

# %% [markdown]
# ## New Linear Program

# %%
def new_LP(query, sim_table, membership_vectors, clust_sim_table, exp_temp_table, ent_table, numclust, relevance_table,
    K, mincover, sigma_t, credibility=[], bias=[], operations=[],
    has_start=True, has_end=False, window_time=None, cluster_list=[], start_nodes=[], end_nodes=[],
    verbose=True, force_cluster=True, previous_varsdict=None):
    
    n = len(query.index) #We can cut out everything after the end.
    # Variable names and indices
    var_i = []
    var_ij = []
    var_k = [str(k) for k in range(0,numclust)]

    for i in range(0, n): # This goes up from 0 to n-1.
        var_i.append(str(i))
        for j in window_i_j[i]:
            if i == j:
                print("ERROR IN WINDOW - BASE")
            var_ij.append(str(i) + "_" + str(j))

    potential_edges = len(var_ij)
    
    # Linear program variable declaration.
    minedge = LpVariable("minedge", lowBound = 0, upBound = 1)
    node_act_vars = LpVariable.dicts("node_act", var_i, lowBound = 0, upBound = 1)
    node_next_vars = LpVariable.dicts("node_next", var_ij, lowBound = 0,  upBound = 1)
    clust_active_vars = LpVariable.dicts("clust_active", var_k, lowBound = 0, upBound = 1)

    # Create the 'prob' variable to contain the problem data
    prob = LpProblem("StoryChainProblem", LpMaximize)
    # The objective function is added to 'prob' first
    prob += minedge * potential_edges - lpSum([node_next_vars[ij] for ij in var_ij]), "WeakestLink"

    # Check duplicates in interactions
    replace = [False] * len(operations)
    for idx, op in enumerate(operations):
        op_ref = op.split(":",1)[1]
        for k in range(idx):
            if op_ref == operations[k].split(":",1)[1]:
                replace[k] = True
    # Fixtures.
    min_threshold_edge = 0.1 / K
    min_threshold_node = 0.4 / K
    for idx, op in enumerate(operations):
        op_ref = op.split(":",1)[1]
        # Omit ACL in this part, handle separetely.
        if "ACL" in op:
            continue

        temp = ""
        if "-" in op_ref:
            i = int(op_ref.split("-",1)[0])
            j = int(op_ref.split("-",1)[1])
            temp = str(i) + "_" + str(j)
        else:
            i = int(op_ref)
            temp = str(i)
        op_ref = temp

        if "AN" in op:
            if verbose:
                print('AddedNode ' + str(op_ref))
            if not replace[idx]:
                if prob.constraints.get('RemovedNode' + str(op_ref)) is not None:
                    del prob.constraints['RemovedNode' + str(op_ref)]
                prob += node_act_vars[str(op_ref)] >= min_threshold_node, 'AddedNode' + str(op_ref) # Makes problem infeasible if we add too many, divide threhsold by K? By number of added constraints?
        elif "AE" in op:
            if verbose:
                print('AddedEdge ' + str(op_ref))
            if not replace[idx]:
                if prob.constraints.get('RemovedEdge' + str(op_ref)) is not None:
                    del prob.constraints['RemovedEdge' + str(op_ref)]
                if str(op_ref) not in node_next_vars.keys():
                    # Special case for time-based windows where the time difference is too big.
                    # The connection does not exist by default and you need to add the variable manually for the specific edge.
                    node_next_vars[str(op_ref)] = LpVariable("node_next_" + str(op_ref), lowBound=0, upBound=1)
                    if i == j:
                        print("ERROR IN WINDOW - AE")
                    var_ij.append(str(op_ref))#str(i) + "_" + str(j))
                    window_i_j[i].append(j)
                    window_j_i[j].append(i)
                prob += node_next_vars[str(op_ref)] >= min_threshold_edge, 'AddedEdge' + str(op_ref)
        elif "RN" in op:
            if verbose:
                print('RemovedNode ' + str(op_ref))
            if not replace[idx]:
                if prob.constraints.get('AddedNode' + str(op_ref)) is not None:
                    del prob.constraints['AddedNode' + str(op_ref)]
                if prob.constraints.get('AddedNodeCluster' + str(op_ref)) is not None:
                    del prob.constraints['AddedNodeCluster' + str(op_ref)]
                prob += node_act_vars[str(op_ref)] == 0, 'RemovedNode' + str(op_ref)
        elif "RE" in op:
            if verbose:
                print('RemovedEdge ' + str(op_ref))
            if not replace[idx]:
                if prob.constraints.get('AddedEdge' + str(op_ref)) is not None:
                    del prob.constraints['AddedEdge' + str(op_ref)]
                prob += node_next_vars[str(op_ref)] == 0, 'RemovedEdge' + str(op_ref)

    if force_cluster:
        #min_threshold_edge = 0.1 / K
        #min_threshold_node = 0.4 / K
        min_threshold_edge = 0.05
        min_threshold_node = 0.01
        for cluster in cluster_list:
            cluster_sorted = sorted(cluster)
            #print("Cluster:")
            #print(cluster_sorted)
            for idx, event in enumerate(cluster_sorted):
                if verbose:
                    print('AddedNodeCluster ' + str(event))
                if prob.constraints.get('RemovedNode' + str(event)) is not None:
                    del prob.constraints['RemovedNode' + str(event)]
                if prob.constraints.get('AddedNodeCluster' + str(event)) is not None:
                    del prob.constraints['AddedNodeCluster' + str(event)]

                prob += node_act_vars[str(event)] >= min_threshold_node, 'AddedNodeCluster' + str(event)
                #print("Filtered cluster " + str(cluster_sorted[(idx + 1):]))
                if len(cluster_sorted[(idx + 1):]) >= 1:
                    for j in cluster_sorted[(idx + 1):]:
                        op_ref = str(event) + "_" + str(j)
                        #print("Forced connections: " + str(op_ref))
                        if str(op_ref) not in node_next_vars.keys():
                            # Special case for time-based windows where the time difference is too big.
                            # The connection does not exist by default and you need to add the variable manually for the specific edge.
                            if event == j:
                                print("ERROR IN WINDOW - ACL")
                            node_next_vars[str(op_ref)] = LpVariable("node_next_" + str(op_ref), lowBound=0, upBound=1)
                            var_ij.append(str(op_ref))
                            window_i_j[event].append(j)
                            window_j_i[j].append(event)
                            #print(window_i_j[i])
                            #print(window_j_i[i])
                    prob += lpSum([node_next_vars[str(event) + "_" + str(j)] for j in cluster_sorted[(idx + 1):]]) >= min_threshold_edge, 'InternalEdgeCluster' + str(event)
                    if verbose:
                        print('InternalEdgeCluster' + str(event) + ":" + str(cluster_sorted[(idx + 1):]))
    #for combination in itertools.combinations(cluster_list,2):
    #    for node_i in combination[0]:
    #        for node_j in combination[1]:
    #            if int(node_i) < int(node_j):
    #                prob += node_act_vars[str(op_ref)] >= min_threshold_node, 'AddedNode' + str(op_ref)

    # Chain restrictions
    if has_start:
        num_starts = len(start_nodes)
        if verbose:
            print("Start node(s):")
            print(start_nodes)
        if num_starts == 0: # This is the default when no list is given and it has a start.
            prob += node_act_vars[str(0)] == 1, 'InitialNode'
        else:
            if verbose:
                print("Added start node(s)")
                print("--- %s seconds ---" % (time() - start_time))
            initial_energy = 1.0 / num_starts
            earliest_start = min(start_nodes)
            for node in start_nodes:
                prob += node_act_vars[str(node)] == initial_energy, 'InitialNode' + str(node)
            for node in range(0, earliest_start):
                prob += node_act_vars[str(node)] == 0, 'BeforeStart' + str(node)
    if has_end:
        num_ends = len(end_nodes)
        if verbose:
            print("End node(s):")
            print(end_nodes)
        if num_ends == 0: # This is the default when no list is given and it has a start.
            prob += node_act_vars[str(n - 1)] == 1, 'FinalNode'
        else:
            if verbose:
                print("Added end node(s)")
                print("--- %s seconds ---" % (time() - start_time))
            final_energy = 1.0 / num_ends
            latest_end = min(end_nodes)
            for node in end_nodes:
                prob += node_act_vars[str(node)] == final_energy, 'FinalNode' + str(node)
            for node in range(latest_end + 1, n):
                prob += node_act_vars[str(node)] == 0, 'AfterEnd' + str(node)

    if verbose:
        print("Chain constraints created.")
        print("--- %s seconds ---" % (time() - start_time))
    prob += lpSum([node_act_vars[i] for i in var_i]) == K, 'KNodes'
    
    if verbose:
        print("Expected length constraints created.")
        print("--- %s seconds ---" % (time() - start_time))


    if has_start:
        if verbose:
            print("Equality constraints.")
            print("--- %s seconds ---" % (time() - start_time))
        for j in range(1, n):
            if j not in start_nodes:
                prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for i in window_j_i[j]]) == node_act_vars[str(j)], 'InEdgeReq' + str(j)
            else:
                if verbose:
                    print("Generating specific starting node constraints.")
                    print("--- %s seconds ---" % (time() - start_time))
                prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for i in window_j_i[j]]) == 0, 'InEdgeReq' + str(j)
    else:
        if verbose:
            print("Inequality constraints.")
            print("--- %s seconds ---" % (time() - start_time))
        for j in range(1, n):
            prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for i in window_j_i[j]]) <= node_act_vars[str(j)], 'InEdgeReq' + str(j)
    if verbose:
        print("In-degree constraints created.")
        print("--- %s seconds ---" % (time() - start_time))

    if has_end:
        if verbose:
            print("Equality constraints.")
            print("--- %s seconds ---" % (time() - start_time))
        for i in range(0, n - 1):
            if i not in end_nodes:
                prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for j in window_i_j[i]]) == node_act_vars[str(i)], 'OutEdgeReq'  + str(i)
            else:
                if verbose:
                    print("Generating specific starting node constraints.")
                    print("--- %s seconds ---" % (time() - start_time))
                prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for j in window_i_j[i]]) == 0, 'OutEdgeReq'  + str(i)
    else:
        if verbose:
            print("Inequality constraints.")
            print("--- %s seconds ---" % (time() - start_time))
        for i in range(0, n - 1):
            prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for j in window_i_j[i]]) <= node_act_vars[str(i)], 'OutEdgeReq'  + str(i)
    if verbose:
        print("Out-degree constraints created.")
        print("--- %s seconds ---" % (time() - start_time))

    # Coverage
    if numclust > 1:
        prob += lpSum([clust_active_vars[str(k)] for k in var_k]) >= numclust * mincover, "MinCover"
        for k in range(0, numclust):
            prob += clust_active_vars[str(k)] == lpSum([node_next_vars[str(i) + "_" + str(j)] * sqrt(membership_vectors[i, k] * membership_vectors[j, k]) for i in range(0, n - 1) for j in window_i_j[i]]), "CoverDef" + str(k)
        if verbose:
            print("Clustering constraints created.")
            print("--- %s seconds ---" % (time() - start_time))
    else:
        if verbose:
            print("No clustering constraints created - only 1 cluster.")
            print("--- %s seconds ---" % (time() - start_time))

    # Objective
    for i in range(0, n):
        for j in window_i_j[i]:
            coherence_weights = [0.5, 0.5]
            entity_multiplier = min(1 + ent_table[i, j], 2) # Five or more entities in common means double the connection strength.
            relevance_multiplier = (relevance_table[i] * relevance_table[j]) ** 0.5 # Geometric mean the relevances, multiply based on how far it is from 0.5.
            coherence = (sim_table[i, j] ** coherence_weights[0]) * (clust_sim_table[i, j] ** coherence_weights[1])
            weighted_coherence = min(coherence * entity_multiplier * relevance_multiplier, 1.0)
            prob += minedge <= 1 - node_next_vars[str(i) + "_" + str(j)] + weighted_coherence, "Objective" + str(i) + "_" + str(j)
    if verbose:
        print("Objective constraints created.")
        print("--- %s seconds ---" % (time() - start_time))

    if previous_varsdict:
        current_names = [v.name for v in prob.variables() if "node_act" in v.name]
        if verbose:
            print("Generated list of names.")
            print("--- %s seconds ---" % (time() - start_time))
        for k, v in previous_varsdict.items():
            if "node_act" in k and k in current_names:
                node_act_vars[k.replace("node_act_", "")].setInitialValue(v)

    if verbose:
        if previous_varsdict:
            print("Used previous solution as starting point.")
            print("--- %s seconds ---" % (time() - start_time))
        else:
            print("No previous solution available.")
            print("--- %s seconds ---" % (time() - start_time))
    # The problem data is written to an .lp file
    return prob

# %% [markdown]
# ## LP Preprocessing

# %%
def solve_LP_from_query(query, dataset,
    operations=[], K = 6, mincover=0.20,
    min_samples=2, min_cluster_size=2,
    n_neighbors=2, min_dist=0.01,
    sigma_t = 30,
    start_nodes=[], end_nodes=[],
    verbose=True, random_state=42,
    force_cluster=True,
    use_entities=True, use_temporal=True, strict_start=False, umap_init='spectral', cosine_sim = True, use_new_LP=False):

    global start_time
    start_time = time()
    # Min-cluster-size = 10, n_neighbors=2
    doc_list = []
    for index, article in query.iterrows():
        doc_list.append(article['embed'])
    X = np.array(doc_list)

    # Find cluster list
    cluster_dict = {}
    for idx, op in enumerate(operations):
        if "ACL" in op:
            op_ref = op.split(":",1)[1]
            # Remove _out (this case only happens if you mark a story node before adding it to the map.)
            node_set = set([int(node.replace('_out', '')) for node in literal_eval(op_ref.split("-",1)[0])])
            cluster_id = int(op_ref.split("-",1)[1])
            if cluster_id not in cluster_dict:
                cluster_dict[cluster_id] = node_set
            else:
                for key, value in cluster_dict.items():
                    if key != cluster_id:
                        cluster_dict[key] = cluster_dict[key].difference(node_set) # Make sure we only keep the latest interaction.
                cluster_dict[cluster_id] = cluster_dict[cluster_id].union(node_set)
    cluster_list = []
    for key, value in cluster_dict.items():
        cluster_list.append([int(node) for node in value])
    if verbose:
        print("Cluster List (base) " + str(cluster_list))

    clusterable_embedding = umap.UMAP(n_neighbors=n_neighbors,  min_dist=min_dist, init=umap_init, random_state=np.random.RandomState(random_state)).fit_transform(X)
    
    if len(cluster_list) > 0:
        target = -np.ones(X.shape[0])
        for clust_idx, cluster in enumerate(cluster_list):
            target[cluster] = clust_idx
        clusterable_embedding = umap.UMAP(n_neighbors=n_neighbors, min_dist=min_dist, init=umap_init, random_state=np.random.RandomState(random_state)).fit_transform(X, y=target)
    if verbose:
        print("Computed projection.")
        print("--- %s seconds ---" % (time() - start_time))

    if cosine_sim:
        similarities = np.clip(cosine_similarity(clusterable_embedding), -1 , 1)
        # Force normalize
        sim_table = (1 - np.arccos(similarities) / pi)
        mask = np.ones(sim_table.shape, dtype=bool)
        np.fill_diagonal(mask, 0)
        max_value = sim_table[mask].max()
        min_value = sim_table[mask].min()
        sim_table = (sim_table - min_value) / (max_value - min_value)
        sim_table = np.clip(sim_table, 0, 1)
    else:
        dist_mat = distance.cdist(clusterable_embedding, clusterable_embedding, 'euclidean')

        mask = np.ones(dist_mat.shape, dtype=bool)
        np.fill_diagonal(mask, 0)
        max_value = dist_mat[mask].max()
        min_value = dist_mat[mask].min()
        dist_mat = (dist_mat - min_value)/(max_value - min_value)
        sim_table = np.clip(1 - dist_mat, -1, 1)
    if verbose:
        print("Computed similarities.")
        print("--- %s seconds ---" % (time() - start_time))


    hdbscan_model = hdbscan.HDBSCAN(min_samples=min_samples,min_cluster_size=min_cluster_size,prediction_data=True)
    labels = hdbscan_model.fit_predict(clusterable_embedding)
    membership_vectors = hdbscan.prediction.all_points_membership_vectors(hdbscan_model)
    numclust = 1
    clust_sim = np.zeros((membership_vectors.shape[0], membership_vectors.shape[0]))
    if verbose:
        print("Computed clustering.")
        print("--- %s seconds ---" % (time() - start_time))

    if len(membership_vectors.shape) > 1:
        numclust = membership_vectors.shape[1]
        membership_vectors[membership_vectors < 1/numclust] = 0
        #np.set_printoptions(threshold=sys.maxsize)
        # If any row is full of zeros replace with uniform distribution.
        membership_vectors[np.all(membership_vectors == 0, axis=1)] = np.ones(numclust) / numclust
        row_sums = membership_vectors.sum(axis=1)
        membership_vectors = membership_vectors / row_sums[:, np.newaxis]
        clust_sim = distance.cdist(membership_vectors, membership_vectors, lambda u,v:distance.jensenshannon(u,v,base=2.0))
    else:
        membership_vectors = np.ones((membership_vectors.shape[0], 1)) # No clusters special case (all noise according to HDBSCAN)

    clust_sim_table = 1 - clust_sim
    if verbose:
        print("Computed clustering similarities.")
        print("--- %s seconds ---" % (time() - start_time))

    n = len(query.index)
    # Compute temporal distances

    varsdict_filename = 'varsdict_' + dataset  + "_" + str(n) + '.pickle'

    temporal_distance_table = compute_temp_distance_table(query, dataset)

    if sigma_t != 0 and use_temporal:
        exp_temp_table = np.exp(-temporal_distance_table / sigma_t)
    else:
        exp_temp_table = np.ones(temporal_distance_table.shape)

    if verbose:
        print("Computed temporal distance table.")
        print("--- %s seconds ---" % (time() - start_time))

    window_time = None
    if sigma_t != 0 and use_temporal:
        window_time = sigma_t * 3 # Days

    if window_time is None:
        for i in range(0, n):
            window_i_j[i] = list(range(i + 1, n))
        for j in range(0, n):
            window_j_i[j] = list(range(0, j))
    else:
        for j in range(0, n):
            window_j_i[j] = []
        for i in range(0, n):
            window_i_j[i] = []
        for i in range(0, n - 1):
            window = 0
            for j in range(i + 1, n):
                if temporal_distance_table[i,j] <= window_time:
                    window += 1
            window = max(min(5, n - i), window)
            window_i_j[i] = list(range(i + 1, min(i + window, n)))
            for j in window_i_j[i]:
                window_j_i[j].append(i)

    if verbose:
        print("Computed temporal windows.")
        print("--- %s seconds ---" % (time() - start_time))

    ent_table, ent_doc_list = get_entity_table(query, dataset)
    if verbose:
        print("Computed entity similarities.")
        print("--- %s seconds ---" % (time() - start_time))
    if not use_entities:
        ent_table = np.zeros(ent_table.shape)

    # Deprecated relevance table computation
    relevance_table = [1.0] * membership_vectors.shape[0] # Create a vector full of 1s
    focus_query = None
    if focus_query: # Uses focus_query (string)
        #torch.cuda.empty_cache()
        model = SentenceTransformer('all-MiniLM-L6-v2')
        q = model.encode(focus_query)
        q = q.reshape(1, -1)
        euc_dist = distance.cdist(q, X, metric='euclidean')
        euc_dist = (euc_dist - np.min(euc_dist)) / (np.max(euc_dist) - np.min(euc_dist))
        sim_list = 1 - euc_dist
        relevance_table = sim_list[0] # Remove one dimension.
        if verbose:
            print("Computed query relevance table.")
            print("--- %s seconds ---" % (time() - start_time))

    has_start = False
    if start_nodes is not None:
        has_start = (len(start_nodes) > 0)
    if end_nodes is not None:
        has_end = (len(end_nodes) > 0)
    if verbose:
        print("Creating LP...")

    # Read previous solution and feed to LP. If none there is no previous solution.
    previous_varsdict = None
    if os.path.isfile(varsdict_filename):
        with open(varsdict_filename, 'rb') as handle:
            previous_varsdict = pickle.load(handle)
    if use_new_LP:
        prob = new_LP(query, sim_table, membership_vectors, clust_sim_table, exp_temp_table, ent_table, numclust, relevance_table,
            K=K, mincover=mincover, sigma_t=sigma_t,
            operations=operations, cluster_list=cluster_list,
            has_start=has_start, has_end=has_end,
            start_nodes=start_nodes, end_nodes=end_nodes, verbose=verbose, force_cluster=force_cluster)
    else:
        prob = create_LP(query, sim_table, membership_vectors, clust_sim_table, exp_temp_table, ent_table, numclust, relevance_table,
            K=K, mincover=mincover, sigma_t=sigma_t,
            operations=operations, cluster_list=cluster_list,
            has_start=has_start, has_end=has_end,
            start_nodes=start_nodes, end_nodes=end_nodes, verbose=verbose, force_cluster=force_cluster)
    if verbose:
        print("Saving model...")
        print("--- %s seconds ---" % (time() - start_time))
    prob.writeLP("left_story.lp")
    if verbose:
        print("Solving model...")
        print("--- %s seconds ---" % (time() - start_time))
    prob.solve(PULP_CBC_CMD(mip=False, warmStart=True))#(GLPK_CMD(path = 'C:\\glpk-4.65\\w64\\glpsol.exe', options = ["--tmlim", "180"]))


    varsdict = extract_varsdict(prob)
    # Overwrite last solution.
    with open(varsdict_filename, 'wb') as handle:
        pickle.dump(varsdict, handle, protocol=pickle.HIGHEST_PROTOCOL)
    graph_df = build_graph_df_multiple_starts(query, varsdict, prune=ceil(sqrt(K)), threshold=0.1/K, cluster_dict=cluster_dict)
    #graph_df = build_graph_df_multiple_starts(query, varsdict, prune=None, threshold=0.001, cluster_dict=cluster_dict)

    if verbose:
        print("Graph data frame construction...")
        print("--- %s seconds ---" % (time() - start_time))

    if strict_start:
        graph_df = graph_clean_up(graph_df, start_nodes)

    if verbose:
        print("Graph clean up...")
        print("--- %s seconds ---" % (time() - start_time))

    cluster_assignment = np.argmax(membership_vectors, axis=1)
    scatter_df = pd.DataFrame(data=clusterable_embedding, columns=['X', 'Y'])
    scatter_df['id'] = query['id']
    scatter_df['cluster_id'] = cluster_assignment
    scatter_df['cluster_id'] = scatter_df['cluster_id'].astype(str)
    scatter_df['title'] = query['title']

    if verbose:
        print("Scatter data frame construction...")
        print("--- %s seconds ---" % (time() - start_time))

    return [graph_df, (numclust, LpStatus[prob.status]), scatter_df, sim_table, clust_sim_table, ent_table, ent_doc_list, cluster_assignment]

# %% [markdown]
# ## LP Wrapper

# %%
def generate_map(query, dataset, previous_actions=[], k_input=8, mincover_input=20, window=30, start_nodes=[], 
                 verbose=True, random_state=42, force_cluster=False, use_temporal=False, use_entities=False, use_new_LP=False):
    operation_list = []
    for item in previous_actions:
        if item.get("action") == "add-node":
            for node in item['content']:
                operation_list.append("AN:" + node)
        elif item.get("action") == "add-edge":
             operation_list.append("AE:" + item["content"])
        elif item.get("action") == "remove-node":
            for node in item['content']:
                operation_list.append("RN:" + node)
        elif item.get("action") == "remove-edge":
            for edge in item['content']:
                operation_list.append("RE:" + edge)
        elif item.get("action") == "add-cluster-list":
             operation_list.append("ACL:" + str(item['content'][0]) + "-" + str(item['content'][1]))
    
    # Solve LP and create new graph_df.
    cluster_size_est = np.sqrt(len(query.index))/2
    cluster_size_est = 5 * round(cluster_size_est / 5) # Round to nearest multiple of 5
    n_neighbors = 2
    if len(query.index) > 40:
        n_neighbors = 10
    elif len(query.index) > 120:
        n_neighbors = cluster_size_est

    graph_df_new, status, scatter_df, sim_table, clust_sim_table, ent_table, ent_doc_list, cluster_assignment = solve_LP_from_query(query, 
        dataset=dataset, operations=operation_list, 
        K=k_input, mincover=mincover_input/100, 
        min_samples=2, min_cluster_size=cluster_size_est, n_neighbors=n_neighbors, min_dist=1/100,
        start_nodes=start_nodes, verbose=verbose, random_state=random_state, force_cluster=force_cluster,
        use_temporal=use_temporal, use_entities=use_entities, use_new_LP=use_new_LP)        

    status_msg = "LP Status: " + status[1] + ", Clusters: " + str(status[0])

    if 'Optimal' in status[1]:
        # Generate graph from LP solution.
        G = build_graph(graph_df_new)
        storylines = graph_stories(G, start_nodes=start_nodes, end_nodes=[])
        status_msg += ", Storylines: " + str(len(storylines))

        # We now apply transitive reduction.
        remove_list_transitive = []
        for story in storylines:
            max_idx = len(story) - 1
            for idx, node in enumerate(story):
                out_edges = G.out_edges(node)
                # If it's not the last element in the story (no need to clean the last one, because there are no in-story outgoing edges)
                if idx != max_idx:
                    for edge in out_edges:
                        if edge[1] in story and edge[1] != story[idx + 1]: # If it's an in-story edge and not the immediately adjacent one.
                            remove_list_transitive.append(edge)
        G.remove_edges_from(remove_list_transitive)
        # We now filter redundant interstory connections.
        remove_list_interstory = []
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            keep_set = set()
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            if len(edge_boundary_list_i) > 0:
                earliest_i = min(edge_boundary_list_i, key = lambda t: (t[0], t[1]))
                latest_i = max(edge_boundary_list_i, key = lambda t: (t[0], t[1]))
            else:
                earliest_i = None
            if len(edge_boundary_list_j) > 0:
                earliest_j = min(edge_boundary_list_j, key = lambda t: (t[1], t[0]))
                latest_j = max(edge_boundary_list_j, key = lambda t: (t[1], t[0]))
            else:
                earliest_j = None
            if not earliest_i and not earliest_j:
                # No connections
                continue
            elif earliest_i and not earliest_j:
                # One-sided.
                if earliest_i == latest_i: # There's only one connection, keep it.
                    continue
                elif earliest_i[0] == latest_i[0]:
                    # This means that the second values are different, but the first one is the same.
                    # For this special case we keep the earliest one.
                    keep_set.add(earliest_i)
                else:
                    # Keep both
                    keep_set.add(earliest_i)
                    keep_set.add(latest_i)
            elif not earliest_i and earliest_j:
                # One-sided and reversed.
                if earliest_j == latest_j: # There's only one connection, keep it.
                    continue
                elif earliest_j[1] == latest_j[1]:
                    # This means that the first values are different, but the second one is the same.
                    # For this special case we keep the earliest one.
                    keep_set.add(earliest_j)
                else:
                    # Keep both
                    keep_set.add(earliest_j)
                    keep_set.add(latest_j)
            else:
                # Two-sided.
                if earliest_i[0] < earliest_j[1]:
                    # E_i happened first. Keep it
                    keep_set.add(earliest_i)
                    if latest_i[0] > latest_j[1]:
                        # L_i happened last. Keep it.
                        keep_set.add(latest_i)
                    else:
                        keep_set.add(latest_j)
                else:
                    # E_j happened first.
                    keep_set.add(earliest_j)
                    if latest_i[0] > latest_j[1]:
                        # E_i happened last. Keep it.
                        keep_set.add(latest_i)
                    else:
                        keep_set.add(latest_j)
            redundant_edge_set = set(edge_boundary_list_i) | set(edge_boundary_list_j)
            remove_list_interstory += list(redundant_edge_set - keep_set)

        G.remove_edges_from(remove_list_interstory)

        for node in G.nodes:
            sum_node = sum([exp(-data['weight']) for u, v, data in G.out_edges(node, data=True)])
            if sum_node == 0:
                continue
            for u, v, data in G.out_edges(node, data=True):
                G[u][v]['weight'] = -log(exp(-data['weight']) / sum_node)
            sum_node = sum([exp(-G[u][v]['weight']) for u, v, data in G.out_edges(node, data=True)])
        # Update graph_df
        for i, row in graph_df_new.iterrows():
            new_adj_list = [v for u, v in G.out_edges(str(row['id']))]
            new_adj_weights = [exp(-G[u][v]['weight']) for u, v in G.out_edges(str(row['id']))]
            graph_df_new.at[i,'adj_list'] = new_adj_list
            graph_df_new.at[i,'adj_weights'] = new_adj_weights

        for node in G.nodes:  
            sum_node = sum([exp(-data['weight']) for u, v, data in G.out_edges(node, data=True)])
            if sum_node == 0:
                continue
            for u, v, data in G.out_edges(node, data=True):
                G[u][v]['weight'] = -log(exp(-data['weight']) / sum_node)
            sum_node = sum([exp(-data['weight']) for u, v, data in G.out_edges(node, data=True)])

        # Update graph_df
        for i, row in graph_df_new.iterrows():
            new_adj_list = [v for u, v in G.out_edges(str(row['id']))]
            new_adj_weights = [exp(-G[u][v]['weight']) for u, v in G.out_edges(str(row['id']))]
            graph_df_new.at[i,'adj_list'] = new_adj_list
            graph_df_new.at[i,'adj_weights'] = new_adj_weights
            
        #print(graph_df_new)
        return G, graph_df_new, storylines

# %% [markdown]
# ## GraphViz

# %%
def is_path_edge(i, j, val_list):
    k = 0
    while int(val_list[k]) <= int(i):
        if int(val_list[k]) == int(i) and int(val_list[k+1]) == int(j):
            return True
        k += 1
    return False

# %%
def graph_viz_gen(graph_df, sp, full=False, antichains=None):
    col_pol = {'FL': "#021893", 'LL': "#3537ae", 'CM': "#740699", 'LR': "#b70b0b", 'FR': "#990623"}
    transparency = "60" #80 is 50%
    graph_viz_clean = None
    start = int(sp[0])
    end = int(sp[-1])

    graph_viz = "digraph Story { \n" 
    graph_viz += "graph [fontname = \"candara\"];\n"
    graph_viz += "node [shape=none, margin=0, fontname = \"candara\"];\n"
    graph_viz += "edge [fontname = \"calibri light\"];\n"
        
    if antichains is not None:
        graph_viz += "subgraph cluster_antichain { \n"
        graph_viz += "style=filled; color=lightgray; label =<<b>Max Antichain</b>>; labeljust=\"l\"; \n"
        for idx in antichains:
            row = graph_df.loc[graph_df['index'] == idx]
            node_label = '<table><tr><td><b>' + row['publication'].values[0] + '</b></td><td>' + row['date'].values[0] + '</td></tr><tr><td colspan="2">' + row['title'].values[0].replace("\"", "'") + '</td></tr></table>'
            #node_label = "{" + "{" + row['publication'].values[0] + "|" + row['date'].values[0] + "}" + "| " + row['title'].values[0].replace("\"", "'") + "}"
            color = "style=filled, fillcolor=\"" + col_pol['LL'] + transparency + "\""
            color += ", color=black"
            url = row['url'].values[0]
            if pd.isna(url):
                href = "href=\"#\""
            else:
                href = "href=\"" + url + "\""
            tooltip = "tooltip=\"" + row['title'].values[0].replace("\"", "'") + "\""
            #graph_viz += "\"" + str(idx) + "\"" + " [label=\"" + node_label + "\", " + color + "] \n"
            graph_viz += "\"" + str(idx) + "\"" + " [label=<" + node_label + ">, " + color + "," + href + "," + tooltip + "] \n"
        graph_viz += "} \n"
    for index, row in graph_df.iterrows():
        if antichains is not None:
            if row['id'] not in antichains:
                if row['id'] == end or row['id'] == start:
                    node_label = '<table BORDER="2" CELLSPACING="0"><tr><td><b>' + row['publication'] + '</b></td><td>' + row['date'] + '</td></tr><tr><td colspan="2">' + row['title'].replace("\"", "'") + '</td></tr></table>'
                else:
                    node_label = '<table BORDER="0" CELLBORDER="1" CELLSPACING="0"><tr><td><b>' + row['publication'] + '</b></td><td>' + row['date'] + '</td></tr><tr><td colspan="2">' + row['title'].replace("\"", "'") + '</td></tr></table>'
                color = "style=filled, fillcolor=\"" +  col_pol['LL'] + transparency + "\""
                url = row['url']
                if pd.isna(url):
                    href = "href=\"#\""
                else:
                    href = "href=\"" + url + "\""
                tooltip = "tooltip=\"" + row['title'].replace("\"", "'") + "\""
                graph_viz += "\"" + str(row['id']) + "\"" + " [label=<" + node_label + ">, " + color + "," + href + "," + tooltip + "] \n"
        else:
            if row['id'] == end or row['id'] == start:
                node_label = '<table BORDER="2" CELLSPACING="0"><tr><td><b>' + row['publication'] + '</b></td><td>' + row['date'] + '</td></tr><tr><td colspan="2">' + row['title'].replace("\"", "'") + '</td></tr></table>'
                #node_label = "{" + "{" + row['publication'] + "|" + row['date'] + "}" + "| " + row['title'].replace("\"", "'") + "}"
            else:
                node_label = '<table BORDER="0" CELLBORDER="1" CELLSPACING="0"><tr><td><b>' + row['publication'] + '</b></td><td>' + row['date'] + '</td></tr><tr><td colspan="2">' + row['title'].replace("\"", "'") + '</td></tr></table>'
           
            color = "style=filled, fillcolor=\"" +  col_pol['LL'] + transparency + "\""
            url = row['url']
            if pd.isna(url):
                href = "href=\"#\""
            else:
                href = "href=\"" + url + "\""
            tooltip = "tooltip=\"" + row['title'].replace("\"", "'") + "\""
            graph_viz += "\"" + str(row['id']) + "\"" + " [label=<" + node_label + ">, " + color + "," + href + "," + tooltip + "] \n"
               
        # Edges are always added, regardless of previous status.
        for idx, adj in enumerate(row['adj_list']):
            if is_path_edge(row['id'], adj, sp):
                edge_label = "[ label=\"" + str(round(row['adj_weights'][idx],3)) + "\",penwidth=4]"
            else:
                edge_label = "[ label=\"" + str(round(row['adj_weights'][idx],3)) + "\" ]"
            graph_viz += "\"" + str(row['id']) + "\"" + "->" + "\"" + str(adj) + "\"" + edge_label + " \n"

    graph_viz_clean = graph_viz + "}"
        
    return graph_viz_clean

# %% [markdown]
# ## Solve map (basic LP)

# %%
G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=[], verbose=False, random_state=42)

# %%
graph_df['date'] = graph_df['date'].apply(lambda x: x.strftime("%m/%d/%Y"))

# %% [markdown]
# ## Generate Viz

# %%
dot_source = graph_viz_gen(graph_df, sp=storylines[0])
text_file = open("test.js", "w")
temp_js = dot_source.replace("C:/Users/brian/Desktop/StoryChains", "./")
n = text_file.write("dotSrc = `" + temp_js + "`")
text_file.close()
    
graphs = pydot.graph_from_dot_data(dot_source)
svg_string = graphs[0].create_svg()
graphs[0].write_svg('test.svg')  
svg_string = svg_string.replace(b"C:/Users/brian/Desktop/StoryChains/", b"")
svg_cut = svg_string.replace(b'<?xml version="1.0" encoding="UTF-8" standalone="no"?>\r\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\r\n "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\r\n<!-- Generated by graphviz version 2.38.0 (20140413.2041)\r\n -->\r\n<!-- Title: Story Pages: 1 -->\r\n',b'')
svg_cut = svg_string.replace(b'<a xlink:href',b'<a target="_blank" xlink:href')
html_string = b"""<div><style>path:hover{stroke-width:5;stroke:green;transition:0.3s}
            a:hover polygon {
            transition:1.0s;
            fill: #606060!important;
            fill-opacity: 0.2!important;
            opacity: 1.0!important;
            stroke: #646464;
            stroke-width: 1px;
            stroke-linejoin: round;
            }</style></div><div>""" + svg_cut + b"</div>"
with open('test.html', 'wb') as f:
    f.write(html_string)
display(SVG(svg_string))

# %%
# Complexity metrics
n_nodes = G.number_of_nodes()# Number of nodes
n_edges = G.number_of_edges()# Number of edges
n_stories = len(storylines)# Number of storylines
n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
total_interstory = 0
for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
    edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
    edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
    total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
# Number of inter-story connections 
complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
print("Complexity: " + str(complexity_list))
# Out:
# Complexity: [19, 23, 6, 3, 3, 10]

# %% [markdown]
# ## Solve map (newLP)

# %%
G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=[], verbose=False, random_state=42, use_new_LP=True)

# %%
graph_df['date'] = graph_df['date'].apply(lambda x: x.strftime("%m/%d/%Y"))

# %% [markdown]
# ## Generate Viz

# %%
dot_source = graph_viz_gen(graph_df, sp=storylines[0])
text_file = open("test.js", "w")
temp_js = dot_source.replace("C:/Users/brian/Desktop/StoryChains", "./")
n = text_file.write("dotSrc = `" + temp_js + "`")
text_file.close()
    
graphs = pydot.graph_from_dot_data(dot_source)
svg_string = graphs[0].create_svg()
graphs[0].write_svg('test.svg')  
svg_string = svg_string.replace(b"C:/Users/brian/Desktop/StoryChains/", b"")
svg_cut = svg_string.replace(b'<?xml version="1.0" encoding="UTF-8" standalone="no"?>\r\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\r\n "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\r\n<!-- Generated by graphviz version 2.38.0 (20140413.2041)\r\n -->\r\n<!-- Title: Story Pages: 1 -->\r\n',b'')
svg_cut = svg_string.replace(b'<a xlink:href',b'<a target="_blank" xlink:href')
html_string = b"""<div><style>path:hover{stroke-width:5;stroke:green;transition:0.3s}
            a:hover polygon {
            transition:1.0s;
            fill: #606060!important;
            fill-opacity: 0.2!important;
            opacity: 1.0!important;
            stroke: #646464;
            stroke-width: 1px;
            stroke-linejoin: round;
            }</style></div><div>""" + svg_cut + b"</div>"
with open('test.html', 'wb') as f:
    f.write(html_string)
display(SVG(svg_string))

# %%
# Complexity metrics
n_nodes = G.number_of_nodes()# Number of nodes
n_edges = G.number_of_edges()# Number of edges
n_stories = len(storylines)# Number of storylines
n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
total_interstory = 0
for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
    edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
    edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
    total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
# Number of inter-story connections 
complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
print("Complexity: " + str(complexity_list))
# Out:
# Complexity: [15, 18, 4, 2, 2, 7]

# %% [markdown]
# ## Simulation (new LP)

# %%
base_total_samples = 10

# %% [markdown]
# ## Remove Nodes
# ### Removing Nodes from Map (Right-leaning articles only)
# Goal: Remove right-biased news articles from the map. We fix a center starting point from Reuters: "Cuba sees biggest protests for decades as pandemic adds to woes" (Node ID: 124)

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state, use_new_LP=True)
        filter_nodes = graph_df[graph_df.bias == 'Right']
        percent_filter_nodes = len(filter_nodes.index) / len(graph_df.index)
        remove_node_list = [str(node) for node in filter_nodes.id.tolist()]
        remove_node = {"action": "remove-node", "content": remove_node_list}
        previous_actions.append(remove_node)
        percent_list.append(percent_filter_nodes)
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list

    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.42857142857142855 {'action': 'remove-node', 'content': ['23', '35', '36', '49', '56', '76', '112', '132', '136']}
# Complexity: [21, 28, 9, 3, 6, 16]
# Step: 2 0.34782608695652173 {'action': 'remove-node', 'content': ['17', '40', '51', '52', '54', '58', '96', '127']}
# Complexity: [23, 31, 9, 4, 5, 17]
# Step: 3 0.05555555555555555 {'action': 'remove-node', 'content': ['31']}
# Complexity: [18, 22, 6, 4, 2, 10]
# Step: 4 0.05263157894736842 {'action': 'remove-node', 'content': ['150']}
# Complexity: [19, 25, 7, 4, 3, 13]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 23, 5, 3, 2, 8]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.28 {'action': 'remove-node', 'content': ['22', '45', '47', '54', '71', '89', '127']}
# Complexity: [25, 33, 10, 5, 5, 18]
# Step: 2 0.2857142857142857 {'action': 'remove-node', 'content': ['18', '52', '53', '59', '64', '66']}
# Complexity: [21, 26, 10, 4, 6, 15]
# Step: 3 0.2857142857142857 {'action': 'remove-node', 'content': ['16', '35', '44', '56', '93', '136']}
# Complexity: [21, 26, 13, 3, 10, 18]
# Step: 4 0.08695652173913043 {'action': 'remove-node', 'content': ['28', '36']}
# Complexity: [23, 28, 12, 4, 8, 17]
# Step: 5 0.09090909090909091 {'action': 'remove-node', 'content': ['23', '73']}
# Complexity: [22, 29, 12, 3, 9, 19]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 25, 8, 5, 3, 13]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.34782608695652173 {'action': 'remove-node', 'content': ['22', '23', '36', '49', '64', '66', '76', '127']}
# Complexity: [23, 29, 8, 4, 4, 14]
# Step: 2 0.36 {'action': 'remove-node', 'content': ['35', '40', '45', '51', '54', '69', '89', '95', '132']}
# Complexity: [25, 29, 7, 4, 3, 11]
# Step: 3 0.14285714285714285 {'action': 'remove-node', 'content': ['52', '58', '150']}
# Complexity: [21, 25, 7, 3, 4, 11]
# Step: 4 0.043478260869565216 {'action': 'remove-node', 'content': ['28']}
# Complexity: [23, 26, 6, 3, 3, 9]
# Step: 5 0.041666666666666664 {'action': 'remove-node', 'content': ['73']}
# Complexity: [24, 30, 9, 2, 7, 15]
# Step: 6 0.08695652173913043 {'action': 'remove-node', 'content': ['59', '84']}
# Complexity: [23, 29, 9, 3, 6, 15]
# Step: 7 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 25, 7, 3, 4, 12]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.42857142857142855 {'action': 'remove-node', 'content': ['36', '45', '49', '58', '69', '89', '103', '132', '136']}
# Complexity: [21, 24, 7, 4, 3, 10]
# Step: 2 0.22727272727272727 {'action': 'remove-node', 'content': ['16', '17', '18', '72', '134']}
# Complexity: [22, 26, 8, 3, 5, 12]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 20, 5, 3, 2, 6]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.2631578947368421 {'action': 'remove-node', 'content': ['35', '40', '53', '59', '127']}
# Complexity: [19, 25, 9, 4, 5, 15]
# Step: 2 0.47368421052631576 {'action': 'remove-node', 'content': ['18', '47', '66', '73', '93', '104', '129', '131', '132']}
# Complexity: [19, 21, 7, 5, 2, 9]
# Step: 3 0.2857142857142857 {'action': 'remove-node', 'content': ['69', '76', '84', '108', '112', '150']}
# Complexity: [21, 23, 9, 4, 5, 11]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 21, 6, 3, 3, 9]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.38095238095238093 {'action': 'remove-node', 'content': ['19', '36', '47', '56', '64', '66', '104', '108']}
# Complexity: [21, 29, 7, 5, 2, 15]
# Step: 2 0.16666666666666666 {'action': 'remove-node', 'content': ['35', '54', '69', '150']}
# Complexity: [24, 30, 9, 4, 5, 15]
# Step: 3 0.22727272727272727 {'action': 'remove-node', 'content': ['17', '76', '127', '129', '132']}
# Complexity: [22, 25, 9, 4, 5, 12]
# Step: 4 0.08695652173913043 {'action': 'remove-node', 'content': ['84', '133']}
# Complexity: [23, 24, 10, 5, 5, 11]
# Step: 5 0.041666666666666664 {'action': 'remove-node', 'content': ['53']}
# Complexity: [24, 29, 11, 4, 7, 16]
# Step: 6 0.09090909090909091 {'action': 'remove-node', 'content': ['18', '146']}
# Complexity: [22, 25, 7, 4, 3, 10]
# Step: 7 0.08695652173913043 {'action': 'remove-node', 'content': ['45', '136']}
# Complexity: [23, 27, 9, 5, 4, 13]
# Step: 8 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [24, 27, 10, 4, 6, 13]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.36363636363636365 {'action': 'remove-node', 'content': ['35', '36', '45', '47', '54', '71', '127', '134']}
# Complexity: [22, 29, 7, 4, 3, 14]
# Step: 2 0.2916666666666667 {'action': 'remove-node', 'content': ['49', '51', '52', '66', '69', '76', '136']}
# Complexity: [24, 28, 9, 7, 2, 13]
# Step: 3 0.19047619047619047 {'action': 'remove-node', 'content': ['18', '40', '59', '73']}
# Complexity: [21, 27, 10, 4, 6, 16]
# Step: 4 0.13636363636363635 {'action': 'remove-node', 'content': ['56', '96', '116']}
# Complexity: [22, 28, 10, 3, 7, 16]
# Step: 5 0.043478260869565216 {'action': 'remove-node', 'content': ['129']}
# Complexity: [23, 29, 9, 6, 3, 15]
# Step: 6 0.09523809523809523 {'action': 'remove-node', 'content': ['44', '146']}
# Complexity: [21, 25, 7, 4, 3, 11]
# Step: 7 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 23, 8, 5, 3, 11]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.36363636363636365 {'action': 'remove-node', 'content': ['18', '31', '36', '47', '49', '84', '103', '127']}
# Complexity: [22, 26, 6, 5, 1, 10]
# Step: 2 0.14285714285714285 {'action': 'remove-node', 'content': ['19', '35', '54']}
# Complexity: [21, 23, 7, 6, 1, 9]
# Step: 3 0.13636363636363635 {'action': 'remove-node', 'content': ['40', '59', '73']}
# Complexity: [22, 26, 6, 3, 3, 10]
# Step: 4 0.05 {'action': 'remove-node', 'content': ['132']}
# Complexity: [20, 24, 5, 4, 1, 9]
# Step: 5 0.13043478260869565 {'action': 'remove-node', 'content': ['17', '45', '96']}
# Complexity: [23, 28, 8, 5, 3, 13]
# Step: 6 0.047619047619047616 {'action': 'remove-node', 'content': ['104']}
# Complexity: [21, 25, 7, 3, 4, 11]
# Step: 7 0.09090909090909091 {'action': 'remove-node', 'content': ['66', '131']}
# Complexity: [22, 28, 9, 6, 3, 15]
# Step: 8 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [22, 27, 5, 5, 0, 10]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.4090909090909091 {'action': 'remove-node', 'content': ['21', '31', '45', '53', '58', '84', '89', '118', '134']}
# Complexity: [22, 27, 7, 4, 3, 12]
# Step: 2 0.25 {'action': 'remove-node', 'content': ['35', '49', '127', '129', '136']}
# Complexity: [20, 23, 8, 3, 5, 11]
# Step: 3 0.1 {'action': 'remove-node', 'content': ['17', '72']}
# Complexity: [20, 24, 9, 2, 7, 13]
# Step: 4 0.13636363636363635 {'action': 'remove-node', 'content': ['16', '28', '76']}
# Complexity: [22, 28, 8, 4, 4, 14]
# Step: 5 0.125 {'action': 'remove-node', 'content': ['40', '54', '112']}
# Complexity: [24, 29, 9, 4, 5, 14]
# Step: 6 0.047619047619047616 {'action': 'remove-node', 'content': ['32']}
# Complexity: [21, 25, 8, 3, 5, 12]
# Step: 7 0.09523809523809523 {'action': 'remove-node', 'content': ['36', '66']}
# Complexity: [21, 27, 10, 3, 7, 16]
# Step: 8 0.09523809523809523 {'action': 'remove-node', 'content': ['51', '150']}
# Complexity: [21, 25, 9, 3, 6, 13]
# Step: 9 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [23, 28, 11, 4, 7, 16]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.18518518518518517 {'action': 'remove-node', 'content': ['36', '53', '84', '127', '146']}
# Complexity: [27, 34, 8, 5, 3, 15]
# Step: 2 0.25 {'action': 'remove-node', 'content': ['35', '45', '96', '103', '134']}
# Complexity: [20, 26, 8, 3, 5, 14]
# Step: 3 0.08695652173913043 {'action': 'remove-node', 'content': ['18', '89']}
# Complexity: [23, 27, 6, 6, 0, 10]
# Step: 4 0.05 {'action': 'remove-node', 'content': ['40']}
# Complexity: [20, 27, 7, 6, 1, 14]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [22, 26, 8, 4, 4, 12]

# %%
results_delete_right = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_delete_right.json', 'w') as fp:
    json.dump(results_delete_right, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Fox and Breitbart only

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state, use_new_LP=True)
        filter_nodes = graph_df[graph_df['url'].str.contains('foxnews') | graph_df['url'].str.contains('breitbart')]
        percent_filter_nodes = len(filter_nodes.index) / len(graph_df.index)
        remove_node_list = [str(node) for node in filter_nodes.id.tolist()]
        remove_node = {"action": "remove-node", "content": remove_node_list}
        previous_actions.append(remove_node)
        percent_list.append(percent_filter_nodes)
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.38095238095238093 {'action': 'remove-node', 'content': ['23', '35', '36', '49', '56', '112', '132', '136']}
# Complexity: [21, 28, 9, 3, 6, 16]
# Step: 2 0.30434782608695654 {'action': 'remove-node', 'content': ['40', '51', '52', '54', '58', '103', '127']}
# Complexity: [23, 28, 7, 5, 2, 12]
# Step: 3 0.05263157894736842 {'action': 'remove-node', 'content': ['150']}
# Complexity: [19, 24, 7, 4, 3, 12]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 25, 7, 5, 2, 13]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.2 {'action': 'remove-node', 'content': ['45', '47', '54', '71', '127']}
# Complexity: [25, 33, 10, 5, 5, 18]
# Step: 2 0.2857142857142857 {'action': 'remove-node', 'content': ['18', '23', '36', '51', '66', '136']}
# Complexity: [21, 26, 9, 5, 4, 14]
# Step: 3 0.047619047619047616 {'action': 'remove-node', 'content': ['72']}
# Complexity: [21, 28, 11, 4, 7, 18]
# Step: 4 0.05 {'action': 'remove-node', 'content': ['40']}
# Complexity: [20, 25, 10, 3, 7, 15]
# Step: 5 0.17391304347826086 {'action': 'remove-node', 'content': ['52', '58', '59', '64']}
# Complexity: [23, 28, 10, 4, 6, 15]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 26, 8, 4, 4, 14]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.2608695652173913 {'action': 'remove-node', 'content': ['23', '36', '49', '64', '66', '127']}
# Complexity: [23, 29, 8, 4, 4, 14]
# Step: 2 0.2608695652173913 {'action': 'remove-node', 'content': ['35', '45', '51', '52', '69', '132']}
# Complexity: [23, 27, 8, 4, 4, 12]
# Step: 3 0.15 {'action': 'remove-node', 'content': ['58', '72', '129']}
# Complexity: [20, 25, 7, 4, 3, 12]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [21, 25, 7, 4, 3, 11]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.38095238095238093 {'action': 'remove-node', 'content': ['36', '45', '49', '58', '69', '103', '132', '136']}
# Complexity: [21, 24, 7, 4, 3, 10]
# Step: 2 0.045454545454545456 {'action': 'remove-node', 'content': ['18']}
# Complexity: [22, 27, 9, 3, 6, 14]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 21, 6, 4, 2, 8]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.21052631578947367 {'action': 'remove-node', 'content': ['35', '40', '59', '127']}
# Complexity: [19, 25, 9, 4, 5, 15]
# Step: 2 0.25 {'action': 'remove-node', 'content': ['28', '56', '84', '112', '132']}
# Complexity: [20, 25, 10, 3, 7, 15]
# Step: 3 0.10526315789473684 {'action': 'remove-node', 'content': ['58', '136']}
# Complexity: [19, 24, 10, 4, 6, 15]
# Step: 4 0.15789473684210525 {'action': 'remove-node', 'content': ['18', '47', '104']}
# Complexity: [19, 24, 10, 3, 7, 15]
# Step: 5 0.1875 {'action': 'remove-node', 'content': ['108', '116', '129']}
# Complexity: [16, 20, 7, 3, 4, 11]
# Step: 6 0.10526315789473684 {'action': 'remove-node', 'content': ['69', '150']}
# Complexity: [19, 24, 10, 2, 8, 15]
# Step: 7 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 23, 10, 3, 7, 14]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.38095238095238093 {'action': 'remove-node', 'content': ['19', '36', '47', '56', '64', '66', '104', '108']}
# Complexity: [21, 29, 7, 5, 2, 15]
# Step: 2 0.16666666666666666 {'action': 'remove-node', 'content': ['35', '54', '69', '150']}
# Complexity: [24, 30, 9, 4, 5, 15]
# Step: 3 0.13636363636363635 {'action': 'remove-node', 'content': ['127', '129', '132']}
# Complexity: [22, 25, 9, 4, 5, 12]
# Step: 4 0.09090909090909091 {'action': 'remove-node', 'content': ['59', '84']}
# Complexity: [22, 24, 8, 4, 4, 10]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [24, 25, 8, 5, 3, 9]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.3181818181818182 {'action': 'remove-node', 'content': ['35', '36', '45', '47', '54', '71', '127']}
# Complexity: [22, 29, 7, 4, 3, 14]
# Step: 2 0.08695652173913043 {'action': 'remove-node', 'content': ['51', '136']}
# Complexity: [23, 28, 8, 3, 5, 13]
# Step: 3 0.09523809523809523 {'action': 'remove-node', 'content': ['56', '116']}
# Complexity: [21, 28, 8, 5, 3, 15]
# Step: 4 0.1 {'action': 'remove-node', 'content': ['40', '129']}
# Complexity: [20, 25, 10, 4, 6, 15]
# Step: 5 0.041666666666666664 {'action': 'remove-node', 'content': ['44']}
# Complexity: [24, 29, 11, 4, 7, 16]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 26, 9, 4, 5, 15]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.3181818181818182 {'action': 'remove-node', 'content': ['18', '36', '47', '49', '84', '103', '127']}
# Complexity: [22, 26, 6, 5, 1, 10]
# Step: 2 0.20833333333333334 {'action': 'remove-node', 'content': ['19', '66', '69', '132', '150']}
# Complexity: [24, 28, 9, 4, 5, 13]
# Step: 3 0.1 {'action': 'remove-node', 'content': ['40', '59']}
# Complexity: [20, 24, 8, 3, 5, 12]
# Step: 4 0.045454545454545456 {'action': 'remove-node', 'content': ['54']}
# Complexity: [22, 27, 8, 3, 5, 13]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 25, 9, 3, 6, 14]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.18181818181818182 {'action': 'remove-node', 'content': ['21', '45', '58', '84']}
# Complexity: [22, 27, 7, 4, 3, 12]
# Step: 2 0.14285714285714285 {'action': 'remove-node', 'content': ['35', '49', '127']}
# Complexity: [21, 25, 5, 3, 2, 9]
# Step: 3 0.13043478260869565 {'action': 'remove-node', 'content': ['52', '59', '66']}
# Complexity: [23, 26, 7, 4, 3, 10]
# Step: 4 0.045454545454545456 {'action': 'remove-node', 'content': ['26']}
# Complexity: [22, 28, 9, 5, 4, 15]
# Step: 5 0.15384615384615385 {'action': 'remove-node', 'content': ['23', '51', '54', '112']}
# Complexity: [26, 30, 8, 6, 2, 12]
# Step: 6 0.041666666666666664 {'action': 'remove-node', 'content': ['40']}
# Complexity: [24, 29, 9, 5, 4, 14]
# Step: 7 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 23, 7, 3, 4, 10]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.1111111111111111 {'action': 'remove-node', 'content': ['36', '84', '127']}
# Complexity: [27, 34, 8, 5, 3, 15]
# Step: 2 0.1111111111111111 {'action': 'remove-node', 'content': ['18', '45']}
# Complexity: [18, 23, 6, 3, 3, 11]
# Step: 3 0.09090909090909091 {'action': 'remove-node', 'content': ['35', '93']}
# Complexity: [22, 27, 7, 3, 4, 12]
# Step: 4 0.09523809523809523 {'action': 'remove-node', 'content': ['51', '72']}
# Complexity: [21, 22, 6, 3, 3, 7]
# Step: 5 0.05263157894736842 {'action': 'remove-node', 'content': ['58']}
# Complexity: [19, 20, 6, 2, 4, 7]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [22, 27, 8, 3, 5, 13]

# %%
results_delete_right = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_delete_fox_bb.json', 'w') as fp:
    json.dump(results_delete_right, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Removing Miami + Florida references
# There's 39 after the protests start.

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
i = 0
total_samples = base_total_samples
while i < total_samples:
    drop = False
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, 
                                               verbose=False, random_state=random_state, force_cluster=False, use_new_LP=True)
        filter_nodes = graph_df[graph_df.title.str.contains('miami', case=False) | 
                                   graph_df.title.str.contains('florida', case=False)]
        percent_filter_nodes = len(filter_nodes.index) / len(graph_df.index)
        remove_node_list = [str(node) for node in filter_nodes.id.tolist()]
        remove_node = {"action": "remove-node", "content": remove_node_list}
        previous_actions.append(remove_node)
        percent_list.append(percent_filter_nodes)
        if percent_filter_nodes == 0 and inner_iter_count == 0: # first iteration has no miami/florida nodes. 
            drop = True
            total_samples += 1
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    i += 1
    for action in previous_actions:
        actions += action['content']
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.23809523809523808 {'action': 'remove-node', 'content': ['35', '36', '49', '56', '87']}
# Complexity: [21, 28, 9, 3, 6, 16]
# Step: 2 0.13043478260869565 {'action': 'remove-node', 'content': ['38', '40', '51']}
# Complexity: [23, 29, 11, 4, 7, 17]
# Step: 3 0.09090909090909091 {'action': 'remove-node', 'content': ['41', '97']}
# Complexity: [22, 26, 10, 5, 5, 14]
# Step: 4 0.14285714285714285 {'action': 'remove-node', 'content': ['58', '63', '140']}
# Complexity: [21, 26, 8, 3, 5, 13]
# Step: 5 0.08695652173913043 {'action': 'remove-node', 'content': ['46', '88']}
# Complexity: [23, 27, 9, 5, 4, 13]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 27, 10, 5, 5, 17]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.04 {'action': 'remove-node', 'content': ['63']}
# Complexity: [25, 33, 10, 5, 5, 18]
# Step: 2 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [24, 29, 10, 4, 6, 15]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.13043478260869565 {'action': 'remove-node', 'content': ['36', '49', '87']}
# Complexity: [23, 29, 8, 4, 4, 14]
# Step: 2 0.125 {'action': 'remove-node', 'content': ['35', '51', '88']}
# Complexity: [24, 29, 8, 4, 4, 13]
# Step: 3 0.17391304347826086 {'action': 'remove-node', 'content': ['38', '53', '68', '140']}
# Complexity: [23, 28, 8, 3, 5, 13]
# Step: 4 0.045454545454545456 {'action': 'remove-node', 'content': ['40']}
# Complexity: [22, 26, 7, 2, 5, 11]
# Step: 5 0.08333333333333333 {'action': 'remove-node', 'content': ['41', '63']}
# Complexity: [24, 30, 9, 5, 4, 15]
# Step: 6 0.08695652173913043 {'action': 'remove-node', 'content': ['58', '97']}
# Complexity: [23, 29, 8, 5, 3, 14]
# Step: 7 0.037037037037037035 {'action': 'remove-node', 'content': ['122']}
# Complexity: [27, 33, 12, 5, 7, 18]
# Step: 8 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [22, 25, 7, 3, 4, 10]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.19047619047619047 {'action': 'remove-node', 'content': ['36', '49', '58', '63']}
# Complexity: [21, 24, 7, 4, 3, 10]
# Step: 2 0.045454545454545456 {'action': 'remove-node', 'content': ['126']}
# Complexity: [22, 28, 10, 5, 5, 16]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 21, 7, 3, 4, 10]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.3157894736842105 {'action': 'remove-node', 'content': ['35', '40', '53', '87', '94', '126']}
# Complexity: [19, 25, 9, 4, 5, 15]
# Step: 2 0.1111111111111111 {'action': 'remove-node', 'content': ['97', '140']}
# Complexity: [18, 23, 10, 2, 8, 15]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [21, 25, 9, 3, 6, 13]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.19047619047619047 {'action': 'remove-node', 'content': ['36', '56', '63', '140']}
# Complexity: [21, 29, 7, 5, 2, 15]
# Step: 2 0.041666666666666664 {'action': 'remove-node', 'content': ['35']}
# Complexity: [24, 29, 7, 6, 1, 12]
# Step: 3 0.041666666666666664 {'action': 'remove-node', 'content': ['53']}
# Complexity: [24, 30, 10, 5, 5, 16]
# Step: 4 0.041666666666666664 {'action': 'remove-node', 'content': ['40']}
# Complexity: [24, 32, 11, 5, 6, 19]
# Step: 5 0.05263157894736842 {'action': 'remove-node', 'content': ['41']}
# Complexity: [19, 24, 9, 4, 5, 14]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [22, 27, 8, 5, 3, 13]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.18181818181818182 {'action': 'remove-node', 'content': ['35', '36', '68', '88']}
# Complexity: [22, 29, 7, 4, 3, 14]
# Step: 2 0.12 {'action': 'remove-node', 'content': ['51', '56', '63']}
# Complexity: [25, 32, 9, 6, 3, 16]
# Step: 3 0.04 {'action': 'remove-node', 'content': ['38']}
# Complexity: [25, 31, 11, 7, 4, 17]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [21, 27, 7, 4, 3, 13]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.13636363636363635 {'action': 'remove-node', 'content': ['36', '49', '63']}
# Complexity: [22, 26, 6, 5, 1, 10]
# Step: 2 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [26, 33, 8, 4, 4, 15]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.09090909090909091 {'action': 'remove-node', 'content': ['53', '58']}
# Complexity: [22, 27, 7, 4, 3, 12]
# Step: 2 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [21, 26, 9, 4, 5, 14]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.2222222222222222 {'action': 'remove-node', 'content': ['36', '53', '63', '87', '97', '122']}
# Complexity: [27, 34, 8, 5, 3, 15]
# Step: 2 0.045454545454545456 {'action': 'remove-node', 'content': ['126']}
# Complexity: [22, 29, 11, 4, 7, 18]
# Step: 3 0.08333333333333333 {'action': 'remove-node', 'content': ['35', '94']}
# Complexity: [24, 30, 10, 6, 4, 16]
# Step: 4 0.038461538461538464 {'action': 'remove-node', 'content': ['88']}
# Complexity: [26, 29, 9, 6, 3, 12]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [22, 27, 9, 5, 4, 14]

# %%
results_delete_florida = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_delete_florida.json', 'w') as fp:
    json.dump(results_delete_florida, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Remove Edges
# ### Remove Inconsistent Edges
# Goal: Remove right-biased news articles from the map. We use the same starting point from before.

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_edges = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_edges > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state, use_new_LP=True)
        edges = list(G.edges())
        filter_edges = []
        for node_i, node_j in edges:
            bias_i = graph_df.loc[graph_df['id'] == int(node_i)].iloc[0]['bias']
            bias_j = graph_df.loc[graph_df['id'] == int(node_j)].iloc[0]['bias']
            if (bias_i == 'Right' and bias_j == 'Left') or (bias_i == 'Left' and bias_j == 'Right'):
                filter_edges.append((node_i, node_j))
        remove_edge_list = [node_i + "-" + node_j for node_i, node_j in filter_edges]
        percent_filter_edges = len(filter_edges) / len(edges)
        
        remove_edge = {"action": "remove-edge", "content": remove_edge_list}
        previous_actions.append(remove_edge)
        percent_list.append(percent_filter_edges)
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_edges, remove_edge)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.32142857142857145 {'action': 'remove-edge', 'content': ['11-36', '36-87', '36-50', '87-132', '50-56', '49-77', '76-77', '77-112', '124-132']}
# Complexity: [21, 28, 9, 3, 6, 16]
# Step: 2 0.14814814814814814 {'action': 'remove-edge', 'content': ['90-132', '49-65', '86-127', '127-138']}
# Complexity: [22, 27, 7, 3, 4, 12]
# Step: 3 0.03571428571428571 {'action': 'remove-edge', 'content': ['132-138']}
# Complexity: [23, 28, 12, 5, 7, 17]
# Step: 4 0.1 {'action': 'remove-edge', 'content': ['36-65', '77-133', '86-132']}
# Complexity: [24, 30, 12, 6, 6, 18]
# Step: 5 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [23, 28, 12, 6, 6, 17]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.30303030303030304 {'action': 'remove-edge', 'content': ['33-54', '11-22', '11-45', '11-47', '45-48', '89-91', '61-71', '67-71', '91-127', '127-138']}
# Complexity: [25, 33, 10, 5, 5, 18]
# Step: 2 0.1724137931034483 {'action': 'remove-edge', 'content': ['11-71', '33-35', '33-47', '47-48', '127-135']}
# Complexity: [23, 29, 8, 4, 4, 14]
# Step: 3 0.21428571428571427 {'action': 'remove-edge', 'content': ['11-18', '33-59', '18-48', '89-90', '83-89', '90-127']}
# Complexity: [23, 28, 6, 4, 2, 11]
# Step: 4 0.10714285714285714 {'action': 'remove-edge', 'content': ['48-59', '71-83', '83-127']}
# Complexity: [21, 28, 9, 4, 5, 16]
# Step: 5 0.037037037037037035 {'action': 'remove-edge', 'content': ['33-66']}
# Complexity: [21, 27, 6, 4, 2, 12]
# Step: 6 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [23, 29, 8, 4, 4, 14]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.27586206896551724 {'action': 'remove-edge', 'content': ['20-23', '11-22', '33-49', '36-39', '39-49', '66-87', '76-77', '90-127']}
# Complexity: [23, 29, 8, 4, 4, 14]
# Step: 2 0.125 {'action': 'remove-edge', 'content': ['20-22', '33-36', '36-87']}
# Complexity: [21, 24, 5, 4, 1, 8]
# Step: 3 0.12121212121212122 {'action': 'remove-edge', 'content': ['11-36', '66-83', '33-35', '65-66']}
# Complexity: [26, 33, 11, 5, 6, 18]
# Step: 4 0.07407407407407407 {'action': 'remove-edge', 'content': ['11-23', '33-40']}
# Complexity: [23, 27, 8, 3, 5, 12]
# Step: 5 0.09375 {'action': 'remove-edge', 'content': ['12-36', '33-136', '77-84']}
# Complexity: [26, 32, 9, 5, 4, 15]
# Step: 6 0.03571428571428571 {'action': 'remove-edge', 'content': ['20-36']}
# Complexity: [23, 28, 7, 5, 2, 12]
# Step: 7 0.06896551724137931 {'action': 'remove-edge', 'content': ['11-16', '20-28']}
# Complexity: [25, 29, 9, 5, 4, 13]
# Step: 8 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [26, 34, 10, 5, 5, 18]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.125 {'action': 'remove-edge', 'content': ['11-36', '89-90', '103-135']}
# Complexity: [21, 24, 7, 4, 3, 10]
# Step: 2 0.125 {'action': 'remove-edge', 'content': ['11-16', '72-83', '134-135']}
# Complexity: [20, 24, 7, 4, 3, 11]
# Step: 3 0.16 {'action': 'remove-edge', 'content': ['27-58', '11-58', '69-86', '124-136']}
# Complexity: [22, 25, 7, 3, 4, 10]
# Step: 4 0.07692307692307693 {'action': 'remove-edge', 'content': ['36-86', '124-132']}
# Complexity: [23, 26, 7, 4, 3, 10]
# Step: 5 0.03571428571428571 {'action': 'remove-edge', 'content': ['11-89']}
# Complexity: [23, 28, 7, 3, 4, 12]
# Step: 6 0.03225806451612903 {'action': 'remove-edge', 'content': ['72-90']}
# Complexity: [24, 31, 10, 4, 6, 17]
# Step: 7 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [19, 25, 7, 4, 3, 13]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.24 {'action': 'remove-edge', 'content': ['53-87', '11-35', '35-50', '27-35', '50-53', '59-65']}
# Complexity: [19, 25, 9, 4, 5, 15]
# Step: 2 0.05 {'action': 'remove-edge', 'content': ['53-107']}
# Complexity: [15, 20, 7, 3, 4, 12]
# Step: 3 0.043478260869565216 {'action': 'remove-edge', 'content': ['53-91']}
# Complexity: [18, 23, 8, 4, 4, 13]
# Step: 4 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [16, 21, 8, 3, 5, 13]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.1724137931034483 {'action': 'remove-edge', 'content': ['11-19', '11-47', '19-27', '27-36', '27-47']}
# Complexity: [21, 29, 7, 5, 2, 15]
# Step: 2 0.07142857142857142 {'action': 'remove-edge', 'content': ['11-54', '36-67']}
# Complexity: [23, 28, 7, 5, 2, 12]
# Step: 3 0.03571428571428571 {'action': 'remove-edge', 'content': ['27-54']}
# Complexity: [22, 28, 6, 4, 2, 12]
# Step: 4 0.037037037037037035 {'action': 'remove-edge', 'content': ['27-66']}
# Complexity: [22, 27, 7, 4, 3, 12]
# Step: 5 0.13043478260869565 {'action': 'remove-edge', 'content': ['11-66', '36-48', '66-113']}
# Complexity: [21, 23, 4, 2, 2, 6]
# Step: 6 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [21, 25, 8, 3, 5, 12]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.13793103448275862 {'action': 'remove-edge', 'content': ['11-47', '33-35', '36-43', '43-71']}
# Complexity: [22, 29, 7, 4, 3, 14]
# Step: 2 0.15151515151515152 {'action': 'remove-edge', 'content': ['11-36', '34-35', '89-113', '127-138', '124-127']}
# Complexity: [27, 33, 8, 6, 2, 14]
# Step: 3 0.1111111111111111 {'action': 'remove-edge', 'content': ['33-54', '89-90', '113-127']}
# Complexity: [23, 27, 5, 4, 1, 9]
# Step: 4 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [26, 33, 7, 6, 1, 14]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.11538461538461539 {'action': 'remove-edge', 'content': ['11-36', '33-84', '127-138']}
# Complexity: [22, 26, 6, 5, 1, 10]
# Step: 2 0.03225806451612903 {'action': 'remove-edge', 'content': ['11-47']}
# Complexity: [23, 31, 8, 3, 5, 16]
# Step: 3 0.11428571428571428 {'action': 'remove-edge', 'content': ['33-49', '47-61', '61-84', '90-127']}
# Complexity: [28, 35, 8, 4, 4, 15]
# Step: 4 0.029411764705882353 {'action': 'remove-edge', 'content': ['34-36']}
# Complexity: [27, 34, 8, 5, 3, 15]
# Step: 5 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [25, 31, 7, 4, 3, 13]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.25925925925925924 {'action': 'remove-edge', 'content': ['11-21', '11-31', '21-27', '31-34', '27-45', '34-84', '89-90']}
# Complexity: [22, 27, 7, 4, 3, 12]
# Step: 2 0.07692307692307693 {'action': 'remove-edge', 'content': ['101-127', '27-31']}
# Complexity: [21, 26, 8, 4, 4, 13]
# Step: 3 0.03225806451612903 {'action': 'remove-edge', 'content': ['127-138']}
# Complexity: [25, 31, 9, 5, 4, 15]
# Step: 4 0.07407407407407407 {'action': 'remove-edge', 'content': ['11-45', '84-138']}
# Complexity: [22, 27, 7, 4, 3, 12]
# Step: 5 0.038461538461538464 {'action': 'remove-edge', 'content': ['83-84']}
# Complexity: [22, 26, 6, 3, 3, 10]
# Step: 6 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [26, 30, 8, 4, 4, 12]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.20588235294117646 {'action': 'remove-edge', 'content': ['11-36', '33-53', '36-86', '84-86', '117-146', '113-127', '144-146']}
# Complexity: [27, 34, 8, 5, 3, 15]
# Step: 2 0.08 {'action': 'remove-edge', 'content': ['86-93', '107-118']}
# Complexity: [22, 25, 5, 3, 2, 8]
# Step: 3 0.06451612903225806 {'action': 'remove-edge', 'content': ['11-28', '53-86']}
# Complexity: [24, 31, 9, 5, 4, 16]
# Step: 4 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [24, 29, 7, 4, 3, 12]

# %%
results_delete_edges = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_delete_edges.json', 'w') as fp:
    json.dump(results_delete_edges, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Add Edges + Remove Edges
# ### Make Storylines Consistent (Starting from "Center" Storyline)

# %%
from collections import Counter
def most_common(lst):
    # Exclude local and center.
    lst[:] = [x for x in lst if x != 'Center' and x != 'Local']
    if len(lst) == 0:
        return None
    data = Counter(lst)
    return max(lst, key=data.get)

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples

for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list_nodes = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state, use_new_LP=True)
        nodes = list(G.nodes())
        remove_node_list = []
        add_edges = []
        #print("Storylines: " + str(storylines))
        for story in storylines:
            #print("Current story: " + str(story))
            story_biases = [graph_df.loc[graph_df['id'] == int(story_node)].iloc[0]['bias'] for story_node in story]
            story_bias = most_common(story_biases)
            opposite_bias = None
            if story_bias == 'Left':
                opposite_bias = 'Right'
            else:
                opposite_bias = 'Left'
            skip_count = 0
            mark = None
            if opposite_bias is not None:
                for node in story:
                    bias = graph_df.loc[graph_df['id'] == int(node)].iloc[0]['bias']
                    if mark is not None and skip_count > 0 and bias != opposite_bias:
                        add_edge = {"action": "add-edge", "content": str(mark) + "-" + str(node)} # String of edge id
                        add_edges.append(str(mark) + "-" + str(node))
                        previous_actions.append(add_edge)
                        mark = node
                        skip_count = 0
                    if bias != opposite_bias:
                        mark = node
                    else:
                        remove_node_list.append(node)
                        skip_count += 1            
        remove_node = {"action": "remove-node", "content": remove_node_list}
        for node in remove_node_list:
            previous_actions[:] = [action for action in previous_actions if not (action['action'] == 'add-edge' and str(node) in action['content'].split("-"))]
        previous_actions.append(remove_node)                
        percent_filter_nodes = len(remove_node_list) / len(nodes)              
        percent_list_nodes.append(percent_filter_nodes)
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node, "add-edge: " + str(add_edges))
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    for action in previous_actions:
        if type(action['content']) == list:
            actions += action['content']
        else:
            actions.append(action['content'])
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list_nodes)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.14285714285714285 {'action': 'remove-node', 'content': ['50', '87', '49']} add-edge: ['36-56', '132-136', '77-124']
# Complexity: [21, 28, 9, 3, 6, 16]
# Step: 2 0.13043478260869565 {'action': 'remove-node', 'content': ['77', '86', '138']} add-edge: ['52-127']
# Complexity: [23, 27, 10, 3, 7, 14]
# Step: 3 0.047619047619047616 {'action': 'remove-node', 'content': ['128']} add-edge: []
# Complexity: [21, 27, 9, 3, 6, 15]
# Step: 4 0.043478260869565216 {'action': 'remove-node', 'content': ['11']} add-edge: ['10-36']
# Complexity: [23, 28, 12, 4, 8, 17]
# Step: 5 0.1 {'action': 'remove-node', 'content': ['132', '17']} add-edge: ['98-141', '12-25']
# Complexity: [20, 25, 10, 5, 5, 15]
# Step: 6 0.07142857142857142 {'action': 'remove-node', 'content': ['36', '56']} add-edge: ['25-43', '43-159']
# Complexity: [28, 31, 15, 4, 11, 18]
# Step: 7 0.03225806451612903 {'action': 'remove-node', 'content': ['101']} add-edge: []
# Complexity: [31, 34, 16, 4, 12, 19]
# Step: 8 0.023255813953488372 {'action': 'remove-node', 'content': ['113']} add-edge: ['40-126']
# Complexity: [43, 53, 23, 8, 15, 33]
# Step: 9 0.12195121951219512 {'action': 'remove-node', 'content': ['58', '144', '141', '33', '39']} add-edge: ['12-90', '108-151', '40-52']
# Complexity: [41, 42, 21, 9, 12, 22]
# Step: 10 0.07692307692307693 {'action': 'remove-node', 'content': ['51', '154', '65']} add-edge: []
# Complexity: [39, 44, 16, 8, 8, 21]
# Step: 11 0.030303030303030304 {'action': 'remove-node', 'content': ['12']} add-edge: ['10-22']
# Complexity: [33, 36, 16, 6, 10, 19]
# Step: 12 0.046511627906976744 {'action': 'remove-node', 'content': ['13', '67']} add-edge: ['10-14']
# Complexity: [43, 48, 26, 7, 19, 31]
# Step: 13 0.08571428571428572 {'action': 'remove-node', 'content': ['135', '26', '54']} add-edge: ['20-48', '48-75']
# Complexity: [35, 42, 14, 5, 9, 21]
# Step: 14 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [26, 31, 11, 5, 6, 16]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.2 {'action': 'remove-node', 'content': ['89', '127', '47', '71', '67']} add-edge: ['63-91', '91-138', '61-111']
# Complexity: [25, 33, 10, 5, 5, 18]
# Step: 2 0.13636363636363635 {'action': 'remove-node', 'content': ['84', '36', '50']} add-edge: ['147-154', '53-64']
# Complexity: [22, 25, 10, 6, 4, 13]
# Step: 3 0.1 {'action': 'remove-node', 'content': ['52', '53']} add-edge: ['33-65']
# Complexity: [20, 25, 11, 3, 8, 16]
# Step: 4 0.047619047619047616 {'action': 'remove-node', 'content': ['69']} add-edge: ['33-70']
# Complexity: [21, 25, 11, 4, 7, 15]
# Step: 5 0.05 {'action': 'remove-node', 'content': ['54']} add-edge: []
# Complexity: [20, 24, 9, 6, 3, 13]
# Step: 6 0.1 {'action': 'remove-node', 'content': ['49', '27']} add-edge: ['33-70']
# Complexity: [20, 24, 11, 4, 7, 15]
# Step: 7 0.05555555555555555 {'action': 'remove-node', 'content': ['11']} add-edge: ['10-18']
# Complexity: [18, 22, 9, 3, 6, 13]
# Step: 8 0.05 {'action': 'remove-node', 'content': ['129']} add-edge: []
# Complexity: [20, 25, 10, 4, 6, 15]
# Step: 9 0.043478260869565216 {'action': 'remove-node', 'content': ['59']} add-edge: []
# Complexity: [23, 29, 10, 5, 5, 16]
# Step: 10 0.043478260869565216 {'action': 'remove-node', 'content': ['66']} add-edge: []
# Complexity: [23, 27, 9, 4, 5, 13]
# Step: 11 0.041666666666666664 {'action': 'remove-node', 'content': ['34']} add-edge: []
# Complexity: [24, 29, 11, 3, 8, 16]
# Step: 12 0.05 {'action': 'remove-node', 'content': ['61']} add-edge: []
# Complexity: [20, 24, 8, 4, 4, 12]
# Step: 13 0.045454545454545456 {'action': 'remove-node', 'content': ['72']} add-edge: ['63-81']
# Complexity: [22, 25, 9, 3, 6, 12]
# Step: 14 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [21, 25, 8, 4, 4, 12]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.21739130434782608 {'action': 'remove-node', 'content': ['127', '49', '66', '20', '77']} add-edge: ['90-139', '33-110', '23-36']
# Complexity: [23, 29, 8, 4, 4, 14]
# Step: 2 0.25 {'action': 'remove-node', 'content': ['35', '45', '53', '86', '39', '107']} add-edge: ['33-90', '75-122', '52-57', '76-136']
# Complexity: [24, 28, 4, 3, 1, 8]
# Step: 3 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [18, 23, 8, 4, 4, 13]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.09523809523809523 {'action': 'remove-node', 'content': ['103', '90']} add-edge: ['92-135']
# Complexity: [21, 24, 7, 4, 3, 10]
# Step: 2 0.15789473684210525 {'action': 'remove-node', 'content': ['65', '86', '138']} add-edge: ['52-69', '69-136']
# Complexity: [19, 22, 5, 3, 2, 8]
# Step: 3 0.1111111111111111 {'action': 'remove-node', 'content': ['11', '113']} add-edge: ['10-58']
# Complexity: [18, 20, 6, 2, 4, 8]
# Step: 4 0.13333333333333333 {'action': 'remove-node', 'content': ['135', '16']} add-edge: ['89-149']
# Complexity: [15, 16, 3, 3, 0, 4]
# Step: 5 0.045454545454545456 {'action': 'remove-node', 'content': ['12']} add-edge: ['10-17']
# Complexity: [22, 26, 5, 4, 1, 9]
# Step: 6 0.05263157894736842 {'action': 'remove-node', 'content': ['58']} add-edge: []
# Complexity: [19, 22, 5, 3, 2, 8]
# Step: 7 0.05 {'action': 'remove-node', 'content': ['17']} add-edge: []
# Complexity: [20, 22, 4, 4, 0, 6]
# Step: 8 0.043478260869565216 {'action': 'remove-node', 'content': ['27']} add-edge: ['36-37']
# Complexity: [23, 25, 7, 3, 4, 9]
# Step: 9 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [20, 24, 7, 4, 3, 11]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.15789473684210525 {'action': 'remove-node', 'content': ['11', '127', '65']} add-edge: ['35-40', '114-142', '59-94']
# Complexity: [19, 25, 9, 4, 5, 15]
# Step: 2 0.05555555555555555 {'action': 'remove-node', 'content': ['53']} add-edge: ['12-94']
# Complexity: [18, 21, 11, 3, 8, 14]
# Step: 3 0.037037037037037035 {'action': 'remove-node', 'content': ['35']} add-edge: ['12-37']
# Complexity: [27, 27, 20, 2, 18, 20]
# Step: 4 0.09523809523809523 {'action': 'remove-node', 'content': ['18', '91']} add-edge: []
# Complexity: [21, 21, 13, 4, 9, 13]
# Step: 5 0.058823529411764705 {'action': 'remove-node', 'content': ['113']} add-edge: ['103-142']
# Complexity: [17, 17, 9, 5, 4, 9]
# Step: 6 0.05263157894736842 {'action': 'remove-node', 'content': ['150']} add-edge: []
# Complexity: [19, 14, 10, 5, 5, 5]
# Step: 7 0.08333333333333333 {'action': 'remove-node', 'content': ['83', '121']} add-edge: ['108-140']
# Complexity: [24, 17, 10, 8, 2, 3]
# Step: 8 0.04 {'action': 'remove-node', 'content': ['138']} add-edge: []
# Complexity: [25, 17, 11, 10, 1, 3]
# Step: 9 0.1 {'action': 'remove-node', 'content': ['141', '73']} add-edge: ['67-75']
# Complexity: [20, 14, 9, 6, 3, 3]
# Step: 10 0.07692307692307693 {'action': 'remove-node', 'content': ['23']} add-edge: []
# Complexity: [13, 11, 8, 3, 5, 6]
# Step: 11 0.15 {'action': 'remove-node', 'content': ['16', '28', '44']} add-edge: []
# Complexity: [20, 14, 10, 7, 3, 4]
# Step: 12 0.05555555555555555 {'action': 'remove-node', 'content': ['154']} add-edge: ['146-156']
# Complexity: [18, 13, 8, 5, 3, 3]
# Step: 13 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [26, 17, 15, 9, 6, 6]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.09523809523809523 {'action': 'remove-node', 'content': ['36', '64']} add-edge: []
# Complexity: [21, 29, 7, 5, 2, 15]
# Step: 2 0.19047619047619047 {'action': 'remove-node', 'content': ['11', '54', '20', '67']} add-edge: ['10-66', '27-63', '19-70']
# Complexity: [21, 26, 6, 4, 2, 11]
# Step: 3 0.10714285714285714 {'action': 'remove-node', 'content': ['19', '66', '150']} add-edge: ['13-27', '27-85']
# Complexity: [28, 31, 13, 5, 8, 16]
# Step: 4 0.05 {'action': 'remove-node', 'content': ['17']} add-edge: ['12-60']
# Complexity: [20, 24, 9, 5, 4, 13]
# Step: 5 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [29, 31, 18, 4, 14, 20]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.09090909090909091 {'action': 'remove-node', 'content': ['11', '113']} add-edge: ['10-47']
# Complexity: [22, 29, 7, 4, 3, 14]
# Step: 2 0.1111111111111111 {'action': 'remove-node', 'content': ['56', '91', '36']} add-edge: ['37-159', '85-151', '34-50']
# Complexity: [27, 29, 9, 5, 4, 11]
# Step: 3 0.037037037037037035 {'action': 'remove-node', 'content': ['34']} add-edge: ['51-66']
# Complexity: [27, 33, 10, 7, 3, 16]
# Step: 4 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [27, 32, 9, 5, 4, 14]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.18181818181818182 {'action': 'remove-node', 'content': ['84', '127', '36', '47']} add-edge: ['33-138', '11-85']
# Complexity: [22, 26, 6, 5, 1, 10]
# Step: 2 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [24, 30, 9, 4, 5, 15]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.13636363636363635 {'action': 'remove-node', 'content': ['11', '27', '90']} add-edge: ['10-21', '21-45']
# Complexity: [22, 27, 7, 4, 3, 12]
# Step: 2 0.1 {'action': 'remove-node', 'content': ['84', '127']} add-edge: ['63-92', '92-135']
# Complexity: [20, 26, 8, 5, 3, 14]
# Step: 3 0.04 {'action': 'remove-node', 'content': ['13']} add-edge: ['25-35']
# Complexity: [25, 28, 9, 4, 5, 12]
# Step: 4 0.15 {'action': 'remove-node', 'content': ['141', '35', '83']} add-edge: ['139-151', '30-86']
# Complexity: [20, 24, 5, 4, 1, 9]
# Step: 5 0.038461538461538464 {'action': 'remove-node', 'content': ['53']} add-edge: ['25-151']
# Complexity: [26, 33, 9, 6, 3, 16]
# Step: 6 0.08695652173913043 {'action': 'remove-node', 'content': ['31', '150']} add-edge: ['30-55', '139-151']
# Complexity: [23, 27, 8, 3, 5, 12]
# Step: 7 0.03571428571428571 {'action': 'remove-node', 'content': ['26']} add-edge: ['25-151']
# Complexity: [28, 35, 12, 6, 6, 19]
# Step: 8 0.041666666666666664 {'action': 'remove-node', 'content': ['12']} add-edge: ['10-17']
# Complexity: [24, 31, 7, 6, 1, 14]
# Step: 9 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [23, 28, 10, 4, 6, 15]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.1111111111111111 {'action': 'remove-node', 'content': ['53', '146', '127']} add-edge: ['33-57']
# Complexity: [27, 34, 8, 5, 3, 15]
# Step: 2 0.07692307692307693 {'action': 'remove-node', 'content': ['35', '134']} add-edge: ['11-63', '113-139']
# Complexity: [26, 30, 10, 5, 5, 14]
# Step: 3 0.03571428571428571 {'action': 'remove-node', 'content': ['45']} add-edge: ['62-85']
# Complexity: [28, 30, 11, 4, 7, 13]
# Step: 4 0.10714285714285714 {'action': 'remove-node', 'content': ['36', '27', '51']} add-edge: ['11-86', '63-92']
# Complexity: [28, 31, 10, 5, 5, 13]
# Step: 5 0.125 {'action': 'remove-node', 'content': ['113', '135', '34', '93']} add-edge: ['103-139', '107-121']
# Complexity: [32, 34, 12, 8, 4, 14]
# Step: 6 0.058823529411764705 {'action': 'remove-node', 'content': ['58', '44']} add-edge: ['38-77']
# Complexity: [34, 43, 13, 7, 6, 22]
# Step: 7 0.034482758620689655 {'action': 'remove-node', 'content': ['107']} add-edge: ['29-118']
# Complexity: [29, 32, 12, 6, 6, 15]
# Step: 8 0.08823529411764706 {'action': 'remove-node', 'content': ['96', '108', '116']} add-edge: ['86-117']
# Complexity: [34, 39, 13, 6, 7, 18]
# Step: 9 0.13333333333333333 {'action': 'remove-node', 'content': ['40', '118', '86', '117']} add-edge: ['11-139', '77-120']
# Complexity: [30, 36, 11, 5, 6, 17]
# Step: 10 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [23, 28, 8, 5, 3, 13]

# %%
results_consistent_story = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_consistent_story.json', 'w') as fp:
    json.dump(results_consistent_story, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## "Clustering"
# 2 clusters only: High-bias Breitbart vs Center-unbiased storylines.
# Metric: internal storyline consistency (avoid connections between high-bias and low-bias articles)
#
# ### Semi-supervised umap with constraints

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
i = 0
total_samples = base_total_samples
while i < total_samples:
    print("===================================")
    print("Sample #" + str(i) + " (Valid Sample #" + str(len(all_complexities)) + ")")
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consistent throughout the same iteration.
    drop = False
    while percent_filter >= 0.05:
        G, graph_df, storylines = generate_map(query, dataset, k_input=6, start_nodes=[10], previous_actions=previous_actions, 
                                               verbose=False, random_state=random_state, force_cluster=True, use_new_LP=True)
        nodes = list(G.edges())
        
        breitbart_nodes = graph_df[graph_df.url.str.contains('breitbart')] # Cluster 1
        center_nodes = graph_df[graph_df.bias == 'Center'] # Cluster 2
        breitbart_cluster_full = [str(node) for node in breitbart_nodes['id'].tolist()]
        center_cluster_full = [str(node) for node in center_nodes['id'].tolist()]
        
        previous_breitbart = [node for node_list in previous_actions for node in node_list["content"][0] if node_list["content"][1] == 1]
        previous_center = [node for node_list in previous_actions for node in node_list["content"][0] if node_list["content"][1] == 2]

        print("Previous actions:")
        print(previous_breitbart)
        print(previous_center)
        
        breitbart_cluster_int = sorted([int(node) for node in list(set(breitbart_cluster_full).difference(previous_breitbart))])
        center_cluster_int = sorted([int(node) for node in list(set(center_cluster_full).difference(previous_center))])
        
        breitbart_cluster = [str(node) for node in breitbart_cluster_int]
        center_cluster = [str(node) for node in center_cluster_int]
        
        breitbart_action = {"action": "add-cluster-list", "content": [breitbart_cluster[:min(3, len(breitbart_cluster))], 1]}
        center_action = {"action": "add-cluster-list", "content": [center_cluster[:min(3, len(center_cluster))], 2]}
        
        previous_actions.append(breitbart_action)
        previous_actions.append(center_action)
        
        non_isolated_nodes = set()
        breitbart_n = len(breitbart_cluster_full)
        center_n = len(center_cluster_full)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        for combination in itertools.combinations(breitbart_cluster_full,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
                
        for combination in itertools.combinations(center_cluster_full,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            try:
                sp_1 = nx.shortest_path_length(G, combination[0], combination[1])
            except nx.NetworkXNoPath:
                sp_1 = 0
            try:
                sp_2 = nx.shortest_path_length(G, combination[1], combination[0])
            except nx.NetworkXNoPath:
                sp_2 = 0
            has_path = (sp_1 == 2) or (sp_2 == 2) # Separation of 2. 
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1

                
        print("Total cluster 1: " + str(breitbart_n))
        print("Total cluster 2: " + str(center_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
        if breitbart_n + center_n == 0:
            percent_filter = 0.0
        else:        
            percent_filter = 1 - len(non_isolated_nodes) / (breitbart_n + center_n)
        percent_list.append(percent_filter)
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, breitbart_action, center_action)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
        
        if len(breitbart_cluster) == 0 and len(center_cluster) == 0:
            print("Nothing to add - Early stopping.")
            break
        
    i += 1
    actions = []
    for action in previous_actions:
        if action['action'] == 'add-cluster-list':
            actions += action['content'][0] 
        elif type(action['content']) == list:
            actions += action['content']
        else:
            actions.append(action['content'])
            
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0 (Valid Sample #0)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 4
# Same story 1 Direct connection 1 Same parent 1 Same children 0
# Step: 1 0.2857142857142857 {'action': 'add-cluster-list', 'content': [['23', '36', '136'], 1]} {'action': 'add-cluster-list', 'content': [['10', '14', '157'], 2]}
# Complexity: [17, 21, 5, 4, 1, 9]
# Previous actions:
# ['23', '36', '136']
# ['10', '14', '157']
# Total cluster 1: 3
# Total cluster 2: 6
# Same story 7 Direct connection 2 Same parent 0 Same children 0
# Step: 2 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['62', '139', '159'], 2]}
# Complexity: [16, 18, 5, 4, 1, 7]
# ===================================
# Sample #1 (Valid Sample #1)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 5
# Same story 1 Direct connection 1 Same parent 0 Same children 1
# Step: 1 0.2857142857142857 {'action': 'add-cluster-list', 'content': [['45', '47'], 1]} {'action': 'add-cluster-list', 'content': [['10', '62', '99'], 2]}
# Complexity: [15, 18, 6, 3, 3, 9]
# Previous actions:
# ['45', '47']
# ['10', '62', '99']
# Total cluster 1: 4
# Total cluster 2: 8
# Same story 6 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.25 {'action': 'add-cluster-list', 'content': [['36', '84'], 1]} {'action': 'add-cluster-list', 'content': [['80', '106', '119'], 2]}
# Complexity: [21, 23, 5, 5, 0, 7]
# Previous actions:
# ['45', '47', '36', '84']
# ['10', '62', '99', '80', '106', '119']
# Total cluster 1: 4
# Total cluster 2: 8
# Same story 10 Direct connection 3 Same parent 2 Same children 0
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['85', '159'], 2]}
# Complexity: [21, 23, 6, 4, 2, 8]
# ===================================
# Sample #2 (Valid Sample #2)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 6
# Same story 8 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [['36', '66'], 1]} {'action': 'add-cluster-list', 'content': [['10', '70', '85'], 2]}
# Complexity: [15, 17, 5, 2, 3, 7]
# ===================================
# Sample #3 (Valid Sample #2)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 2
# Same story 2 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.19999999999999996 {'action': 'add-cluster-list', 'content': [['58', '103', '136'], 1]} {'action': 'add-cluster-list', 'content': [['10', '92'], 2]}
# Complexity: [13, 13, 4, 2, 2, 4]
# Previous actions:
# ['58', '103', '136']
# ['10', '92']
# Total cluster 1: 4
# Total cluster 2: 4
# Same story 6 Direct connection 0 Same parent 1 Same children 0
# Step: 2 0.125 {'action': 'add-cluster-list', 'content': [['28'], 1]} {'action': 'add-cluster-list', 'content': [['25', '159'], 2]}
# Complexity: [17, 20, 5, 3, 2, 8]
# Previous actions:
# ['58', '103', '136', '28']
# ['10', '92', '25', '159']
# Total cluster 1: 4
# Total cluster 2: 5
# Same story 5 Direct connection 1 Same parent 0 Same children 1
# Step: 3 0.11111111111111116 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['105'], 2]}
# Complexity: [20, 22, 6, 5, 1, 8]
# Previous actions:
# ['58', '103', '136', '28']
# ['10', '92', '25', '159', '105']
# Total cluster 1: 5
# Total cluster 2: 8
# Same story 6 Direct connection 6 Same parent 2 Same children 4
# Step: 4 0.0 {'action': 'add-cluster-list', 'content': [['71'], 1]} {'action': 'add-cluster-list', 'content': [['37', '85', '139'], 2]}
# Complexity: [21, 27, 8, 6, 2, 14]
# ===================================
# Sample #4 (Valid Sample #3)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 0
# Total cluster 2: 4
# Same story 1 Direct connection 0 Same parent 0 Same children 1
# Step: 1 0.25 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['10', '37', '85'], 2]}
# Complexity: [11, 13, 4, 3, 1, 6]
# Previous actions:
# []
# ['10', '37', '85']
# Total cluster 1: 2
# Total cluster 2: 6
# Same story 2 Direct connection 0 Same parent 1 Same children 0
# Step: 2 0.375 {'action': 'add-cluster-list', 'content': [['66', '150'], 1]} {'action': 'add-cluster-list', 'content': [['25', '155', '159'], 2]}
# Complexity: [21, 28, 8, 5, 3, 15]
# Previous actions:
# ['66', '150']
# ['10', '37', '85', '25', '155', '159']
# Total cluster 1: 5
# Total cluster 2: 9
# Same story 3 Direct connection 4 Same parent 1 Same children 3
# Step: 3 0.3571428571428571 {'action': 'add-cluster-list', 'content': [['54', '72', '136'], 1]} {'action': 'add-cluster-list', 'content': [['99', '100', '123'], 2]}
# Complexity: [41, 53, 15, 12, 3, 27]
# Previous actions:
# ['66', '150', '54', '72', '136']
# ['10', '37', '85', '25', '155', '159', '99', '100', '123']
# Total cluster 1: 8
# Total cluster 2: 9
# Same story 23 Direct connection 3 Same parent 0 Same children 1
# Step: 4 0.11764705882352944 {'action': 'add-cluster-list', 'content': [['36', '47', '84'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [29, 30, 9, 7, 2, 10]
# Previous actions:
# ['66', '150', '54', '72', '136', '36', '47', '84']
# ['10', '37', '85', '25', '155', '159', '99', '100', '123']
# Total cluster 1: 10
# Total cluster 2: 11
# Same story 23 Direct connection 9 Same parent 3 Same children 8
# Step: 5 0.09523809523809523 {'action': 'add-cluster-list', 'content': [['23', '103'], 1]} {'action': 'add-cluster-list', 'content': [['110', '139'], 2]}
# Complexity: [25, 33, 8, 6, 2, 16]
# Previous actions:
# ['66', '150', '54', '72', '136', '36', '47', '84', '23', '103']
# ['10', '37', '85', '25', '155', '159', '99', '100', '123', '110', '139']
# Total cluster 1: 11
# Total cluster 2: 11
# Same story 33 Direct connection 8 Same parent 2 Same children 11
# Step: 6 0.045454545454545414 {'action': 'add-cluster-list', 'content': [['71'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [29, 35, 9, 5, 4, 15]
# ===================================
# Sample #5 (Valid Sample #4)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 6
# Same story 4 Direct connection 1 Same parent 1 Same children 0
# Step: 1 0.2222222222222222 {'action': 'add-cluster-list', 'content': [['36', '47', '66'], 1]} {'action': 'add-cluster-list', 'content': [['10', '14', '24'], 2]}
# Complexity: [15, 17, 4, 4, 0, 6]
# Previous actions:
# ['36', '47', '66']
# ['10', '14', '24']
# Total cluster 1: 4
# Total cluster 2: 4
# Same story 2 Direct connection 1 Same parent 0 Same children 1
# Step: 2 0.375 {'action': 'add-cluster-list', 'content': [['19'], 1]} {'action': 'add-cluster-list', 'content': [['159'], 2]}
# Complexity: [21, 22, 6, 4, 2, 7]
# Previous actions:
# ['36', '47', '66', '19']
# ['10', '14', '24', '159']
# Total cluster 1: 4
# Total cluster 2: 8
# Same story 6 Direct connection 4 Same parent 2 Same children 2
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['37', '78', '139'], 2]}
# Complexity: [17, 23, 6, 6, 0, 12]
# ===================================
# Sample #6 (Valid Sample #5)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 4
# Total cluster 2: 3
# Same story 2 Direct connection 0 Same parent 1 Same children 1
# Step: 1 0.1428571428571429 {'action': 'add-cluster-list', 'content': [['36', '47', '54'], 1]} {'action': 'add-cluster-list', 'content': [['10', '75', '159'], 2]}
# Complexity: [20, 23, 5, 5, 0, 8]
# Previous actions:
# ['36', '47', '54']
# ['10', '75', '159']
# Total cluster 1: 3
# Total cluster 2: 5
# Same story 6 Direct connection 2 Same parent 1 Same children 1
# Step: 2 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['139', '157'], 2]}
# Complexity: [18, 20, 6, 3, 3, 8]
# ===================================
# Sample #7 (Valid Sample #6)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 4
# Total cluster 2: 6
# Same story 8 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.19999999999999996 {'action': 'add-cluster-list', 'content': [['36', '47', '66'], 1]} {'action': 'add-cluster-list', 'content': [['10', '60', '62'], 2]}
# Complexity: [14, 15, 3, 3, 0, 4]
# Previous actions:
# ['36', '47', '66']
# ['10', '60', '62']
# Total cluster 1: 5
# Total cluster 2: 6
# Same story 5 Direct connection 3 Same parent 0 Same children 1
# Step: 2 0.18181818181818177 {'action': 'add-cluster-list', 'content': [['103', '136'], 1]} {'action': 'add-cluster-list', 'content': [['110', '158', '159'], 2]}
# Complexity: [17, 19, 5, 3, 2, 7]
# Previous actions:
# ['36', '47', '66', '103', '136']
# ['10', '60', '62', '110', '158', '159']
# Total cluster 1: 6
# Total cluster 2: 11
# Same story 13 Direct connection 4 Same parent 1 Same children 1
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['23'], 1]} {'action': 'add-cluster-list', 'content': [['79', '85', '92'], 2]}
# Complexity: [23, 24, 7, 5, 2, 8]
# ===================================
# Sample #8 (Valid Sample #7)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 1
# Total cluster 2: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.5 {'action': 'add-cluster-list', 'content': [['84'], 1]} {'action': 'add-cluster-list', 'content': [['10', '85', '139'], 2]}
# Complexity: [12, 13, 3, 3, 0, 4]
# Previous actions:
# ['84']
# ['10', '85', '139']
# Total cluster 1: 0
# Total cluster 2: 4
# Same story 1 Direct connection 2 Same parent 0 Same children 0
# Step: 2 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['159'], 2]}
# Complexity: [15, 18, 4, 4, 0, 7]
# ===================================
# Sample #9 (Valid Sample #8)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 1
# Total cluster 2: 3
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-cluster-list', 'content': [['36'], 1]} {'action': 'add-cluster-list', 'content': [['10', '62', '153'], 2]}
# Complexity: [17, 18, 4, 3, 1, 5]
# Previous actions:
# ['36']
# ['10', '62', '153']
# Total cluster 1: 0
# Total cluster 2: 7
# Same story 4 Direct connection 2 Same parent 1 Same children 0
# Step: 2 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['37', '139', '152'], 2]}
# Complexity: [16, 17, 6, 4, 2, 7]
# ===================================
# Sample #10 (Valid Sample #9)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 3
# Same story 1 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.4 {'action': 'add-cluster-list', 'content': [['36', '45'], 1]} {'action': 'add-cluster-list', 'content': [['10', '157', '159'], 2]}
# Complexity: [15, 17, 3, 3, 0, 5]
# Previous actions:
# ['36', '45']
# ['10', '157', '159']
# Total cluster 1: 9
# Total cluster 2: 16
# Same story 13 Direct connection 4 Same parent 9 Same children 6
# Step: 2 0.07999999999999996 {'action': 'add-cluster-list', 'content': [['28', '47', '58'], 1]} {'action': 'add-cluster-list', 'content': [['24', '37', '41'], 2]}
# Complexity: [60, 122, 16, 12, 4, 78]
# Previous actions:
# ['36', '45', '28', '47', '58']
# ['10', '157', '159', '24', '37', '41']
# Total cluster 1: 11
# Total cluster 2: 20
# Same story 15 Direct connection 10 Same parent 3 Same children 5
# Step: 3 0.06451612903225812 {'action': 'add-cluster-list', 'content': [['44', '66', '84'], 1]} {'action': 'add-cluster-list', 'content': [['57', '62', '78'], 2]}
# Complexity: [64, 103, 21, 18, 3, 60]
# Previous actions:
# ['36', '45', '28', '47', '58', '44', '66', '84']
# ['10', '157', '159', '24', '37', '41', '57', '62', '78']
# Total cluster 1: 9
# Total cluster 2: 9
# Same story 21 Direct connection 6 Same parent 0 Same children 7
# Step: 4 0.05555555555555558 {'action': 'add-cluster-list', 'content': [['71'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [25, 29, 8, 6, 2, 12]
# Previous actions:
# ['36', '45', '28', '47', '58', '44', '66', '84', '71']
# ['10', '157', '159', '24', '37', '41', '57', '62', '78']
# Total cluster 1: 9
# Total cluster 2: 9
# Same story 39 Direct connection 3 Same parent 0 Same children 1
# Step: 5 0.05555555555555558 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [28, 29, 7, 6, 1, 8]
# Nothing to add - Early stopping.

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_clustering_bb_center.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Test with Florida/Miami news vs general US news

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
i = 0
total_samples = base_total_samples
while i < total_samples:
    print("===================================")
    print("Sample #" + str(i) + " (Valid Sample #" + str(len(all_complexities)) + ")")
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    drop = False
    
    while percent_filter >= 0.05:
        G, graph_df, storylines = generate_map(query, dataset, k_input=6, start_nodes=[10], previous_actions=previous_actions, 
                                               verbose=False, random_state=random_state, force_cluster=True, use_new_LP=True)
        nodes = list(G.edges())
        
        breitbart_nodes = graph_df[graph_df.title.str.contains('miami', case=False) | 
                                   graph_df.title.str.contains('florida', case=False)] # Cluster 1
        center_nodes = graph_df[(graph_df.title.str.contains(r'(?:\s|\b)[Uu](?:\.)?[sS](?:\.)?[Aa]?(?:\.)?(?:\s|\b)', regex=True) |
                                 graph_df.title.str.contains('united states', case=False)) & 
                                 ~(graph_df.title.str.contains('miami', case=False) 
                                   | graph_df.title.str.contains('florida', case=False))] # Cluster 2
        breitbart_cluster = [str(node) for node in breitbart_nodes['id'].tolist()]
        center_cluster = [str(node) for node in center_nodes['id'].tolist()]
        
        breitbart_action = {"action": "add-cluster-list", "content": [breitbart_cluster, 1]}
        center_action = {"action": "add-cluster-list", "content": [center_cluster, 2]}

        breitbart_cluster_full = [str(node) for node in breitbart_nodes['id'].tolist()]
        center_cluster_full = [str(node) for node in center_nodes['id'].tolist()]
        
        previous_breitbart = [node for node_list in previous_actions for node in node_list["content"][0] if node_list["content"][1] == 1]
        previous_center = [node for node_list in previous_actions for node in node_list["content"][0] if node_list["content"][1] == 2]

        print("Previous actions:")
        print(previous_breitbart)
        print(previous_center)
        
        breitbart_cluster_int = sorted([int(node) for node in list(set(breitbart_cluster_full).difference(previous_breitbart))])
        center_cluster_int = sorted([int(node) for node in list(set(center_cluster_full).difference(previous_center))])
        
        breitbart_cluster = [str(node) for node in breitbart_cluster_int]
        center_cluster = [str(node) for node in center_cluster_int]
        
        breitbart_action = {"action": "add-cluster-list", "content": [breitbart_cluster[:min(3, len(breitbart_cluster))], 1]}
        center_action = {"action": "add-cluster-list", "content": [center_cluster[:min(3, len(center_cluster))], 2]}
        
        previous_actions.append(breitbart_action)
        previous_actions.append(center_action)
        
        non_isolated_nodes = set()
        breitbart_n = len(breitbart_cluster_full)
        center_n = len(center_cluster_full)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        count_has_path = 0
        for combination in itertools.combinations(breitbart_cluster_full,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
                
        for combination in itertools.combinations(center_cluster_full,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1

        print("Total cluster 1: " + str(breitbart_n))
        print("Total cluster 2: " + str(center_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
        
        if breitbart_n + center_n == 0:
            percent_filter = 0.0
        else:
            percent_filter = 1 - len(non_isolated_nodes) / (breitbart_n + center_n)
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
            
        percent_list.append(percent_filter)

        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, breitbart_action, center_action)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
        
        if len(breitbart_cluster) == 0 and len(center_cluster) == 0:
            print("Nothing to add - Early stopping.")
            break
    i += 1
    actions = []
    for action in previous_actions:
        if action['action'] == 'add-cluster-list':
            actions += action['content'][0] 
        elif type(action['content']) == list:
            actions += action['content']
        else:
            actions.append(action['content'])
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0 (Valid Sample #0)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 5
# Total cluster 2: 0
# Same story 2 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [['35', '36', '49'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [17, 21, 5, 4, 1, 9]
# ===================================
# Sample #1 (Valid Sample #0)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 1
# Total cluster 2: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-cluster-list', 'content': [['63'], 1]} {'action': 'add-cluster-list', 'content': [['111'], 2]}
# Complexity: [15, 18, 6, 3, 3, 9]
# Previous actions:
# ['63']
# ['111']
# Total cluster 1: 3
# Total cluster 2: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.6666666666666667 {'action': 'add-cluster-list', 'content': [['35', '94'], 1]} {'action': 'add-cluster-list', 'content': [['22', '54', '146'], 2]}
# Complexity: [18, 20, 4, 4, 0, 6]
# Previous actions:
# ['63', '35', '94']
# ['111', '22', '54', '146']
# Total cluster 1: 3
# Total cluster 2: 4
# Same story 1 Direct connection 4 Same parent 0 Same children 1
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [20, 26, 5, 4, 1, 11]
# Nothing to add - Early stopping.
# ===================================
# Sample #2 (Valid Sample #1)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 4
# Same story 1 Direct connection 0 Same parent 0 Same children 1
# Step: 1 0.4285714285714286 {'action': 'add-cluster-list', 'content': [['36', '49', '87'], 1]} {'action': 'add-cluster-list', 'content': [['22', '33', '110'], 2]}
# Complexity: [15, 17, 5, 2, 3, 7]
# Previous actions:
# ['36', '49', '87']
# ['22', '33', '110']
# Total cluster 1: 6
# Total cluster 2: 7
# Same story 5 Direct connection 3 Same parent 1 Same children 1
# Step: 2 0.23076923076923073 {'action': 'add-cluster-list', 'content': [['63', '68', '140'], 1]} {'action': 'add-cluster-list', 'content': [['119', '121', '139'], 2]}
# Complexity: [31, 37, 10, 7, 3, 16]
# Previous actions:
# ['36', '49', '87', '63', '68', '140']
# ['22', '33', '110', '119', '121', '139']
# Total cluster 1: 6
# Total cluster 2: 9
# Same story 30 Direct connection 0 Same parent 0 Same children 0
# Step: 3 0.19999999999999996 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['65', '104', '111'], 2]}
# Complexity: [29, 30, 6, 5, 1, 7]
# Previous actions:
# ['36', '49', '87', '63', '68', '140']
# ['22', '33', '110', '119', '121', '139', '65', '104', '111']
# Total cluster 1: 8
# Total cluster 2: 14
# Same story 25 Direct connection 6 Same parent 2 Same children 4
# Step: 4 0.045454545454545414 {'action': 'add-cluster-list', 'content': [['35', '53'], 1]} {'action': 'add-cluster-list', 'content': [['24', '25', '80'], 2]}
# Complexity: [32, 37, 7, 6, 1, 12]
# ===================================
# Sample #3 (Valid Sample #2)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 0
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [['58', '63'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [13, 13, 4, 2, 2, 4]
# ===================================
# Sample #4 (Valid Sample #2)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 0
# Same story 1 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [['35', '40', '53'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [11, 13, 4, 3, 1, 6]
# ===================================
# Sample #5 (Valid Sample #2)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-cluster-list', 'content': [['36', '63'], 1]} {'action': 'add-cluster-list', 'content': [['24', '111'], 2]}
# Complexity: [15, 17, 4, 4, 0, 6]
# Previous actions:
# ['36', '63']
# ['24', '111']
# Total cluster 1: 3
# Total cluster 2: 5
# Same story 2 Direct connection 3 Same parent 1 Same children 1
# Step: 2 0.0 {'action': 'add-cluster-list', 'content': [['49'], 1]} {'action': 'add-cluster-list', 'content': [['33', '110', '139'], 2]}
# Complexity: [18, 22, 5, 5, 0, 9]
# ===================================
# Sample #6 (Valid Sample #3)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.6 {'action': 'add-cluster-list', 'content': [['35', '36'], 1]} {'action': 'add-cluster-list', 'content': [['33', '54', '75'], 2]}
# Complexity: [20, 23, 5, 5, 0, 8]
# Previous actions:
# ['35', '36']
# ['33', '54', '75']
# Total cluster 1: 8
# Total cluster 2: 8
# Same story 18 Direct connection 0 Same parent 0 Same children 1
# Step: 2 0.25 {'action': 'add-cluster-list', 'content': [['38', '40', '56'], 1]} {'action': 'add-cluster-list', 'content': [['29', '104', '105'], 2]}
# Complexity: [37, 40, 13, 8, 5, 16]
# Previous actions:
# ['35', '36', '38', '40', '56']
# ['33', '54', '75', '29', '104', '105']
# Total cluster 1: 5
# Total cluster 2: 8
# Same story 26 Direct connection 1 Same parent 0 Same children 0
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['22', '139'], 2]}
# Complexity: [23, 24, 4, 4, 0, 5]
# ===================================
# Sample #7 (Valid Sample #4)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 1
# Total cluster 2: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-cluster-list', 'content': [['36'], 1]} {'action': 'add-cluster-list', 'content': [['33', '139'], 2]}
# Complexity: [14, 15, 3, 3, 0, 4]
# Previous actions:
# ['36']
# ['33', '139']
# Total cluster 1: 3
# Total cluster 2: 4
# Same story 1 Direct connection 0 Same parent 1 Same children 1
# Step: 2 0.2857142857142857 {'action': 'add-cluster-list', 'content': [['35', '56', '63'], 1]} {'action': 'add-cluster-list', 'content': [['65', '104'], 2]}
# Complexity: [15, 20, 5, 4, 1, 10]
# Previous actions:
# ['36', '35', '56', '63']
# ['33', '139', '65', '104']
# Total cluster 1: 5
# Total cluster 2: 4
# Same story 4 Direct connection 3 Same parent 0 Same children 1
# Step: 3 0.11111111111111116 {'action': 'add-cluster-list', 'content': [['51'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [18, 19, 6, 3, 3, 7]
# Previous actions:
# ['36', '35', '56', '63', '51']
# ['33', '139', '65', '104']
# Total cluster 1: 6
# Total cluster 2: 6
# Same story 7 Direct connection 2 Same parent 0 Same children 1
# Step: 4 0.25 {'action': 'add-cluster-list', 'content': [['140'], 1]} {'action': 'add-cluster-list', 'content': [['24', '105'], 2]}
# Complexity: [20, 23, 9, 5, 4, 12]
# Previous actions:
# ['36', '35', '56', '63', '51', '140']
# ['33', '139', '65', '104', '24', '105']
# Total cluster 1: 6
# Total cluster 2: 7
# Same story 21 Direct connection 3 Same parent 0 Same children 3
# Step: 5 0.07692307692307687 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['22'], 2]}
# Complexity: [20, 25, 6, 4, 2, 11]
# Previous actions:
# ['36', '35', '56', '63', '51', '140']
# ['33', '139', '65', '104', '24', '105', '22']
# Total cluster 1: 6
# Total cluster 2: 7
# Same story 27 Direct connection 2 Same parent 0 Same children 3
# Step: 6 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [20, 25, 6, 4, 2, 11]
# Nothing to add - Early stopping.
# ===================================
# Sample #8 (Valid Sample #5)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 0
# Total cluster 2: 2
# Same story 0 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['21', '139'], 2]}
# Complexity: [12, 13, 3, 3, 0, 4]
# ===================================
# Sample #9 (Valid Sample #5)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 5
# Total cluster 2: 1
# Same story 4 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.16666666666666663 {'action': 'add-cluster-list', 'content': [['36', '63', '87'], 1]} {'action': 'add-cluster-list', 'content': [['146'], 2]}
# Complexity: [17, 18, 4, 3, 1, 5]
# Previous actions:
# ['36', '63', '87']
# ['146']
# Total cluster 1: 6
# Total cluster 2: 2
# Same story 2 Direct connection 3 Same parent 3 Same children 0
# Step: 2 0.375 {'action': 'add-cluster-list', 'content': [['35', '51', '53'], 1]} {'action': 'add-cluster-list', 'content': [['33', '139'], 2]}
# Complexity: [15, 20, 4, 4, 0, 9]
# Previous actions:
# ['36', '63', '87', '35', '51', '53']
# ['146', '33', '139']
# Total cluster 1: 6
# Total cluster 2: 4
# Same story 3 Direct connection 4 Same parent 0 Same children 1
# Step: 3 0.09999999999999998 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['110'], 2]}
# Complexity: [22, 26, 8, 4, 4, 12]
# Previous actions:
# ['36', '63', '87', '35', '51', '53']
# ['146', '33', '139', '110']
# Total cluster 1: 11
# Total cluster 2: 9
# Same story 14 Direct connection 5 Same parent 2 Same children 3
# Step: 4 0.19999999999999996 {'action': 'add-cluster-list', 'content': [['38', '49', '68'], 1]} {'action': 'add-cluster-list', 'content': [['21', '54', '75'], 2]}
# Complexity: [38, 44, 14, 10, 4, 20]
# Previous actions:
# ['36', '63', '87', '35', '51', '53', '38', '49', '68']
# ['146', '33', '139', '110', '21', '54', '75']
# Total cluster 1: 9
# Total cluster 2: 8
# Same story 37 Direct connection 1 Same parent 0 Same children 1
# Step: 5 0.05882352941176472 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['22'], 2]}
# Complexity: [27, 29, 8, 5, 3, 10]
# Previous actions:
# ['36', '63', '87', '35', '51', '53', '38', '49', '68']
# ['146', '33', '139', '110', '21', '54', '75', '22']
# Total cluster 1: 9
# Total cluster 2: 8
# Same story 33 Direct connection 3 Same parent 0 Same children 1
# Step: 6 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [27, 30, 9, 5, 4, 12]
# Nothing to add - Early stopping.
# ===================================
# Sample #10 (Valid Sample #6)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-cluster-list', 'content': [['36', '63'], 1]} {'action': 'add-cluster-list', 'content': [['65'], 2]}
# Complexity: [15, 17, 3, 3, 0, 5]
# Previous actions:
# ['36', '63']
# ['65']
# Total cluster 1: 4
# Total cluster 2: 4
# Same story 6 Direct connection 0 Same parent 1 Same children 0
# Step: 2 0.125 {'action': 'add-cluster-list', 'content': [['35', '68'], 1]} {'action': 'add-cluster-list', 'content': [['33', '110', '128'], 2]}
# Complexity: [15, 17, 7, 2, 5, 9]
# Previous actions:
# ['36', '63', '35', '68']
# ['65', '33', '110', '128']
# Total cluster 1: 6
# Total cluster 2: 10
# Same story 6 Direct connection 6 Same parent 1 Same children 3
# Step: 3 0.1875 {'action': 'add-cluster-list', 'content': [['53', '88'], 1]} {'action': 'add-cluster-list', 'content': [['80', '105', '119'], 2]}
# Complexity: [43, 55, 15, 13, 2, 27]
# Previous actions:
# ['36', '63', '35', '68', '53', '88']
# ['65', '33', '110', '128', '80', '105', '119']
# Total cluster 1: 9
# Total cluster 2: 10
# Same story 12 Direct connection 6 Same parent 2 Same children 10
# Step: 4 0.10526315789473684 {'action': 'add-cluster-list', 'content': [['38', '49', '126'], 1]} {'action': 'add-cluster-list', 'content': [['24', '29', '139'], 2]}
# Complexity: [47, 68, 26, 9, 17, 47]
# Previous actions:
# ['36', '63', '35', '68', '53', '88', '38', '49', '126']
# ['65', '33', '110', '128', '80', '105', '119', '24', '29', '139']
# Total cluster 1: 9
# Total cluster 2: 11
# Same story 19 Direct connection 14 Same parent 1 Same children 7
# Step: 5 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['22'], 2]}
# Complexity: [29, 43, 9, 7, 2, 23]
# ===================================
# Sample #11 (Valid Sample #7)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 0
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-cluster-list', 'content': [['36', '63'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [15, 17, 4, 3, 1, 6]
# Previous actions:
# ['36', '63']
# []
# Total cluster 1: 3
# Total cluster 2: 2
# Same story 1 Direct connection 1 Same parent 1 Same children 0
# Step: 2 0.4 {'action': 'add-cluster-list', 'content': [['56'], 1]} {'action': 'add-cluster-list', 'content': [['104', '139'], 2]}
# Complexity: [17, 22, 7, 5, 2, 12]
# Previous actions:
# ['36', '63', '56']
# ['104', '139']
# Total cluster 1: 4
# Total cluster 2: 2
# Same story 3 Direct connection 1 Same parent 0 Same children 1
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['88'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [16, 20, 5, 5, 0, 9]
# ===================================
# Sample #12 (Valid Sample #8)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 2
# Same story 2 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [['46', '140'], 1]} {'action': 'add-cluster-list', 'content': [['22', '33'], 2]}
# Complexity: [17, 21, 6, 4, 2, 10]
# ===================================
# Sample #13 (Valid Sample #8)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 4
# Total cluster 2: 1
# Same story 2 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.19999999999999996 {'action': 'add-cluster-list', 'content': [['36', '56', '87'], 1]} {'action': 'add-cluster-list', 'content': [['74'], 2]}
# Complexity: [20, 20, 3, 3, 0, 3]
# Previous actions:
# ['36', '56', '87']
# ['74']
# Total cluster 1: 6
# Total cluster 2: 5
# Same story 5 Direct connection 3 Same parent 0 Same children 2
# Step: 2 0.09090909090909094 {'action': 'add-cluster-list', 'content': [['38', '51', '122'], 1]} {'action': 'add-cluster-list', 'content': [['24', '25', '33'], 2]}
# Complexity: [19, 26, 8, 6, 2, 15]
# Previous actions:
# ['36', '56', '87', '38', '51', '122']
# ['74', '24', '25', '33']
# Total cluster 1: 8
# Total cluster 2: 9
# Same story 12 Direct connection 7 Same parent 1 Same children 6
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['58', '63'], 1]} {'action': 'add-cluster-list', 'content': [['22', '65', '110'], 2]}
# Complexity: [26, 32, 9, 4, 5, 15]
# ===================================
# Sample #14 (Valid Sample #9)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 3
# Same story 1 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.19999999999999996 {'action': 'add-cluster-list', 'content': [['35', '63'], 1]} {'action': 'add-cluster-list', 'content': [['33', '75', '111'], 2]}
# Complexity: [14, 15, 3, 2, 1, 4]
# Previous actions:
# ['35', '63']
# ['33', '75', '111']
# Total cluster 1: 4
# Total cluster 2: 5
# Same story 5 Direct connection 1 Same parent 0 Same children 0
# Step: 2 0.2222222222222222 {'action': 'add-cluster-list', 'content': [['49', '87'], 1]} {'action': 'add-cluster-list', 'content': [['65', '110'], 2]}
# Complexity: [22, 23, 6, 5, 1, 7]
# Previous actions:
# ['35', '63', '49', '87']
# ['33', '75', '111', '65', '110']
# Total cluster 1: 5
# Total cluster 2: 7
# Same story 9 Direct connection 3 Same parent 1 Same children 1
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['36'], 1]} {'action': 'add-cluster-list', 'content': [['139', '143'], 2]}
# Complexity: [20, 25, 8, 6, 2, 13]

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_clustering_florida.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Add Node
# Adding nodes and clustering.
#
# ### Miami + Florida

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
subset_query = query.loc[124:].astype({'id': 'int32'})
i = 0

while i < total_samples:
    print("===================================")
    print("Sample #" + str(i) + " (Valid Sample #" + str(len(all_complexities)) + ")")
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    drop = False
    while percent_filter > 0:
        G, graph_df, storylines = generate_map(query, dataset, k_input=6, start_nodes=[10], 
                                               previous_actions=previous_actions, verbose=False, 
                                               random_state=random_state, force_cluster=True, use_new_LP=True)
        
        all_relevant_nodes = subset_query[subset_query.title.str.contains('miami', case=False) 
                                                 | subset_query.title.str.contains('florida', case=False)]
        relevant_nodes = graph_df[graph_df.title.str.contains('miami', case=False) | 
                                   graph_df.title.str.contains('florida', case=False)]
        
        unselected_relevant_nodes = (all_relevant_nodes.merge(relevant_nodes, on=['id'], how='left', indicator=True)
                                     .query('_merge == "left_only"')
                                     .drop('_merge', 1))
        relevant_node_list = [str(node) for node in relevant_nodes.id.tolist()]
        # Select first 10% nodes.
        percentage = 10
        selected_nodes_df = unselected_relevant_nodes.head(int(len(unselected_relevant_nodes.index) * (percentage / 100)))
        selected_nodes_list = [str(node) for node in selected_nodes_df.id.tolist()]
        
        add_node = {"action": "add-node", "content": selected_nodes_list}
        previous_actions.append(add_node)
        
        # Mark nodes as part of the same cluster
        new_cluster = {"action": "add-cluster-list", "content": [relevant_node_list, 1]}
        previous_actions.append(new_cluster)
        
        # Are the relevant nodes connected?
        non_isolated_nodes = set()
        relevant_node_n = len(relevant_nodes)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        count_has_path = 0
        for combination in itertools.combinations(relevant_node_list,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1

                
        print("# of Relevant Nodes: " + str(relevant_node_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
            
        if relevant_node_n == 0:
            percent_filter = 0.0
        else:
            percent_filter = 1 - len(non_isolated_nodes) / relevant_node_n
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
            
        percent_list.append(percent_filter)
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, add_node, "Relevant nodes: " + str(relevant_node_list))
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    
    i += 1
    actions = []
    for action in previous_actions:
        actions += action['content']
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0 (Valid Sample #0)
# ===================================
# # of Relevant Nodes: 5
# Same story 2 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '36', '49', '63', '87']
# Complexity: [17, 21, 5, 4, 1, 9]
# ===================================
# Sample #1 (Valid Sample #0)
# ===================================
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['63']
# Complexity: [15, 18, 6, 3, 3, 9]
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.33333333333333337 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '63', '94']
# Complexity: [18, 20, 4, 4, 0, 6]
# # of Relevant Nodes: 3
# Same story 3 Direct connection 0 Same parent 0 Same children 0
# Step: 3 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '63', '94']
# Complexity: [19, 22, 3, 3, 0, 6]
# ===================================
# Sample #2 (Valid Sample #1)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.33333333333333337 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '49', '87']
# Complexity: [15, 17, 5, 2, 3, 7]
# # of Relevant Nodes: 5
# Same story 3 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.4 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '49', '63', '87', '140']
# Complexity: [18, 24, 9, 4, 5, 15]
# # of Relevant Nodes: 6
# Same story 2 Direct connection 2 Same parent 1 Same children 0
# Step: 3 0.33333333333333337 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '49', '63', '87', '122', '140']
# Complexity: [22, 29, 10, 5, 5, 17]
# # of Relevant Nodes: 7
# Same story 3 Direct connection 4 Same parent 4 Same children 1
# Step: 4 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '49', '53', '63', '87', '122', '140']
# Complexity: [18, 27, 8, 4, 4, 17]
# ===================================
# Sample #3 (Valid Sample #2)
# ===================================
# # of Relevant Nodes: 2
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['58', '63']
# Complexity: [13, 13, 4, 2, 2, 4]
# ===================================
# Sample #4 (Valid Sample #2)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '40', '53']
# Complexity: [11, 13, 4, 3, 1, 6]
# ===================================
# Sample #5 (Valid Sample #2)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '63']
# Complexity: [15, 17, 4, 4, 0, 6]
# # of Relevant Nodes: 4
# Same story 0 Direct connection 2 Same parent 1 Same children 0
# Step: 2 0.25 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '49', '63', '68']
# Complexity: [17, 22, 5, 4, 1, 10]
# # of Relevant Nodes: 4
# Same story 0 Direct connection 3 Same parent 1 Same children 0
# Step: 3 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '49', '63', '68']
# Complexity: [17, 22, 5, 4, 1, 10]
# ===================================
# Sample #6 (Valid Sample #3)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '36']
# Complexity: [20, 23, 5, 5, 0, 8]
# # of Relevant Nodes: 4
# Same story 6 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '36', '88', '126']
# Complexity: [20, 23, 7, 4, 3, 10]
# ===================================
# Sample #7 (Valid Sample #4)
# ===================================
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36']
# Complexity: [14, 15, 3, 3, 0, 4]
# # of Relevant Nodes: 2
# Same story 0 Direct connection 1 Same parent 0 Same children 0
# Step: 2 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '56']
# Complexity: [16, 19, 6, 3, 3, 9]
# ===================================
# Sample #8 (Valid Sample #5)
# ===================================
# # of Relevant Nodes: 0
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: []
# Complexity: [12, 13, 3, 3, 0, 4]
# ===================================
# Sample #9 (Valid Sample #5)
# ===================================
# # of Relevant Nodes: 5
# Same story 4 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '63', '87', '97', '122']
# Complexity: [17, 18, 4, 3, 1, 5]
# ===================================
# Sample #10 (Valid Sample #5)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '63']
# Complexity: [15, 17, 3, 3, 0, 5]
# # of Relevant Nodes: 4
# Same story 3 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.25 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '36', '63', '68']
# Complexity: [15, 17, 6, 3, 3, 8]
# # of Relevant Nodes: 4
# Same story 3 Direct connection 1 Same parent 1 Same children 0
# Step: 3 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '36', '63', '68']
# Complexity: [15, 18, 6, 3, 3, 9]
# ===================================
# Sample #11 (Valid Sample #6)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '63']
# Complexity: [15, 17, 4, 3, 1, 6]
# # of Relevant Nodes: 3
# Same story 1 Direct connection 1 Same parent 1 Same children 0
# Step: 2 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '56', '63']
# Complexity: [17, 22, 7, 5, 2, 12]
# ===================================
# Sample #12 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 2
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['46', '140']
# Complexity: [17, 21, 6, 4, 2, 10]
# ===================================
# Sample #13 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 4
# Same story 2 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '56', '87', '97']
# Complexity: [20, 20, 3, 3, 0, 3]
# ===================================
# Sample #14 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '63']
# Complexity: [14, 15, 3, 2, 1, 4]
# ===================================
# Sample #15 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 5
# Same story 2 Direct connection 1 Same parent 0 Same children 1
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '56', '63', '68', '140']
# Complexity: [16, 17, 4, 3, 1, 5]
# ===================================
# Sample #16 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 2
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '88']
# Complexity: [12, 13, 3, 2, 1, 4]
# ===================================
# Sample #17 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 1
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '36', '53']
# Complexity: [15, 19, 5, 3, 2, 9]
# ===================================
# Sample #18 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35']
# Complexity: [26, 28, 6, 5, 1, 8]
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 2 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['63']
# Complexity: [16, 18, 4, 4, 0, 6]
# # of Relevant Nodes: 3
# Same story 0 Direct connection 1 Same parent 0 Same children 1
# Step: 3 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '49', '63']
# Complexity: [33, 43, 12, 9, 3, 22]
# ===================================
# Sample #19 (Valid Sample #8)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '58', '68']
# Complexity: [14, 14, 3, 3, 0, 3]
# ===================================
# Sample #20 (Valid Sample #8)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '68']
# Complexity: [16, 20, 5, 3, 2, 9]
# # of Relevant Nodes: 4
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.5 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '38', '68', '140']
# Complexity: [14, 17, 7, 5, 2, 10]
# # of Relevant Nodes: 4
# Same story 3 Direct connection 1 Same parent 0 Same children 1
# Step: 3 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['36', '38', '68', '140']
# Complexity: [17, 19, 6, 4, 2, 8]
# ===================================
# Sample #21 (Valid Sample #9)
# ===================================
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['38']
# Complexity: [16, 22, 6, 3, 3, 12]
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 2 1.0 {'action': 'add-node', 'content': []} Relevant nodes: ['63']
# Complexity: [18, 20, 3, 3, 0, 5]
# # of Relevant Nodes: 2
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 3 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['38', '63']
# Complexity: [19, 21, 3, 3, 0, 5]

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_add_florida.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Biden

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
subset_query = query.loc[124:].astype({'id': 'int32'})
i = 0

while i < total_samples:
    print("===================================")
    print("Sample #" + str(i) + " (Valid Sample #" + str(len(all_complexities)) + ")")
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    drop = False
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    
    while percent_filter > 0:
        G, graph_df, storylines = generate_map(query, dataset, k_input=6, start_nodes=[10], 
                                               previous_actions=previous_actions, verbose=False, 
                                               random_state=random_state, force_cluster=True, use_new_LP=True)
        
        all_relevant_nodes = subset_query[subset_query.title.str.contains('biden', case=False) 
                                                 | subset_query.title.str.contains('biden', case=False)]
        relevant_nodes = graph_df[graph_df.title.str.contains('biden', case=False) | 
                                   graph_df.title.str.contains('biden', case=False)]
        
        unselected_relevant_nodes = (all_relevant_nodes.merge(relevant_nodes, on=['id'], how='left', indicator=True)
                                     .query('_merge == "left_only"')
                                     .drop('_merge', 1))
        relevant_node_list = [str(node) for node in relevant_nodes.id.tolist()]
        # Select first 10% nodes.
        percentage = 10
        selected_nodes_df = unselected_relevant_nodes.head(int(len(unselected_relevant_nodes.index) * (percentage / 100)))
        selected_nodes_list = [str(node) for node in selected_nodes_df.id.tolist()]
        
        add_node = {"action": "add-node", "content": selected_nodes_list}
        previous_actions.append(add_node)
        
        # Mark nodes as part of the same cluster
        new_cluster = {"action": "add-cluster-list", "content": [relevant_node_list, 1]}
        previous_actions.append(new_cluster)
        
        # Are the relevant nodes connected?
        non_isolated_nodes = set()
        relevant_node_n = len(relevant_nodes)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        count_has_path = 0
        for combination in itertools.combinations(relevant_node_list,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
        
        print("# of Relevant Nodes: " + str(relevant_node_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
            
        if relevant_node_n == 0:
            percent_filter = 0.0
        else:
            percent_filter = 1 - len(non_isolated_nodes) / relevant_node_n
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
            
        percent_list.append(percent_filter)
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, add_node, "Relevant nodes: " + str(relevant_node_list))
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    
    i += 1
    actions = []
    for action in previous_actions:
        actions += action['content']
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0 (Valid Sample #0)
# ===================================
# # of Relevant Nodes: 5
# Same story 2 Direct connection 0 Same parent 1 Same children 1
# Step: 1 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['49', '77', '127', '132', '151']
# Complexity: [17, 21, 5, 4, 1, 9]
# ===================================
# Sample #1 (Valid Sample #0)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['111', '127', '138']
# Complexity: [15, 18, 6, 3, 3, 9]
# ===================================
# Sample #2 (Valid Sample #0)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.33333333333333337 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['49', '70', '127']
# Complexity: [15, 17, 5, 2, 3, 7]
# # of Relevant Nodes: 8
# Same story 5 Direct connection 3 Same parent 1 Same children 1
# Step: 2 0.0 {'action': 'add-node', 'content': ['131']} Relevant nodes: ['25', '49', '70', '127', '129', '132', '138', '151']
# Complexity: [19, 21, 5, 5, 0, 7]
# ===================================
# Sample #3 (Valid Sample #1)
# ===================================
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['132']
# Complexity: [13, 13, 4, 2, 2, 4]
# # of Relevant Nodes: 8
# Same story 11 Direct connection 0 Same parent 0 Same children 2
# Step: 2 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['34', '53', '70', '106', '108', '127', '147', '151']
# Complexity: [19, 23, 4, 4, 0, 8]
# ===================================
# Sample #4 (Valid Sample #2)
# ===================================
# # of Relevant Nodes: 2
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['53', '127']
# Complexity: [11, 13, 4, 3, 1, 6]
# ===================================
# Sample #5 (Valid Sample #2)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.33333333333333337 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['70', '111', '151']
# Complexity: [15, 17, 4, 4, 0, 6]
# # of Relevant Nodes: 7
# Same story 3 Direct connection 2 Same parent 1 Same children 4
# Step: 2 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['70', '71', '75', '111', '127', '138', '151']
# Complexity: [21, 26, 8, 6, 2, 13]
# ===================================
# Sample #6 (Valid Sample #3)
# ===================================
# # of Relevant Nodes: 7
# Same story 10 Direct connection 1 Same parent 0 Same children 1
# Step: 1 0.1428571428571429 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['54', '71', '75', '76', '127', '138', '151']
# Complexity: [20, 23, 5, 5, 0, 8]
# # of Relevant Nodes: 9
# Same story 4 Direct connection 4 Same parent 1 Same children 10
# Step: 2 0.0 {'action': 'add-node', 'content': ['131']} Relevant nodes: ['34', '54', '71', '75', '76', '127', '129', '138', '151']
# Complexity: [22, 26, 9, 5, 4, 13]
# ===================================
# Sample #7 (Valid Sample #4)
# ===================================
# # of Relevant Nodes: 0
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['127']} Relevant nodes: []
# Complexity: [14, 15, 3, 3, 0, 4]
# ===================================
# Sample #8 (Valid Sample #4)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.33333333333333337 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['21', '34', '151']
# Complexity: [12, 13, 3, 3, 0, 4]
# # of Relevant Nodes: 11
# Same story 17 Direct connection 1 Same parent 0 Same children 0
# Step: 2 0.09090909090909094 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['21', '34', '75', '108', '118', '120', '127', '147', '151', '152', '154']
# Complexity: [24, 26, 6, 4, 2, 8]
# # of Relevant Nodes: 13
# Same story 15 Direct connection 4 Same parent 2 Same children 4
# Step: 3 0.07692307692307687 {'action': 'add-node', 'content': ['131']} Relevant nodes: ['21', '34', '71', '75', '108', '118', '120', '127', '129', '147', '151', '152', '154']
# Complexity: [24, 30, 8, 5, 3, 14]
# # of Relevant Nodes: 17
# Same story 31 Direct connection 6 Same parent 3 Same children 5
# Step: 4 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['21', '34', '51', '71', '75', '108', '118', '120', '127', '129', '131', '138', '140', '147', '151', '152', '154']
# Complexity: [26, 30, 7, 5, 2, 11]
# ===================================
# Sample #9 (Valid Sample #5)
# ===================================
# # of Relevant Nodes: 3
# Same story 3 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['107', '117', '146']
# Complexity: [17, 18, 4, 3, 1, 5]
# ===================================
# Sample #10 (Valid Sample #5)
# ===================================
# # of Relevant Nodes: 4
# Same story 6 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['76', '127', '138', '151']
# Complexity: [15, 17, 3, 3, 0, 5]
# ===================================
# Sample #11 (Valid Sample #5)
# ===================================
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['132']
# Complexity: [15, 17, 4, 3, 1, 6]
# # of Relevant Nodes: 5
# Same story 1 Direct connection 1 Same parent 0 Same children 0
# Step: 2 0.4 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['34', '39', '71', '104', '127']
# Complexity: [16, 20, 6, 4, 2, 10]
# # of Relevant Nodes: 10
# Same story 18 Direct connection 2 Same parent 2 Same children 1
# Step: 3 0.0 {'action': 'add-node', 'content': ['131']} Relevant nodes: ['34', '39', '68', '71', '74', '104', '127', '129', '132', '151']
# Complexity: [17, 20, 4, 3, 1, 7]
# ===================================
# Sample #12 (Valid Sample #6)
# ===================================
# # of Relevant Nodes: 2
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['127', '140']
# Complexity: [17, 21, 6, 4, 2, 10]
# ===================================
# Sample #13 (Valid Sample #6)
# ===================================
# # of Relevant Nodes: 4
# Same story 3 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.25 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['70', '71', '74', '152']
# Complexity: [20, 20, 3, 3, 0, 3]
# # of Relevant Nodes: 10
# Same story 7 Direct connection 3 Same parent 1 Same children 1
# Step: 2 0.09999999999999998 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['34', '70', '71', '74', '77', '104', '108', '111', '151', '152']
# Complexity: [17, 19, 7, 4, 3, 9]
# # of Relevant Nodes: 15
# Same story 11 Direct connection 6 Same parent 0 Same children 21
# Step: 3 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['25', '32', '34', '70', '71', '74', '76', '77', '104', '108', '111', '127', '138', '151', '152']
# Complexity: [26, 33, 11, 6, 5, 18]
# ===================================
# Sample #14 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 3
# Same story 3 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['75', '111', '151']
# Complexity: [14, 15, 3, 2, 1, 4]
# ===================================
# Sample #15 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 8
# Same story 9 Direct connection 2 Same parent 1 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['68', '71', '95', '106', '127', '138', '140', '151']
# Complexity: [16, 17, 4, 3, 1, 5]
# ===================================
# Sample #16 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['151']
# Complexity: [12, 13, 3, 2, 1, 4]
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 2 1.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['120', '127']
# Complexity: [18, 20, 5, 4, 1, 7]
# # of Relevant Nodes: 4
# Same story 1 Direct connection 1 Same parent 1 Same children 1
# Step: 3 0.0 {'action': 'add-node', 'content': ['131']} Relevant nodes: ['120', '127', '129', '151']
# Complexity: [21, 24, 7, 5, 2, 10]
# ===================================
# Sample #17 (Valid Sample #8)
# ===================================
# # of Relevant Nodes: 4
# Same story 3 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.25 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['39', '53', '141', '151']
# Complexity: [15, 19, 5, 3, 2, 9]
# # of Relevant Nodes: 8
# Same story 11 Direct connection 2 Same parent 0 Same children 2
# Step: 2 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['39', '51', '53', '54', '127', '133', '141', '151']
# Complexity: [19, 21, 6, 5, 1, 8]
# ===================================
# Sample #18 (Valid Sample #9)
# ===================================
# # of Relevant Nodes: 9
# Same story 21 Direct connection 2 Same parent 0 Same children 1
# Step: 1 0.0 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['52', '116', '117', '118', '133', '143', '144', '146', '151']
# Complexity: [26, 28, 6, 5, 1, 8]
# ===================================
# Sample #19 (Valid Sample #9)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['127']} Relevant nodes: ['68', '151']
# Complexity: [14, 14, 3, 3, 0, 3]
# # of Relevant Nodes: 10
# Same story 10 Direct connection 2 Same parent 2 Same children 0
# Step: 2 0.0 {'action': 'add-node', 'content': ['129']} Relevant nodes: ['25', '32', '68', '76', '77', '106', '107', '127', '138', '151']
# Complexity: [22, 25, 5, 5, 0, 8]

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts}
with open('results_add_biden.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Generate Final Plot

# %%
f = open('results_delete_right.json')
results_delete_right = json.load(f)
f = open('results_delete_fox_bb.json')
results_delete_fox_bb = json.load(f)
f = open('results_delete_florida.json')
results_delete_florida = json.load(f)
f = open('results_delete_edges.json')
results_delete_edges = json.load(f)
f = open('results_consistent_story.json')
results_consistent_story = json.load(f)
f = open('results_clustering_bb_center.json')
results_clustering_bb_center = json.load(f)
f = open('results_clustering_florida.json')
results_clustering_florida = json.load(f)
f = open('results_add_florida.json')
results_add_florida = json.load(f)
f = open('results_add_biden.json')
results_add_biden = json.load(f)

# %%
def average_series(json_dict):
    all_iterations = json_dict['iterations']
    all_percents = json_dict['percents']
    max_iter = max(all_iterations)
    extended_percent_list = []
    for percent_list in all_percents:
        percent_list_extended = percent_list + [percent_list[-1] for _ in range(max_iter - len(percent_list))]
        extended_percent_list.append(percent_list_extended)
    extended_percent_array = np.array(extended_percent_list)
    average_percent = np.mean(extended_percent_array, axis=0)
    return average_percent

# %%
def generate_x_y(json_dict):
    y = average_series(json_dict)
    x = range(max(json_dict['iterations']))
    return x, y

# %%
average_percent = average_series(results_delete_right)
max_iter = max(results_delete_right['iterations'])

# %%
heigth = 40
width = 32
plt.rcParams['figure.figsize'] = [heigth/2.54, width/2.54]
plt.rcParams.update({'font.size': 14})

# %%
fig, axs = plt.subplots(3, 3)

x, y = generate_x_y(results_delete_florida)
axs[0, 0].plot(x, y, 'tab:red')
axs[0, 0].set_title(r'$\bf{(a)}$ ' + 'T1 - Remove Irrelevant Events\nFlorida/Miami')

x, y = generate_x_y(results_delete_fox_bb)
axs[0, 1].plot(x, y, 'tab:red')
axs[0, 1].set_title(r'$\bf{(b)}$ ' + 'T1 - Remove Irrelevant Events\nFox News/Breitbart')

x, y = generate_x_y(results_delete_right)
axs[0, 2].plot(x, y, 'tab:red')
axs[0, 2].set_title(r'$\bf{(c)}$ ' + 'T1 - Remove Irrelevant Events\nRight-leaning Sources')

x, y = generate_x_y(results_delete_edges)
axs[1, 0].plot(x, y, 'tab:blue')
axs[1, 0].set_title(r'$\bf{(d)}$ ' + 'T2 - Removing Inconsistent Edges')

x, y = generate_x_y(results_consistent_story)
axs[1, 1].plot(x, y, 'tab:green')
axs[1, 1].set_title(r'$\bf{(e)}$ ' + 'T3 - Clean Up Storylines')

x, y = generate_x_y(results_clustering_florida)
axs[1, 2].plot(x, y, 'tab:orange')
axs[1, 2].set_title(r'$\bf{(f)}$ ' + 'T4 - Cluster Events\nMiami/Florida vs. Other US News')

x, y = generate_x_y(results_clustering_bb_center)
axs[2, 0].plot(x, y, 'tab:orange')
axs[2, 0].set_title(r'$\bf{(g)}$ ' + 'T4 - Cluster Events\nBreitbart vs. Unbiased News')

x, y = generate_x_y(results_add_florida)
axs[2, 1].plot(x, y, 'tab:purple')
axs[2, 1].set_title(r'$\bf{(h)}$ ' + 'T5 - Add Relevant Events\nFlorida/Miami')

x, y = generate_x_y(results_add_biden)
axs[2, 2].plot(x, y, 'tab:purple')
axs[2, 2].set_title(r'$\bf{(i)}$ ' + 'T5 - Add Relevant Events\nBiden')

for ax in axs.flat:
    ax.set(xlabel='Iterations', ylabel='Error Rate')

fig.tight_layout()
# Hide x labels and tick labels for top plots and y ticks for right plots.
from matplotlib.ticker import MaxNLocator
for ax in axs.flat:
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    #ax.label_outer()
