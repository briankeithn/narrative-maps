# %% [markdown]
# # Testing Other LPs

# %% [markdown]
# ## Imports

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import sys
import os
cwd = os.getcwd()
print(cwd)
nwd = os.path.join(cwd, "..", "narratives")
sys.path.insert(0, nwd)
# Out:
# C:\narrative-maps\tests

# %%
import matplotlib.pyplot as plt

# %%
import pydot
from IPython.display import SVG

# %%
from packages.solve_LP import *
from packages.graph_utils import *

# %% [markdown]
# ## Reading Data

# %%
def clean_publication(graph_df):
    publication_dict = {'www.bbc.com': 'bbc',
                    'www.aljazeera.com': 'ajz',
                    'www.nytimes.com': 'nyt',
                    'www.theguardian.com': 'tgn',
                    'edition.cnn.com': 'cnn',
                    'www.cnn.com': 'cnn',
                    'Reuters': 'reu',
                    'www.reuters.com': 'reu',
                    'Business Insider': 'bin',
                    'CNN': 'cnn',
                    'The Hill': 'hill',
                    'The New York Times': 'nyt',
                    'CNBC': 'cnbc',
                    'Breitbart': 'brb',
                    'www.breitbart.com': 'brb',
                    'Fox News': 'fox',
                    'www.foxnews.com': 'fox',
                    'CIA': 'cia',
                    'FBI': 'fbi',
                    'Army CID': 'cid',
                    'INS': 'ins',
                    'Sanctioned Intercepts': 'sai',
                    'NSA': 'nsa',
                    'abcnews.go.com': 'abc',
                    'apnews.com': 'apn',
                    'www.firstpost.com': 'fpost',
                    'theconversation.com': 'tcon',
                    'nypost.com': 'nyp',
                    'newscomworld.com': 'nwc',
                    'havanatimes.org': 'hvt',
                    'www.nbcnews.com': 'nbc',
                    'www.local10.com': 'l10',
                    'www.trtworld.com': 'trt',
                    'www.washingtonpost.com': 'wapo',
                    'www.xinhuanet.com': 'xinhua'
                    }
    graph_df['publication'] = graph_df['publication'].map(publication_dict).fillna('default')
    return graph_df

# %%
def read_query(dataset, start_date=None, end_date=None, partial=False):
    data_file = str(dataset) + '.csv'
    data_file_path = os.path.join(cwd, "..", "data", data_file)
    if partial:
        columns_to_skip = 'embed'
        query = pd.read_csv(data_file_path, usecols=lambda x: x not in columns_to_skip)
    else:
        query = pd.read_csv(data_file_path)
    query = clean_publication(query)

    # Inferring datatime format (this might bring issues depending on the data!)
    query['date'] = pd.to_datetime(query['date'], infer_datetime_format=True) #8/22/2019 12:15

    if start_date is not None:
        query = query[(query['date'] >= pd.to_datetime(start_date, format='%Y-%m-%d'))]

    if end_date is not None:
        query = query[(query['date'] <= pd.to_datetime(end_date, format='%Y-%m-%d'))]

    if not partial:
        embed_list = ['embed']
        query[embed_list] = query[embed_list].replace(r'( )+', ',', regex=True)
        query[embed_list] = query[embed_list].replace('\[,', '[', regex=True)
        query[embed_list] = query[embed_list].replace(',]', ']', regex=True)
        query[embed_list] = query[embed_list].applymap(literal_eval).applymap(np.array)

        if 'cluster_vec' in query.columns: # Predefined clusters!
            query[['cluster_vec']] = query[['cluster_vec']].applymap(literal_eval).applymap(np.array)

    query.reset_index(inplace=True)
    query['id'] = [str(i) for i in list(query.index)]

    return query

# %%
dataset = "cuba_160"
query = read_query(dataset)
sim_table = compute_sim(query)

# %% [markdown]
# ## Plots

# %%
def plot_complexity_metric(all_iterations, all_complexities, column):
    max_val_list = []
    for idx, complexity in enumerate(all_complexities):
        max_val_list.append(max(complexity[column]))
    max_val = max(max_val_list) 
    fig, ax = plt.subplots(ncols=2, figsize=(10,4))
    ax[0].title.set_text('All runs')
    ax[0].set_xlabel('# of Iterations')
    ax[0].set_ylabel(column)
    ax[0].set_ylim(0, max_val)
    ax[1].title.set_text('Average')
    ax[1].set_xlabel('# of Iterations')
    ax[1].set_ylabel(column)
    ax[1].set_ylim(0, max_val)
    # All elements    
    for idx, complexity in enumerate(all_complexities):
        ax[0].plot(list(range(len(complexity[column]))), complexity[column], '-r')
    # Average
    max_iter = max(all_iterations)
    extended_metric_list = []
    for idx, complexity in enumerate(all_complexities):
        metric_list_extended = list(complexity[column]) + [list(complexity[column])[-1] for _ in range(max_iter - len(complexity[column]))]
        extended_metric_list.append(metric_list_extended)
    extended_metric_array = np.array(extended_metric_list)
    average_metric = np.nanmedian(extended_metric_array, axis=0)
    ax[1].plot(list(range(max_iter)), average_metric, '-r')
    
def plot_error_rate(all_iterations, all_percents):
    max_val_list = []
    for idx, percent_list in enumerate(all_percents):
        max_val_list.append(max(percent_list))
    max_val = max(max_val_list) 
    fig, ax = plt.subplots(ncols=2, figsize=(10,4))
    ax[0].title.set_text('All runs')
    ax[0].set_xlabel('# of Iterations')
    ax[0].set_ylabel('Error Rate')
    ax[0].set_ylim(0, max_val)
    ax[1].title.set_text('Average')
    ax[1].set_xlabel('# of Iterations')
    ax[1].set_ylabel('Error Rate')
    ax[1].set_ylim(0, max_val)
    # All elements
    for idx, percent_list in enumerate(all_percents):
        ax[0].plot(list(range(all_iterations[idx])), percent_list, '-r')
    # Average
    max_iter = max(all_iterations)
    extended_percent_list = []
    for percent_list in all_percents:
        percent_list_extended = percent_list + [percent_list[-1] for _ in range(max_iter - len(percent_list))]
        extended_percent_list.append(percent_list_extended)
    extended_percent_array = np.array(extended_percent_list)
    average_percent = np.nanmedian(extended_percent_array, axis=0)
    ax[1].plot(list(range(max_iter)), average_percent, '-r')

# %%
def plot_all(all_iterations, all_percents, all_complexities):
    plot_error_rate(all_iterations, all_percents)
    plot_complexity_metric(all_iterations, all_complexities, column='Nodes')
    plot_complexity_metric(all_iterations, all_complexities, column='Edges')
    plot_complexity_metric(all_iterations, all_complexities, column='Stories')
    plot_complexity_metric(all_iterations, all_complexities, column='Interstory Connections')

# %% [markdown]
# ## New Linear Program

# %%
def new_LP(query, sim_table, membership_vectors, clust_sim_table, exp_temp_table, ent_table, numclust, relevance_table,
    K, mincover, sigma_t, credibility=[], bias=[], operations=[],
    has_start=True, has_end=False, window_time=None, cluster_list=[], start_nodes=[], end_nodes=[],
    verbose=True, force_cluster=True, previous_varsdict=None):
    
    n = len(query.index) #We can cut out everything after the end.
    # Variable names and indices
    var_i = []
    var_ij = []
    var_k = [str(k) for k in range(0,numclust)]

    for i in range(0, n): # This goes up from 0 to n-1.
        var_i.append(str(i))
        for j in window_i_j[i]:
            if i == j:
                print("ERROR IN WINDOW - BASE")
            var_ij.append(str(i) + "_" + str(j))

    potential_edges = n * (n - 1) / 2
    
    # Linear program variable declaration.
    minedge = LpVariable("minedge", lowBound = 0, upBound = 1)
    node_act_vars = LpVariable.dicts("node_act", var_i, lowBound = 0, upBound = 1)
    node_next_vars = LpVariable.dicts("node_next", var_ij, lowBound = 0,  upBound = 1)
    clust_active_vars = LpVariable.dicts("clust_active", var_k, lowBound = 0, upBound = 1)

    # Create the 'prob' variable to contain the problem data
    prob = LpProblem("StoryChainProblem", LpMaximize)
    # The objective function is added to 'prob' first
    prob += minedge * potential_edges - lpSum([node_next_vars[ij] for ij in var_ij]), "WeakestLink"

    # Check duplicates in interactions
    replace = [False] * len(operations)
    for idx, op in enumerate(operations):
        op_ref = op.split(":",1)[1]
        for k in range(idx):
            if op_ref == operations[k].split(":",1)[1]:
                replace[k] = True
    # Fixtures.
    min_threshold_edge = 0.1 / K
    min_threshold_node = 0.4 / K
    for idx, op in enumerate(operations):
        op_ref = op.split(":",1)[1]
        # Omit ACL in this part, handle separetely.
        if "ACL" in op:
            continue

        temp = ""
        if "-" in op_ref:
            i = int(op_ref.split("-",1)[0])
            j = int(op_ref.split("-",1)[1])
            temp = str(i) + "_" + str(j)
        else:
            i = int(op_ref)
            temp = str(i)
        op_ref = temp

        if "AN" in op:
            if verbose:
                print('AddedNode ' + str(op_ref))
            if not replace[idx]:
                if prob.constraints.get('RemovedNode' + str(op_ref)) is not None:
                    del prob.constraints['RemovedNode' + str(op_ref)]
                prob += node_act_vars[str(op_ref)] >= min_threshold_node, 'AddedNode' + str(op_ref) # Makes problem infeasible if we add too many, divide threhsold by K? By number of added constraints?
        elif "AE" in op:
            if verbose:
                print('AddedEdge ' + str(op_ref))
            if not replace[idx]:
                if prob.constraints.get('RemovedEdge' + str(op_ref)) is not None:
                    del prob.constraints['RemovedEdge' + str(op_ref)]
                if str(op_ref) not in node_next_vars.keys():
                    # Special case for time-based windows where the time difference is too big.
                    # The connection does not exist by default and you need to add the variable manually for the specific edge.
                    node_next_vars[str(op_ref)] = LpVariable("node_next_" + str(op_ref), lowBound=0, upBound=1)
                    if i == j:
                        print("ERROR IN WINDOW - AE")
                    var_ij.append(str(op_ref))#str(i) + "_" + str(j))
                    window_i_j[i].append(j)
                    window_j_i[j].append(i)
                prob += node_next_vars[str(op_ref)] >= min_threshold_edge, 'AddedEdge' + str(op_ref)
        elif "RN" in op:
            if verbose:
                print('RemovedNode ' + str(op_ref))
            if not replace[idx]:
                if prob.constraints.get('AddedNode' + str(op_ref)) is not None:
                    del prob.constraints['AddedNode' + str(op_ref)]
                if prob.constraints.get('AddedNodeCluster' + str(op_ref)) is not None:
                    del prob.constraints['AddedNodeCluster' + str(op_ref)]
                prob += node_act_vars[str(op_ref)] == 0, 'RemovedNode' + str(op_ref)
        elif "RE" in op:
            if verbose:
                print('RemovedEdge ' + str(op_ref))
            if not replace[idx]:
                if prob.constraints.get('AddedEdge' + str(op_ref)) is not None:
                    del prob.constraints['AddedEdge' + str(op_ref)]
                prob += node_next_vars[str(op_ref)] == 0, 'RemovedEdge' + str(op_ref)

    if force_cluster:
        #min_threshold_edge = 0.1 / K
        #min_threshold_node = 0.4 / K
        min_threshold_edge = 0.05
        min_threshold_node = 0.01
        for cluster in cluster_list:
            cluster_sorted = sorted(cluster)
            #print("Cluster:")
            #print(cluster_sorted)
            for idx, event in enumerate(cluster_sorted):
                if verbose:
                    print('AddedNodeCluster ' + str(event))
                if prob.constraints.get('RemovedNode' + str(event)) is not None:
                    del prob.constraints['RemovedNode' + str(event)]
                if prob.constraints.get('AddedNodeCluster' + str(event)) is not None:
                    del prob.constraints['AddedNodeCluster' + str(event)]

                prob += node_act_vars[str(event)] >= min_threshold_node, 'AddedNodeCluster' + str(event)
                #print("Filtered cluster " + str(cluster_sorted[(idx + 1):]))
                if len(cluster_sorted[(idx + 1):]) >= 1:
                    for j in cluster_sorted[(idx + 1):]:
                        op_ref = str(event) + "_" + str(j)
                        #print("Forced connections: " + str(op_ref))
                        if str(op_ref) not in node_next_vars.keys():
                            # Special case for time-based windows where the time difference is too big.
                            # The connection does not exist by default and you need to add the variable manually for the specific edge.
                            if event == j:
                                print("ERROR IN WINDOW - ACL")
                            node_next_vars[str(op_ref)] = LpVariable("node_next_" + str(op_ref), lowBound=0, upBound=1)
                            var_ij.append(str(op_ref))
                            window_i_j[event].append(j)
                            window_j_i[j].append(event)
                            #print(window_i_j[i])
                            #print(window_j_i[i])
                    prob += lpSum([node_next_vars[str(event) + "_" + str(j)] for j in cluster_sorted[(idx + 1):]]) >= min_threshold_edge, 'InternalEdgeCluster' + str(event)
                    if verbose:
                        print('InternalEdgeCluster' + str(event) + ":" + str(cluster_sorted[(idx + 1):]))
    #for combination in itertools.combinations(cluster_list,2):
    #    for node_i in combination[0]:
    #        for node_j in combination[1]:
    #            if int(node_i) < int(node_j):
    #                prob += node_act_vars[str(op_ref)] >= min_threshold_node, 'AddedNode' + str(op_ref)

    # Chain restrictions
    if has_start:
        num_starts = len(start_nodes)
        if verbose:
            print("Start node(s):")
            print(start_nodes)
        if num_starts == 0: # This is the default when no list is given and it has a start.
            prob += node_act_vars[str(0)] == 1, 'InitialNode'
        else:
            if verbose:
                print("Added start node(s)")
                print("--- %s seconds ---" % (time() - start_time))
            initial_energy = 1.0 / num_starts
            earliest_start = min(start_nodes)
            for node in start_nodes:
                prob += node_act_vars[str(node)] == initial_energy, 'InitialNode' + str(node)
            for node in range(0, earliest_start):
                prob += node_act_vars[str(node)] == 0, 'BeforeStart' + str(node)
    if has_end:
        num_ends = len(end_nodes)
        if verbose:
            print("End node(s):")
            print(end_nodes)
        if num_ends == 0: # This is the default when no list is given and it has a start.
            prob += node_act_vars[str(n - 1)] == 1, 'FinalNode'
        else:
            if verbose:
                print("Added end node(s)")
                print("--- %s seconds ---" % (time() - start_time))
            final_energy = 1.0 / num_ends
            latest_end = min(end_nodes)
            for node in end_nodes:
                prob += node_act_vars[str(node)] == final_energy, 'FinalNode' + str(node)
            for node in range(latest_end + 1, n):
                prob += node_act_vars[str(node)] == 0, 'AfterEnd' + str(node)

    if verbose:
        print("Chain constraints created.")
        print("--- %s seconds ---" % (time() - start_time))
    prob += lpSum([node_act_vars[i] for i in var_i]) == K, 'KNodes'
    
    if verbose:
        print("Expected length constraints created.")
        print("--- %s seconds ---" % (time() - start_time))


    if has_start:
        if verbose:
            print("Equality constraints.")
            print("--- %s seconds ---" % (time() - start_time))
        for j in range(1, n):
            if j not in start_nodes:
                prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for i in window_j_i[j]]) == node_act_vars[str(j)], 'InEdgeReq' + str(j)
            else:
                if verbose:
                    print("Generating specific starting node constraints.")
                    print("--- %s seconds ---" % (time() - start_time))
                prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for i in window_j_i[j]]) == 0, 'InEdgeReq' + str(j)
    else:
        if verbose:
            print("Inequality constraints.")
            print("--- %s seconds ---" % (time() - start_time))
        for j in range(1, n):
            prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for i in window_j_i[j]]) <= node_act_vars[str(j)], 'InEdgeReq' + str(j)
    if verbose:
        print("In-degree constraints created.")
        print("--- %s seconds ---" % (time() - start_time))

    if has_end:
        if verbose:
            print("Equality constraints.")
            print("--- %s seconds ---" % (time() - start_time))
        for i in range(0, n - 1):
            if i not in end_nodes:
                prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for j in window_i_j[i]]) == node_act_vars[str(i)], 'OutEdgeReq'  + str(i)
            else:
                if verbose:
                    print("Generating specific starting node constraints.")
                    print("--- %s seconds ---" % (time() - start_time))
                prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for j in window_i_j[i]]) == 0, 'OutEdgeReq'  + str(i)
    else:
        if verbose:
            print("Inequality constraints.")
            print("--- %s seconds ---" % (time() - start_time))
        for i in range(0, n - 1):
            prob += lpSum([node_next_vars[str(i) + "_" + str(j)] for j in window_i_j[i]]) <= node_act_vars[str(i)], 'OutEdgeReq'  + str(i)
    if verbose:
        print("Out-degree constraints created.")
        print("--- %s seconds ---" % (time() - start_time))

    # Coverage
    if numclust > 1:
        prob += lpSum([clust_active_vars[str(k)] for k in var_k]) >= numclust * mincover, "MinCover"
        for k in range(0, numclust):
            prob += clust_active_vars[str(k)] == lpSum([node_next_vars[str(i) + "_" + str(j)] * sqrt(membership_vectors[i, k] * membership_vectors[j, k]) for i in range(0, n - 1) for j in window_i_j[i]]), "CoverDef" + str(k)
        if verbose:
            print("Clustering constraints created.")
            print("--- %s seconds ---" % (time() - start_time))
    else:
        if verbose:
            print("No clustering constraints created - only 1 cluster.")
            print("--- %s seconds ---" % (time() - start_time))

    # Objective
    for i in range(0, n):
        for j in window_i_j[i]:
            coherence_weights = [0.5, 0.5]
            entity_multiplier = min(1 + ent_table[i, j], 2) # Five or more entities in common means double the connection strength.
            relevance_multiplier = (relevance_table[i] * relevance_table[j]) ** 0.5 # Geometric mean the relevances, multiply based on how far it is from 0.5.
            coherence = (sim_table[i, j] ** coherence_weights[0]) * (clust_sim_table[i, j] ** coherence_weights[1])
            weighted_coherence = min(coherence * entity_multiplier * relevance_multiplier, 1.0)
            prob += minedge <= 1 - node_next_vars[str(i) + "_" + str(j)] + weighted_coherence, "Objective" + str(i) + "_" + str(j)
    if verbose:
        print("Objective constraints created.")
        print("--- %s seconds ---" % (time() - start_time))

    if previous_varsdict:
        current_names = [v.name for v in prob.variables() if "node_act" in v.name]
        if verbose:
            print("Generated list of names.")
            print("--- %s seconds ---" % (time() - start_time))
        for k, v in previous_varsdict.items():
            if "node_act" in k and k in current_names:
                node_act_vars[k.replace("node_act_", "")].setInitialValue(v)

    if verbose:
        if previous_varsdict:
            print("Used previous solution as starting point.")
            print("--- %s seconds ---" % (time() - start_time))
        else:
            print("No previous solution available.")
            print("--- %s seconds ---" % (time() - start_time))
    # The problem data is written to an .lp file
    return prob

# %% [markdown]
# ## LP Preprocessing

# %%
def solve_LP_from_query(query, dataset,
    operations=[], K = 6, mincover=0.20,
    min_samples=2, min_cluster_size=2,
    n_neighbors=2, min_dist=0.01,
    sigma_t = 30,
    start_nodes=[], end_nodes=[],
    verbose=True, random_state=42,
    force_cluster=True,
    use_entities=True, use_temporal=True, strict_start=False, umap_init='spectral', cosine_sim = True, use_new_LP=False):

    global start_time
    start_time = time()
    # Min-cluster-size = 10, n_neighbors=2
    doc_list = []
    for index, article in query.iterrows():
        doc_list.append(article['embed'])
    X = np.array(doc_list)

    # Find cluster list
    cluster_dict = {}
    for idx, op in enumerate(operations):
        if "ACL" in op:
            op_ref = op.split(":",1)[1]
            # Remove _out (this case only happens if you mark a story node before adding it to the map.)
            node_set = set([int(node.replace('_out', '')) for node in literal_eval(op_ref.split("-",1)[0])])
            cluster_id = int(op_ref.split("-",1)[1])
            if cluster_id not in cluster_dict:
                cluster_dict[cluster_id] = node_set
            else:
                for key, value in cluster_dict.items():
                    if key != cluster_id:
                        cluster_dict[key] = cluster_dict[key].difference(node_set) # Make sure we only keep the latest interaction.
                cluster_dict[cluster_id] = cluster_dict[cluster_id].union(node_set)
    cluster_list = []
    for key, value in cluster_dict.items():
        cluster_list.append([int(node) for node in value])
    if verbose:
        print("Cluster List (base) " + str(cluster_list))

    clusterable_embedding = umap.UMAP(n_neighbors=n_neighbors,  min_dist=min_dist, init=umap_init, random_state=np.random.RandomState(random_state)).fit_transform(X)
    
    if len(cluster_list) > 0:
        target = -np.ones(X.shape[0])
        for clust_idx, cluster in enumerate(cluster_list):
            target[cluster] = clust_idx
        clusterable_embedding = umap.UMAP(n_neighbors=n_neighbors, min_dist=min_dist, init=umap_init, random_state=np.random.RandomState(random_state)).fit_transform(X, y=target)
    if verbose:
        print("Computed projection.")
        print("--- %s seconds ---" % (time() - start_time))

    if cosine_sim:
        similarities = np.clip(cosine_similarity(clusterable_embedding), -1 , 1)
        # Force normalize
        sim_table = (1 - np.arccos(similarities) / pi)
        mask = np.ones(sim_table.shape, dtype=bool)
        np.fill_diagonal(mask, 0)
        max_value = sim_table[mask].max()
        min_value = sim_table[mask].min()
        sim_table = (sim_table - min_value) / (max_value - min_value)
        sim_table = np.clip(sim_table, 0, 1)
    else:
        dist_mat = distance.cdist(clusterable_embedding, clusterable_embedding, 'euclidean')

        mask = np.ones(dist_mat.shape, dtype=bool)
        np.fill_diagonal(mask, 0)
        max_value = dist_mat[mask].max()
        min_value = dist_mat[mask].min()
        dist_mat = (dist_mat - min_value)/(max_value - min_value)
        sim_table = np.clip(1 - dist_mat, -1, 1)
    if verbose:
        print("Computed similarities.")
        print("--- %s seconds ---" % (time() - start_time))


    hdbscan_model = hdbscan.HDBSCAN(min_samples=min_samples,min_cluster_size=min_cluster_size,prediction_data=True)
    labels = hdbscan_model.fit_predict(clusterable_embedding)
    membership_vectors = hdbscan.prediction.all_points_membership_vectors(hdbscan_model)
    numclust = 1
    clust_sim = np.zeros((membership_vectors.shape[0], membership_vectors.shape[0]))
    if verbose:
        print("Computed clustering.")
        print("--- %s seconds ---" % (time() - start_time))

    if len(membership_vectors.shape) > 1:
        numclust = membership_vectors.shape[1]
        membership_vectors[membership_vectors < 1/numclust] = 0
        #np.set_printoptions(threshold=sys.maxsize)
        # If any row is full of zeros replace with uniform distribution.
        membership_vectors[np.all(membership_vectors == 0, axis=1)] = np.ones(numclust) / numclust
        row_sums = membership_vectors.sum(axis=1)
        membership_vectors = membership_vectors / row_sums[:, np.newaxis]
        clust_sim = distance.cdist(membership_vectors, membership_vectors, lambda u,v:distance.jensenshannon(u,v,base=2.0))
    else:
        membership_vectors = np.ones((membership_vectors.shape[0], 1)) # No clusters special case (all noise according to HDBSCAN)

    clust_sim_table = 1 - clust_sim
    if verbose:
        print("Computed clustering similarities.")
        print("--- %s seconds ---" % (time() - start_time))

    n = len(query.index)
    # Compute temporal distances

    varsdict_filename = 'varsdict_' + dataset  + "_" + str(n) + '.pickle'

    temporal_distance_table = compute_temp_distance_table(query, dataset)

    if sigma_t != 0 and use_temporal:
        exp_temp_table = np.exp(-temporal_distance_table / sigma_t)
    else:
        exp_temp_table = np.ones(temporal_distance_table.shape)

    if verbose:
        print("Computed temporal distance table.")
        print("--- %s seconds ---" % (time() - start_time))

    window_time = None
    if sigma_t != 0 and use_temporal:
        window_time = sigma_t * 3 # Days

    if window_time is None:
        for i in range(0, n):
            window_i_j[i] = list(range(i + 1, n))
        for j in range(0, n):
            window_j_i[j] = list(range(0, j))
    else:
        for j in range(0, n):
            window_j_i[j] = []
        for i in range(0, n):
            window_i_j[i] = []
        for i in range(0, n - 1):
            window = 0
            for j in range(i + 1, n):
                if temporal_distance_table[i,j] <= window_time:
                    window += 1
            window = max(min(5, n - i), window)
            window_i_j[i] = list(range(i + 1, min(i + window, n)))
            for j in window_i_j[i]:
                window_j_i[j].append(i)

    if verbose:
        print("Computed temporal windows.")
        print("--- %s seconds ---" % (time() - start_time))

    ent_table, ent_doc_list = get_entity_table(query, dataset)
    if verbose:
        print("Computed entity similarities.")
        print("--- %s seconds ---" % (time() - start_time))
    if not use_entities:
        ent_table = np.zeros(ent_table.shape)

    # Deprecated relevance table computation
    relevance_table = [1.0] * membership_vectors.shape[0] # Create a vector full of 1s
    focus_query = None
    if focus_query: # Uses focus_query (string)
        #torch.cuda.empty_cache()
        model = SentenceTransformer('all-MiniLM-L6-v2')
        q = model.encode(focus_query)
        q = q.reshape(1, -1)
        euc_dist = distance.cdist(q, X, metric='euclidean')
        euc_dist = (euc_dist - np.min(euc_dist)) / (np.max(euc_dist) - np.min(euc_dist))
        sim_list = 1 - euc_dist
        relevance_table = sim_list[0] # Remove one dimension.
        if verbose:
            print("Computed query relevance table.")
            print("--- %s seconds ---" % (time() - start_time))

    has_start = False
    if start_nodes is not None:
        has_start = (len(start_nodes) > 0)
    if end_nodes is not None:
        has_end = (len(end_nodes) > 0)
    if verbose:
        print("Creating LP...")

    # Read previous solution and feed to LP. If none there is no previous solution.
    previous_varsdict = None
    if os.path.isfile(varsdict_filename):
        with open(varsdict_filename, 'rb') as handle:
            previous_varsdict = pickle.load(handle)
    if use_new_LP:
        prob = new_LP(query, sim_table, membership_vectors, clust_sim_table, exp_temp_table, ent_table, numclust, relevance_table,
            K=K, mincover=mincover, sigma_t=sigma_t,
            operations=operations, cluster_list=cluster_list,
            has_start=has_start, has_end=has_end,
            start_nodes=start_nodes, end_nodes=end_nodes, verbose=verbose, force_cluster=force_cluster)
    else:
        prob = create_LP(query, sim_table, membership_vectors, clust_sim_table, exp_temp_table, ent_table, numclust, relevance_table,
            K=K, mincover=mincover, sigma_t=sigma_t,
            operations=operations, cluster_list=cluster_list,
            has_start=has_start, has_end=has_end,
            start_nodes=start_nodes, end_nodes=end_nodes, verbose=verbose, force_cluster=force_cluster)
    if verbose:
        print("Saving model...")
        print("--- %s seconds ---" % (time() - start_time))
    prob.writeLP("left_story.lp")
    if verbose:
        print("Solving model...")
        print("--- %s seconds ---" % (time() - start_time))
    prob.solve(PULP_CBC_CMD(mip=False, warmStart=True))#(GLPK_CMD(path = 'C:\\glpk-4.65\\w64\\glpsol.exe', options = ["--tmlim", "180"]))


    varsdict = extract_varsdict(prob)
    # Overwrite last solution.
    with open(varsdict_filename, 'wb') as handle:
        pickle.dump(varsdict, handle, protocol=pickle.HIGHEST_PROTOCOL)
    graph_df = build_graph_df_multiple_starts(query, varsdict, prune=ceil(sqrt(K)), threshold=0.1/K, cluster_dict=cluster_dict)
    #graph_df = build_graph_df_multiple_starts(query, varsdict, prune=None, threshold=0.0/K, cluster_dict=cluster_dict)

    if verbose:
        print("Graph data frame construction...")
        print("--- %s seconds ---" % (time() - start_time))

    if strict_start:
        graph_df = graph_clean_up(graph_df, start_nodes)

    if verbose:
        print("Graph clean up...")
        print("--- %s seconds ---" % (time() - start_time))

    cluster_assignment = np.argmax(membership_vectors, axis=1)
    scatter_df = pd.DataFrame(data=clusterable_embedding, columns=['X', 'Y'])
    scatter_df['id'] = query['id']
    scatter_df['cluster_id'] = cluster_assignment
    scatter_df['cluster_id'] = scatter_df['cluster_id'].astype(str)
    scatter_df['title'] = query['title']

    if verbose:
        print("Scatter data frame construction...")
        print("--- %s seconds ---" % (time() - start_time))

    return [graph_df, (numclust, LpStatus[prob.status]), scatter_df, sim_table, clust_sim_table, ent_table, ent_doc_list, cluster_assignment]

# %% [markdown]
# ## LP Wrapper

# %%
def generate_map(query, dataset, previous_actions=[], k_input=8, mincover_input=30, window=30, start_nodes=[], 
                 verbose=True, random_state=42, force_cluster=False, use_temporal=True, use_entities=False, use_new_LP=False):
    operation_list = []
    for item in previous_actions:
        if item.get("action") == "add-node":
            for node in item['content']:
                operation_list.append("AN:" + node)
        elif item.get("action") == "add-edge":
             operation_list.append("AE:" + item["content"])
        elif item.get("action") == "remove-node":
            for node in item['content']:
                operation_list.append("RN:" + node)
        elif item.get("action") == "remove-edge":
            for edge in item['content']:
                operation_list.append("RE:" + edge)
        elif item.get("action") == "add-cluster-list":
             operation_list.append("ACL:" + str(item['content'][0]) + "-" + str(item['content'][1]))
    
    # Solve LP and create new graph_df.
    cluster_size_est = np.sqrt(len(query.index))/2
    cluster_size_est = 5 * round(cluster_size_est / 5) # Round to nearest multiple of 5
    n_neighbors = 2
    if len(query.index) > 40:
        n_neighbors = 10
    elif len(query.index) > 120:
        n_neighbors = cluster_size_est

    graph_df_new, status, scatter_df, sim_table, clust_sim_table, ent_table, ent_doc_list, cluster_assignment = solve_LP_from_query(query, 
        dataset=dataset, operations=operation_list, 
        K=k_input, mincover=mincover_input/100, 
        min_samples=2, min_cluster_size=cluster_size_est, n_neighbors=n_neighbors, min_dist=1/100,
        start_nodes=start_nodes, verbose=verbose, random_state=random_state, force_cluster=force_cluster,
        use_temporal=use_temporal, use_entities=use_entities, use_new_LP=use_new_LP)        

    status_msg = "LP Status: " + status[1] + ", Clusters: " + str(status[0])

    if 'Optimal' in status[1]:
        # Generate graph from LP solution.
        G = build_graph(graph_df_new)
        storylines = graph_stories(G, start_nodes=start_nodes, end_nodes=[])
        status_msg += ", Storylines: " + str(len(storylines))

        # We now apply transitive reduction.
        remove_list_transitive = []
        for story in storylines:
            max_idx = len(story) - 1
            for idx, node in enumerate(story):
                out_edges = G.out_edges(node)
                # If it's not the last element in the story (no need to clean the last one, because there are no in-story outgoing edges)
                if idx != max_idx:
                    for edge in out_edges:
                        if edge[1] in story and edge[1] != story[idx + 1]: # If it's an in-story edge and not the immediately adjacent one.
                            remove_list_transitive.append(edge)
        G.remove_edges_from(remove_list_transitive)
        # We now filter redundant interstory connections.
        remove_list_interstory = []
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            keep_set = set()
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            if len(edge_boundary_list_i) > 0:
                earliest_i = min(edge_boundary_list_i, key = lambda t: (t[0], t[1]))
                latest_i = max(edge_boundary_list_i, key = lambda t: (t[0], t[1]))
            else:
                earliest_i = None
            if len(edge_boundary_list_j) > 0:
                earliest_j = min(edge_boundary_list_j, key = lambda t: (t[1], t[0]))
                latest_j = max(edge_boundary_list_j, key = lambda t: (t[1], t[0]))
            else:
                earliest_j = None
            if not earliest_i and not earliest_j:
                # No connections
                continue
            elif earliest_i and not earliest_j:
                # One-sided.
                if earliest_i == latest_i: # There's only one connection, keep it.
                    continue
                elif earliest_i[0] == latest_i[0]:
                    # This means that the second values are different, but the first one is the same.
                    # For this special case we keep the earliest one.
                    keep_set.add(earliest_i)
                else:
                    # Keep both
                    keep_set.add(earliest_i)
                    keep_set.add(latest_i)
            elif not earliest_i and earliest_j:
                # One-sided and reversed.
                if earliest_j == latest_j: # There's only one connection, keep it.
                    continue
                elif earliest_j[1] == latest_j[1]:
                    # This means that the first values are different, but the second one is the same.
                    # For this special case we keep the earliest one.
                    keep_set.add(earliest_j)
                else:
                    # Keep both
                    keep_set.add(earliest_j)
                    keep_set.add(latest_j)
            else:
                # Two-sided.
                if earliest_i[0] < earliest_j[1]:
                    # E_i happened first. Keep it
                    keep_set.add(earliest_i)
                    if latest_i[0] > latest_j[1]:
                        # L_i happened last. Keep it.
                        keep_set.add(latest_i)
                    else:
                        keep_set.add(latest_j)
                else:
                    # E_j happened first.
                    keep_set.add(earliest_j)
                    if latest_i[0] > latest_j[1]:
                        # E_i happened last. Keep it.
                        keep_set.add(latest_i)
                    else:
                        keep_set.add(latest_j)
            redundant_edge_set = set(edge_boundary_list_i) | set(edge_boundary_list_j)
            remove_list_interstory += list(redundant_edge_set - keep_set)

        G.remove_edges_from(remove_list_interstory)

        for node in G.nodes:
            sum_node = sum([exp(-data['weight']) for u, v, data in G.out_edges(node, data=True)])
            if sum_node == 0:
                continue
            for u, v, data in G.out_edges(node, data=True):
                G[u][v]['weight'] = -log(exp(-data['weight']) / sum_node)
            sum_node = sum([exp(-G[u][v]['weight']) for u, v, data in G.out_edges(node, data=True)])
        # Update graph_df
        for i, row in graph_df_new.iterrows():
            new_adj_list = [v for u, v in G.out_edges(str(row['id']))]
            new_adj_weights = [exp(-G[u][v]['weight']) for u, v in G.out_edges(str(row['id']))]
            graph_df_new.at[i,'adj_list'] = new_adj_list
            graph_df_new.at[i,'adj_weights'] = new_adj_weights

        for node in G.nodes:  
            sum_node = sum([exp(-data['weight']) for u, v, data in G.out_edges(node, data=True)])
            if sum_node == 0:
                continue
            for u, v, data in G.out_edges(node, data=True):
                G[u][v]['weight'] = -log(exp(-data['weight']) / sum_node)
            sum_node = sum([exp(-data['weight']) for u, v, data in G.out_edges(node, data=True)])

        # Update graph_df
        for i, row in graph_df_new.iterrows():
            new_adj_list = [v for u, v in G.out_edges(str(row['id']))]
            new_adj_weights = [exp(-G[u][v]['weight']) for u, v in G.out_edges(str(row['id']))]
            graph_df_new.at[i,'adj_list'] = new_adj_list
            graph_df_new.at[i,'adj_weights'] = new_adj_weights
            
        #print(graph_df_new)
        return G, graph_df_new, storylines

# %% [markdown]
# ## GraphViz

# %%
def is_path_edge(i, j, val_list):
    k = 0
    while int(val_list[k]) <= int(i):
        if int(val_list[k]) == int(i) and int(val_list[k+1]) == int(j):
            return True
        k += 1
        if k >= len(val_list):
            return False
    return False

# %%
def graph_viz_gen(graph_df, sp, full=False, antichains=None):
    col_pol = {'FL': "#021893", 'LL': "#3537ae", 'CM': "#740699", 'LR': "#b70b0b", 'FR': "#990623"}
    transparency = "60" #80 is 50%
    graph_viz_clean = None
    start = int(sp[0])
    end = int(sp[-1])

    graph_viz = "digraph Story { \n" 
    graph_viz += "graph [fontname = \"candara\"];\n"
    graph_viz += "node [shape=none, margin=0, fontname = \"candara\"];\n"
    graph_viz += "edge [fontname = \"calibri light\"];\n"
        
    if antichains is not None:
        graph_viz += "subgraph cluster_antichain { \n"
        graph_viz += "style=filled; color=lightgray; label =<<b>Max Antichain</b>>; labeljust=\"l\"; \n"
        for idx in antichains:
            row = graph_df.loc[graph_df['index'] == idx]
            node_label = '<table><tr><td><b>' + row['publication'].values[0] + '</b></td><td>' + row['date'].values[0] + '</td></tr><tr><td colspan="2">' + row['title'].values[0].replace("\"", "'") + '</td></tr></table>'
            #node_label = "{" + "{" + row['publication'].values[0] + "|" + row['date'].values[0] + "}" + "| " + row['title'].values[0].replace("\"", "'") + "}"
            color = "style=filled, fillcolor=\"" + col_pol['LL'] + transparency + "\""
            color += ", color=black"
            url = row['url'].values[0]
            if pd.isna(url):
                href = "href=\"#\""
            else:
                href = "href=\"" + url + "\""
            tooltip = "tooltip=\"" + row['title'].values[0].replace("\"", "'") + "\""
            #graph_viz += "\"" + str(idx) + "\"" + " [label=\"" + node_label + "\", " + color + "] \n"
            graph_viz += "\"" + str(idx) + "\"" + " [label=<" + node_label + ">, " + color + "," + href + "," + tooltip + "] \n"
        graph_viz += "} \n"
    for index, row in graph_df.iterrows():
        if antichains is not None:
            if row['id'] not in antichains:
                if row['id'] == end or row['id'] == start:
                    node_label = '<table BORDER="2" CELLSPACING="0"><tr><td><b>' + row['publication'] + '</b></td><td>' + row['date'] + '</td></tr><tr><td colspan="2">' + row['title'].replace("\"", "'") + '</td></tr></table>'
                else:
                    node_label = '<table BORDER="0" CELLBORDER="1" CELLSPACING="0"><tr><td><b>' + row['publication'] + '</b></td><td>' + row['date'] + '</td></tr><tr><td colspan="2">' + row['title'].replace("\"", "'") + '</td></tr></table>'
                color = "style=filled, fillcolor=\"" +  col_pol['LL'] + transparency + "\""
                url = row['url']
                if pd.isna(url):
                    href = "href=\"#\""
                else:
                    href = "href=\"" + url + "\""
                tooltip = "tooltip=\"" + row['title'].replace("\"", "'") + "\""
                graph_viz += "\"" + str(row['id']) + "\"" + " [label=<" + node_label + ">, " + color + "," + href + "," + tooltip + "] \n"
        else:
            if row['id'] == end or row['id'] == start:
                node_label = '<table BORDER="2" CELLSPACING="0"><tr><td><b>' + row['publication'] + '</b></td><td>' + row['date'] + '</td></tr><tr><td colspan="2">' + row['title'].replace("\"", "'") + '</td></tr></table>'
                #node_label = "{" + "{" + row['publication'] + "|" + row['date'] + "}" + "| " + row['title'].replace("\"", "'") + "}"
            else:
                node_label = '<table BORDER="0" CELLBORDER="1" CELLSPACING="0"><tr><td><b>' + row['publication'] + '</b></td><td>' + row['date'] + '</td></tr><tr><td colspan="2">' + row['title'].replace("\"", "'") + '</td></tr></table>'
           
            color = "style=filled, fillcolor=\"" +  col_pol['LL'] + transparency + "\""
            url = row['url']
            if pd.isna(url):
                href = "href=\"#\""
            else:
                href = "href=\"" + url + "\""
            tooltip = "tooltip=\"" + row['title'].replace("\"", "'") + "\""
            graph_viz += "\"" + str(row['id']) + "\"" + " [label=<" + node_label + ">, " + color + "," + href + "," + tooltip + "] \n"
               
        # Edges are always added, regardless of previous status.
        for idx, adj in enumerate(row['adj_list']):
            if is_path_edge(row['id'], adj, sp):
                edge_label = "[ label=\"" + str(round(row['adj_weights'][idx],3)) + "\",penwidth=4]"
            else:
                edge_label = "[ label=\"" + str(round(row['adj_weights'][idx],3)) + "\" ]"
            graph_viz += "\"" + str(row['id']) + "\"" + "->" + "\"" + str(adj) + "\"" + edge_label + " \n"

    graph_viz_clean = graph_viz + "}"
        
    return graph_viz_clean

# %% [markdown]
# ## Solve map (basic LP)

# %%
G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=[], verbose=False, random_state=42)

# %%
graph_df['date'] = graph_df['date'].apply(lambda x: x.strftime("%m/%d/%Y"))

# %% [markdown]
# ## Generate Viz

# %%
dot_source = graph_viz_gen(graph_df, sp=storylines[0])
text_file = open("test.js", "w")
temp_js = dot_source.replace("C:/Users/brian/Desktop/StoryChains", "./")
n = text_file.write("dotSrc = `" + temp_js + "`")
text_file.close()
    
graphs = pydot.graph_from_dot_data(dot_source)
svg_string = graphs[0].create_svg()
graphs[0].write_svg('test.svg')  
svg_string = svg_string.replace(b"C:/Users/brian/Desktop/StoryChains/", b"")
svg_cut = svg_string.replace(b'<?xml version="1.0" encoding="UTF-8" standalone="no"?>\r\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\r\n "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\r\n<!-- Generated by graphviz version 2.38.0 (20140413.2041)\r\n -->\r\n<!-- Title: Story Pages: 1 -->\r\n',b'')
svg_cut = svg_string.replace(b'<a xlink:href',b'<a target="_blank" xlink:href')
html_string = b"""<div><style>path:hover{stroke-width:5;stroke:green;transition:0.3s}
            a:hover polygon {
            transition:1.0s;
            fill: #606060!important;
            fill-opacity: 0.2!important;
            opacity: 1.0!important;
            stroke: #646464;
            stroke-width: 1px;
            stroke-linejoin: round;
            }</style></div><div>""" + svg_cut + b"</div>"
with open('test.html', 'wb') as f:
    f.write(html_string)
display(SVG(svg_string))

# %%
# Complexity metrics
n_nodes = G.number_of_nodes()# Number of nodes
n_edges = G.number_of_edges()# Number of edges
n_stories = len(storylines)# Number of storylines
n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
total_interstory = 0
for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
    edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
    edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
    total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
# Number of inter-story connections 
complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
print("Complexity: " + str(complexity_list))
# Out:
# Complexity: [26, 29, 6, 4, 2, 9]

# %% [markdown]
# ## Solve map (newLP)

# %%
G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=[], verbose=False, random_state=42, use_new_LP=True)

# %%
graph_df['date'] = graph_df['date'].apply(lambda x: x.strftime("%m/%d/%Y"))

# %% [markdown]
# ## Generate Viz

# %%
dot_source = graph_viz_gen(graph_df, sp=storylines[0])
text_file = open("test.js", "w")
temp_js = dot_source.replace("C:/Users/brian/Desktop/StoryChains", "./")
n = text_file.write("dotSrc = `" + temp_js + "`")
text_file.close()
    
graphs = pydot.graph_from_dot_data(dot_source)
svg_string = graphs[0].create_svg()
graphs[0].write_svg('test.svg')  
svg_string = svg_string.replace(b"C:/Users/brian/Desktop/StoryChains/", b"")
svg_cut = svg_string.replace(b'<?xml version="1.0" encoding="UTF-8" standalone="no"?>\r\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\r\n "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\r\n<!-- Generated by graphviz version 2.38.0 (20140413.2041)\r\n -->\r\n<!-- Title: Story Pages: 1 -->\r\n',b'')
svg_cut = svg_string.replace(b'<a xlink:href',b'<a target="_blank" xlink:href')
html_string = b"""<div><style>path:hover{stroke-width:5;stroke:green;transition:0.3s}
            a:hover polygon {
            transition:1.0s;
            fill: #606060!important;
            fill-opacity: 0.2!important;
            opacity: 1.0!important;
            stroke: #646464;
            stroke-width: 1px;
            stroke-linejoin: round;
            }</style></div><div>""" + svg_cut + b"</div>"
with open('test.html', 'wb') as f:
    f.write(html_string)
display(SVG(svg_string))

# %%
# Complexity metrics
n_nodes = G.number_of_nodes()# Number of nodes
n_edges = G.number_of_edges()# Number of edges
n_stories = len(storylines)# Number of storylines
n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
total_interstory = 0
for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
    edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
    edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
    total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
# Number of inter-story connections 
complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
print("Complexity: " + str(complexity_list))
# Out:
# Complexity: [16, 19, 6, 4, 2, 9]

# %% [markdown]
# ## Simulation (new LP)

# %%
base_total_samples = 10

# %% [markdown]
# ## Remove Nodes
# ### Removing Nodes from Map (Right-leaning articles only)
# Goal: Remove right-biased news articles from the map. We fix a center starting point from Reuters: "Cuba sees biggest protests for decades as pandemic adds to woes" (Node ID: 124)

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state, use_new_LP=True)
        filter_nodes = graph_df[graph_df.bias == 'Right']
        percent_filter_nodes = len(filter_nodes.index) / len(graph_df.index)
        remove_node_list = [str(node) for node in filter_nodes.id.tolist()]
        remove_node = {"action": "remove-node", "content": remove_node_list}
        previous_actions.append(remove_node)
        percent_list.append(percent_filter_nodes)
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list

    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.36363636363636365 {'action': 'remove-node', 'content': ['35', '36', '49', '64', '112', '127', '132', '136']}
# Complexity: [22, 28, 6, 4, 2, 12]
# Step: 2 0.32 {'action': 'remove-node', 'content': ['17', '31', '40', '51', '52', '54', '76', '131']}
# Complexity: [25, 30, 8, 3, 5, 13]
# Step: 3 0.09090909090909091 {'action': 'remove-node', 'content': ['58', '150']}
# Complexity: [22, 26, 7, 3, 4, 11]
# Step: 4 0.05263157894736842 {'action': 'remove-node', 'content': ['103']}
# Complexity: [19, 22, 6, 3, 3, 9]
# Step: 5 0.09523809523809523 {'action': 'remove-node', 'content': ['22', '134']}
# Complexity: [21, 25, 9, 4, 5, 13]
# Step: 6 0.043478260869565216 {'action': 'remove-node', 'content': ['53']}
# Complexity: [23, 28, 9, 3, 6, 14]
# Step: 7 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 24, 8, 3, 5, 12]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.2727272727272727 {'action': 'remove-node', 'content': ['18', '45', '59', '71', '89', '127']}
# Complexity: [22, 29, 8, 4, 4, 15]
# Step: 2 0.1 {'action': 'remove-node', 'content': ['49', '72']}
# Complexity: [20, 23, 7, 4, 3, 10]
# Step: 3 0.2 {'action': 'remove-node', 'content': ['52', '53', '66', '69']}
# Complexity: [20, 25, 6, 4, 2, 11]
# Step: 4 0.09090909090909091 {'action': 'remove-node', 'content': ['54', '96']}
# Complexity: [22, 24, 6, 5, 1, 8]
# Step: 5 0.125 {'action': 'remove-node', 'content': ['47', '73', '93']}
# Complexity: [24, 30, 7, 5, 2, 13]
# Step: 6 0.041666666666666664 {'action': 'remove-node', 'content': ['116']}
# Complexity: [24, 28, 9, 6, 3, 13]
# Step: 7 0.16 {'action': 'remove-node', 'content': ['28', '64', '84', '129']}
# Complexity: [25, 30, 8, 5, 3, 13]
# Step: 8 0.043478260869565216 {'action': 'remove-node', 'content': ['22']}
# Complexity: [23, 27, 5, 5, 0, 9]
# Step: 9 0.045454545454545456 {'action': 'remove-node', 'content': ['131']}
# Complexity: [22, 26, 8, 4, 4, 12]
# Step: 10 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 24, 4, 3, 1, 8]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.4444444444444444 {'action': 'remove-node', 'content': ['22', '36', '49', '64', '66', '84', '127', '136']}
# Complexity: [18, 20, 4, 3, 1, 6]
# Step: 2 0.45 {'action': 'remove-node', 'content': ['40', '51', '52', '53', '54', '69', '89', '95', '132']}
# Complexity: [20, 22, 5, 4, 1, 7]
# Step: 3 0.17647058823529413 {'action': 'remove-node', 'content': ['35', '76', '93']}
# Complexity: [17, 20, 5, 3, 2, 8]
# Step: 4 0.16666666666666666 {'action': 'remove-node', 'content': ['17', '45', '58']}
# Complexity: [18, 20, 4, 3, 1, 6]
# Step: 5 0.043478260869565216 {'action': 'remove-node', 'content': ['28']}
# Complexity: [23, 25, 6, 4, 2, 8]
# Step: 6 0.05 {'action': 'remove-node', 'content': ['16']}
# Complexity: [20, 26, 6, 4, 2, 12]
# Step: 7 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [22, 25, 8, 4, 4, 11]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.4230769230769231 {'action': 'remove-node', 'content': ['18', '36', '56', '58', '69', '72', '89', '96', '103', '134', '136']}
# Complexity: [26, 26, 5, 5, 0, 5]
# Step: 2 0.15384615384615385 {'action': 'remove-node', 'content': ['17', '22', '23', '45']}
# Complexity: [26, 29, 8, 7, 1, 11]
# Step: 3 0.05 {'action': 'remove-node', 'content': ['28']}
# Complexity: [20, 21, 5, 3, 2, 6]
# Step: 4 0.05 {'action': 'remove-node', 'content': ['16']}
# Complexity: [20, 21, 5, 3, 2, 6]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 21, 5, 4, 1, 6]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.2777777777777778 {'action': 'remove-node', 'content': ['35', '40', '53', '59', '127']}
# Complexity: [18, 25, 9, 3, 6, 16]
# Step: 2 0.45454545454545453 {'action': 'remove-node', 'content': ['28', '66', '69', '73', '84', '93', '104', '129', '131', '132']}
# Complexity: [22, 26, 8, 3, 5, 12]
# Step: 3 0.23529411764705882 {'action': 'remove-node', 'content': ['18', '108', '112', '136']}
# Complexity: [17, 20, 7, 3, 4, 10]
# Step: 4 0.11764705882352941 {'action': 'remove-node', 'content': ['76', '150']}
# Complexity: [17, 19, 7, 3, 4, 9]
# Step: 5 0.05263157894736842 {'action': 'remove-node', 'content': ['146']}
# Complexity: [19, 20, 7, 4, 3, 8]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [15, 18, 5, 3, 2, 8]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.391304347826087 {'action': 'remove-node', 'content': ['19', '36', '47', '56', '64', '66', '84', '104', '108']}
# Complexity: [23, 27, 6, 3, 3, 10]
# Step: 2 0.18181818181818182 {'action': 'remove-node', 'content': ['17', '35', '54', '132']}
# Complexity: [22, 25, 7, 4, 3, 10]
# Step: 3 0.21428571428571427 {'action': 'remove-node', 'content': ['53', '58', '76', '127', '133', '150']}
# Complexity: [28, 31, 11, 7, 4, 14]
# Step: 4 0.1111111111111111 {'action': 'remove-node', 'content': ['16', '129', '146']}
# Complexity: [27, 28, 6, 5, 1, 7]
# Step: 5 0.05263157894736842 {'action': 'remove-node', 'content': ['136']}
# Complexity: [19, 19, 5, 3, 2, 5]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 25, 8, 4, 4, 13]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.4090909090909091 {'action': 'remove-node', 'content': ['35', '36', '45', '47', '69', '76', '89', '127', '134']}
# Complexity: [22, 26, 6, 3, 3, 10]
# Step: 2 0.20833333333333334 {'action': 'remove-node', 'content': ['51', '53', '54', '93', '116']}
# Complexity: [24, 31, 10, 4, 6, 17]
# Step: 3 0.25 {'action': 'remove-node', 'content': ['18', '40', '56', '58', '129']}
# Complexity: [20, 22, 5, 4, 1, 7]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 24, 5, 4, 1, 9]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.30434782608695654 {'action': 'remove-node', 'content': ['36', '47', '49', '59', '64', '84', '108']}
# Complexity: [23, 27, 6, 5, 1, 10]
# Step: 2 0.14285714285714285 {'action': 'remove-node', 'content': ['66', '73', '96']}
# Complexity: [21, 23, 6, 3, 3, 8]
# Step: 3 0.08695652173913043 {'action': 'remove-node', 'content': ['17', '19']}
# Complexity: [23, 27, 9, 6, 3, 13]
# Step: 4 0.2608695652173913 {'action': 'remove-node', 'content': ['18', '29', '40', '53', '54', '146']}
# Complexity: [23, 25, 5, 3, 2, 7]
# Step: 5 0.1 {'action': 'remove-node', 'content': ['104', '150']}
# Complexity: [20, 24, 6, 4, 2, 10]
# Step: 6 0.047619047619047616 {'action': 'remove-node', 'content': ['131']}
# Complexity: [21, 25, 7, 6, 1, 11]
# Step: 7 0.09523809523809523 {'action': 'remove-node', 'content': ['127', '132']}
# Complexity: [21, 25, 5, 5, 0, 9]
# Step: 8 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [22, 26, 7, 6, 1, 11]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.5 {'action': 'remove-node', 'content': ['17', '21', '31', '58', '84', '89', '134']}
# Complexity: [14, 19, 7, 2, 5, 12]
# Step: 2 0.25 {'action': 'remove-node', 'content': ['35', '49', '51', '127']}
# Complexity: [16, 20, 5, 3, 2, 9]
# Step: 3 0.2777777777777778 {'action': 'remove-node', 'content': ['16', '40', '52', '69', '96']}
# Complexity: [18, 20, 4, 3, 1, 6]
# Step: 4 0.21052631578947367 {'action': 'remove-node', 'content': ['29', '36', '59', '136']}
# Complexity: [19, 23, 7, 3, 4, 11]
# Step: 5 0.058823529411764705 {'action': 'remove-node', 'content': ['45']}
# Complexity: [17, 21, 7, 4, 3, 11]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [16, 19, 6, 3, 3, 9]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.375 {'action': 'remove-node', 'content': ['23', '36', '45', '52', '53', '93', '118', '127', '146']}
# Complexity: [24, 26, 7, 3, 4, 9]
# Step: 2 0.18181818181818182 {'action': 'remove-node', 'content': ['22', '89', '96', '134']}
# Complexity: [22, 23, 6, 4, 2, 7]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 21, 5, 4, 1, 6]

# %%
results_delete_right = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts, "complexity": [p.to_dict() for p in all_complexities]}
with open('results_delete_right.json', 'w') as fp:
    json.dump(results_delete_right, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Fox and Breitbart only

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state, use_new_LP=True)
        filter_nodes = graph_df[graph_df['url'].str.contains('foxnews') | graph_df['url'].str.contains('breitbart')]
        percent_filter_nodes = len(filter_nodes.index) / len(graph_df.index)
        remove_node_list = [str(node) for node in filter_nodes.id.tolist()]
        remove_node = {"action": "remove-node", "content": remove_node_list}
        previous_actions.append(remove_node)
        percent_list.append(percent_filter_nodes)
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.36363636363636365 {'action': 'remove-node', 'content': ['35', '36', '49', '64', '112', '127', '132', '136']}
# Complexity: [22, 28, 6, 4, 2, 12]
# Step: 2 0.16 {'action': 'remove-node', 'content': ['40', '51', '52', '54']}
# Complexity: [25, 30, 8, 3, 5, 13]
# Step: 3 0.13636363636363635 {'action': 'remove-node', 'content': ['58', '103', '150']}
# Complexity: [22, 27, 9, 4, 5, 14]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [23, 28, 9, 4, 5, 14]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.22727272727272727 {'action': 'remove-node', 'content': ['18', '45', '59', '71', '127']}
# Complexity: [22, 29, 8, 4, 4, 15]
# Step: 2 0.15384615384615385 {'action': 'remove-node', 'content': ['49', '66', '69', '72']}
# Complexity: [26, 31, 10, 4, 6, 15]
# Step: 3 0.09090909090909091 {'action': 'remove-node', 'content': ['52', '84']}
# Complexity: [22, 24, 6, 3, 3, 8]
# Step: 4 0.13043478260869565 {'action': 'remove-node', 'content': ['47', '54', '93']}
# Complexity: [23, 27, 10, 6, 4, 14]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [28, 32, 8, 6, 2, 12]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.3888888888888889 {'action': 'remove-node', 'content': ['36', '49', '64', '66', '84', '127', '136']}
# Complexity: [18, 20, 4, 3, 1, 6]
# Step: 2 0.15789473684210525 {'action': 'remove-node', 'content': ['35', '45', '132']}
# Complexity: [19, 21, 6, 3, 3, 8]
# Step: 3 0.047619047619047616 {'action': 'remove-node', 'content': ['28']}
# Complexity: [21, 23, 6, 5, 1, 8]
# Step: 4 0.1875 {'action': 'remove-node', 'content': ['40', '52', '108']}
# Complexity: [16, 18, 4, 2, 2, 6]
# Step: 5 0.047619047619047616 {'action': 'remove-node', 'content': ['58']}
# Complexity: [21, 28, 7, 6, 1, 14]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 25, 6, 4, 2, 11]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.3076923076923077 {'action': 'remove-node', 'content': ['18', '36', '56', '58', '69', '72', '103', '136']}
# Complexity: [26, 26, 5, 5, 0, 5]
# Step: 2 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 22, 6, 2, 4, 9]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.2222222222222222 {'action': 'remove-node', 'content': ['35', '40', '59', '127']}
# Complexity: [18, 25, 9, 3, 6, 16]
# Step: 2 0.29411764705882354 {'action': 'remove-node', 'content': ['56', '84', '112', '129', '132']}
# Complexity: [17, 21, 7, 4, 3, 11]
# Step: 3 0.1111111111111111 {'action': 'remove-node', 'content': ['58', '104']}
# Complexity: [18, 21, 8, 4, 4, 11]
# Step: 4 0.2222222222222222 {'action': 'remove-node', 'content': ['18', '47', '116', '136']}
# Complexity: [18, 23, 8, 5, 3, 13]
# Step: 5 0.10526315789473684 {'action': 'remove-node', 'content': ['108', '150']}
# Complexity: [19, 23, 9, 4, 5, 13]
# Step: 6 0.05263157894736842 {'action': 'remove-node', 'content': ['69']}
# Complexity: [19, 23, 11, 3, 8, 15]
# Step: 7 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 23, 9, 3, 6, 13]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.391304347826087 {'action': 'remove-node', 'content': ['19', '36', '47', '56', '64', '66', '84', '104', '108']}
# Complexity: [23, 27, 6, 3, 3, 10]
# Step: 2 0.13636363636363635 {'action': 'remove-node', 'content': ['35', '54', '132']}
# Complexity: [22, 25, 7, 4, 3, 10]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [23, 26, 7, 3, 4, 10]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.2727272727272727 {'action': 'remove-node', 'content': ['35', '36', '45', '47', '69', '127']}
# Complexity: [22, 26, 6, 3, 3, 10]
# Step: 2 0.15789473684210525 {'action': 'remove-node', 'content': ['23', '51', '136']}
# Complexity: [19, 24, 7, 3, 4, 12]
# Step: 3 0.24 {'action': 'remove-node', 'content': ['40', '54', '56', '71', '93', '116']}
# Complexity: [25, 25, 6, 4, 2, 6]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [24, 31, 8, 4, 4, 15]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.30434782608695654 {'action': 'remove-node', 'content': ['36', '47', '49', '59', '64', '84', '108']}
# Complexity: [23, 27, 6, 5, 1, 10]
# Step: 2 0.047619047619047616 {'action': 'remove-node', 'content': ['66']}
# Complexity: [21, 23, 6, 3, 3, 8]
# Step: 3 0.07407407407407407 {'action': 'remove-node', 'content': ['19', '54']}
# Complexity: [27, 29, 7, 6, 1, 9]
# Step: 4 0.09090909090909091 {'action': 'remove-node', 'content': ['52', '69']}
# Complexity: [22, 27, 9, 3, 6, 14]
# Step: 5 0.045454545454545456 {'action': 'remove-node', 'content': ['35']}
# Complexity: [22, 27, 9, 4, 5, 14]
# Step: 6 0.041666666666666664 {'action': 'remove-node', 'content': ['40']}
# Complexity: [24, 29, 7, 4, 3, 12]
# Step: 7 0.047619047619047616 {'action': 'remove-node', 'content': ['58']}
# Complexity: [21, 26, 7, 4, 3, 12]
# Step: 8 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [24, 28, 9, 5, 4, 13]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.21428571428571427 {'action': 'remove-node', 'content': ['21', '58', '84']}
# Complexity: [14, 19, 7, 2, 5, 12]
# Step: 2 0.1875 {'action': 'remove-node', 'content': ['35', '49', '127']}
# Complexity: [16, 21, 6, 3, 3, 11]
# Step: 3 0.11764705882352941 {'action': 'remove-node', 'content': ['26', '51']}
# Complexity: [17, 21, 5, 4, 1, 9]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 22, 7, 3, 4, 11]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.25 {'action': 'remove-node', 'content': ['23', '36', '45', '52', '93', '127']}
# Complexity: [24, 26, 7, 3, 4, 9]
# Step: 2 0.1 {'action': 'remove-node', 'content': ['35', '64']}
# Complexity: [20, 24, 5, 2, 3, 9]
# Step: 3 0.07692307692307693 {'action': 'remove-node', 'content': ['51', '56']}
# Complexity: [26, 31, 6, 5, 1, 11]
# Step: 4 0.043478260869565216 {'action': 'remove-node', 'content': ['71']}
# Complexity: [23, 27, 6, 6, 0, 10]
# Step: 5 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 23, 5, 3, 2, 8]

# %%
results_delete_right = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts, "complexity": [p.to_dict() for p in all_complexities]}
with open('results_delete_fox_bb.json', 'w') as fp:
    json.dump(results_delete_right, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Removing Miami + Florida references
# There's 39 after the protests start.

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
i = 0
total_samples = base_total_samples
while i < total_samples:
    drop = False
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, 
                                               verbose=False, random_state=random_state, force_cluster=False, use_new_LP=True)
        filter_nodes = graph_df[graph_df.title.str.contains('miami', case=False) | 
                                   graph_df.title.str.contains('florida', case=False)]
        percent_filter_nodes = len(filter_nodes.index) / len(graph_df.index)
        remove_node_list = [str(node) for node in filter_nodes.id.tolist()]
        remove_node = {"action": "remove-node", "content": remove_node_list}
        previous_actions.append(remove_node)
        percent_list.append(percent_filter_nodes)
        if percent_filter_nodes == 0 and inner_iter_count == 0: # first iteration has no miami/florida nodes. 
            drop = True
            total_samples += 1
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    i += 1
    for action in previous_actions:
        actions += action['content']
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.22727272727272727 {'action': 'remove-node', 'content': ['35', '36', '49', '87', '94']}
# Complexity: [22, 28, 6, 4, 2, 12]
# Step: 2 0.25 {'action': 'remove-node', 'content': ['38', '40', '51', '58', '88']}
# Complexity: [20, 23, 4, 4, 0, 7]
# Step: 3 0.13636363636363635 {'action': 'remove-node', 'content': ['53', '63', '97']}
# Complexity: [22, 28, 8, 5, 3, 14]
# Step: 4 0.043478260869565216 {'action': 'remove-node', 'content': ['41']}
# Complexity: [23, 29, 8, 4, 4, 14]
# Step: 5 0.09090909090909091 {'action': 'remove-node', 'content': ['126', '140']}
# Complexity: [22, 28, 7, 3, 4, 13]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [22, 26, 9, 4, 5, 13]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.045454545454545456 {'action': 'remove-node', 'content': ['63']}
# Complexity: [22, 29, 8, 4, 4, 15]
# Step: 2 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [24, 27, 8, 7, 1, 11]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.16666666666666666 {'action': 'remove-node', 'content': ['36', '49', '87']}
# Complexity: [18, 20, 4, 3, 1, 6]
# Step: 2 0.19047619047619047 {'action': 'remove-node', 'content': ['51', '68', '88', '122']}
# Complexity: [21, 24, 6, 3, 3, 9]
# Step: 3 0.1111111111111111 {'action': 'remove-node', 'content': ['53', '97']}
# Complexity: [18, 20, 6, 3, 3, 8]
# Step: 4 0.08 {'action': 'remove-node', 'content': ['38', '40']}
# Complexity: [25, 29, 7, 5, 2, 11]
# Step: 5 0.047619047619047616 {'action': 'remove-node', 'content': ['94']}
# Complexity: [21, 24, 4, 4, 0, 7]
# Step: 6 0.041666666666666664 {'action': 'remove-node', 'content': ['35']}
# Complexity: [24, 27, 8, 4, 4, 11]
# Step: 7 0.09523809523809523 {'action': 'remove-node', 'content': ['41', '63']}
# Complexity: [21, 23, 5, 3, 2, 7]
# Step: 8 0.043478260869565216 {'action': 'remove-node', 'content': ['58']}
# Complexity: [23, 25, 5, 4, 1, 7]
# Step: 9 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [18, 21, 5, 3, 2, 8]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.19230769230769232 {'action': 'remove-node', 'content': ['36', '56', '58', '63', '68']}
# Complexity: [26, 26, 5, 5, 0, 5]
# Step: 2 0.04 {'action': 'remove-node', 'content': ['126']}
# Complexity: [25, 27, 7, 5, 2, 9]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [23, 26, 7, 4, 3, 10]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.3333333333333333 {'action': 'remove-node', 'content': ['35', '40', '53', '88', '94', '126']}
# Complexity: [18, 25, 9, 3, 6, 16]
# Step: 2 0.11764705882352941 {'action': 'remove-node', 'content': ['97', '140']}
# Complexity: [17, 22, 9, 1, 8, 14]
# Step: 3 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [19, 24, 9, 5, 4, 14]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.17391304347826086 {'action': 'remove-node', 'content': ['36', '56', '63', '140']}
# Complexity: [23, 27, 6, 3, 3, 10]
# Step: 2 0.043478260869565216 {'action': 'remove-node', 'content': ['35']}
# Complexity: [23, 27, 6, 4, 2, 10]
# Step: 3 0.038461538461538464 {'action': 'remove-node', 'content': ['53']}
# Complexity: [26, 28, 8, 6, 2, 10]
# Step: 4 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [17, 20, 5, 4, 1, 8]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.13636363636363635 {'action': 'remove-node', 'content': ['35', '36', '63']}
# Complexity: [22, 26, 6, 3, 3, 10]
# Step: 2 0.08333333333333333 {'action': 'remove-node', 'content': ['51', '56']}
# Complexity: [24, 26, 6, 4, 2, 8]
# Step: 3 0.13636363636363635 {'action': 'remove-node', 'content': ['58', '68', '94']}
# Complexity: [22, 24, 4, 4, 0, 6]
# Step: 4 0.09523809523809523 {'action': 'remove-node', 'content': ['87', '97']}
# Complexity: [21, 22, 4, 3, 1, 5]
# Step: 5 0.041666666666666664 {'action': 'remove-node', 'content': ['88']}
# Complexity: [24, 30, 8, 5, 3, 14]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 25, 6, 4, 2, 11]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.17391304347826086 {'action': 'remove-node', 'content': ['36', '49', '87', '122']}
# Complexity: [23, 27, 6, 5, 1, 10]
# Step: 2 0.08695652173913043 {'action': 'remove-node', 'content': ['94', '140']}
# Complexity: [23, 26, 8, 3, 5, 11]
# Step: 3 0.09523809523809523 {'action': 'remove-node', 'content': ['35', '88']}
# Complexity: [21, 26, 7, 4, 3, 12]
# Step: 4 0.043478260869565216 {'action': 'remove-node', 'content': ['40']}
# Complexity: [23, 27, 5, 5, 0, 9]
# Step: 5 0.041666666666666664 {'action': 'remove-node', 'content': ['41']}
# Complexity: [24, 28, 7, 5, 2, 11]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [20, 23, 5, 3, 2, 8]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.07142857142857142 {'action': 'remove-node', 'content': ['58']}
# Complexity: [14, 19, 7, 2, 5, 12]
# Step: 2 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [13, 15, 4, 2, 2, 6]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.20833333333333334 {'action': 'remove-node', 'content': ['36', '46', '53', '87', '88']}
# Complexity: [24, 26, 7, 3, 4, 9]
# Step: 2 0.1 {'action': 'remove-node', 'content': ['35', '63']}
# Complexity: [20, 22, 5, 3, 2, 7]
# Step: 3 0.08695652173913043 {'action': 'remove-node', 'content': ['41', '94']}
# Complexity: [23, 28, 7, 6, 1, 12]
# Step: 4 0.09090909090909091 {'action': 'remove-node', 'content': ['51', '97']}
# Complexity: [22, 27, 6, 4, 2, 11]
# Step: 5 0.043478260869565216 {'action': 'remove-node', 'content': ['58']}
# Complexity: [23, 27, 6, 4, 2, 10]
# Step: 6 0.0 {'action': 'remove-node', 'content': []}
# Complexity: [23, 27, 8, 5, 3, 12]

# %%
results_delete_florida = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts, "complexity": [p.to_dict() for p in all_complexities]}
with open('results_delete_florida.json', 'w') as fp:
    json.dump(results_delete_florida, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Remove Edges
# ### Remove Inconsistent Edges
# Goal: Remove right-biased news articles from the map. We use the same starting point from before.

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_edges = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_edges > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state, use_new_LP=True)
        edges = list(G.edges())
        filter_edges = []
        for node_i, node_j in edges:
            bias_i = graph_df.loc[graph_df['id'] == int(node_i)].iloc[0]['bias']
            bias_j = graph_df.loc[graph_df['id'] == int(node_j)].iloc[0]['bias']
            if (bias_i == 'Right' and bias_j == 'Left') or (bias_i == 'Left' and bias_j == 'Right'):
                filter_edges.append((node_i, node_j))
        remove_edge_list = [node_i + "-" + node_j for node_i, node_j in filter_edges]
        percent_filter_edges = len(filter_edges) / len(edges)
        
        remove_edge = {"action": "remove-edge", "content": remove_edge_list}
        previous_actions.append(remove_edge)
        percent_list.append(percent_filter_edges)
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_edges, remove_edge)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    for action in previous_actions:
        actions += action['content']
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.25 {'action': 'remove-edge', 'content': ['11-36', '33-36', '64-77', '49-77', '77-112', '124-132', '136-138']}
# Complexity: [22, 28, 6, 4, 2, 12]
# Step: 2 0.12 {'action': 'remove-edge', 'content': ['36-87', '87-127', '76-77']}
# Complexity: [22, 25, 7, 3, 4, 10]
# Step: 3 0.13793103448275862 {'action': 'remove-edge', 'content': ['49-65', '87-132', '86-127', '113-127']}
# Complexity: [23, 29, 7, 4, 3, 13]
# Step: 4 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [22, 26, 7, 5, 2, 11]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.3793103448275862 {'action': 'remove-edge', 'content': ['11-18', '11-45', '18-48', '45-48', '48-59', '61-89', '89-90', '89-135', '83-89', '127-135', '90-127']}
# Complexity: [22, 29, 8, 4, 4, 15]
# Step: 2 0.3333333333333333 {'action': 'remove-edge', 'content': ['11-59', '11-47', '33-49', '47-48', '49-65', '65-69', '89-91', '69-86', '91-127', '127-138']}
# Complexity: [25, 30, 6, 6, 0, 11]
# Step: 3 0.21739130434782608 {'action': 'remove-edge', 'content': ['33-71', '61-71', '107-108', '107-127', '132-138']}
# Complexity: [20, 23, 5, 4, 1, 8]
# Step: 4 0.12 {'action': 'remove-edge', 'content': ['33-35', '89-101', '101-127']}
# Complexity: [21, 25, 6, 4, 2, 10]
# Step: 5 0.2 {'action': 'remove-edge', 'content': ['11-22', '11-71', '61-127', '71-77', '134-135']}
# Complexity: [24, 25, 7, 5, 2, 8]
# Step: 6 0.14285714285714285 {'action': 'remove-edge', 'content': ['33-54', '54-65', '67-71', '71-86']}
# Complexity: [25, 28, 5, 5, 0, 8]
# Step: 7 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [23, 27, 6, 4, 2, 10]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.3 {'action': 'remove-edge', 'content': ['33-36', '66-87', '64-77', '77-84', '90-127', '84-107']}
# Complexity: [18, 20, 4, 3, 1, 6]
# Step: 2 0.17857142857142858 {'action': 'remove-edge', 'content': ['11-35', '33-35', '64-65', '65-76', '89-90']}
# Complexity: [23, 28, 6, 4, 2, 11]
# Step: 3 0.12 {'action': 'remove-edge', 'content': ['33-49', '66-90', '76-77']}
# Complexity: [21, 25, 5, 4, 1, 9]
# Step: 4 0.03333333333333333 {'action': 'remove-edge', 'content': ['49-65']}
# Complexity: [24, 30, 6, 5, 1, 12]
# Step: 5 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [21, 25, 5, 4, 1, 9]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.15384615384615385 {'action': 'remove-edge', 'content': ['11-58', '69-86', '134-135', '124-136']}
# Complexity: [26, 26, 5, 5, 0, 5]
# Step: 2 0.14814814814814814 {'action': 'remove-edge', 'content': ['27-58', '11-36', '76-86', '124-132']}
# Complexity: [26, 27, 3, 3, 0, 4]
# Step: 3 0.17391304347826086 {'action': 'remove-edge', 'content': ['89-90', '27-36', '84-86', '103-135']}
# Complexity: [23, 23, 5, 3, 2, 5]
# Step: 4 0.1111111111111111 {'action': 'remove-edge', 'content': ['52-86', '72-90', '124-129']}
# Complexity: [27, 27, 4, 4, 0, 4]
# Step: 5 0.034482758620689655 {'action': 'remove-edge', 'content': ['116-117']}
# Complexity: [28, 29, 6, 5, 1, 7]
# Step: 6 0.03571428571428571 {'action': 'remove-edge', 'content': ['136-138']}
# Complexity: [26, 28, 4, 4, 0, 6]
# Step: 7 0.07407407407407407 {'action': 'remove-edge', 'content': ['86-112', '54-86']}
# Complexity: [27, 27, 4, 4, 0, 4]
# Step: 8 0.06451612903225806 {'action': 'remove-edge', 'content': ['54-65', '86-132']}
# Complexity: [30, 31, 5, 5, 0, 6]
# Step: 9 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [30, 32, 6, 6, 0, 8]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.2 {'action': 'remove-edge', 'content': ['11-35', '35-50', '50-53', '53-107', '59-65']}
# Complexity: [18, 25, 9, 3, 6, 16]
# Step: 2 0.13636363636363635 {'action': 'remove-edge', 'content': ['53-87', '53-91', '113-129']}
# Complexity: [18, 22, 9, 3, 6, 13]
# Step: 3 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [18, 22, 9, 3, 6, 13]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.2222222222222222 {'action': 'remove-edge', 'content': ['11-66', '11-19', '11-47', '66-67', '19-27', '27-36']}
# Complexity: [23, 27, 6, 3, 3, 10]
# Step: 2 0.041666666666666664 {'action': 'remove-edge', 'content': ['27-47']}
# Complexity: [21, 24, 8, 4, 4, 11]
# Step: 3 0.07692307692307693 {'action': 'remove-edge', 'content': ['15-36', '27-66']}
# Complexity: [22, 26, 5, 5, 0, 9]
# Step: 4 0.08 {'action': 'remove-edge', 'content': ['36-67', '19-20']}
# Complexity: [21, 25, 5, 4, 1, 9]
# Step: 5 0.03571428571428571 {'action': 'remove-edge', 'content': ['11-36']}
# Complexity: [23, 28, 7, 4, 3, 12]
# Step: 6 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [23, 28, 7, 4, 3, 12]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.34615384615384615 {'action': 'remove-edge', 'content': ['11-47', '11-36', '33-35', '35-65', '65-69', '89-90', '76-86', '86-127', '127-138']}
# Complexity: [22, 26, 6, 3, 3, 10]
# Step: 2 0.2222222222222222 {'action': 'remove-edge', 'content': ['11-45', '33-36', '45-48', '36-48', '89-113', '134-135']}
# Complexity: [21, 27, 5, 4, 1, 11]
# Step: 3 0.16129032258064516 {'action': 'remove-edge', 'content': ['33-54', '34-35', '54-65', '35-86', '124-127']}
# Complexity: [26, 31, 7, 5, 2, 12]
# Step: 4 0.10344827586206896 {'action': 'remove-edge', 'content': ['22-33', '36-43', '89-135']}
# Complexity: [25, 29, 6, 5, 1, 10]
# Step: 5 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [21, 24, 5, 5, 0, 8]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.1111111111111111 {'action': 'remove-edge', 'content': ['11-47', '33-36', '108-117']}
# Complexity: [23, 27, 6, 5, 1, 10]
# Step: 2 0.12 {'action': 'remove-edge', 'content': ['11-36', '33-49', '33-84']}
# Complexity: [21, 25, 5, 3, 2, 9]
# Step: 3 0.041666666666666664 {'action': 'remove-edge', 'content': ['33-35']}
# Complexity: [22, 24, 5, 3, 2, 7]
# Step: 4 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [21, 25, 5, 5, 0, 9]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.05263157894736842 {'action': 'remove-edge', 'content': ['11-31']}
# Complexity: [14, 19, 7, 2, 5, 12]
# Step: 2 0.1 {'action': 'remove-edge', 'content': ['31-34', '34-84']}
# Complexity: [16, 20, 6, 4, 2, 10]
# Step: 3 0.043478260869565216 {'action': 'remove-edge', 'content': ['89-90']}
# Complexity: [19, 23, 8, 4, 4, 12]
# Step: 4 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [17, 19, 7, 3, 4, 9]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.34615384615384615 {'action': 'remove-edge', 'content': ['11-23', '11-36', '20-45', '52-86', '86-93', '93-107', '107-146', '117-118', '118-121']}
# Complexity: [24, 26, 7, 3, 4, 9]
# Step: 2 0.041666666666666664 {'action': 'remove-edge', 'content': ['33-53']}
# Complexity: [22, 24, 4, 3, 1, 6]
# Step: 3 0.1111111111111111 {'action': 'remove-edge', 'content': ['93-117', '84-86', '117-146']}
# Complexity: [24, 27, 5, 5, 0, 8]
# Step: 4 0.17391304347826086 {'action': 'remove-edge', 'content': ['20-23', '69-86', '87-127', '121-146']}
# Complexity: [22, 23, 4, 3, 1, 5]
# Step: 5 0.1 {'action': 'remove-edge', 'content': ['53-86', '108-117', '144-146']}
# Complexity: [27, 30, 5, 5, 0, 8]
# Step: 6 0.0 {'action': 'remove-edge', 'content': []}
# Complexity: [23, 24, 4, 3, 1, 5]

# %%
results_delete_edges = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts, "complexity": [p.to_dict() for p in all_complexities]}
with open('results_delete_edges.json', 'w') as fp:
    json.dump(results_delete_edges, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Add Edges + Remove Edges
# ### Make Storylines Consistent (Starting from "Center" Storyline)

# %%
from collections import Counter
def most_common(lst):
    # Exclude local and center.
    lst[:] = [x for x in lst if x != 'Center' and x != 'Local']
    if len(lst) == 0:
        return None
    data = Counter(lst)
    return max(lst, key=data.get)

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples

for i in range(total_samples):
    print("===================================")
    print("Sample #" + str(i))
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter_nodes = 1.0
    percent_list_nodes = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    while percent_filter_nodes > 0:
        G, graph_df, storylines = generate_map(query, dataset, start_nodes=[10], previous_actions=previous_actions, verbose=False, random_state=random_state, use_new_LP=True)
        nodes = list(G.nodes())
        remove_node_list = []
        add_edges = []
        #print("Storylines: " + str(storylines))
        for story in storylines:
            #print("Current story: " + str(story))
            story_biases = [graph_df.loc[graph_df['id'] == int(story_node)].iloc[0]['bias'] for story_node in story]
            story_bias = most_common(story_biases)
            opposite_bias = None
            if story_bias == 'Left':
                opposite_bias = 'Right'
            else:
                opposite_bias = 'Left'
            skip_count = 0
            mark = None
            if opposite_bias is not None:
                for node in story:
                    bias = graph_df.loc[graph_df['id'] == int(node)].iloc[0]['bias']
                    if mark is not None and skip_count > 0 and bias != opposite_bias:
                        add_edge = {"action": "add-edge", "content": str(mark) + "-" + str(node)} # String of edge id
                        add_edges.append(str(mark) + "-" + str(node))
                        previous_actions.append(add_edge)
                        mark = node
                        skip_count = 0
                    if bias != opposite_bias:
                        mark = node
                    else:
                        remove_node_list.append(node)
                        skip_count += 1            
        remove_node = {"action": "remove-node", "content": remove_node_list}
        for node in remove_node_list:
            previous_actions[:] = [action for action in previous_actions if not (action['action'] == 'add-edge' and str(node) in action['content'].split("-"))]
        previous_actions.append(remove_node)                
        percent_filter_nodes = len(remove_node_list) / len(nodes)              
        percent_list_nodes.append(percent_filter_nodes)
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter_nodes, remove_node, "add-edge: " + str(add_edges))
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    actions = []
    for action in previous_actions:
        if type(action['content']) == list:
            actions += action['content']
        else:
            actions.append(action['content'])
    all_iterations.append(inner_iter_count)
    all_percents.append(percent_list_nodes)
    all_counts.append(len(actions))
    all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0
# ===================================
# Step: 1 0.22727272727272727 {'action': 'remove-node', 'content': ['127', '136', '11', '77', '132']} add-edge: ['94-138', '10-36', '64-112', '124-139']
# Complexity: [22, 28, 6, 4, 2, 12]
# Step: 2 0.09523809523809523 {'action': 'remove-node', 'content': ['50', '86']} add-edge: ['37-56']
# Complexity: [21, 22, 6, 4, 2, 7]
# Step: 3 0.05 {'action': 'remove-node', 'content': ['12']} add-edge: ['10-36']
# Complexity: [20, 26, 7, 4, 3, 13]
# Step: 4 0.045454545454545456 {'action': 'remove-node', 'content': ['36']} add-edge: ['13-41']
# Complexity: [22, 24, 8, 4, 4, 10]
# Step: 5 0.05555555555555555 {'action': 'remove-node', 'content': ['67', '43']} add-edge: ['66-75', '56-71']
# Complexity: [36, 42, 13, 9, 4, 19]
# Step: 6 0.05405405405405406 {'action': 'remove-node', 'content': ['58', '98']} add-edge: ['13-94', '75-111']
# Complexity: [37, 46, 15, 5, 10, 24]
# Step: 7 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [38, 41, 14, 7, 7, 17]
# ===================================
# Sample #1
# ===================================
# Step: 1 0.13636363636363635 {'action': 'remove-node', 'content': ['45', '89', '127']} add-edge: ['11-48', '83-135', '90-148']
# Complexity: [22, 29, 8, 4, 4, 15]
# Step: 2 0.25 {'action': 'remove-node', 'content': ['18', '23', '71', '36', '107']} add-edge: ['11-33', '50-85', '65-70', '84-119']
# Complexity: [20, 21, 5, 5, 0, 6]
# Step: 3 0.20833333333333334 {'action': 'remove-node', 'content': ['53', '154', '33', '34', '65']} add-edge: ['11-98', '52-54', '54-69']
# Complexity: [24, 28, 4, 4, 0, 8]
# Step: 4 0.08695652173913043 {'action': 'remove-node', 'content': ['11', '47']} add-edge: ['10-70']
# Complexity: [23, 27, 8, 6, 2, 12]
# Step: 5 0.09523809523809523 {'action': 'remove-node', 'content': ['108', '39']} add-edge: []
# Complexity: [21, 25, 6, 4, 2, 10]
# Step: 6 0.1111111111111111 {'action': 'remove-node', 'content': ['12', '77']} add-edge: ['10-63', '70-84']
# Complexity: [18, 20, 4, 3, 1, 6]
# Step: 7 0.05 {'action': 'remove-node', 'content': ['131']} add-edge: ['122-143']
# Complexity: [20, 23, 5, 4, 1, 8]
# Step: 8 0.05263157894736842 {'action': 'remove-node', 'content': ['132']} add-edge: ['122-140']
# Complexity: [19, 22, 6, 3, 3, 9]
# Step: 9 0.1 {'action': 'remove-node', 'content': ['144', '146']} add-edge: []
# Complexity: [20, 26, 7, 6, 1, 13]
# Step: 10 0.1 {'action': 'remove-node', 'content': ['141', '22']} add-edge: ['122-143', '13-30']
# Complexity: [20, 23, 4, 3, 1, 7]
# Step: 11 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [24, 26, 9, 5, 4, 11]
# ===================================
# Sample #2
# ===================================
# Step: 1 0.3333333333333333 {'action': 'remove-node', 'content': ['36', '49', '64', '84', '127', '136']} add-edge: ['33-77', '77-107']
# Complexity: [18, 20, 4, 3, 1, 6]
# Step: 2 0.19047619047619047 {'action': 'remove-node', 'content': ['35', '53', '96', '132']} add-edge: ['33-75', '107-140']
# Complexity: [21, 25, 9, 4, 5, 13]
# Step: 3 0.15789473684210525 {'action': 'remove-node', 'content': ['66', '71', '76']} add-edge: ['10-74', '75-77']
# Complexity: [19, 19, 3, 2, 1, 3]
# Step: 4 0.09523809523809523 {'action': 'remove-node', 'content': ['52', '90']} add-edge: ['33-57', '89-97']
# Complexity: [21, 23, 4, 3, 1, 6]
# Step: 5 0.05555555555555555 {'action': 'remove-node', 'content': ['11']} add-edge: ['17-41']
# Complexity: [18, 22, 7, 3, 4, 11]
# Step: 6 0.15 {'action': 'remove-node', 'content': ['51', '131', '58']} add-edge: ['27-65', '107-139', '12-75']
# Complexity: [20, 22, 6, 2, 4, 8]
# Step: 7 0.15 {'action': 'remove-node', 'content': ['40', '69', '33']} add-edge: ['20-75']
# Complexity: [20, 23, 8, 5, 3, 11]
# Step: 8 0.08695652173913043 {'action': 'remove-node', 'content': ['45', '89']} add-edge: ['12-83', '83-101']
# Complexity: [23, 27, 8, 3, 5, 12]
# Step: 9 0.2 {'action': 'remove-node', 'content': ['12', '65', '77', '86', '107', '39']} add-edge: ['10-28', '31-108']
# Complexity: [30, 33, 7, 6, 1, 10]
# Step: 10 0.058823529411764705 {'action': 'remove-node', 'content': ['72']} add-edge: ['85-87']
# Complexity: [17, 19, 4, 3, 1, 6]
# Step: 11 0.09090909090909091 {'action': 'remove-node', 'content': ['48', '73']} add-edge: ['30-75']
# Complexity: [22, 25, 7, 4, 3, 10]
# Step: 12 0.10526315789473684 {'action': 'remove-node', 'content': ['108', '146']} add-edge: ['75-122', '122-147']
# Complexity: [19, 21, 6, 4, 2, 8]
# Step: 13 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [19, 22, 7, 5, 2, 10]
# ===================================
# Sample #3
# ===================================
# Step: 1 0.15384615384615385 {'action': 'remove-node', 'content': ['58', '89', '86', '124']} add-edge: ['11-63', '63-92', '69-114', '114-136']
# Complexity: [26, 26, 5, 5, 0, 5]
# Step: 2 0.18181818181818182 {'action': 'remove-node', 'content': ['96', '103', '11', '138']} add-edge: ['92-135', '17-30']
# Complexity: [22, 23, 4, 3, 1, 5]
# Step: 3 0.045454545454545456 {'action': 'remove-node', 'content': ['65']} add-edge: ['49-69']
# Complexity: [22, 24, 6, 4, 2, 8]
# Step: 4 0.17391304347826086 {'action': 'remove-node', 'content': ['87', '23', '135', '27']} add-edge: ['63-94', '134-149']
# Complexity: [23, 24, 5, 5, 0, 6]
# Step: 5 0.15384615384615385 {'action': 'remove-node', 'content': ['12', '93', '118', '90']} add-edge: ['10-17', '117-120', '72-92']
# Complexity: [26, 25, 6, 4, 2, 5]
# Step: 6 0.041666666666666664 {'action': 'remove-node', 'content': ['13']} add-edge: ['10-17']
# Complexity: [24, 25, 4, 4, 0, 5]
# Step: 7 0.07142857142857142 {'action': 'remove-node', 'content': ['108', '146']} add-edge: ['42-117', '143-156']
# Complexity: [28, 27, 5, 4, 1, 4]
# Step: 8 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [32, 32, 7, 5, 2, 7]
# ===================================
# Sample #4
# ===================================
# Step: 1 0.16666666666666666 {'action': 'remove-node', 'content': ['107', '113', '65']} add-edge: ['53-142', '59-94']
# Complexity: [18, 25, 9, 3, 6, 16]
# Step: 2 0.1 {'action': 'remove-node', 'content': ['11', '39']} add-edge: ['10-53']
# Complexity: [20, 23, 13, 2, 11, 16]
# Step: 3 0.0625 {'action': 'remove-node', 'content': ['12']} add-edge: ['10-35']
# Complexity: [16, 18, 9, 2, 7, 11]
# Step: 4 0.05263157894736842 {'action': 'remove-node', 'content': ['13']} add-edge: ['10-35']
# Complexity: [19, 21, 12, 2, 10, 14]
# Step: 5 0.043478260869565216 {'action': 'remove-node', 'content': ['144']} add-edge: []
# Complexity: [23, 27, 16, 1, 15, 20]
# Step: 6 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [19, 22, 12, 1, 11, 15]
# ===================================
# Sample #5
# ===================================
# Step: 1 0.13043478260869565 {'action': 'remove-node', 'content': ['47', '27', '67']} add-edge: ['11-85', '19-36', '66-70']
# Complexity: [23, 27, 6, 3, 3, 10]
# Step: 2 0.045454545454545456 {'action': 'remove-node', 'content': ['66']} add-edge: ['11-85']
# Complexity: [22, 25, 4, 4, 0, 7]
# Step: 3 0.09523809523809523 {'action': 'remove-node', 'content': ['89', '20']} add-edge: ['24-109', '19-60']
# Complexity: [21, 26, 6, 4, 2, 11]
# Step: 4 0.047619047619047616 {'action': 'remove-node', 'content': ['36']} add-edge: ['11-68']
# Complexity: [21, 25, 9, 5, 4, 13]
# Step: 5 0.03571428571428571 {'action': 'remove-node', 'content': ['54']} add-edge: ['11-70']
# Complexity: [28, 31, 9, 8, 1, 12]
# Step: 6 0.07407407407407407 {'action': 'remove-node', 'content': ['19', '34']} add-edge: ['11-85']
# Complexity: [27, 29, 8, 6, 2, 10]
# Step: 7 0.08333333333333333 {'action': 'remove-node', 'content': ['11', '136']} add-edge: ['10-24']
# Complexity: [24, 25, 9, 3, 6, 10]
# Step: 8 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [18, 22, 8, 4, 4, 12]
# ===================================
# Sample #6
# ===================================
# Step: 1 0.22727272727272727 {'action': 'remove-node', 'content': ['36', '33', '65', '90', '113']} add-edge: ['11-82', '35-69']
# Complexity: [22, 26, 6, 3, 3, 10]
# Step: 2 0.1935483870967742 {'action': 'remove-node', 'content': ['11', '86', '35', '50', '56', '27']} add-edge: ['10-47', '51-127', '68-70']
# Complexity: [31, 32, 11, 9, 2, 12]
# Step: 3 0.03571428571428571 {'action': 'remove-node', 'content': ['43']} add-edge: ['68-70']
# Complexity: [28, 30, 7, 5, 2, 9]
# Step: 4 0.030303030303030304 {'action': 'remove-node', 'content': ['73']} add-edge: ['14-78']
# Complexity: [33, 33, 10, 5, 5, 10]
# Step: 5 0.0967741935483871 {'action': 'remove-node', 'content': ['96', '15', '93']} add-edge: ['45-51', '121-141']
# Complexity: [31, 34, 7, 6, 1, 10]
# Step: 6 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [29, 34, 7, 5, 2, 12]
# ===================================
# Sample #7
# ===================================
# Step: 1 0.13043478260869565 {'action': 'remove-node', 'content': ['47', '33', '117']} add-edge: ['11-125', '36-49', '108-122']
# Complexity: [23, 27, 6, 5, 1, 10]
# Step: 2 0.15 {'action': 'remove-node', 'content': ['66', '73', '86']} add-edge: ['11-67', '67-99']
# Complexity: [20, 22, 5, 3, 2, 7]
# Step: 3 0.11538461538461539 {'action': 'remove-node', 'content': ['11', '141', '49']} add-edge: ['10-36', '38-63']
# Complexity: [26, 29, 7, 5, 2, 10]
# Step: 4 0.09523809523809523 {'action': 'remove-node', 'content': ['12', '61']} add-edge: ['10-36', '40-84']
# Complexity: [21, 26, 8, 4, 4, 13]
# Step: 5 0.045454545454545456 {'action': 'remove-node', 'content': ['13']} add-edge: ['10-36']
# Complexity: [22, 28, 9, 4, 5, 15]
# Step: 6 0.10526315789473684 {'action': 'remove-node', 'content': ['39', '121']} add-edge: ['36-57']
# Complexity: [19, 21, 4, 3, 1, 6]
# Step: 7 0.1111111111111111 {'action': 'remove-node', 'content': ['144', '59']} add-edge: ['122-146', '20-75']
# Complexity: [18, 22, 6, 3, 3, 10]
# Step: 8 0.045454545454545456 {'action': 'remove-node', 'content': ['42']} add-edge: ['36-93']
# Complexity: [22, 26, 7, 4, 3, 11]
# Step: 9 0.047619047619047616 {'action': 'remove-node', 'content': ['20']} add-edge: ['10-36']
# Complexity: [21, 25, 5, 3, 2, 9]
# Step: 10 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [20, 24, 5, 4, 1, 9]
# ===================================
# Sample #8
# ===================================
# Step: 1 0.07142857142857142 {'action': 'remove-node', 'content': ['11']} add-edge: ['10-31']
# Complexity: [14, 19, 7, 2, 5, 12]
# Step: 2 0.23529411764705882 {'action': 'remove-node', 'content': ['31', '127', '135', '90']} add-edge: ['30-86', '86-139']
# Complexity: [17, 19, 4, 4, 0, 6]
# Step: 3 0.06666666666666667 {'action': 'remove-node', 'content': ['49']} add-edge: ['27-86']
# Complexity: [15, 17, 5, 3, 2, 7]
# Step: 4 0.06666666666666667 {'action': 'remove-node', 'content': ['84']} add-edge: ['27-86']
# Complexity: [15, 18, 5, 4, 1, 8]
# Step: 5 0.1875 {'action': 'remove-node', 'content': ['17', '35', '52']} add-edge: ['14-27', '27-115']
# Complexity: [16, 19, 6, 1, 5, 9]
# Step: 6 0.1 {'action': 'remove-node', 'content': ['40', '34']} add-edge: ['27-55', '25-115']
# Complexity: [20, 25, 7, 2, 5, 12]
# Step: 7 0.1111111111111111 {'action': 'remove-node', 'content': ['21', '86']} add-edge: ['14-25']
# Complexity: [18, 23, 7, 4, 3, 12]
# Step: 8 0.05 {'action': 'remove-node', 'content': ['13']} add-edge: ['25-29']
# Complexity: [20, 24, 7, 3, 4, 11]
# Step: 9 0.15 {'action': 'remove-node', 'content': ['12', '51', '54']} add-edge: ['10-59', '30-138']
# Complexity: [20, 24, 6, 3, 3, 10]
# Step: 10 0.18181818181818182 {'action': 'remove-node', 'content': ['101', '138', '134', '141']} add-edge: ['55-151', '115-139']
# Complexity: [22, 26, 5, 4, 1, 9]
# Step: 11 0.058823529411764705 {'action': 'remove-node', 'content': ['147']} add-edge: []
# Complexity: [17, 19, 6, 4, 2, 8]
# Step: 12 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [17, 20, 7, 2, 5, 10]
# ===================================
# Sample #9
# ===================================
# Step: 1 0.20833333333333334 {'action': 'remove-node', 'content': ['36', '52', '93', '118', '127']} add-edge: ['11-86', '86-107', '117-121']
# Complexity: [24, 26, 7, 3, 4, 9]
# Step: 2 0.14814814814814814 {'action': 'remove-node', 'content': ['134', '53', '64', '146']} add-edge: ['92-135', '30-77', '120-156']
# Complexity: [27, 30, 6, 4, 2, 9]
# Step: 3 0.12903225806451613 {'action': 'remove-node', 'content': ['51', '32', '49', '69']} add-edge: ['46-126', '34-86']
# Complexity: [31, 33, 9, 4, 5, 11]
# Step: 4 0.058823529411764705 {'action': 'remove-node', 'content': ['35', '116']} add-edge: ['27-94', '107-117']
# Complexity: [34, 36, 8, 4, 4, 10]
# Step: 5 0.07407407407407407 {'action': 'remove-node', 'content': ['58', '96']} add-edge: ['41-63', '92-139']
# Complexity: [27, 27, 9, 6, 3, 9]
# Step: 6 0.047619047619047616 {'action': 'remove-node', 'content': ['66', '107']} add-edge: ['14-75', '44-119']
# Complexity: [42, 47, 18, 7, 11, 23]
# Step: 7 0.08108108108108109 {'action': 'remove-node', 'content': ['45', '27', '86']} add-edge: ['48-90', '76-108']
# Complexity: [37, 39, 11, 8, 3, 13]
# Step: 8 0.0625 {'action': 'remove-node', 'content': ['40', '108']} add-edge: ['11-63', '105-117']
# Complexity: [32, 32, 7, 6, 1, 7]
# Step: 9 0.0 {'action': 'remove-node', 'content': []} add-edge: []
# Complexity: [25, 28, 10, 5, 5, 13]

# %%
results_consistent_story = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts, "complexity": [p.to_dict() for p in all_complexities]}
with open('results_consistent_story.json', 'w') as fp:
    json.dump(results_consistent_story, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## "Clustering"
# 2 clusters only: High-bias Breitbart vs Center-unbiased storylines.
# Metric: internal storyline consistency (avoid connections between high-bias and low-bias articles)
#
# ### Semi-supervised umap with constraints

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
i = 0
total_samples = base_total_samples
while i < total_samples:
    print("===================================")
    print("Sample #" + str(i) + " (Valid Sample #" + str(len(all_complexities)) + ")")
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consistent throughout the same iteration.
    drop = False
    while percent_filter > 0:
        G, graph_df, storylines = generate_map(query, dataset, k_input=8, start_nodes=[10], previous_actions=previous_actions, 
                                               verbose=False, random_state=random_state, force_cluster=True, use_new_LP=True)
        nodes = list(G.edges())
        
        breitbart_nodes = graph_df[graph_df.url.str.contains('breitbart')] # Cluster 1
        center_nodes = graph_df[graph_df.bias == 'Center'] # Cluster 2
        breitbart_cluster_full = [str(node) for node in breitbart_nodes['id'].tolist()]
        center_cluster_full = [str(node) for node in center_nodes['id'].tolist()]
        
        previous_breitbart = [node for node_list in previous_actions for node in node_list["content"][0] if node_list["content"][1] == 1]
        previous_center = [node for node_list in previous_actions for node in node_list["content"][0] if node_list["content"][1] == 2]

        print("Previous actions:")
        print(previous_breitbart)
        print(previous_center)
        
        breitbart_cluster_int = sorted([int(node) for node in list(set(breitbart_cluster_full).difference(previous_breitbart))])
        center_cluster_int = sorted([int(node) for node in list(set(center_cluster_full).difference(previous_center))])
        
        breitbart_cluster = [str(node) for node in breitbart_cluster_int]
        center_cluster = [str(node) for node in center_cluster_int]
        
        breitbart_action = {"action": "add-cluster-list", "content": [breitbart_cluster[:min(3, len(breitbart_cluster))], 1]}
        center_action = {"action": "add-cluster-list", "content": [center_cluster[:min(3, len(center_cluster))], 2]}
        
        previous_actions.append(breitbart_action)
        previous_actions.append(center_action)
        
        non_isolated_nodes = set()
        breitbart_n = len(breitbart_cluster_full)
        center_n = len(center_cluster_full)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        for combination in itertools.combinations(breitbart_cluster_full,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
                
        for combination in itertools.combinations(center_cluster_full,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            try:
                sp_1 = nx.shortest_path_length(G, combination[0], combination[1])
            except nx.NetworkXNoPath:
                sp_1 = 0
            try:
                sp_2 = nx.shortest_path_length(G, combination[1], combination[0])
            except nx.NetworkXNoPath:
                sp_2 = 0
            has_path = (sp_1 == 2) or (sp_2 == 2) # Separation of 2. 
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1

                
        print("Total cluster 1: " + str(breitbart_n))
        print("Total cluster 2: " + str(center_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
        if breitbart_n + center_n == 0:
            percent_filter = 0.0
        else:        
            percent_filter = 1 - len(non_isolated_nodes) / (breitbart_n + center_n)
        percent_list.append(percent_filter)
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, breitbart_action, center_action)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
        
        if len(breitbart_cluster) == 0 and len(center_cluster) == 0:
            print("Nothing to add - Early stopping.")
            break
        
    i += 1
    actions = []
    for action in previous_actions:
        if action['action'] == 'add-cluster-list':
            actions += action['content'][0] 
        elif type(action['content']) == list:
            actions += action['content']
        else:
            actions.append(action['content'])
            
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0 (Valid Sample #0)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 6
# Same story 2 Direct connection 1 Same parent 1 Same children 0
# Step: 1 0.25 {'action': 'add-cluster-list', 'content': [['36', '136'], 1]} {'action': 'add-cluster-list', 'content': [['10', '14', '25'], 2]}
# Complexity: [22, 28, 6, 4, 2, 12]
# Previous actions:
# ['36', '136']
# ['10', '14', '25']
# Total cluster 1: 4
# Total cluster 2: 7
# Same story 6 Direct connection 2 Same parent 2 Same children 2
# Step: 2 0.09090909090909094 {'action': 'add-cluster-list', 'content': [['45', '58'], 1]} {'action': 'add-cluster-list', 'content': [['62', '81', '85'], 2]}
# Complexity: [19, 21, 5, 4, 1, 7]
# Previous actions:
# ['36', '136', '45', '58']
# ['10', '14', '25', '62', '81', '85']
# Total cluster 1: 5
# Total cluster 2: 12
# Same story 17 Direct connection 2 Same parent 1 Same children 4
# Step: 3 0.05882352941176472 {'action': 'add-cluster-list', 'content': [['47'], 1]} {'action': 'add-cluster-list', 'content': [['37', '70', '110'], 2]}
# Complexity: [28, 35, 12, 5, 7, 19]
# Previous actions:
# ['36', '136', '45', '58', '47']
# ['10', '14', '25', '62', '81', '85', '37', '70', '110']
# Total cluster 1: 6
# Total cluster 2: 19
# Same story 24 Direct connection 10 Same parent 6 Same children 5
# Step: 4 0.07999999999999996 {'action': 'add-cluster-list', 'content': [['116'], 1]} {'action': 'add-cluster-list', 'content': [['41', '75', '92'], 2]}
# Complexity: [56, 74, 15, 15, 0, 33]
# Previous actions:
# ['36', '136', '45', '58', '47', '116']
# ['10', '14', '25', '62', '81', '85', '37', '70', '110', '41', '75', '92']
# Total cluster 1: 9
# Total cluster 2: 15
# Same story 46 Direct connection 3 Same parent 0 Same children 3
# Step: 5 0.125 {'action': 'add-cluster-list', 'content': [['54', '71', '84'], 1]} {'action': 'add-cluster-list', 'content': [['80', '106', '139'], 2]}
# Complexity: [32, 34, 7, 6, 1, 9]
# Previous actions:
# ['36', '136', '45', '58', '47', '116', '54', '71', '84']
# ['10', '14', '25', '62', '81', '85', '37', '70', '110', '41', '75', '92', '80', '106', '139']
# Total cluster 1: 9
# Total cluster 2: 15
# Same story 21 Direct connection 10 Same parent 1 Same children 6
# Step: 6 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [31, 40, 11, 8, 3, 20]
# Nothing to add - Early stopping.
# ===================================
# Sample #1 (Valid Sample #1)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 5
# Same story 2 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.4285714285714286 {'action': 'add-cluster-list', 'content': [['45', '71'], 1]} {'action': 'add-cluster-list', 'content': [['10', '62', '99'], 2]}
# Complexity: [22, 29, 8, 4, 4, 15]
# Previous actions:
# ['45', '71']
# ['10', '62', '99']
# Total cluster 1: 5
# Total cluster 2: 10
# Same story 14 Direct connection 4 Same parent 1 Same children 1
# Step: 2 0.06666666666666665 {'action': 'add-cluster-list', 'content': [['36', '84', '116'], 1]} {'action': 'add-cluster-list', 'content': [['14', '80', '92'], 2]}
# Complexity: [26, 28, 7, 4, 3, 9]
# Previous actions:
# ['45', '71', '36', '84', '116']
# ['10', '62', '99', '14', '80', '92']
# Total cluster 1: 8
# Total cluster 2: 8
# Same story 13 Direct connection 4 Same parent 0 Same children 1
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['28', '58', '150'], 1]} {'action': 'add-cluster-list', 'content': [['57', '139'], 2]}
# Complexity: [27, 33, 10, 6, 4, 16]
# ===================================
# Sample #2 (Valid Sample #2)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 4
# Total cluster 2: 4
# Same story 3 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.25 {'action': 'add-cluster-list', 'content': [['36', '66', '84'], 1]} {'action': 'add-cluster-list', 'content': [['10', '70', '110'], 2]}
# Complexity: [18, 20, 4, 3, 1, 6]
# Previous actions:
# ['36', '66', '84']
# ['10', '70', '110']
# Total cluster 1: 7
# Total cluster 2: 16
# Same story 11 Direct connection 5 Same parent 1 Same children 4
# Step: 2 0.17391304347826086 {'action': 'add-cluster-list', 'content': [['44', '71', '72'], 1]} {'action': 'add-cluster-list', 'content': [['60', '75', '85'], 2]}
# Complexity: [61, 88, 23, 14, 9, 50]
# Previous actions:
# ['36', '66', '84', '44', '71', '72']
# ['10', '70', '110', '60', '75', '85']
# Total cluster 1: 8
# Total cluster 2: 7
# Same story 17 Direct connection 4 Same parent 0 Same children 1
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['45', '47'], 1]} {'action': 'add-cluster-list', 'content': [['109'], 2]}
# Complexity: [29, 31, 10, 5, 5, 12]
# ===================================
# Sample #3 (Valid Sample #3)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 5
# Total cluster 2: 7
# Same story 7 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.5 {'action': 'add-cluster-list', 'content': [['36', '58', '72'], 1]} {'action': 'add-cluster-list', 'content': [['10', '70', '74'], 2]}
# Complexity: [26, 26, 5, 5, 0, 5]
# Previous actions:
# ['36', '58', '72']
# ['10', '70', '74']
# Total cluster 1: 5
# Total cluster 2: 8
# Same story 7 Direct connection 5 Same parent 1 Same children 3
# Step: 2 0.15384615384615385 {'action': 'add-cluster-list', 'content': [['84', '103'], 1]} {'action': 'add-cluster-list', 'content': [['14', '81', '110'], 2]}
# Complexity: [24, 27, 9, 5, 4, 12]
# Previous actions:
# ['36', '58', '72', '84', '103']
# ['10', '70', '74', '14', '81', '110']
# Total cluster 1: 5
# Total cluster 2: 12
# Same story 12 Direct connection 9 Same parent 3 Same children 5
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['25', '62', '85'], 2]}
# Complexity: [29, 37, 10, 6, 4, 18]
# ===================================
# Sample #4 (Valid Sample #4)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 0
# Total cluster 2: 4
# Same story 1 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.25 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['10', '14', '37'], 2]}
# Complexity: [18, 25, 9, 3, 6, 16]
# Previous actions:
# []
# ['10', '14', '37']
# Total cluster 1: 3
# Total cluster 2: 8
# Same story 6 Direct connection 2 Same parent 0 Same children 3
# Step: 2 0.09090909090909094 {'action': 'add-cluster-list', 'content': [['36', '84', '103'], 1]} {'action': 'add-cluster-list', 'content': [['92', '109', '120'], 2]}
# Complexity: [27, 30, 7, 5, 2, 10]
# Previous actions:
# ['36', '84', '103']
# ['10', '14', '37', '92', '109', '120']
# Total cluster 1: 4
# Total cluster 2: 8
# Same story 5 Direct connection 4 Same parent 0 Same children 1
# Step: 3 0.16666666666666663 {'action': 'add-cluster-list', 'content': [['66'], 1]} {'action': 'add-cluster-list', 'content': [['57', '110'], 2]}
# Complexity: [24, 27, 8, 5, 3, 11]
# Previous actions:
# ['36', '84', '103', '66']
# ['10', '14', '37', '92', '109', '120', '57', '110']
# Total cluster 1: 5
# Total cluster 2: 18
# Same story 10 Direct connection 7 Same parent 2 Same children 4
# Step: 4 0.17391304347826086 {'action': 'add-cluster-list', 'content': [['44'], 1]} {'action': 'add-cluster-list', 'content': [['60', '74', '79'], 2]}
# Complexity: [60, 80, 19, 17, 2, 39]
# Previous actions:
# ['36', '84', '103', '66', '44']
# ['10', '14', '37', '92', '109', '120', '57', '110', '60', '74', '79']
# Total cluster 1: 7
# Total cluster 2: 15
# Same story 22 Direct connection 8 Same parent 4 Same children 7
# Step: 5 0.0 {'action': 'add-cluster-list', 'content': [['136', '150'], 1]} {'action': 'add-cluster-list', 'content': [['70', '142', '143'], 2]}
# Complexity: [41, 50, 12, 8, 4, 21]
# ===================================
# Sample #5 (Valid Sample #5)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 5
# Total cluster 2: 7
# Same story 7 Direct connection 1 Same parent 3 Same children 0
# Step: 1 0.08333333333333337 {'action': 'add-cluster-list', 'content': [['19', '36', '47'], 1]} {'action': 'add-cluster-list', 'content': [['10', '14', '24'], 2]}
# Complexity: [23, 27, 6, 3, 3, 10]
# Previous actions:
# ['19', '36', '47']
# ['10', '14', '24']
# Total cluster 1: 3
# Total cluster 2: 6
# Same story 5 Direct connection 1 Same parent 0 Same children 0
# Step: 2 0.11111111111111116 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['62', '139', '152'], 2]}
# Complexity: [23, 28, 7, 6, 1, 12]
# Previous actions:
# ['19', '36', '47']
# ['10', '14', '24', '62', '139', '152']
# Total cluster 1: 5
# Total cluster 2: 8
# Same story 12 Direct connection 3 Same parent 1 Same children 3
# Step: 3 0.15384615384615385 {'action': 'add-cluster-list', 'content': [['28', '66'], 1]} {'action': 'add-cluster-list', 'content': [['25', '99'], 2]}
# Complexity: [24, 30, 9, 4, 5, 15]
# Previous actions:
# ['19', '36', '47', '28', '66']
# ['10', '14', '24', '62', '139', '152', '25', '99']
# Total cluster 1: 6
# Total cluster 2: 8
# Same story 12 Direct connection 4 Same parent 2 Same children 3
# Step: 4 0.0714285714285714 {'action': 'add-cluster-list', 'content': [['44'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [22, 25, 6, 5, 1, 9]
# Previous actions:
# ['19', '36', '47', '28', '66', '44']
# ['10', '14', '24', '62', '139', '152', '25', '99']
# Total cluster 1: 6
# Total cluster 2: 8
# Same story 12 Direct connection 6 Same parent 2 Same children 3
# Step: 5 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [22, 25, 6, 5, 1, 9]
# Nothing to add - Early stopping.
# ===================================
# Sample #6 (Valid Sample #6)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 4
# Same story 4 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.1428571428571429 {'action': 'add-cluster-list', 'content': [['36', '45', '47'], 1]} {'action': 'add-cluster-list', 'content': [['10', '62', '157'], 2]}
# Complexity: [22, 26, 6, 3, 3, 10]
# Previous actions:
# ['36', '45', '47']
# ['10', '62', '157']
# Total cluster 1: 7
# Total cluster 2: 7
# Same story 6 Direct connection 4 Same parent 1 Same children 2
# Step: 2 0.2142857142857143 {'action': 'add-cluster-list', 'content': [['58', '66', '84'], 1]} {'action': 'add-cluster-list', 'content': [['37', '78', '85'], 2]}
# Complexity: [31, 39, 8, 7, 1, 16]
# Previous actions:
# ['36', '45', '47', '58', '66', '84']
# ['10', '62', '157', '37', '78', '85']
# Total cluster 1: 6
# Total cluster 2: 13
# Same story 20 Direct connection 7 Same parent 4 Same children 3
# Step: 3 0.052631578947368474 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['14', '24', '25'], 2]}
# Complexity: [29, 39, 9, 7, 2, 19]
# Previous actions:
# ['36', '45', '47', '58', '66', '84']
# ['10', '62', '157', '37', '78', '85', '14', '24', '25']
# Total cluster 1: 6
# Total cluster 2: 11
# Same story 17 Direct connection 3 Same parent 1 Same children 1
# Step: 4 0.05882352941176472 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['137', '139'], 2]}
# Complexity: [24, 29, 8, 6, 2, 13]
# Previous actions:
# ['36', '45', '47', '58', '66', '84']
# ['10', '62', '157', '37', '78', '85', '14', '24', '25', '137', '139']
# Total cluster 1: 7
# Total cluster 2: 12
# Same story 20 Direct connection 6 Same parent 1 Same children 5
# Step: 5 0.052631578947368474 {'action': 'add-cluster-list', 'content': [['54'], 1]} {'action': 'add-cluster-list', 'content': [['152'], 2]}
# Complexity: [29, 33, 8, 6, 2, 12]
# Previous actions:
# ['36', '45', '47', '58', '66', '84', '54']
# ['10', '62', '157', '37', '78', '85', '14', '24', '25', '137', '139', '152']
# Total cluster 1: 8
# Total cluster 2: 14
# Same story 21 Direct connection 9 Same parent 3 Same children 5
# Step: 6 0.045454545454545414 {'action': 'add-cluster-list', 'content': [['136'], 1]} {'action': 'add-cluster-list', 'content': [['99', '123'], 2]}
# Complexity: [33, 45, 12, 7, 5, 24]
# Previous actions:
# ['36', '45', '47', '58', '66', '84', '54', '136']
# ['10', '62', '157', '37', '78', '85', '14', '24', '25', '137', '139', '152', '99', '123']
# Total cluster 1: 9
# Total cluster 2: 16
# Same story 38 Direct connection 8 Same parent 4 Same children 5
# Step: 7 0.07999999999999996 {'action': 'add-cluster-list', 'content': [['71'], 1]} {'action': 'add-cluster-list', 'content': [['70', '120'], 2]}
# Complexity: [35, 42, 10, 7, 3, 17]
# Previous actions:
# ['36', '45', '47', '58', '66', '84', '54', '136', '71']
# ['10', '62', '157', '37', '78', '85', '14', '24', '25', '137', '139', '152', '99', '123', '70', '120']
# Total cluster 1: 9
# Total cluster 2: 18
# Same story 68 Direct connection 9 Same parent 2 Same children 7
# Step: 8 0.03703703703703709 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['74', '142'], 2]}
# Complexity: [34, 41, 9, 5, 4, 16]
# Previous actions:
# ['36', '45', '47', '58', '66', '84', '54', '136', '71']
# ['10', '62', '157', '37', '78', '85', '14', '24', '25', '137', '139', '152', '99', '123', '70', '120', '74', '142']
# Total cluster 1: 9
# Total cluster 2: 18
# Same story 28 Direct connection 12 Same parent 1 Same children 3
# Step: 9 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [38, 45, 10, 7, 3, 17]
# Nothing to add - Early stopping.
# ===================================
# Sample #7 (Valid Sample #7)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 7
# Same story 4 Direct connection 1 Same parent 0 Same children 1
# Step: 1 0.19999999999999996 {'action': 'add-cluster-list', 'content': [['36', '47', '84'], 1]} {'action': 'add-cluster-list', 'content': [['10', '60', '62'], 2]}
# Complexity: [23, 27, 6, 5, 1, 10]
# Previous actions:
# ['36', '47', '84']
# ['10', '60', '62']
# Total cluster 1: 4
# Total cluster 2: 8
# Same story 12 Direct connection 1 Same parent 0 Same children 1
# Step: 2 0.08333333333333337 {'action': 'add-cluster-list', 'content': [['66'], 1]} {'action': 'add-cluster-list', 'content': [['14', '37', '78'], 2]}
# Complexity: [24, 25, 6, 5, 1, 7]
# Previous actions:
# ['36', '47', '84', '66']
# ['10', '60', '62', '14', '37', '78']
# Total cluster 1: 5
# Total cluster 2: 10
# Same story 12 Direct connection 4 Same parent 1 Same children 3
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['23'], 1]} {'action': 'add-cluster-list', 'content': [['70', '85', '110'], 2]}
# Complexity: [23, 26, 6, 5, 1, 9]
# ===================================
# Sample #8 (Valid Sample #8)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 3
# Same story 3 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [['58', '84'], 1]} {'action': 'add-cluster-list', 'content': [['10', '85', '139'], 2]}
# Complexity: [14, 19, 7, 2, 5, 12]
# ===================================
# Sample #9 (Valid Sample #8)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 4
# Same story 6 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.1428571428571429 {'action': 'add-cluster-list', 'content': [['23', '36', '45'], 1]} {'action': 'add-cluster-list', 'content': [['10', '62', '92'], 2]}
# Complexity: [24, 26, 7, 3, 4, 9]
# Previous actions:
# ['23', '36', '45']
# ['10', '62', '92']
# Total cluster 1: 4
# Total cluster 2: 7
# Same story 18 Direct connection 2 Same parent 0 Same children 0
# Step: 2 0.09090909090909094 {'action': 'add-cluster-list', 'content': [['136'], 1]} {'action': 'add-cluster-list', 'content': [['14', '78', '85'], 2]}
# Complexity: [26, 31, 7, 5, 2, 12]
# Previous actions:
# ['23', '36', '45', '136']
# ['10', '62', '92', '14', '78', '85']
# Total cluster 1: 6
# Total cluster 2: 7
# Same story 9 Direct connection 3 Same parent 1 Same children 2
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['47', '84'], 1]} {'action': 'add-cluster-list', 'content': [['153'], 2]}
# Complexity: [22, 28, 7, 5, 2, 13]
# ===================================
# Sample #10 (Valid Sample #9)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 8
# Same story 9 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [['36', '54'], 1]} {'action': 'add-cluster-list', 'content': [['10', '80', '99'], 2]}
# Complexity: [24, 26, 6, 5, 1, 8]
# ===================================
# Sample #11 (Valid Sample #9)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 6
# Same story 7 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.33333333333333337 {'action': 'add-cluster-list', 'content': [['36', '45', '84'], 1]} {'action': 'add-cluster-list', 'content': [['10', '14', '62'], 2]}
# Complexity: [27, 30, 5, 5, 0, 8]
# Previous actions:
# ['36', '45', '84']
# ['10', '14', '62']
# Total cluster 1: 4
# Total cluster 2: 5
# Same story 2 Direct connection 1 Same parent 0 Same children 1
# Step: 2 0.4444444444444444 {'action': 'add-cluster-list', 'content': [['66'], 1]} {'action': 'add-cluster-list', 'content': [['99', '139'], 2]}
# Complexity: [22, 28, 11, 4, 7, 17]
# Previous actions:
# ['36', '45', '84', '66']
# ['10', '14', '62', '99', '139']
# Total cluster 1: 4
# Total cluster 2: 7
# Same story 3 Direct connection 4 Same parent 0 Same children 3
# Step: 3 0.18181818181818177 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['106', '157'], 2]}
# Complexity: [26, 34, 9, 7, 2, 17]
# Previous actions:
# ['36', '45', '84', '66']
# ['10', '14', '62', '99', '139', '106', '157']
# Total cluster 1: 4
# Total cluster 2: 9
# Same story 18 Direct connection 4 Same parent 0 Same children 1
# Step: 4 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['109', '115'], 2]}
# Complexity: [24, 29, 8, 6, 2, 13]

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts, "complexity": [p.to_dict() for p in all_complexities]}
with open('results_clustering_bb_center.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Test with Florida/Miami news vs general US news

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
i = 0
total_samples = base_total_samples
while i < total_samples:
    print("===================================")
    print("Sample #" + str(i) + " (Valid Sample #" + str(len(all_complexities)) + ")")
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    drop = False
    
    while percent_filter > 0:
        G, graph_df, storylines = generate_map(query, dataset, k_input=8, start_nodes=[10], previous_actions=previous_actions, 
                                               verbose=False, random_state=random_state, force_cluster=True, use_new_LP=True)
        nodes = list(G.edges())
        
        breitbart_nodes = graph_df[graph_df.title.str.contains('miami', case=False) | 
                                   graph_df.title.str.contains('florida', case=False)] # Cluster 1
        center_nodes = graph_df[(graph_df.title.str.contains(r'(?:\s|\b)[Uu](?:\.)?[sS](?:\.)?[Aa]?(?:\.)?(?:\s|\b)', regex=True) |
                                 graph_df.title.str.contains('united states', case=False)) & 
                                 ~(graph_df.title.str.contains('miami', case=False) 
                                   | graph_df.title.str.contains('florida', case=False))] # Cluster 2
        breitbart_cluster = [str(node) for node in breitbart_nodes['id'].tolist()]
        center_cluster = [str(node) for node in center_nodes['id'].tolist()]
        
        breitbart_action = {"action": "add-cluster-list", "content": [breitbart_cluster[:min(3, len(breitbart_cluster))], 1]}
        center_action = {"action": "add-cluster-list", "content": [center_cluster[:min(3, len(center_cluster))], 2]}

        breitbart_cluster_full = [str(node) for node in breitbart_nodes['id'].tolist()]
        center_cluster_full = [str(node) for node in center_nodes['id'].tolist()]
        
        previous_breitbart = [node for node_list in previous_actions for node in node_list["content"][0] if node_list["content"][1] == 1]
        previous_center = [node for node_list in previous_actions for node in node_list["content"][0] if node_list["content"][1] == 2]

        print("Previous actions:")
        print(previous_breitbart)
        print(previous_center)
        
        breitbart_cluster_int = sorted([int(node) for node in list(set(breitbart_cluster_full).difference(previous_breitbart))])
        center_cluster_int = sorted([int(node) for node in list(set(center_cluster_full).difference(previous_center))])
        
        breitbart_cluster = [str(node) for node in breitbart_cluster_int]
        center_cluster = [str(node) for node in center_cluster_int]
        
        breitbart_action = {"action": "add-cluster-list", "content": [breitbart_cluster, 1]}
        center_action = {"action": "add-cluster-list", "content": [center_cluster, 2]}
        
        previous_actions.append(breitbart_action)
        previous_actions.append(center_action)
        
        non_isolated_nodes = set()
        breitbart_n = len(breitbart_cluster_full)
        center_n = len(center_cluster_full)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        count_has_path = 0
        for combination in itertools.combinations(breitbart_cluster_full,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
                
        for combination in itertools.combinations(center_cluster_full,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1

        print("Total cluster 1: " + str(breitbart_n))
        print("Total cluster 2: " + str(center_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
        
        if breitbart_n + center_n == 0:
            percent_filter = 0.0
        else:
            percent_filter = 1 - len(non_isolated_nodes) / (breitbart_n + center_n)
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
            
        percent_list.append(percent_filter)

        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, breitbart_action, center_action)
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
        
        if len(breitbart_cluster) == 0 and len(center_cluster) == 0:
            print("Nothing to add - Early stopping.")
            break
    i += 1
    actions = []
    for action in previous_actions:
        if action['action'] == 'add-cluster-list':
            actions += action['content'][0] 
        elif type(action['content']) == list:
            actions += action['content']
        else:
            actions.append(action['content'])
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0 (Valid Sample #0)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 5
# Total cluster 2: 4
# Same story 2 Direct connection 2 Same parent 0 Same children 1
# Step: 1 0.2222222222222222 {'action': 'add-cluster-list', 'content': [['35', '36', '49', '87', '94'], 1]} {'action': 'add-cluster-list', 'content': [['25', '33', '112', '139'], 2]}
# Complexity: [22, 28, 6, 4, 2, 12]
# Previous actions:
# ['35', '36', '49', '87', '94']
# ['25', '33', '112', '139']
# Total cluster 1: 6
# Total cluster 2: 6
# Same story 4 Direct connection 6 Same parent 1 Same children 1
# Step: 2 0.0 {'action': 'add-cluster-list', 'content': [['63'], 1]} {'action': 'add-cluster-list', 'content': [['22', '65'], 2]}
# Complexity: [25, 32, 10, 6, 4, 17]
# ===================================
# Sample #1 (Valid Sample #1)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 1
# Total cluster 2: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-cluster-list', 'content': [['63'], 1]} {'action': 'add-cluster-list', 'content': [['33'], 2]}
# Complexity: [22, 29, 8, 4, 4, 15]
# Previous actions:
# ['63']
# ['33']
# Total cluster 1: 0
# Total cluster 2: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.33333333333333337 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['22', '116', '146'], 2]}
# Complexity: [19, 22, 6, 3, 3, 9]
# Previous actions:
# ['63']
# ['33', '22', '116', '146']
# Total cluster 1: 0
# Total cluster 2: 4
# Same story 1 Direct connection 2 Same parent 1 Same children 2
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [22, 27, 6, 3, 3, 11]
# Nothing to add - Early stopping.
# ===================================
# Sample #2 (Valid Sample #2)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 4
# Same story 2 Direct connection 1 Same parent 0 Same children 1
# Step: 1 0.1428571428571429 {'action': 'add-cluster-list', 'content': [['36', '49', '87'], 1]} {'action': 'add-cluster-list', 'content': [['22', '33', '110', '139'], 2]}
# Complexity: [18, 20, 4, 3, 1, 6]
# Previous actions:
# ['36', '49', '87']
# ['22', '33', '110', '139']
# Total cluster 1: 6
# Total cluster 2: 4
# Same story 7 Direct connection 3 Same parent 1 Same children 1
# Step: 2 0.0 {'action': 'add-cluster-list', 'content': [['35', '51', '140'], 1]} {'action': 'add-cluster-list', 'content': [[], 2]}
# Complexity: [22, 28, 7, 5, 2, 13]
# ===================================
# Sample #3 (Valid Sample #3)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 5
# Total cluster 2: 2
# Same story 5 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-cluster-list', 'content': [['36', '56', '58', '63', '68'], 1]} {'action': 'add-cluster-list', 'content': [['74', '110'], 2]}
# Complexity: [26, 26, 5, 5, 0, 5]
# ===================================
# Sample #4 (Valid Sample #3)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 6
# Total cluster 2: 2
# Same story 3 Direct connection 2 Same parent 1 Same children 1
# Step: 1 0.25 {'action': 'add-cluster-list', 'content': [['35', '40', '53', '88', '94', '126'], 1]} {'action': 'add-cluster-list', 'content': [['65', '142'], 2]}
# Complexity: [18, 25, 9, 3, 6, 16]
# Previous actions:
# ['35', '40', '53', '88', '94', '126']
# ['65', '142']
# Total cluster 1: 10
# Total cluster 2: 5
# Same story 16 Direct connection 2 Same parent 1 Same children 3
# Step: 2 0.06666666666666665 {'action': 'add-cluster-list', 'content': [['36', '38', '122', '140'], 1]} {'action': 'add-cluster-list', 'content': [['33', '104', '105'], 2]}
# Complexity: [29, 35, 11, 4, 7, 17]
# Previous actions:
# ['35', '40', '53', '88', '94', '126', '36', '38', '122', '140']
# ['65', '142', '33', '104', '105']
# Total cluster 1: 11
# Total cluster 2: 7
# Same story 8 Direct connection 9 Same parent 1 Same children 20
# Step: 3 0.05555555555555558 {'action': 'add-cluster-list', 'content': [['87'], 1]} {'action': 'add-cluster-list', 'content': [['29', '139'], 2]}
# Complexity: [30, 35, 14, 5, 9, 19]
# Previous actions:
# ['35', '40', '53', '88', '94', '126', '36', '38', '122', '140', '87']
# ['65', '142', '33', '104', '105', '29', '139']
# Total cluster 1: 12
# Total cluster 2: 8
# Same story 21 Direct connection 8 Same parent 1 Same children 4
# Step: 4 0.0 {'action': 'add-cluster-list', 'content': [['49'], 1]} {'action': 'add-cluster-list', 'content': [['128'], 2]}
# Complexity: [34, 41, 11, 5, 6, 18]
# ===================================
# Sample #5 (Valid Sample #4)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 4
# Total cluster 2: 3
# Same story 1 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.5714285714285714 {'action': 'add-cluster-list', 'content': [['36', '56', '63', '140'], 1]} {'action': 'add-cluster-list', 'content': [['24', '104', '111'], 2]}
# Complexity: [23, 27, 6, 3, 3, 10]
# Previous actions:
# ['36', '56', '63', '140']
# ['24', '104', '111']
# Total cluster 1: 6
# Total cluster 2: 7
# Same story 9 Direct connection 3 Same parent 1 Same children 3
# Step: 2 0.15384615384615385 {'action': 'add-cluster-list', 'content': [['49', '68'], 1]} {'action': 'add-cluster-list', 'content': [['33', '110', '112', '139'], 2]}
# Complexity: [24, 28, 7, 6, 1, 11]
# Previous actions:
# ['36', '56', '63', '140', '49', '68']
# ['24', '104', '111', '33', '110', '112', '139']
# Total cluster 1: 7
# Total cluster 2: 12
# Same story 26 Direct connection 3 Same parent 0 Same children 3
# Step: 3 0.10526315789473684 {'action': 'add-cluster-list', 'content': [['35'], 1]} {'action': 'add-cluster-list', 'content': [['65', '75', '105', '147', '156'], 2]}
# Complexity: [37, 42, 7, 5, 2, 12]
# Previous actions:
# ['36', '56', '63', '140', '49', '68', '35']
# ['24', '104', '111', '33', '110', '112', '139', '65', '75', '105', '147', '156']
# Total cluster 1: 7
# Total cluster 2: 13
# Same story 22 Direct connection 9 Same parent 1 Same children 4
# Step: 4 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['128'], 2]}
# Complexity: [30, 34, 7, 6, 1, 11]
# ===================================
# Sample #6 (Valid Sample #5)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 3
# Total cluster 2: 2
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.6 {'action': 'add-cluster-list', 'content': [['35', '36', '63'], 1]} {'action': 'add-cluster-list', 'content': [['33', '65'], 2]}
# Complexity: [22, 26, 6, 3, 3, 10]
# Previous actions:
# ['35', '36', '63']
# ['33', '65']
# Total cluster 1: 5
# Total cluster 2: 9
# Same story 3 Direct connection 9 Same parent 3 Same children 4
# Step: 2 0.0714285714285714 {'action': 'add-cluster-list', 'content': [['68', '126'], 1]} {'action': 'add-cluster-list', 'content': [['74', '115', '116', '128', '139', '142', '143'], 2]}
# Complexity: [22, 28, 11, 4, 7, 17]
# Previous actions:
# ['35', '36', '63', '68', '126']
# ['33', '65', '74', '115', '116', '128', '139', '142', '143']
# Total cluster 1: 8
# Total cluster 2: 11
# Same story 32 Direct connection 1 Same parent 0 Same children 0
# Step: 3 0.1578947368421053 {'action': 'add-cluster-list', 'content': [['38', '122', '140'], 1]} {'action': 'add-cluster-list', 'content': [['25', '105'], 2]}
# Complexity: [33, 36, 10, 7, 3, 13]
# Previous actions:
# ['35', '36', '63', '68', '126', '38', '122', '140']
# ['33', '65', '74', '115', '116', '128', '139', '142', '143', '25', '105']
# Total cluster 1: 8
# Total cluster 2: 12
# Same story 14 Direct connection 8 Same parent 2 Same children 7
# Step: 4 0.050000000000000044 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['156'], 2]}
# Complexity: [30, 38, 11, 7, 4, 19]
# Previous actions:
# ['35', '36', '63', '68', '126', '38', '122', '140']
# ['33', '65', '74', '115', '116', '128', '139', '142', '143', '25', '105', '156']
# Total cluster 1: 10
# Total cluster 2: 17
# Same story 26 Direct connection 8 Same parent 2 Same children 6
# Step: 5 0.07407407407407407 {'action': 'add-cluster-list', 'content': [['56', '97'], 1]} {'action': 'add-cluster-list', 'content': [['24', '75', '80', '110', '121'], 2]}
# Complexity: [68, 98, 20, 15, 5, 50]
# Previous actions:
# ['35', '36', '63', '68', '126', '38', '122', '140', '56', '97']
# ['33', '65', '74', '115', '116', '128', '139', '142', '143', '25', '105', '156', '24', '75', '80', '110', '121']
# Total cluster 1: 10
# Total cluster 2: 18
# Same story 12 Direct connection 15 Same parent 6 Same children 19
# Step: 6 0.0 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['104'], 2]}
# Complexity: [42, 53, 16, 9, 7, 27]
# ===================================
# Sample #7 (Valid Sample #6)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 4
# Total cluster 2: 3
# Same story 2 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.4285714285714286 {'action': 'add-cluster-list', 'content': [['36', '49', '87', '122'], 1]} {'action': 'add-cluster-list', 'content': [['33', '128', '139'], 2]}
# Complexity: [23, 27, 6, 5, 1, 10]
# Previous actions:
# ['36', '49', '87', '122']
# ['33', '128', '139']
# Total cluster 1: 6
# Total cluster 2: 6
# Same story 11 Direct connection 3 Same parent 1 Same children 2
# Step: 2 0.08333333333333337 {'action': 'add-cluster-list', 'content': [['35', '56'], 1]} {'action': 'add-cluster-list', 'content': [['65', '104', '121'], 2]}
# Complexity: [24, 28, 7, 5, 2, 11]
# Previous actions:
# ['36', '49', '87', '122', '35', '56']
# ['33', '128', '139', '65', '104', '121']
# Total cluster 1: 9
# Total cluster 2: 7
# Same story 13 Direct connection 7 Same parent 6 Same children 2
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['38', '126', '140'], 1]} {'action': 'add-cluster-list', 'content': [['112'], 2]}
# Complexity: [27, 39, 10, 5, 5, 22]
# ===================================
# Sample #8 (Valid Sample #7)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 1
# Total cluster 2: 3
# Same story 0 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.5 {'action': 'add-cluster-list', 'content': [['58'], 1]} {'action': 'add-cluster-list', 'content': [['21', '139', '147'], 2]}
# Complexity: [14, 19, 7, 2, 5, 12]
# Previous actions:
# ['58']
# ['21', '139', '147']
# Total cluster 1: 2
# Total cluster 2: 5
# Same story 4 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.2857142857142857 {'action': 'add-cluster-list', 'content': [['36', '122'], 1]} {'action': 'add-cluster-list', 'content': [['33', '146'], 2]}
# Complexity: [22, 25, 5, 3, 2, 8]
# Previous actions:
# ['58', '36', '122']
# ['21', '139', '147', '33', '146']
# Total cluster 1: 4
# Total cluster 2: 7
# Same story 9 Direct connection 4 Same parent 0 Same children 2
# Step: 3 0.09090909090909094 {'action': 'add-cluster-list', 'content': [['68'], 1]} {'action': 'add-cluster-list', 'content': [['110', '128'], 2]}
# Complexity: [23, 27, 6, 3, 3, 10]
# Previous actions:
# ['58', '36', '122', '68']
# ['21', '139', '147', '33', '146', '110', '128']
# Total cluster 1: 4
# Total cluster 2: 12
# Same story 14 Direct connection 5 Same parent 0 Same children 3
# Step: 4 0.125 {'action': 'add-cluster-list', 'content': [[], 1]} {'action': 'add-cluster-list', 'content': [['75', '104', '111', '121', '142'], 2]}
# Complexity: [33, 36, 8, 6, 2, 11]
# Previous actions:
# ['58', '36', '122', '68']
# ['21', '139', '147', '33', '146', '110', '128', '75', '104', '111', '121', '142']
# Total cluster 1: 11
# Total cluster 2: 14
# Same story 11 Direct connection 10 Same parent 3 Same children 7
# Step: 5 0.16000000000000003 {'action': 'add-cluster-list', 'content': [['41', '49', '51', '53', '56', '87', '94'], 1]} {'action': 'add-cluster-list', 'content': [['144', '156'], 2]}
# Complexity: [68, 97, 28, 17, 11, 57]
# Previous actions:
# ['58', '36', '122', '68', '41', '49', '51', '53', '56', '87', '94']
# ['21', '139', '147', '33', '146', '110', '128', '75', '104', '111', '121', '142', '144', '156']
# Total cluster 1: 15
# Total cluster 2: 15
# Same story 60 Direct connection 7 Same parent 2 Same children 3
# Step: 6 0.033333333333333326 {'action': 'add-cluster-list', 'content': [['35', '46', '63', '88'], 1]} {'action': 'add-cluster-list', 'content': [['54'], 2]}
# Complexity: [44, 50, 9, 9, 0, 15]
# Previous actions:
# ['58', '36', '122', '68', '41', '49', '51', '53', '56', '87', '94', '35', '46', '63', '88']
# ['21', '139', '147', '33', '146', '110', '128', '75', '104', '111', '121', '142', '144', '156', '54']
# Total cluster 1: 16
# Total cluster 2: 16
# Same story 77 Direct connection 7 Same parent 2 Same children 9
# Step: 7 0.0 {'action': 'add-cluster-list', 'content': [['97'], 1]} {'action': 'add-cluster-list', 'content': [['29'], 2]}
# Complexity: [48, 52, 12, 9, 3, 16]
# ===================================
# Sample #9 (Valid Sample #8)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 5
# Total cluster 2: 2
# Same story 3 Direct connection 1 Same parent 2 Same children 0
# Step: 1 0.2857142857142857 {'action': 'add-cluster-list', 'content': [['36', '46', '53', '87', '88'], 1]} {'action': 'add-cluster-list', 'content': [['121', '146'], 2]}
# Complexity: [24, 26, 7, 3, 4, 9]
# Previous actions:
# ['36', '46', '53', '87', '88']
# ['121', '146']
# Total cluster 1: 9
# Total cluster 2: 4
# Same story 6 Direct connection 5 Same parent 1 Same children 2
# Step: 2 0.23076923076923073 {'action': 'add-cluster-list', 'content': [['35', '56', '63', '126'], 1]} {'action': 'add-cluster-list', 'content': [['33', '139'], 2]}
# Complexity: [29, 37, 10, 8, 2, 18]
# Previous actions:
# ['36', '46', '53', '87', '88', '35', '56', '63', '126']
# ['121', '146', '33', '139']
# Total cluster 1: 9
# Total cluster 2: 5
# Same story 6 Direct connection 6 Same parent 1 Same children 3
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['140'], 1]} {'action': 'add-cluster-list', 'content': [['110'], 2]}
# Complexity: [24, 30, 10, 4, 6, 16]
# ===================================
# Sample #10 (Valid Sample #9)
# ===================================
# Previous actions:
# []
# []
# Total cluster 1: 2
# Total cluster 2: 3
# Same story 0 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.6 {'action': 'add-cluster-list', 'content': [['36', '63'], 1]} {'action': 'add-cluster-list', 'content': [['54', '65', '80'], 2]}
# Complexity: [24, 26, 6, 5, 1, 8]
# Previous actions:
# ['36', '63']
# ['54', '65', '80']
# Total cluster 1: 5
# Total cluster 2: 7
# Same story 7 Direct connection 2 Same parent 2 Same children 1
# Step: 2 0.08333333333333337 {'action': 'add-cluster-list', 'content': [['53', '68', '122'], 1]} {'action': 'add-cluster-list', 'content': [['33', '110', '128', '139'], 2]}
# Complexity: [26, 29, 8, 5, 3, 11]
# Previous actions:
# ['36', '63', '53', '68', '122']
# ['54', '65', '80', '33', '110', '128', '139']
# Total cluster 1: 8
# Total cluster 2: 9
# Same story 16 Direct connection 6 Same parent 2 Same children 3
# Step: 3 0.0 {'action': 'add-cluster-list', 'content': [['35', '49', '140'], 1]} {'action': 'add-cluster-list', 'content': [['24', '112'], 2]}
# Complexity: [27, 34, 8, 4, 4, 15]

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts, "complexity": [p.to_dict() for p in all_complexities]}
with open('results_clustering_florida.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Add Node
# Adding nodes and clustering.
#
# ### Miami + Florida

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
subset_query = query.loc[10:].astype({'id': 'int32'})
i = 0

while i < total_samples:
    print("===================================")
    print("Sample #" + str(i) + " (Valid Sample #" + str(len(all_complexities)) + ")")
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    drop = False
    while percent_filter > 0:
        G, graph_df, storylines = generate_map(query, dataset, k_input=8, start_nodes=[10], 
                                               previous_actions=previous_actions, verbose=False, 
                                               random_state=random_state, force_cluster=True, use_new_LP=True)
        
        all_relevant_nodes = subset_query[subset_query.title.str.contains('miami', case=False) 
                                                 | subset_query.title.str.contains('florida', case=False)]
        relevant_nodes = graph_df[graph_df.title.str.contains('miami', case=False) | 
                                   graph_df.title.str.contains('florida', case=False)]
        
        unselected_relevant_nodes = (all_relevant_nodes.merge(relevant_nodes, on=['id'], how='left', indicator=True)
                                     .query('_merge == "left_only"')
                                     .drop('_merge', 1))
        relevant_node_list = [str(node) for node in relevant_nodes.id.tolist()]
        # Select first 10% nodes.
        percentage = 10
        selected_nodes_df = unselected_relevant_nodes.head(int(len(unselected_relevant_nodes.index) * (percentage / 100)))
        selected_nodes_list = [str(node) for node in selected_nodes_df.id.tolist()]
        
        add_node = {"action": "add-node", "content": selected_nodes_list}
        previous_actions.append(add_node)
        
        # Mark nodes as part of the same cluster
        new_cluster = {"action": "add-cluster-list", "content": [relevant_node_list, 1]}
        previous_actions.append(new_cluster)
        
        # Are the relevant nodes connected?
        non_isolated_nodes = set()
        relevant_node_n = len(relevant_nodes)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        count_has_path = 0
        for combination in itertools.combinations(relevant_node_list,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1

                
        print("# of Relevant Nodes: " + str(relevant_node_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
            
        if relevant_node_n == 0:
            percent_filter = 0.0
        else:
            percent_filter = 1 - len(non_isolated_nodes) / relevant_node_n
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
            
        percent_list.append(percent_filter)
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, add_node, "Relevant nodes: " + str(relevant_node_list))
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    
    i += 1
    actions = []
    for action in previous_actions:
        actions += action['content']
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0 (Valid Sample #0)
# ===================================
# # of Relevant Nodes: 5
# Same story 1 Direct connection 2 Same parent 0 Same children 1
# Step: 1 0.0 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '49', '87', '94']
# Complexity: [22, 28, 6, 4, 2, 12]
# ===================================
# Sample #1 (Valid Sample #0)
# ===================================
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['63']
# Complexity: [22, 29, 8, 4, 4, 15]
# # of Relevant Nodes: 2
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.0 {'action': 'add-node', 'content': ['36']} Relevant nodes: ['35', '63']
# Complexity: [24, 28, 6, 2, 4, 10]
# ===================================
# Sample #2 (Valid Sample #1)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.33333333333333337 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '49', '87']
# Complexity: [18, 20, 4, 3, 1, 6]
# # of Relevant Nodes: 6
# Same story 3 Direct connection 1 Same parent 2 Same children 0
# Step: 2 0.16666666666666663 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '49', '56', '87', '140']
# Complexity: [22, 32, 11, 5, 6, 21]
# # of Relevant Nodes: 8
# Same story 3 Direct connection 4 Same parent 2 Same children 1
# Step: 3 0.0 {'action': 'add-node', 'content': ['40']} Relevant nodes: ['35', '36', '38', '49', '51', '56', '87', '140']
# Complexity: [20, 25, 8, 5, 3, 13]
# ===================================
# Sample #3 (Valid Sample #2)
# ===================================
# # of Relevant Nodes: 5
# Same story 4 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '56', '58', '63', '68']
# Complexity: [26, 26, 5, 5, 0, 5]
# ===================================
# Sample #4 (Valid Sample #2)
# ===================================
# # of Relevant Nodes: 6
# Same story 3 Direct connection 2 Same parent 1 Same children 1
# Step: 1 0.0 {'action': 'add-node', 'content': ['36']} Relevant nodes: ['35', '40', '53', '88', '94', '126']
# Complexity: [18, 25, 9, 3, 6, 16]
# ===================================
# Sample #5 (Valid Sample #2)
# ===================================
# # of Relevant Nodes: 4
# Same story 1 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.25 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '56', '63', '140']
# Complexity: [23, 27, 6, 3, 3, 10]
# # of Relevant Nodes: 7
# Same story 3 Direct connection 2 Same parent 0 Same children 0
# Step: 2 0.2857142857142857 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '49', '56', '63', '68', '140']
# Complexity: [22, 26, 7, 6, 1, 11]
# # of Relevant Nodes: 8
# Same story 2 Direct connection 4 Same parent 1 Same children 4
# Step: 3 0.0 {'action': 'add-node', 'content': ['40']} Relevant nodes: ['35', '36', '38', '49', '56', '63', '68', '140']
# Complexity: [29, 35, 11, 6, 5, 17]
# ===================================
# Sample #6 (Valid Sample #3)
# ===================================
# # of Relevant Nodes: 3
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '63']
# Complexity: [22, 26, 6, 3, 3, 10]
# # of Relevant Nodes: 8
# Same story 3 Direct connection 2 Same parent 1 Same children 0
# Step: 2 0.25 {'action': 'add-node', 'content': ['40']} Relevant nodes: ['35', '36', '38', '51', '63', '88', '97', '126']
# Complexity: [24, 28, 8, 5, 3, 12]
# # of Relevant Nodes: 11
# Same story 11 Direct connection 3 Same parent 2 Same children 3
# Step: 3 0.09090909090909094 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '36', '38', '40', '51', '56', '63', '88', '97', '126', '140']
# Complexity: [29, 35, 11, 7, 4, 17]
# # of Relevant Nodes: 13
# Same story 8 Direct connection 7 Same parent 3 Same children 7
# Step: 4 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '36', '38', '40', '51', '56', '63', '87', '88', '94', '97', '126', '140']
# Complexity: [25, 34, 9, 7, 2, 18]
# ===================================
# Sample #7 (Valid Sample #4)
# ===================================
# # of Relevant Nodes: 4
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.5 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '49', '87', '122']
# Complexity: [23, 27, 6, 5, 1, 10]
# # of Relevant Nodes: 6
# Same story 6 Direct connection 0 Same parent 1 Same children 0
# Step: 2 0.16666666666666663 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '49', '56', '87', '122']
# Complexity: [24, 27, 6, 5, 1, 9]
# # of Relevant Nodes: 7
# Same story 10 Direct connection 1 Same parent 1 Same children 1
# Step: 3 0.0 {'action': 'add-node', 'content': ['40']} Relevant nodes: ['35', '36', '38', '49', '56', '87', '122']
# Complexity: [26, 33, 8, 6, 2, 15]
# ===================================
# Sample #8 (Valid Sample #5)
# ===================================
# # of Relevant Nodes: 1
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['58']
# Complexity: [14, 19, 7, 2, 5, 12]
# # of Relevant Nodes: 4
# Same story 1 Direct connection 0 Same parent 2 Same children 0
# Step: 2 0.25 {'action': 'add-node', 'content': ['36']} Relevant nodes: ['35', '40', '68', '88']
# Complexity: [18, 23, 8, 3, 5, 13]
# # of Relevant Nodes: 8
# Same story 7 Direct connection 2 Same parent 0 Same children 3
# Step: 3 0.125 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '40', '58', '68', '88', '122', '140']
# Complexity: [30, 33, 10, 6, 4, 13]
# # of Relevant Nodes: 12
# Same story 7 Direct connection 9 Same parent 8 Same children 5
# Step: 4 0.0 {'action': 'add-node', 'content': []} Relevant nodes: ['35', '36', '38', '40', '51', '53', '58', '63', '68', '88', '122', '140']
# Complexity: [25, 42, 10, 5, 5, 27]
# ===================================
# Sample #9 (Valid Sample #6)
# ===================================
# # of Relevant Nodes: 5
# Same story 3 Direct connection 1 Same parent 2 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '46', '53', '87', '88']
# Complexity: [24, 26, 7, 3, 4, 9]
# ===================================
# Sample #10 (Valid Sample #6)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '63']
# Complexity: [24, 26, 6, 5, 1, 8]
# # of Relevant Nodes: 6
# Same story 3 Direct connection 2 Same parent 1 Same children 1
# Step: 2 0.0 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '53', '63', '68', '122']
# Complexity: [23, 26, 7, 5, 2, 10]
# ===================================
# Sample #11 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '63']
# Complexity: [27, 30, 5, 5, 0, 8]
# ===================================
# Sample #12 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 4
# Same story 2 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['36']} Relevant nodes: ['35', '46', '63', '140']
# Complexity: [23, 27, 5, 4, 1, 9]
# ===================================
# Sample #13 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 4
# Same story 3 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '46', '87', '88']
# Complexity: [22, 24, 5, 5, 0, 7]
# ===================================
# Sample #14 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 2
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['36']} Relevant nodes: ['35', '63']
# Complexity: [19, 20, 5, 4, 1, 6]
# ===================================
# Sample #15 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 4
# Same story 1 Direct connection 1 Same parent 1 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '56', '63', '68']
# Complexity: [26, 28, 8, 5, 3, 10]
# ===================================
# Sample #16 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 4
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '68', '126']
# Complexity: [17, 21, 6, 5, 1, 10]
# # of Relevant Nodes: 5
# Same story 1 Direct connection 1 Same parent 0 Same children 0
# Step: 2 0.19999999999999996 {'action': 'add-node', 'content': ['40']} Relevant nodes: ['35', '36', '38', '68', '126']
# Complexity: [28, 34, 11, 6, 5, 17]
# # of Relevant Nodes: 7
# Same story 4 Direct connection 3 Same parent 1 Same children 0
# Step: 3 0.0 {'action': 'add-node', 'content': ['41']} Relevant nodes: ['35', '36', '38', '40', '63', '68', '126']
# Complexity: [20, 22, 7, 3, 4, 9]
# ===================================
# Sample #17 (Valid Sample #8)
# ===================================
# # of Relevant Nodes: 4
# Same story 1 Direct connection 1 Same parent 1 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '53', '87']
# Complexity: [23, 27, 5, 3, 2, 9]
# ===================================
# Sample #18 (Valid Sample #8)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.33333333333333337 {'action': 'add-node', 'content': ['36']} Relevant nodes: ['35', '63', '87']
# Complexity: [29, 31, 5, 4, 1, 7]
# # of Relevant Nodes: 4
# Same story 0 Direct connection 2 Same parent 1 Same children 0
# Step: 2 0.0 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '63', '87']
# Complexity: [20, 25, 7, 4, 3, 12]
# ===================================
# Sample #19 (Valid Sample #9)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 1 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '58', '122']
# Complexity: [24, 28, 6, 5, 1, 10]
# ===================================
# Sample #20 (Valid Sample #9)
# ===================================
# # of Relevant Nodes: 3
# Same story 0 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.33333333333333337 {'action': 'add-node', 'content': ['35']} Relevant nodes: ['36', '49', '68']
# Complexity: [17, 21, 6, 3, 3, 10]
# # of Relevant Nodes: 5
# Same story 3 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.4 {'action': 'add-node', 'content': ['38']} Relevant nodes: ['35', '36', '49', '68', '140']
# Complexity: [23, 28, 10, 4, 6, 15]
# # of Relevant Nodes: 9
# Same story 5 Direct connection 5 Same parent 5 Same children 1
# Step: 3 0.0 {'action': 'add-node', 'content': ['40']} Relevant nodes: ['35', '36', '38', '49', '53', '68', '87', '122', '140']
# Complexity: [22, 29, 8, 4, 4, 15]

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts, "complexity": [p.to_dict() for p in all_complexities]}
with open('results_add_florida.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ### Biden

# %%
all_iterations = []
all_percents = []
all_counts = []
all_complexities = []
total_samples = base_total_samples
subset_query = query.loc[10:].astype({'id': 'int32'})
i = 0

while i < total_samples:
    print("===================================")
    print("Sample #" + str(i) + " (Valid Sample #" + str(len(all_complexities)) + ")")
    print("===================================")
    inner_iter_count = 0
    previous_actions = []
    percent_filter = 1.0
    percent_list = []
    drop = False
    complexity = pd.DataFrame(columns=['Nodes', 'Edges', 'Stories', 'Regular Stories', 'Singleton Stories', 'Interstory Connections'])
    random_state = i # Random state has to be consisten throughout the same iteration.
    
    while percent_filter > 0:
        G, graph_df, storylines = generate_map(query, dataset, k_input=8, start_nodes=[10], 
                                               previous_actions=previous_actions, verbose=False, 
                                               random_state=random_state, force_cluster=True, use_new_LP=True)
        
        all_relevant_nodes = subset_query[subset_query.title.str.contains('biden', case=False) 
                                                 | subset_query.title.str.contains('biden', case=False)]
        relevant_nodes = graph_df[graph_df.title.str.contains('biden', case=False) | 
                                   graph_df.title.str.contains('biden', case=False)]
        
        unselected_relevant_nodes = (all_relevant_nodes.merge(relevant_nodes, on=['id'], how='left', indicator=True)
                                     .query('_merge == "left_only"')
                                     .drop('_merge', 1))
        relevant_node_list = [str(node) for node in relevant_nodes.id.tolist()]
        # Select first 10% nodes.
        percentage = 10
        selected_nodes_df = unselected_relevant_nodes.head(int(len(unselected_relevant_nodes.index) * (percentage / 100)))
        selected_nodes_list = [str(node) for node in selected_nodes_df.id.tolist()]
        
        add_node = {"action": "add-node", "content": selected_nodes_list}
        previous_actions.append(add_node)
        
        # Mark nodes as part of the same cluster
        new_cluster = {"action": "add-cluster-list", "content": [relevant_node_list, 1]}
        previous_actions.append(new_cluster)
        
        # Are the relevant nodes connected?
        non_isolated_nodes = set()
        relevant_node_n = len(relevant_nodes)

        count_same_story = 0
        count_direct_connection = 0
        count_same_parent = 0
        count_same_children = 0
        count_has_path = 0
        for combination in itertools.combinations(relevant_node_list,2):
            pred_i = G.predecessors(combination[0])
            pred_j = G.predecessors(combination[1])
            succ_i = G.successors(combination[0])
            succ_j = G.successors(combination[1])
            if any(all(node in story for node in combination) for story in storylines) : # pair is in the same storyline
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_story += 1
            elif G.has_edge(*combination) or G.has_edge(*reversed(combination)): # pair is directly connected (even if not in the same storyline)
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_direct_connection += 1
            elif set(pred_i) & set(pred_j): # pair shares the same parent/predecessors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_parent += 1
            elif set(succ_i) & set(succ_j): # pair shares the same children/succesors.
                non_isolated_nodes.add(combination[0])
                non_isolated_nodes.add(combination[1])
                count_same_children += 1
        
        print("# of Relevant Nodes: " + str(relevant_node_n))
        print("Same story " + str(count_same_story), 
              "Direct connection " + str(count_direct_connection), 
              "Same parent " + str(count_same_parent),
              "Same children " + str(count_same_children))
            
        if relevant_node_n == 0:
            percent_filter = 0.0
        else:
            percent_filter = 1 - len(non_isolated_nodes) / relevant_node_n
        
        if percent_filter == 0 and inner_iter_count == 0: 
            # if the map was perfect from the start, we will need more samples and we should drop this one.
            drop = True
            total_samples += 1
            
        percent_list.append(percent_filter)
        
        inner_iter_count += 1
        print("Step: " + str(inner_iter_count), percent_filter, add_node, "Relevant nodes: " + str(relevant_node_list))
        
        # Complexity metrics
        n_nodes = G.number_of_nodes()# Number of nodes
        n_edges = G.number_of_edges()# Number of edges
        n_stories = len(storylines)# Number of storylines
        n_reg_stories = len([story for story in storylines if len(story) > 1])# Number of regular storylines
        n_singletons = len([story for story in storylines if len(story) == 1])# Number of singleton storylines
        total_interstory = 0
        for (story_i, story_j) in list(itertools.combinations(storylines, 2)):
            edge_boundary_list_i = list(nx.edge_boundary(G, story_i, story_j))
            edge_boundary_list_j = list(nx.edge_boundary(G, story_j, story_i))
            total_interstory += len(edge_boundary_list_i) + len(edge_boundary_list_j)
        # Number of inter-story connections 
        complexity_list = [n_nodes, n_edges, n_stories, n_reg_stories, n_singletons, total_interstory]
        print("Complexity: " + str(complexity_list))
        complexity.loc[len(complexity)] = complexity_list
    
    i += 1
    actions = []
    for action in previous_actions:
        actions += action['content']
    if not drop:
        all_iterations.append(inner_iter_count)
        all_percents.append(percent_list)
        all_counts.append(len(actions))
        all_complexities.append(complexity)
# Out:
# ===================================
# Sample #0 (Valid Sample #0)
# ===================================
# # of Relevant Nodes: 7
# Same story 3 Direct connection 2 Same parent 2 Same children 0
# Step: 1 0.1428571428571429 {'action': 'add-node', 'content': ['19', '21', '32', '34']} Relevant nodes: ['25', '49', '77', '127', '132', '138', '151']
# Complexity: [22, 28, 6, 4, 2, 12]
# # of Relevant Nodes: 15
# Same story 9 Direct connection 5 Same parent 1 Same children 10
# Step: 2 0.06666666666666665 {'action': 'add-node', 'content': ['39', '42', '44']} Relevant nodes: ['19', '21', '25', '32', '34', '49', '53', '68', '77', '106', '108', '127', '132', '138', '151']
# Complexity: [24, 28, 9, 5, 4, 13]
# # of Relevant Nodes: 19
# Same story 16 Direct connection 7 Same parent 0 Same children 9
# Step: 3 0.052631578947368474 {'action': 'add-node', 'content': ['51', '52']} Relevant nodes: ['19', '21', '25', '32', '34', '39', '42', '44', '49', '53', '68', '71', '77', '106', '108', '127', '132', '138', '151']
# Complexity: [37, 42, 13, 8, 5, 18]
# # of Relevant Nodes: 21
# Same story 22 Direct connection 10 Same parent 3 Same children 12
# Step: 4 0.04761904761904767 {'action': 'add-node', 'content': ['32', '70']} Relevant nodes: ['19', '21', '25', '34', '39', '42', '44', '49', '51', '52', '53', '54', '68', '71', '77', '106', '108', '127', '132', '138', '151']
# Complexity: [39, 45, 13, 10, 3, 19]
# # of Relevant Nodes: 25
# Same story 48 Direct connection 10 Same parent 3 Same children 5
# Step: 5 0.040000000000000036 {'action': 'add-node', 'content': ['75', '76']} Relevant nodes: ['19', '21', '25', '32', '34', '39', '42', '44', '49', '51', '52', '53', '54', '68', '70', '71', '74', '77', '106', '108', '120', '127', '132', '138', '151']
# Complexity: [43, 50, 13, 9, 4, 20]
# # of Relevant Nodes: 25
# Same story 23 Direct connection 11 Same parent 2 Same children 21
# Step: 6 0.0 {'action': 'add-node', 'content': ['75', '76']} Relevant nodes: ['19', '21', '25', '32', '34', '39', '42', '44', '49', '51', '52', '53', '54', '68', '70', '71', '74', '77', '106', '108', '120', '127', '132', '138', '151']
# Complexity: [41, 49, 16, 12, 4, 24]
# ===================================
# Sample #1 (Valid Sample #1)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['71', '127']
# Complexity: [22, 29, 8, 4, 4, 15]
# ===================================
# Sample #2 (Valid Sample #1)
# ===================================
# # of Relevant Nodes: 5
# Same story 3 Direct connection 0 Same parent 0 Same children 1
# Step: 1 0.19999999999999996 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['49', '70', '77', '107', '127']
# Complexity: [18, 20, 4, 3, 1, 6]
# # of Relevant Nodes: 10
# Same story 9 Direct connection 2 Same parent 0 Same children 1
# Step: 2 0.0 {'action': 'add-node', 'content': ['34', '39', '42']} Relevant nodes: ['19', '21', '25', '32', '49', '70', '77', '107', '127', '140']
# Complexity: [27, 30, 9, 6, 3, 12]
# ===================================
# Sample #3 (Valid Sample #2)
# ===================================
# # of Relevant Nodes: 5
# Same story 6 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.19999999999999996 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['68', '70', '74', '151', '152']
# Complexity: [26, 26, 5, 5, 0, 5]
# # of Relevant Nodes: 15
# Same story 12 Direct connection 7 Same parent 0 Same children 13
# Step: 2 0.0 {'action': 'add-node', 'content': ['34', '39', '42']} Relevant nodes: ['19', '21', '25', '32', '49', '51', '68', '70', '74', '127', '131', '140', '141', '142', '151']
# Complexity: [39, 39, 21, 6, 15, 21]
# ===================================
# Sample #4 (Valid Sample #3)
# ===================================
# # of Relevant Nodes: 4
# Same story 3 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['53', '107', '127', '142']
# Complexity: [18, 25, 9, 3, 6, 16]
# ===================================
# Sample #5 (Valid Sample #3)
# ===================================
# # of Relevant Nodes: 6
# Same story 4 Direct connection 2 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['21', '25', '32', '34']} Relevant nodes: ['19', '70', '104', '108', '111', '140']
# Complexity: [23, 27, 6, 3, 3, 10]
# ===================================
# Sample #6 (Valid Sample #3)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.0 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['76', '127', '138']
# Complexity: [22, 26, 6, 3, 3, 10]
# ===================================
# Sample #7 (Valid Sample #3)
# ===================================
# # of Relevant Nodes: 3
# Same story 1 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.33333333333333337 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['49', '108', '117']
# Complexity: [23, 27, 6, 5, 1, 10]
# # of Relevant Nodes: 16
# Same story 17 Direct connection 3 Same parent 2 Same children 2
# Step: 2 0.0625 {'action': 'add-node', 'content': ['42', '44', '51']} Relevant nodes: ['19', '21', '25', '32', '34', '39', '49', '68', '71', '95', '104', '108', '117', '120', '141', '154']
# Complexity: [28, 35, 9, 5, 4, 16]
# # of Relevant Nodes: 20
# Same story 22 Direct connection 8 Same parent 7 Same children 8
# Step: 3 0.050000000000000044 {'action': 'add-node', 'content': ['52', '53']} Relevant nodes: ['19', '21', '25', '32', '34', '39', '42', '44', '49', '51', '68', '71', '95', '104', '108', '117', '120', '129', '141', '154']
# Complexity: [33, 42, 13, 6, 7, 22]
# # of Relevant Nodes: 23
# Same story 30 Direct connection 9 Same parent 5 Same children 8
# Step: 4 0.04347826086956519 {'action': 'add-node', 'content': ['54', '70']} Relevant nodes: ['19', '21', '25', '32', '34', '39', '42', '44', '49', '51', '52', '53', '68', '71', '95', '104', '108', '117', '120', '129', '141', '151', '154']
# Complexity: [43, 52, 10, 9, 1, 19]
# # of Relevant Nodes: 22
# Same story 10 Direct connection 10 Same parent 5 Same children 19
# Step: 5 0.09090909090909094 {'action': 'add-node', 'content': ['25', '39']} Relevant nodes: ['19', '21', '32', '34', '49', '51', '52', '53', '54', '68', '70', '71', '95', '104', '107', '108', '117', '120', '129', '141', '151', '154']
# Complexity: [37, 47, 17, 10, 7, 27]
# # of Relevant Nodes: 27
# Same story 61 Direct connection 15 Same parent 7 Same children 11
# Step: 6 0.0 {'action': 'add-node', 'content': ['74', '75']} Relevant nodes: ['19', '21', '25', '32', '34', '39', '42', '44', '49', '51', '52', '53', '54', '68', '70', '71', '95', '104', '106', '107', '108', '117', '120', '129', '141', '151', '154']
# Complexity: [42, 58, 8, 7, 1, 24]
# ===================================
# Sample #8 (Valid Sample #4)
# ===================================
# # of Relevant Nodes: 3
# Same story 0 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.33333333333333337 {'action': 'add-node', 'content': ['19', '25', '32', '34']} Relevant nodes: ['21', '147', '151']
# Complexity: [14, 19, 7, 2, 5, 12]
# # of Relevant Nodes: 13
# Same story 6 Direct connection 3 Same parent 3 Same children 2
# Step: 2 0.07692307692307687 {'action': 'add-node', 'content': ['39', '42', '44']} Relevant nodes: ['19', '21', '25', '32', '34', '68', '70', '74', '95', '142', '147', '151', '152']
# Complexity: [23, 28, 11, 4, 7, 16]
# # of Relevant Nodes: 20
# Same story 14 Direct connection 15 Same parent 8 Same children 16
# Step: 3 0.0 {'action': 'add-node', 'content': ['52', '54']} Relevant nodes: ['19', '21', '25', '32', '34', '39', '42', '44', '49', '51', '53', '68', '70', '74', '95', '138', '142', '147', '151', '152']
# Complexity: [34, 49, 14, 10, 4, 29]
# ===================================
# Sample #9 (Valid Sample #5)
# ===================================
# # of Relevant Nodes: 7
# Same story 6 Direct connection 1 Same parent 1 Same children 0
# Step: 1 0.2857142857142857 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['52', '53', '107', '117', '118', '127', '146']
# Complexity: [24, 26, 7, 3, 4, 9]
# # of Relevant Nodes: 16
# Same story 25 Direct connection 8 Same parent 6 Same children 3
# Step: 2 0.0 {'action': 'add-node', 'content': ['34', '39', '42']} Relevant nodes: ['19', '21', '25', '32', '52', '53', '54', '104', '106', '107', '116', '117', '118', '127', '138', '146']
# Complexity: [28, 35, 7, 4, 3, 14]
# ===================================
# Sample #10 (Valid Sample #6)
# ===================================
# # of Relevant Nodes: 7
# Same story 4 Direct connection 1 Same parent 0 Same children 0
# Step: 1 0.2857142857142857 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['54', '76', '106', '127', '132', '138', '151']
# Complexity: [24, 26, 6, 5, 1, 8]
# # of Relevant Nodes: 18
# Same story 16 Direct connection 2 Same parent 3 Same children 6
# Step: 2 0.0 {'action': 'add-node', 'content': ['34', '39']} Relevant nodes: ['19', '21', '25', '32', '53', '54', '76', '104', '106', '127', '132', '138', '140', '142', '143', '144', '146', '151']
# Complexity: [30, 32, 11, 6, 5, 13]
# ===================================
# Sample #11 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 4
# Same story 2 Direct connection 1 Same parent 0 Same children 1
# Step: 1 0.0 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['76', '129', '132', '138']
# Complexity: [27, 30, 5, 5, 0, 8]
# ===================================
# Sample #12 (Valid Sample #7)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['127', '140']
# Complexity: [23, 27, 5, 4, 1, 9]
# # of Relevant Nodes: 10
# Same story 10 Direct connection 0 Same parent 0 Same children 0
# Step: 2 0.09999999999999998 {'action': 'add-node', 'content': ['34', '39', '42']} Relevant nodes: ['19', '21', '25', '32', '68', '71', '95', '127', '140', '152']
# Complexity: [22, 25, 6, 5, 1, 9]
# # of Relevant Nodes: 17
# Same story 23 Direct connection 3 Same parent 3 Same children 3
# Step: 3 0.0 {'action': 'add-node', 'content': ['44', '49', '51']} Relevant nodes: ['19', '21', '25', '32', '34', '39', '42', '68', '71', '95', '104', '108', '127', '140', '141', '152', '154']
# Complexity: [31, 37, 9, 6, 3, 15]
# ===================================
# Sample #13 (Valid Sample #8)
# ===================================
# # of Relevant Nodes: 4
# Same story 3 Direct connection 0 Same parent 0 Same children 0
# Step: 1 0.25 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['52', '127', '132', '133']
# Complexity: [22, 24, 5, 5, 0, 7]
# # of Relevant Nodes: 14
# Same story 11 Direct connection 1 Same parent 2 Same children 1
# Step: 2 0.0714285714285714 {'action': 'add-node', 'content': ['34', '39', '42']} Relevant nodes: ['19', '21', '25', '32', '49', '52', '68', '70', '107', '108', '127', '132', '133', '152']
# Complexity: [34, 41, 10, 8, 2, 17]
# # of Relevant Nodes: 17
# Same story 62 Direct connection 1 Same parent 0 Same children 1
# Step: 3 0.0 {'action': 'add-node', 'content': ['39', '42', '44']} Relevant nodes: ['19', '21', '25', '32', '34', '49', '52', '68', '70', '107', '108', '127', '131', '132', '133', '151', '152']
# Complexity: [31, 34, 7, 6, 1, 10]
# ===================================
# Sample #14 (Valid Sample #9)
# ===================================
# # of Relevant Nodes: 2
# Same story 0 Direct connection 0 Same parent 0 Same children 0
# Step: 1 1.0 {'action': 'add-node', 'content': ['19', '21', '25', '32']} Relevant nodes: ['106', '151']
# Complexity: [19, 20, 5, 4, 1, 6]
# # of Relevant Nodes: 7
# Same story 4 Direct connection 1 Same parent 1 Same children 1
# Step: 2 0.0 {'action': 'add-node', 'content': ['34', '39', '42', '44']} Relevant nodes: ['19', '21', '25', '32', '106', '127', '151']
# Complexity: [23, 26, 8, 6, 2, 11]

# %%
results_clustering = {"iterations": all_iterations, "percents": all_percents, "counts": all_counts, "complexity": [p.to_dict() for p in all_complexities]}
with open('results_add_biden.json', 'w') as fp:
    json.dump(results_clustering, fp)

# %%
plot_all(all_iterations, all_percents, all_complexities)

# %% [markdown]
# ## Generate Final Plot

# %%
f = open('results_delete_right.json')
results_delete_right = json.load(f)
f = open('results_delete_fox_bb.json')
results_delete_fox_bb = json.load(f)
f = open('results_delete_florida.json')
results_delete_florida = json.load(f)
f = open('results_delete_edges.json')
results_delete_edges = json.load(f)
f = open('results_consistent_story.json')
results_consistent_story = json.load(f)
f = open('results_clustering_bb_center.json')
results_clustering_bb_center = json.load(f)
f = open('results_clustering_florida.json')
results_clustering_florida = json.load(f)
f = open('results_add_florida.json')
results_add_florida = json.load(f)
f = open('results_add_biden.json')
results_add_biden = json.load(f)

# %%
f = open('results_delete_right_old.json')
results_delete_right_old = json.load(f)
f = open('results_delete_fox_bb_old.json')
results_delete_fox_bb_old = json.load(f)
f = open('results_delete_florida_old.json')
results_delete_florida_old = json.load(f)
f = open('results_delete_edges_old.json')
results_delete_edges_old = json.load(f)
f = open('results_consistent_story_old.json')
results_consistent_story_old = json.load(f)
f = open('results_clustering_bb_center_old.json')
results_clustering_bb_center_old = json.load(f)
f = open('results_clustering_florida_old.json')
results_clustering_florida_old = json.load(f)
f = open('results_add_florida_old.json')
results_add_florida_old = json.load(f)
f = open('results_add_biden_old.json')
results_add_biden_old = json.load(f)

# %%
def average_series(json_dict):
    all_iterations = json_dict['iterations']
    all_percents = json_dict['percents']
    max_iter = max(all_iterations)
    extended_percent_list = []
    for percent_list in all_percents:
        percent_list_extended = percent_list + [percent_list[-1] for _ in range(max_iter - len(percent_list))]
        extended_percent_list.append(percent_list_extended)
    extended_percent_array = np.array(extended_percent_list)
    average_percent = np.mean(extended_percent_array, axis=0)
    return average_percent

# %%
def generate_x_y(json_dict):
    y = average_series(json_dict)
    x = range(max(json_dict['iterations']))
    return x, y

# %%
average_percent = average_series(results_delete_right)
max_iter = max(results_delete_right['iterations'])

# %%
def average_metric(json_dict, column='Nodes'):
    all_iterations = json_dict['iterations']
    all_percents = [list(iteration[column].values()) for iteration in json_dict['complexity']]
    max_iter = max(all_iterations)
    extended_metric_list = []
    for idx, complexity in enumerate(all_percents):
        metric_list_extended = complexity + [complexity[-1] for _ in range(max_iter - len(complexity))]
        extended_metric_list.append(metric_list_extended)
    extended_metric_array = np.array(extended_metric_list)
    average_metric = np.nanmean(extended_metric_array, axis=0)
    return average_metric

# %%
from matplotlib.lines import Line2D
heigth = 40
width = 32*3
plt.rcParams['figure.figsize'] = [heigth/2.54, width/2.54]
plt.rcParams.update({'font.size': 14})

fig, axs = plt.subplots(9, 3)


## ERROR RATES
x, y = generate_x_y(results_delete_florida)
axs[0, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_delete_florida_old)
axs[0, 0].plot(x, y, 'tab:red')
axs[0, 0].set_title('')

x, y = generate_x_y(results_delete_fox_bb)
axs[1, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_delete_fox_bb_old)
axs[1, 0].plot(x, y, 'tab:red')
axs[1, 0].set_title('')

x, y = generate_x_y(results_delete_right)
axs[2, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_delete_right_old)
axs[2, 0].plot(x, y, 'tab:red')
axs[2, 0].set_title('')


x, y = generate_x_y(results_delete_edges)
axs[3, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_delete_edges_old)
axs[3, 0].plot(x, y, 'tab:red')
axs[3, 0].set_title('')

x, y = generate_x_y(results_consistent_story)
axs[4, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_consistent_story_old)
axs[4, 0].plot(x, y, 'tab:red')
axs[4, 0].set_title('')


x, y = generate_x_y(results_clustering_florida)
axs[5, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_clustering_florida_old)
axs[5, 0].plot(x, y, 'tab:red')
axs[5, 0].set_title('')

x, y = generate_x_y(results_clustering_bb_center)
axs[6, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_clustering_bb_center_old)
axs[6, 0].plot(x, y, 'tab:red')
axs[6, 0].set_title('')

x, y = generate_x_y(results_add_florida)
axs[7, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_add_florida_old)
axs[7, 0].plot(x, y, 'tab:red')
axs[7, 0].set_title('')

x, y = generate_x_y(results_add_biden)
axs[8, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_add_biden_old)
axs[8, 0].plot(x, y, 'tab:red')
axs[8, 0].set_title('')

### NODES
x, y = generate_x_y(results_delete_florida)
axs[0, 1].plot(x, average_metric(results_delete_florida), 'tab:blue')
x, y = generate_x_y(results_delete_florida_old)
axs[0, 1].plot(x, average_metric(results_delete_florida_old), 'tab:red')
axs[0, 1].set_title(r'$\bf{(a)}$ ' + 'T1 - Remove Irrelevant Events: Florida/Miami')

x, y = generate_x_y(results_delete_fox_bb)
axs[1, 1].plot(x, average_metric(results_delete_fox_bb), 'tab:blue')
x, y = generate_x_y(results_delete_fox_bb_old)
axs[1, 1].plot(x, average_metric(results_delete_fox_bb_old), 'tab:red')
axs[1, 1].set_title(r'$\bf{(b)}$ ' + 'T1 - Remove Irrelevant Events: Fox News/Breitbart')

x, y = generate_x_y(results_delete_right)
axs[2, 1].plot(x, average_metric(results_delete_right), 'tab:blue')
x, y = generate_x_y(results_delete_right_old)
axs[2, 1].plot(x, average_metric(results_delete_right_old), 'tab:red')
axs[2, 1].set_title(r'$\bf{(c)}$ ' + 'T1 - Remove Irrelevant Events: Right-leaning Sources')

x, y = generate_x_y(results_delete_edges)
axs[3, 1].plot(x, average_metric(results_delete_edges), 'tab:blue')
x, y = generate_x_y(results_delete_edges_old)
axs[3, 1].plot(x, average_metric(results_delete_edges_old), 'tab:red')
axs[3, 1].set_title(r'$\bf{(d)}$ ' + 'T2 - Removing Inconsistent Edges')

x, y = generate_x_y(results_consistent_story)
axs[4, 1].plot(x, average_metric(results_consistent_story), 'tab:blue')
x, y = generate_x_y(results_consistent_story_old)
axs[4, 1].plot(x, average_metric(results_consistent_story_old), 'tab:red')
axs[4, 1].set_title(r'$\bf{(e)}$ ' + 'T3 - Clean Up Storylines')

x, y = generate_x_y(results_clustering_florida)
axs[5, 1].plot(x, average_metric(results_clustering_florida), 'tab:blue')
x, y = generate_x_y(results_clustering_florida_old)
axs[5, 1].plot(x, average_metric(results_clustering_florida_old), 'tab:red')
axs[5, 1].set_title(r'$\bf{(f)}$ ' + 'T4 - Cluster Events: Miami/Florida vs. Other US News')

x, y = generate_x_y(results_clustering_bb_center)
axs[6, 1].plot(x, average_metric(results_clustering_bb_center), 'tab:blue')
x, y = generate_x_y(results_clustering_bb_center_old)
axs[6, 1].plot(x, average_metric(results_clustering_bb_center_old), 'tab:red')
axs[6, 1].set_title(r'$\bf{(g)}$ ' + 'T4 - Cluster Events: Breitbart vs. Unbiased News')

x, y = generate_x_y(results_add_florida)
axs[7, 1].plot(x, average_metric(results_add_florida), 'tab:blue')
x, y = generate_x_y(results_add_florida_old)
axs[7, 1].plot(x, average_metric(results_add_florida_old), 'tab:red')
axs[7, 1].set_title(r'$\bf{(h)}$ ' + 'T5 - Add Relevant Events: Florida/Miami')

x, y = generate_x_y(results_add_biden)
axs[8, 1].plot(x, average_metric(results_add_biden), 'tab:blue')
x, y = generate_x_y(results_add_biden_old)
axs[8, 1].plot(x, average_metric(results_add_biden_old), 'tab:red')
axs[8, 1].set_title(r'$\bf{(i)}$ ' + 'T5 - Add Relevant Events: Biden')

### EDGES
x, y = generate_x_y(results_delete_florida)
axs[0, 2].plot(x, average_metric(results_delete_florida, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_delete_florida_old)
axs[0, 2].plot(x, average_metric(results_delete_florida_old, column='Edges'), 'tab:red')
axs[0, 2].set_title('')

x, y = generate_x_y(results_delete_fox_bb)
axs[1, 2].plot(x, average_metric(results_delete_fox_bb, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_delete_fox_bb_old)
axs[1, 2].plot(x, average_metric(results_delete_fox_bb_old, column='Edges'), 'tab:red')
axs[1, 2].set_title('')

x, y = generate_x_y(results_delete_right)
axs[2, 2].plot(x, average_metric(results_delete_right, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_delete_right_old)
axs[2, 2].plot(x, average_metric(results_delete_right_old, column='Edges'), 'tab:red')
axs[2, 2].set_title('')

x, y = generate_x_y(results_delete_edges)
axs[3, 2].plot(x, average_metric(results_delete_edges, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_delete_edges_old)
axs[3, 2].plot(x, average_metric(results_delete_edges_old, column='Edges'), 'tab:red')
axs[3, 2].set_title('')

x, y = generate_x_y(results_consistent_story)
axs[4, 2].plot(x, average_metric(results_consistent_story, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_consistent_story_old)
axs[4, 2].plot(x, average_metric(results_consistent_story_old, column='Edges'), 'tab:red')
axs[4, 2].set_title('')

x, y = generate_x_y(results_clustering_florida)
axs[5, 2].plot(x, average_metric(results_clustering_florida, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_clustering_florida_old)
axs[5, 2].plot(x, average_metric(results_clustering_florida_old, column='Edges'), 'tab:red')
axs[5, 2].set_title('')

x, y = generate_x_y(results_clustering_bb_center)
axs[6, 2].plot(x, average_metric(results_clustering_bb_center, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_clustering_bb_center_old)
axs[6, 2].plot(x, average_metric(results_clustering_bb_center_old, column='Edges'), 'tab:red')
axs[6, 2].set_title('')

x, y = generate_x_y(results_add_florida)
axs[7, 2].plot(x, average_metric(results_add_florida, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_add_florida_old)
axs[7, 2].plot(x, average_metric(results_add_florida_old, column='Edges'), 'tab:red')
axs[7, 2].set_title('')

x, y = generate_x_y(results_add_biden)
axs[8, 2].plot(x, average_metric(results_add_biden, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_add_biden_old)
axs[8, 2].plot(x, average_metric(results_add_biden_old, column='Edges'), 'tab:red')
axs[8, 2].set_title('')


count = 0
for ax in axs.flat:
    cur_max = ax.axis()[3] # ymax val
    if count % 3 == 0:
        ax.set(xlabel='Iterations', ylabel='Error Rate')
        ax.set_ylim(ymin=0, ymax=cur_max)
    elif count % 3 == 1:
        ax.set(xlabel='Iterations', ylabel='# of Nodes')
        ax.set_ylim(ymin=0, ymax=round(cur_max * 1.15))
    else:
        ax.set(xlabel='Iterations', ylabel='# of Edges')
        ax.set_ylim(ymin=0, ymax=round(cur_max * 1.15))
    count += 1

fig.tight_layout()
# Hide x labels and tick labels for top plots and y ticks for right plots.
from matplotlib.ticker import MaxNLocator
for ax in axs.flat:
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    #ax.label_outer()
custom_lines = [Line2D([0], [0], color='tab:red', lw=2),
                Line2D([0], [0], color='tab:blue', lw=2)]
fig.legend(custom_lines, ['Basic Model', 'Regularized Model'])

# %%
fig.savefig('line_plot.pdf')

# %%
from matplotlib.lines import Line2D
heigth = 40
width = 32*5/3
plt.rcParams['figure.figsize'] = [heigth/2.54, width/2.54]
plt.rcParams.update({'font.size': 14})

fig, axs = plt.subplots(5, 3)


## ERROR RATES
x, y = generate_x_y(results_delete_fox_bb)
axs[0, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_delete_fox_bb_old)
axs[0, 0].plot(x, y, 'tab:red')
axs[0, 0].set_title('')


x, y = generate_x_y(results_delete_edges)
axs[1, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_delete_edges_old)
axs[1, 0].plot(x, y, 'tab:red')
axs[1, 0].set_title('')

x, y = generate_x_y(results_consistent_story)
axs[2, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_consistent_story_old)
axs[2, 0].plot(x, y, 'tab:red')
axs[2, 0].set_title('')

x, y = generate_x_y(results_clustering_bb_center)
axs[3, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_clustering_bb_center_old)
axs[3, 0].plot(x, y, 'tab:red')
axs[3, 0].set_title('')

x, y = generate_x_y(results_add_florida)
axs[4, 0].plot(x, y, 'tab:blue')
x, y = generate_x_y(results_add_florida_old)
axs[4, 0].plot(x, y, 'tab:red')
axs[4, 0].set_title('')

### NODES
x, y = generate_x_y(results_delete_fox_bb)
axs[0, 1].plot(x, average_metric(results_delete_fox_bb), 'tab:blue')
x, y = generate_x_y(results_delete_fox_bb_old)
axs[0, 1].plot(x, average_metric(results_delete_fox_bb_old), 'tab:red')
axs[0, 1].set_title(r'$\bf{(b)}$ ' + 'T1 - Remove Irrelevant Events: Fox News/Breitbart')

x, y = generate_x_y(results_delete_edges)
axs[1, 1].plot(x, average_metric(results_delete_edges), 'tab:blue')
x, y = generate_x_y(results_delete_edges_old)
axs[1, 1].plot(x, average_metric(results_delete_edges_old), 'tab:red')
axs[1, 1].set_title(r'$\bf{(d)}$ ' + 'T2 - Removing Inconsistent Edges')

x, y = generate_x_y(results_consistent_story)
axs[2, 1].plot(x, average_metric(results_consistent_story), 'tab:blue')
x, y = generate_x_y(results_consistent_story_old)
axs[2, 1].plot(x, average_metric(results_consistent_story_old), 'tab:red')
axs[2, 1].set_title(r'$\bf{(e)}$ ' + 'T3 - Clean Up Storylines')

x, y = generate_x_y(results_clustering_bb_center)
axs[3, 1].plot(x, average_metric(results_clustering_bb_center), 'tab:blue')
x, y = generate_x_y(results_clustering_bb_center_old)
axs[3, 1].plot(x, average_metric(results_clustering_bb_center_old), 'tab:red')
axs[3, 1].set_title(r'$\bf{(g)}$ ' + 'T4 - Cluster Events: Breitbart vs. Unbiased News')

x, y = generate_x_y(results_add_florida)
axs[4, 1].plot(x, average_metric(results_add_florida), 'tab:blue')
x, y = generate_x_y(results_add_florida_old)
axs[4, 1].plot(x, average_metric(results_add_florida_old), 'tab:red')
axs[4, 1].set_title(r'$\bf{(h)}$ ' + 'T5 - Add Relevant Events: Florida/Miami')


### EDGES
x, y = generate_x_y(results_delete_fox_bb)
axs[0, 2].plot(x, average_metric(results_delete_fox_bb, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_delete_fox_bb_old)
axs[0, 2].plot(x, average_metric(results_delete_fox_bb_old, column='Edges'), 'tab:red')
axs[0, 2].set_title('')

x, y = generate_x_y(results_delete_edges)
axs[1, 2].plot(x, average_metric(results_delete_edges, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_delete_edges_old)
axs[1, 2].plot(x, average_metric(results_delete_edges_old, column='Edges'), 'tab:red')
axs[1, 2].set_title('')

x, y = generate_x_y(results_consistent_story)
axs[2, 2].plot(x, average_metric(results_consistent_story, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_consistent_story_old)
axs[2, 2].plot(x, average_metric(results_consistent_story_old, column='Edges'), 'tab:red')
axs[2, 2].set_title('')

x, y = generate_x_y(results_clustering_bb_center)
axs[3, 2].plot(x, average_metric(results_clustering_bb_center, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_clustering_bb_center_old)
axs[3, 2].plot(x, average_metric(results_clustering_bb_center_old, column='Edges'), 'tab:red')
axs[3, 2].set_title('')

x, y = generate_x_y(results_add_florida)
axs[4, 2].plot(x, average_metric(results_add_florida, column='Edges'), 'tab:blue')
x, y = generate_x_y(results_add_florida_old)
axs[4, 2].plot(x, average_metric(results_add_florida_old, column='Edges'), 'tab:red')
axs[4, 2].set_title('')


count = 0
for ax in axs.flat:
    cur_max = ax.axis()[3] # ymax val
    if count % 3 == 0:
        ax.set(xlabel='Iterations', ylabel='Error Rate')
        ax.set_ylim(ymin=0, ymax=cur_max)
    elif count % 3 == 1:
        ax.set(xlabel='Iterations', ylabel='# of Nodes')
        ax.set_ylim(ymin=0, ymax=round(cur_max * 1.15))
    else:
        ax.set(xlabel='Iterations', ylabel='# of Edges')
        ax.set_ylim(ymin=0, ymax=round(cur_max * 1.15))
    count += 1

fig.tight_layout()
# Hide x labels and tick labels for top plots and y ticks for right plots.
from matplotlib.ticker import MaxNLocator
for ax in axs.flat:
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    #ax.label_outer()
custom_lines = [Line2D([0], [0], color='tab:red', lw=2),
                Line2D([0], [0], color='tab:blue', lw=2)]
fig.legend(custom_lines, ['Basic Model', 'Regularized Model'])

# %%
fig.savefig('overfitting_simp.pdf')
